# %% [markdown]
# <a href="https://colab.research.google.com/github/aminfadaei116/Deep-Learning-Course/blob/master/CA1/Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA
import matplotlib.pyplot as plt
from time import process_time

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %% [markdown]
# Next we normalize the Data

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx, landa):
  temp = np.multiply(step(landa - vect),-1)
  temp[idx] = 1
  return temp

def gelu(x):
    return 0.5 * np.multiply(x, 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def Dgelu(x):
  return np.divide(0.053516 * np.power(x, 3) + np.multiply(0.398942, x) , np.power(np.cosh(0.0356774 * np.power(x, 3) +np.multiply(0.79788, x)),2)) + 0.5 * ( 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def RBF_encode(data, number_class, dim):
  data = np.reshape(data, (dim,int(data.size/dim)), order='F')
  data = LA.norm(data,1, axis = 0)
  data = np.reshape(data, (number_class, int(data.size/number_class)), order='F')
  return data

def expand(x):
  temp = []
  for i in range(len(x)):
    temp.append(x[i])
    temp.append(x[i])
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.distance_dim = 2
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.landa = 550
    self.accuracy_graph_epoch = []

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = gelu(self.layer["z0"])
    self.layer["s0"] = Dgelu(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = gelu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = Dgelu(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = RBF_encode(self.layer["z" + str(self.number_hidden_layer)], self.number_class_output, self.distance_dim)
    self.layer["s" + str(self.number_hidden_layer)] = np.sign(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide_RBF(self.score)
    return temp
  
  def decide_RBF(self, data):
    self.result = np.argmin(data, axis=0)
    return self.result

  def cal_loss(self, label) :
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu((self.landa - temp[i]))) - relu(self.landa- temp[i][label[i]]) + temp[i][label[i]])
      self.back_prob_output.append(encode(temp[i], label[i], self.landa))
    self.back_prob_output = np.transpose(self.back_prob_output)/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] - self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] - self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    self.accuracy_graph_epoch.append((self.Test_Network(data, label)))
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1
      self.accuracy_graph_epoch.append((self.Test_Network(data, label)))

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))
    return (Cal_accuracy(label, MyNetwork.forward(data)))

# %%
MyNetwork = Network(128,1,[150],10)
MyNetwork.set_learning_rate(0.1)
MyNetwork.set_turn(10)
MyNetwork.set_batch_size(1)
start = process_time()
MyNetwork.Train_Network(Train_data, Train_label)
print('time of train :', process_time()-start)
# Out:
# 4947.5491916920055  step  0  of the epoch  0 the steps is:  0
# 4943.780050118245  step  1  of the epoch  0 the steps is:  1
# 4946.193408488151  step  2  of the epoch  0 the steps is:  2
# 4945.88944854997  step  3  of the epoch  0 the steps is:  3
# 4944.488565133656  step  4  of the epoch  0 the steps is:  4
# 4940.005762858155  step  5  of the epoch  0 the steps is:  5
# 4940.786457476496  step  6  of the epoch  0 the steps is:  6
# 4941.5696163293815  step  7  of the epoch  0 the steps is:  7
# 4933.411624358318  step  8  of the epoch  0 the steps is:  8
# 4934.606058595351  step  9  of the epoch  0 the steps is:  9
# 4915.434252171463  step  10  of the epoch  0 the steps is:  10
# 4911.731438048075  step  11  of the epoch  0 the steps is:  11
# 4892.732306865307  step  12  of the epoch  0 the steps is:  12
# 4871.534143107392  step  13  of the epoch  0 the steps is:  13
# 4854.631753058882  step  14  of the epoch  0 the steps is:  14
# 4803.199504972417  step  15  of the epoch  0 the steps is:  15
# 4721.079708205235  step  16  of the epoch  0 the steps is:  16
# 4678.124333461264  step  17  of the epoch  0 the steps is:  17
# 4559.30380075439  step  18  of the epoch  0 the steps is:  18
# 4315.284339979786  step  19  of the epoch  0 the steps is:  19
# 4077.421959359798  step  20  of the epoch  0 the steps is:  20
# 3561.1648379431927  step  21  of the epoch  0 the steps is:  21
# 2910.932358908439  step  22  of the epoch  0 the steps is:  22
# 2958.6871210202503  step  23  of the epoch  0 the steps is:  23
# 1273.1126660700374  step  24  of the epoch  0 the steps is:  24
# 853.8623623757169  step  25  of the epoch  0 the steps is:  25
# 810.0011505642148  step  26  of the epoch  0 the steps is:  26
# 1274.8705923728685  step  27  of the epoch  0 the steps is:  27
# 925.2454261410272  step  28  of the epoch  0 the steps is:  28
# 897.8254748660459  step  29  of the epoch  0 the steps is:  29
# 1790.7044901108802  step  30  of the epoch  0 the steps is:  30
# 1414.6892464535163  step  31  of the epoch  0 the steps is:  31
# 2049.4477388993314  step  32  of the epoch  0 the steps is:  32
# 2350.0278000165904  step  33  of the epoch  0 the steps is:  33
# 1782.40669014048  step  34  of the epoch  0 the steps is:  34
# 2188.296809850721  step  35  of the epoch  0 the steps is:  35
# 1787.6428204919207  step  36  of the epoch  0 the steps is:  36
# 1860.2936659142442  step  37  of the epoch  0 the steps is:  37
# 2769.259677791088  step  38  of the epoch  0 the steps is:  38
# 1530.022800970567  step  39  of the epoch  0 the steps is:  39
# 1339.27692664002  step  40  of the epoch  0 the steps is:  40
# 2790.566152244458  step  41  of the epoch  0 the steps is:  41
# 2369.6723685000784  step  42  of the epoch  0 the steps is:  42
# 1226.8115009352357  step  43  of the epoch  0 the steps is:  43
# 1683.8051040630075  step  44  of the epoch  0 the steps is:  44
# 1545.6967484679672  step  45  of the epoch  0 the steps is:  45
# 1785.0653546329768  step  46  of the epoch  0 the steps is:  46
# 1040.296451011828  step  47  of the epoch  0 the steps is:  47
# 1146.3826388531816  step  48  of the epoch  0 the steps is:  48
# 802.3637418250471  step  49  of the epoch  0 the steps is:  49
# 664.2397599656547  step  50  of the epoch  0 the steps is:  50
# 530.3993379731255  step  51  of the epoch  0 the steps is:  51
# 1327.0744519025125  step  52  of the epoch  0 the steps is:  52
# 1018.0657085425464  step  53  of the epoch  0 the steps is:  53
# 958.4895215021878  step  54  of the epoch  0 the steps is:  54
# 1439.9970820535489  step  55  of the epoch  0 the steps is:  55
# 1367.6720177965108  step  56  of the epoch  0 the steps is:  56
# 1224.5898312846111  step  57  of the epoch  0 the steps is:  57
# 221.67907937673485  step  58  of the epoch  0 the steps is:  58
# 625.440870794944  step  59  of the epoch  0 the steps is:  59
# 1851.463190574864  step  60  of the epoch  0 the steps is:  60
# 1092.373773690308  step  61  of the epoch  0 the steps is:  61
# 1383.4155693630582  step  62  of the epoch  0 the steps is:  62
# 1279.5893691209458  step  63  of the epoch  0 the steps is:  63
# 1303.4287676583308  step  64  of the epoch  0 the steps is:  64
# 896.1654323206799  step  65  of the epoch  0 the steps is:  65
# 1100.1060930927893  step  66  of the epoch  0 the steps is:  66
# 1341.4316969096924  step  67  of the epoch  0 the steps is:  67
# 1492.1155156624513  step  68  of the epoch  0 the steps is:  68
# 1269.7438951356653  step  69  of the epoch  0 the steps is:  69
# 1357.2788503219263  step  70  of the epoch  0 the steps is:  70
# 1010.0149000864133  step  71  of the epoch  0 the steps is:  71
# 1011.8707613629376  step  72  of the epoch  0 the steps is:  72
# 1689.998140605916  step  73  of the epoch  0 the steps is:  73
# 939.5043875074023  step  74  of the epoch  0 the steps is:  74
# 965.9825363099033  step  75  of the epoch  0 the steps is:  75
# 1049.0265795163  step  76  of the epoch  0 the steps is:  76
# 934.705192156669  step  77  of the epoch  0 the steps is:  77
# 543.0696507865782  step  78  of the epoch  0 the steps is:  78
# 872.723573436745  step  79  of the epoch  0 the steps is:  79
# 453.18411506851965  step  80  of the epoch  0 the steps is:  80
# 3607.7442534345173  step  81  of the epoch  0 the steps is:  81
# 1006.1142010136334  step  82  of the epoch  0 the steps is:  82
# 2217.6207992743075  step  83  of the epoch  0 the steps is:  83
# 1055.8628045446605  step  84  of the epoch  0 the steps is:  84
# 887.3418475537082  step  85  of the epoch  0 the steps is:  85
# 674.4977659416345  step  86  of the epoch  0 the steps is:  86
# 862.8846574940505  step  87  of the epoch  0 the steps is:  87
# 743.3783675916566  step  88  of the epoch  0 the steps is:  88
# 644.3296691977722  step  89  of the epoch  0 the steps is:  89
# 749.0018544793825  step  90  of the epoch  0 the steps is:  90
# 1572.7447968733889  step  91  of the epoch  0 the steps is:  91
# 1183.1367883244209  step  92  of the epoch  0 the steps is:  92
# 587.7231478749661  step  93  of the epoch  0 the steps is:  93
# 1379.192409488062  step  94  of the epoch  0 the steps is:  94
# 1129.1078262574638  step  95  of the epoch  0 the steps is:  95
# 1196.5458651221322  step  96  of the epoch  0 the steps is:  96
# 1565.4104504041784  step  97  of the epoch  0 the steps is:  97
# 1137.2129601070185  step  98  of the epoch  0 the steps is:  98
# 1092.025951694867  step  99  of the epoch  0 the steps is:  99
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in power
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in cosh
# Streaming output truncated to the last 5000 lines.
# 648.62499657591  step  55003  of the epoch  9 the steps is:  595003
# 238.10446904630027  step  55004  of the epoch  9 the steps is:  595004
# 25.59882690007231  step  55005  of the epoch  9 the steps is:  595005
# 550.9239890961069  step  55006  of the epoch  9 the steps is:  595006
# 549.7528200599792  step  55007  of the epoch  9 the steps is:  595007
# 228.12820268743468  step  55008  of the epoch  9 the steps is:  595008
# 336.7516197111946  step  55009  of the epoch  9 the steps is:  595009
# 550.7362247156867  step  55010  of the epoch  9 the steps is:  595010
# 547.7389339208482  step  55011  of the epoch  9 the steps is:  595011
# 426.96386853488644  step  55012  of the epoch  9 the steps is:  595012
# 1176.5253878472038  step  55013  of the epoch  9 the steps is:  595013
# 510.4674563873331  step  55014  of the epoch  9 the steps is:  595014
# 82.69538021259439  step  55015  of the epoch  9 the steps is:  595015
# 565.9414194027231  step  55016  of the epoch  9 the steps is:  595016
# 891.605025151812  step  55017  of the epoch  9 the steps is:  595017
# 550.6986992286977  step  55018  of the epoch  9 the steps is:  595018
# 809.0375428554223  step  55019  of the epoch  9 the steps is:  595019
# 77.76221447399826  step  55020  of the epoch  9 the steps is:  595020
# 496.6083934457076  step  55021  of the epoch  9 the steps is:  595021
# 67.755353599447  step  55022  of the epoch  9 the steps is:  595022
# 550.5442048696151  step  55023  of the epoch  9 the steps is:  595023
# 402.38357089319106  step  55024  of the epoch  9 the steps is:  595024
# 67.88766566398115  step  55025  of the epoch  9 the steps is:  595025
# 363.1312483950787  step  55026  of the epoch  9 the steps is:  595026
# 385.14255628482863  step  55027  of the epoch  9 the steps is:  595027
# 550.5950606777996  step  55028  of the epoch  9 the steps is:  595028
# 550.63293490399  step  55029  of the epoch  9 the steps is:  595029
# 59.44688713912808  step  55030  of the epoch  9 the steps is:  595030
# 164.0884766647258  step  55031  of the epoch  9 the steps is:  595031
# 269.8296645310047  step  55032  of the epoch  9 the steps is:  595032
# 69.84279179443521  step  55033  of the epoch  9 the steps is:  595033
# 1043.984521431591  step  55034  of the epoch  9 the steps is:  595034
# 934.068899401781  step  55035  of the epoch  9 the steps is:  595035
# 550.6161518731442  step  55036  of the epoch  9 the steps is:  595036
# 695.4311634621286  step  55037  of the epoch  9 the steps is:  595037
# 376.47461111846405  step  55038  of the epoch  9 the steps is:  595038
# 392.6072499478708  step  55039  of the epoch  9 the steps is:  595039
# 287.96697824905857  step  55040  of the epoch  9 the steps is:  595040
# 568.3277236944878  step  55041  of the epoch  9 the steps is:  595041
# 89.03946901232194  step  55042  of the epoch  9 the steps is:  595042
# 282.90533302960733  step  55043  of the epoch  9 the steps is:  595043
# 550.0033923833428  step  55044  of the epoch  9 the steps is:  595044
# 550.3368831774653  step  55045  of the epoch  9 the steps is:  595045
# 274.71453989041936  step  55046  of the epoch  9 the steps is:  595046
# 61.80893230660945  step  55047  of the epoch  9 the steps is:  595047
# 467.62499772253466  step  55048  of the epoch  9 the steps is:  595048
# 550.5333988389215  step  55049  of the epoch  9 the steps is:  595049
# 193.5801071053877  step  55050  of the epoch  9 the steps is:  595050
# 550.0988420759148  step  55051  of the epoch  9 the steps is:  595051
# 386.3970906089433  step  55052  of the epoch  9 the steps is:  595052
# 335.38364375107477  step  55053  of the epoch  9 the steps is:  595053
# 171.93855421553252  step  55054  of the epoch  9 the steps is:  595054
# 175.678207472566  step  55055  of the epoch  9 the steps is:  595055
# 154.2323594631947  step  55056  of the epoch  9 the steps is:  595056
# 45.090125931068144  step  55057  of the epoch  9 the steps is:  595057
# 238.3344765275232  step  55058  of the epoch  9 the steps is:  595058
# 426.40041343679127  step  55059  of the epoch  9 the steps is:  595059
# 88.17031931218446  step  55060  of the epoch  9 the steps is:  595060
# 166.32563679740088  step  55061  of the epoch  9 the steps is:  595061
# 436.41741755782584  step  55062  of the epoch  9 the steps is:  595062
# 550.0244594782715  step  55063  of the epoch  9 the steps is:  595063
# 277.43885047502386  step  55064  of the epoch  9 the steps is:  595064
# 550.674734713189  step  55065  of the epoch  9 the steps is:  595065
# 550.616949146681  step  55066  of the epoch  9 the steps is:  595066
# 71.80059431244737  step  55067  of the epoch  9 the steps is:  595067
# 56.459589470389005  step  55068  of the epoch  9 the steps is:  595068
# 259.7208852922192  step  55069  of the epoch  9 the steps is:  595069
# 209.38226616159088  step  55070  of the epoch  9 the steps is:  595070
# 1089.804315435139  step  55071  of the epoch  9 the steps is:  595071
# 55.70057338868591  step  55072  of the epoch  9 the steps is:  595072
# 87.9440035196346  step  55073  of the epoch  9 the steps is:  595073
# 549.9081855093646  step  55074  of the epoch  9 the steps is:  595074
# 306.63088132410644  step  55075  of the epoch  9 the steps is:  595075
# 550.2504184873159  step  55076  of the epoch  9 the steps is:  595076
# 70.2002216309672  step  55077  of the epoch  9 the steps is:  595077
# 56.365061353000385  step  55078  of the epoch  9 the steps is:  595078
# 245.37571874395582  step  55079  of the epoch  9 the steps is:  595079
# 363.7240004764992  step  55080  of the epoch  9 the steps is:  595080
# 550.2280688523713  step  55081  of the epoch  9 the steps is:  595081
# 191.6209819639264  step  55082  of the epoch  9 the steps is:  595082
# 176.3563231615639  step  55083  of the epoch  9 the steps is:  595083
# 457.5263192210342  step  55084  of the epoch  9 the steps is:  595084
# 140.1138683579453  step  55085  of the epoch  9 the steps is:  595085
# 256.5610717064659  step  55086  of the epoch  9 the steps is:  595086
# 165.7506945886418  step  55087  of the epoch  9 the steps is:  595087
# 176.84681170555345  step  55088  of the epoch  9 the steps is:  595088
# 185.0398994143196  step  55089  of the epoch  9 the steps is:  595089
# 66.41779420209971  step  55090  of the epoch  9 the steps is:  595090
# 550.1789045699672  step  55091  of the epoch  9 the steps is:  595091
# 264.8753173420288  step  55092  of the epoch  9 the steps is:  595092
# 220.06752134378428  step  55093  of the epoch  9 the steps is:  595093
# 522.8290057431423  step  55094  of the epoch  9 the steps is:  595094
# 66.92230249977644  step  55095  of the epoch  9 the steps is:  595095
# 651.4026926539556  step  55096  of the epoch  9 the steps is:  595096
# 216.08085470495936  step  55097  of the epoch  9 the steps is:  595097
# 550.533435996465  step  55098  of the epoch  9 the steps is:  595098
# 546.077788993588  step  55099  of the epoch  9 the steps is:  595099
# 220.02966460183478  step  55100  of the epoch  9 the steps is:  595100
# 502.8044423315702  step  55101  of the epoch  9 the steps is:  595101
# 553.6781838794386  step  55102  of the epoch  9 the steps is:  595102
# 198.48546070376233  step  55103  of the epoch  9 the steps is:  595103
# 120.94516661581355  step  55104  of the epoch  9 the steps is:  595104
# 182.39493595166272  step  55105  of the epoch  9 the steps is:  595105
# 265.8895497087507  step  55106  of the epoch  9 the steps is:  595106
# 73.46753074408176  step  55107  of the epoch  9 the steps is:  595107
# 38.90314161142041  step  55108  of the epoch  9 the steps is:  595108
# 32.55609344744113  step  55109  of the epoch  9 the steps is:  595109
# 947.4667782543078  step  55110  of the epoch  9 the steps is:  595110
# 479.84587798333786  step  55111  of the epoch  9 the steps is:  595111
# 137.44415289659008  step  55112  of the epoch  9 the steps is:  595112
# 656.5124973260245  step  55113  of the epoch  9 the steps is:  595113
# 887.3211583918292  step  55114  of the epoch  9 the steps is:  595114
# 164.08635961753023  step  55115  of the epoch  9 the steps is:  595115
# 52.54837648241124  step  55116  of the epoch  9 the steps is:  595116
# 148.1954206383316  step  55117  of the epoch  9 the steps is:  595117
# 315.3446001495946  step  55118  of the epoch  9 the steps is:  595118
# 347.7631527208921  step  55119  of the epoch  9 the steps is:  595119
# 485.7462817498008  step  55120  of the epoch  9 the steps is:  595120
# 913.2592634809861  step  55121  of the epoch  9 the steps is:  595121
# 108.4020064560778  step  55122  of the epoch  9 the steps is:  595122
# 253.4703773640456  step  55123  of the epoch  9 the steps is:  595123
# 149.10278963828978  step  55124  of the epoch  9 the steps is:  595124
# 550.9772168693644  step  55125  of the epoch  9 the steps is:  595125
# 551.0033681778372  step  55126  of the epoch  9 the steps is:  595126
# 377.3425064171254  step  55127  of the epoch  9 the steps is:  595127
# 760.3183779475214  step  55128  of the epoch  9 the steps is:  595128
# 181.12377043488686  step  55129  of the epoch  9 the steps is:  595129
# 177.64002738086958  step  55130  of the epoch  9 the steps is:  595130
# 283.1651165656694  step  55131  of the epoch  9 the steps is:  595131
# 471.04203560062115  step  55132  of the epoch  9 the steps is:  595132
# 550.1064577903082  step  55133  of the epoch  9 the steps is:  595133
# 226.38890785867295  step  55134  of the epoch  9 the steps is:  595134
# 248.4503412216228  step  55135  of the epoch  9 the steps is:  595135
# 550.3295454135205  step  55136  of the epoch  9 the steps is:  595136
# 334.4949894408403  step  55137  of the epoch  9 the steps is:  595137
# 550.3244051673864  step  55138  of the epoch  9 the steps is:  595138
# 167.37937382380878  step  55139  of the epoch  9 the steps is:  595139
# 384.23573969393027  step  55140  of the epoch  9 the steps is:  595140
# 550.1450302895431  step  55141  of the epoch  9 the steps is:  595141
# 132.19236465642857  step  55142  of the epoch  9 the steps is:  595142
# 442.1024164407022  step  55143  of the epoch  9 the steps is:  595143
# 550.4592672508431  step  55144  of the epoch  9 the steps is:  595144
# 140.15430140591562  step  55145  of the epoch  9 the steps is:  595145
# 262.47769941786515  step  55146  of the epoch  9 the steps is:  595146
# 24.49405823416555  step  55147  of the epoch  9 the steps is:  595147
# 131.57397407340224  step  55148  of the epoch  9 the steps is:  595148
# 334.76751610997326  step  55149  of the epoch  9 the steps is:  595149
# 309.2300229415044  step  55150  of the epoch  9 the steps is:  595150
# 147.78512536171849  step  55151  of the epoch  9 the steps is:  595151
# 803.1237250021427  step  55152  of the epoch  9 the steps is:  595152
# 563.4923206229594  step  55153  of the epoch  9 the steps is:  595153
# 72.58341757101354  step  55154  of the epoch  9 the steps is:  595154
# 550.1197804876257  step  55155  of the epoch  9 the steps is:  595155
# 597.8838301423954  step  55156  of the epoch  9 the steps is:  595156
# 707.5095670614533  step  55157  of the epoch  9 the steps is:  595157
# 57.37009729102641  step  55158  of the epoch  9 the steps is:  595158
# 462.3877936364579  step  55159  of the epoch  9 the steps is:  595159
# 187.53942059649356  step  55160  of the epoch  9 the steps is:  595160
# 188.29882702042886  step  55161  of the epoch  9 the steps is:  595161
# 180.11856123272332  step  55162  of the epoch  9 the steps is:  595162
# 150.5936743215662  step  55163  of the epoch  9 the steps is:  595163
# 956.7620156818958  step  55164  of the epoch  9 the steps is:  595164
# 481.82345279806054  step  55165  of the epoch  9 the steps is:  595165
# 701.6235524215263  step  55166  of the epoch  9 the steps is:  595166
# 510.28246321018247  step  55167  of the epoch  9 the steps is:  595167
# 247.9956437176489  step  55168  of the epoch  9 the steps is:  595168
# 549.8008378658875  step  55169  of the epoch  9 the steps is:  595169
# 550.2658271612753  step  55170  of the epoch  9 the steps is:  595170
# 189.205646117034  step  55171  of the epoch  9 the steps is:  595171
# 247.44914618298216  step  55172  of the epoch  9 the steps is:  595172
# 134.12472279566325  step  55173  of the epoch  9 the steps is:  595173
# 549.7301440436829  step  55174  of the epoch  9 the steps is:  595174
# 558.9527358308527  step  55175  of the epoch  9 the steps is:  595175
# 399.506076705555  step  55176  of the epoch  9 the steps is:  595176
# 56.83758975668778  step  55177  of the epoch  9 the steps is:  595177
# 173.4875427095584  step  55178  of the epoch  9 the steps is:  595178
# 96.36621815392573  step  55179  of the epoch  9 the steps is:  595179
# 129.63637665603193  step  55180  of the epoch  9 the steps is:  595180
# 141.35928342256713  step  55181  of the epoch  9 the steps is:  595181
# 550.2260520993858  step  55182  of the epoch  9 the steps is:  595182
# 497.19340900998986  step  55183  of the epoch  9 the steps is:  595183
# 434.6754344202925  step  55184  of the epoch  9 the steps is:  595184
# 69.2947217803717  step  55185  of the epoch  9 the steps is:  595185
# 349.2010455616871  step  55186  of the epoch  9 the steps is:  595186
# 549.9653708340861  step  55187  of the epoch  9 the steps is:  595187
# 550.439375163576  step  55188  of the epoch  9 the steps is:  595188
# 330.3221503516752  step  55189  of the epoch  9 the steps is:  595189
# 550.2041228970749  step  55190  of the epoch  9 the steps is:  595190
# 90.48958370185395  step  55191  of the epoch  9 the steps is:  595191
# 198.6725937124416  step  55192  of the epoch  9 the steps is:  595192
# 167.5291167097772  step  55193  of the epoch  9 the steps is:  595193
# 294.96367444148694  step  55194  of the epoch  9 the steps is:  595194
# 550.3806483742078  step  55195  of the epoch  9 the steps is:  595195
# 550.3360952430111  step  55196  of the epoch  9 the steps is:  595196
# 163.45000777080813  step  55197  of the epoch  9 the steps is:  595197
# 467.69469529370923  step  55198  of the epoch  9 the steps is:  595198
# 125.91421377416751  step  55199  of the epoch  9 the steps is:  595199
# 134.2307039945907  step  55200  of the epoch  9 the steps is:  595200
# 153.7209569899843  step  55201  of the epoch  9 the steps is:  595201
# 60.138615234750574  step  55202  of the epoch  9 the steps is:  595202
# 54.54919918833875  step  55203  of the epoch  9 the steps is:  595203
# 550.0266545334415  step  55204  of the epoch  9 the steps is:  595204
# 549.9888060495518  step  55205  of the epoch  9 the steps is:  595205
# 39.43396460534302  step  55206  of the epoch  9 the steps is:  595206
# 659.7782345236603  step  55207  of the epoch  9 the steps is:  595207
# 675.3617224465306  step  55208  of the epoch  9 the steps is:  595208
# 550.3818155147218  step  55209  of the epoch  9 the steps is:  595209
# 137.76801605018943  step  55210  of the epoch  9 the steps is:  595210
# 40.05172285528607  step  55211  of the epoch  9 the steps is:  595211
# 382.6134234502013  step  55212  of the epoch  9 the steps is:  595212
# 142.64410271546163  step  55213  of the epoch  9 the steps is:  595213
# 512.4656777734158  step  55214  of the epoch  9 the steps is:  595214
# 550.2974133271708  step  55215  of the epoch  9 the steps is:  595215
# 692.9030253851388  step  55216  of the epoch  9 the steps is:  595216
# 550.2032248239624  step  55217  of the epoch  9 the steps is:  595217
# 417.99899064586657  step  55218  of the epoch  9 the steps is:  595218
# 327.1302398346804  step  55219  of the epoch  9 the steps is:  595219
# 674.115321917973  step  55220  of the epoch  9 the steps is:  595220
# 80.46720527214413  step  55221  of the epoch  9 the steps is:  595221
# 269.53455325497623  step  55222  of the epoch  9 the steps is:  595222
# 550.0186826129052  step  55223  of the epoch  9 the steps is:  595223
# 561.3955227581719  step  55224  of the epoch  9 the steps is:  595224
# 195.97314445800856  step  55225  of the epoch  9 the steps is:  595225
# 855.8903035556032  step  55226  of the epoch  9 the steps is:  595226
# 348.2289169154626  step  55227  of the epoch  9 the steps is:  595227
# 311.9984990291704  step  55228  of the epoch  9 the steps is:  595228
# 259.4603972886289  step  55229  of the epoch  9 the steps is:  595229
# 486.2251311332992  step  55230  of the epoch  9 the steps is:  595230
# 117.39129768673268  step  55231  of the epoch  9 the steps is:  595231
# 693.3999876624839  step  55232  of the epoch  9 the steps is:  595232
# 442.07298280856867  step  55233  of the epoch  9 the steps is:  595233
# 248.248466193017  step  55234  of the epoch  9 the steps is:  595234
# 258.5732111973443  step  55235  of the epoch  9 the steps is:  595235
# 550.9956134053438  step  55236  of the epoch  9 the steps is:  595236
# 550.8283386761112  step  55237  of the epoch  9 the steps is:  595237
# 261.6363055149948  step  55238  of the epoch  9 the steps is:  595238
# 660.4816121051026  step  55239  of the epoch  9 the steps is:  595239
# 660.288645213777  step  55240  of the epoch  9 the steps is:  595240
# 550.8311258628378  step  55241  of the epoch  9 the steps is:  595241
# 550.9323010059777  step  55242  of the epoch  9 the steps is:  595242
# 551.3053314961928  step  55243  of the epoch  9 the steps is:  595243
# 150.988015643331  step  55244  of the epoch  9 the steps is:  595244
# 53.81703398825991  step  55245  of the epoch  9 the steps is:  595245
# 142.47970289281756  step  55246  of the epoch  9 the steps is:  595246
# 25.190073103106215  step  55247  of the epoch  9 the steps is:  595247
# 376.20676218926354  step  55248  of the epoch  9 the steps is:  595248
# 263.63898247547127  step  55249  of the epoch  9 the steps is:  595249
# 317.10197415279146  step  55250  of the epoch  9 the steps is:  595250
# 352.1991022344934  step  55251  of the epoch  9 the steps is:  595251
# 550.3582699968707  step  55252  of the epoch  9 the steps is:  595252
# 1099.1647602627645  step  55253  of the epoch  9 the steps is:  595253
# 549.8870634125195  step  55254  of the epoch  9 the steps is:  595254
# 346.81669175617526  step  55255  of the epoch  9 the steps is:  595255
# 34.127152437455265  step  55256  of the epoch  9 the steps is:  595256
# 594.3701380979126  step  55257  of the epoch  9 the steps is:  595257
# 994.5488179489483  step  55258  of the epoch  9 the steps is:  595258
# 223.13631158196603  step  55259  of the epoch  9 the steps is:  595259
# 46.655825693522274  step  55260  of the epoch  9 the steps is:  595260
# 550.0440673111252  step  55261  of the epoch  9 the steps is:  595261
# 553.3264686289092  step  55262  of the epoch  9 the steps is:  595262
# 34.9161685497383  step  55263  of the epoch  9 the steps is:  595263
# 189.74456825430678  step  55264  of the epoch  9 the steps is:  595264
# 217.66434039671896  step  55265  of the epoch  9 the steps is:  595265
# 484.9198697096141  step  55266  of the epoch  9 the steps is:  595266
# 550.2637205937351  step  55267  of the epoch  9 the steps is:  595267
# 255.2307642062844  step  55268  of the epoch  9 the steps is:  595268
# 549.8711910838247  step  55269  of the epoch  9 the steps is:  595269
# 530.3128447178208  step  55270  of the epoch  9 the steps is:  595270
# 123.57801357514967  step  55271  of the epoch  9 the steps is:  595271
# 194.67720739601845  step  55272  of the epoch  9 the steps is:  595272
# 259.6210044978442  step  55273  of the epoch  9 the steps is:  595273
# 550.2969117122033  step  55274  of the epoch  9 the steps is:  595274
# 549.7766586531191  step  55275  of the epoch  9 the steps is:  595275
# 550.3759280756988  step  55276  of the epoch  9 the steps is:  595276
# 670.2328220619577  step  55277  of the epoch  9 the steps is:  595277
# 550.3491447925373  step  55278  of the epoch  9 the steps is:  595278
# 315.6458740094416  step  55279  of the epoch  9 the steps is:  595279
# 549.7627760156374  step  55280  of the epoch  9 the steps is:  595280
# 550.2934492119441  step  55281  of the epoch  9 the steps is:  595281
# 255.41202262216086  step  55282  of the epoch  9 the steps is:  595282
# 550.2443246589053  step  55283  of the epoch  9 the steps is:  595283
# 550.1928558109449  step  55284  of the epoch  9 the steps is:  595284
# 550.4806526121218  step  55285  of the epoch  9 the steps is:  595285
# 446.28596151862024  step  55286  of the epoch  9 the steps is:  595286
# 550.6071746711222  step  55287  of the epoch  9 the steps is:  595287
# 279.1783713682981  step  55288  of the epoch  9 the steps is:  595288
# 327.6090017928189  step  55289  of the epoch  9 the steps is:  595289
# 550.6190219181425  step  55290  of the epoch  9 the steps is:  595290
# 157.3898279402481  step  55291  of the epoch  9 the steps is:  595291
# 208.864935553745  step  55292  of the epoch  9 the steps is:  595292
# 560.473729036291  step  55293  of the epoch  9 the steps is:  595293
# 562.0768261545222  step  55294  of the epoch  9 the steps is:  595294
# 171.9025609867598  step  55295  of the epoch  9 the steps is:  595295
# 312.74294334001763  step  55296  of the epoch  9 the steps is:  595296
# 549.9874405796121  step  55297  of the epoch  9 the steps is:  595297
# 1222.4467114672757  step  55298  of the epoch  9 the steps is:  595298
# 401.66412931775494  step  55299  of the epoch  9 the steps is:  595299
# 469.98012916988125  step  55300  of the epoch  9 the steps is:  595300
# 998.7448821736168  step  55301  of the epoch  9 the steps is:  595301
# 370.94307700448724  step  55302  of the epoch  9 the steps is:  595302
# 92.06469654574664  step  55303  of the epoch  9 the steps is:  595303
# 33.71637029384263  step  55304  of the epoch  9 the steps is:  595304
# 616.8961719185611  step  55305  of the epoch  9 the steps is:  595305
# 214.02463575100012  step  55306  of the epoch  9 the steps is:  595306
# 631.0762318802624  step  55307  of the epoch  9 the steps is:  595307
# 550.1144523035236  step  55308  of the epoch  9 the steps is:  595308
# 550.5151301853433  step  55309  of the epoch  9 the steps is:  595309
# 235.8226798149687  step  55310  of the epoch  9 the steps is:  595310
# 366.65090792605736  step  55311  of the epoch  9 the steps is:  595311
# 681.6115287722652  step  55312  of the epoch  9 the steps is:  595312
# 549.9371072787814  step  55313  of the epoch  9 the steps is:  595313
# 161.99332935113088  step  55314  of the epoch  9 the steps is:  595314
# 549.8716955574132  step  55315  of the epoch  9 the steps is:  595315
# 550.3205660261854  step  55316  of the epoch  9 the steps is:  595316
# 549.8007289941911  step  55317  of the epoch  9 the steps is:  595317
# 46.178528627349436  step  55318  of the epoch  9 the steps is:  595318
# 253.65386378038215  step  55319  of the epoch  9 the steps is:  595319
# 278.14580585634  step  55320  of the epoch  9 the steps is:  595320
# 549.6604435124937  step  55321  of the epoch  9 the steps is:  595321
# 524.9531675387533  step  55322  of the epoch  9 the steps is:  595322
# 549.571597620131  step  55323  of the epoch  9 the steps is:  595323
# 596.6557381433332  step  55324  of the epoch  9 the steps is:  595324
# 550.5969491781184  step  55325  of the epoch  9 the steps is:  595325
# 336.53205003113067  step  55326  of the epoch  9 the steps is:  595326
# 66.8317248770797  step  55327  of the epoch  9 the steps is:  595327
# 159.39145754780336  step  55328  of the epoch  9 the steps is:  595328
# 303.38859428125863  step  55329  of the epoch  9 the steps is:  595329
# 551.1325648297972  step  55330  of the epoch  9 the steps is:  595330
# 549.3556851627999  step  55331  of the epoch  9 the steps is:  595331
# 550.7872313766832  step  55332  of the epoch  9 the steps is:  595332
# 551.097670126559  step  55333  of the epoch  9 the steps is:  595333
# 549.3695527840343  step  55334  of the epoch  9 the steps is:  595334
# 549.3718810113155  step  55335  of the epoch  9 the steps is:  595335
# 567.815446609651  step  55336  of the epoch  9 the steps is:  595336
# 139.20387666015216  step  55337  of the epoch  9 the steps is:  595337
# 915.9604961471955  step  55338  of the epoch  9 the steps is:  595338
# 401.7519021763498  step  55339  of the epoch  9 the steps is:  595339
# 104.19043166678745  step  55340  of the epoch  9 the steps is:  595340
# 513.7958851934527  step  55341  of the epoch  9 the steps is:  595341
# 476.589504563584  step  55342  of the epoch  9 the steps is:  595342
# 181.40729306299113  step  55343  of the epoch  9 the steps is:  595343
# 342.02527196155603  step  55344  of the epoch  9 the steps is:  595344
# 381.26956441829805  step  55345  of the epoch  9 the steps is:  595345
# 290.15135023140584  step  55346  of the epoch  9 the steps is:  595346
# 555.2625865330897  step  55347  of the epoch  9 the steps is:  595347
# 326.3074538118369  step  55348  of the epoch  9 the steps is:  595348
# 305.35573751393747  step  55349  of the epoch  9 the steps is:  595349
# 254.59098253935034  step  55350  of the epoch  9 the steps is:  595350
# 551.1424904550842  step  55351  of the epoch  9 the steps is:  595351
# 259.4670163724953  step  55352  of the epoch  9 the steps is:  595352
# 130.11830071576458  step  55353  of the epoch  9 the steps is:  595353
# 243.48319174906993  step  55354  of the epoch  9 the steps is:  595354
# 444.8168936493445  step  55355  of the epoch  9 the steps is:  595355
# 550.8267969552363  step  55356  of the epoch  9 the steps is:  595356
# 138.9592929884543  step  55357  of the epoch  9 the steps is:  595357
# 71.63755438508093  step  55358  of the epoch  9 the steps is:  595358
# 575.8161960904122  step  55359  of the epoch  9 the steps is:  595359
# 550.1287803733351  step  55360  of the epoch  9 the steps is:  595360
# 373.9707737816474  step  55361  of the epoch  9 the steps is:  595361
# 550.3086794088414  step  55362  of the epoch  9 the steps is:  595362
# 94.86517561784945  step  55363  of the epoch  9 the steps is:  595363
# 533.3006390605378  step  55364  of the epoch  9 the steps is:  595364
# 494.0713302302909  step  55365  of the epoch  9 the steps is:  595365
# 531.2803173713348  step  55366  of the epoch  9 the steps is:  595366
# 550.0517667737895  step  55367  of the epoch  9 the steps is:  595367
# 275.8214460922645  step  55368  of the epoch  9 the steps is:  595368
# 202.43222932381985  step  55369  of the epoch  9 the steps is:  595369
# 486.06576756425125  step  55370  of the epoch  9 the steps is:  595370
# 1089.1592248443746  step  55371  of the epoch  9 the steps is:  595371
# 671.4445983145744  step  55372  of the epoch  9 the steps is:  595372
# 55.46904207722548  step  55373  of the epoch  9 the steps is:  595373
# 41.76675247609836  step  55374  of the epoch  9 the steps is:  595374
# 170.40163772106408  step  55375  of the epoch  9 the steps is:  595375
# 217.59793362415968  step  55376  of the epoch  9 the steps is:  595376
# 328.1608205112235  step  55377  of the epoch  9 the steps is:  595377
# 341.7222484322923  step  55378  of the epoch  9 the steps is:  595378
# 149.96032389510253  step  55379  of the epoch  9 the steps is:  595379
# 549.8837155691476  step  55380  of the epoch  9 the steps is:  595380
# 688.0664695224207  step  55381  of the epoch  9 the steps is:  595381
# 550.5845897355133  step  55382  of the epoch  9 the steps is:  595382
# 502.15440823802146  step  55383  of the epoch  9 the steps is:  595383
# 102.66457302761313  step  55384  of the epoch  9 the steps is:  595384
# 1149.1173131013497  step  55385  of the epoch  9 the steps is:  595385
# 552.1812514902593  step  55386  of the epoch  9 the steps is:  595386
# 82.5029563748665  step  55387  of the epoch  9 the steps is:  595387
# 393.93825908430847  step  55388  of the epoch  9 the steps is:  595388
# 418.0955897631298  step  55389  of the epoch  9 the steps is:  595389
# 72.14030411221833  step  55390  of the epoch  9 the steps is:  595390
# 144.96171750854307  step  55391  of the epoch  9 the steps is:  595391
# 550.4210443048613  step  55392  of the epoch  9 the steps is:  595392
# 539.5120224932192  step  55393  of the epoch  9 the steps is:  595393
# 1291.9850384359547  step  55394  of the epoch  9 the steps is:  595394
# 1350.6379484331537  step  55395  of the epoch  9 the steps is:  595395
# 313.4402375476215  step  55396  of the epoch  9 the steps is:  595396
# 426.2184180762893  step  55397  of the epoch  9 the steps is:  595397
# 456.88778981389447  step  55398  of the epoch  9 the steps is:  595398
# 550.3281565040724  step  55399  of the epoch  9 the steps is:  595399
# 297.7628180397975  step  55400  of the epoch  9 the steps is:  595400
# 398.4923280963652  step  55401  of the epoch  9 the steps is:  595401
# 369.98840940837624  step  55402  of the epoch  9 the steps is:  595402
# 110.13239361231899  step  55403  of the epoch  9 the steps is:  595403
# 619.5436734038262  step  55404  of the epoch  9 the steps is:  595404
# 428.12473154790956  step  55405  of the epoch  9 the steps is:  595405
# 524.7619008744964  step  55406  of the epoch  9 the steps is:  595406
# 590.5857809795991  step  55407  of the epoch  9 the steps is:  595407
# 91.94668262714214  step  55408  of the epoch  9 the steps is:  595408
# 409.1365742100858  step  55409  of the epoch  9 the steps is:  595409
# 149.8822261098886  step  55410  of the epoch  9 the steps is:  595410
# 550.0247574756269  step  55411  of the epoch  9 the steps is:  595411
# 549.9997717578965  step  55412  of the epoch  9 the steps is:  595412
# 550.1020572972968  step  55413  of the epoch  9 the steps is:  595413
# 230.2205418738793  step  55414  of the epoch  9 the steps is:  595414
# 549.2178819307474  step  55415  of the epoch  9 the steps is:  595415
# 549.9140260373515  step  55416  of the epoch  9 the steps is:  595416
# 773.6908920973283  step  55417  of the epoch  9 the steps is:  595417
# 79.69540444423376  step  55418  of the epoch  9 the steps is:  595418
# 338.7454849531001  step  55419  of the epoch  9 the steps is:  595419
# 550.293629639183  step  55420  of the epoch  9 the steps is:  595420
# 551.1705913134006  step  55421  of the epoch  9 the steps is:  595421
# 209.13879351787108  step  55422  of the epoch  9 the steps is:  595422
# 357.67392134921306  step  55423  of the epoch  9 the steps is:  595423
# 556.1188806489441  step  55424  of the epoch  9 the steps is:  595424
# 550.2970533035209  step  55425  of the epoch  9 the steps is:  595425
# 536.7900328100511  step  55426  of the epoch  9 the steps is:  595426
# 61.74154456333372  step  55427  of the epoch  9 the steps is:  595427
# 135.66196513975478  step  55428  of the epoch  9 the steps is:  595428
# 550.3730034335637  step  55429  of the epoch  9 the steps is:  595429
# 549.9978393463529  step  55430  of the epoch  9 the steps is:  595430
# 550.1334387784486  step  55431  of the epoch  9 the steps is:  595431
# 128.68997376912472  step  55432  of the epoch  9 the steps is:  595432
# 223.1803360016871  step  55433  of the epoch  9 the steps is:  595433
# 273.116191787704  step  55434  of the epoch  9 the steps is:  595434
# 356.2202720276374  step  55435  of the epoch  9 the steps is:  595435
# 515.8845943678896  step  55436  of the epoch  9 the steps is:  595436
# 329.12890200485947  step  55437  of the epoch  9 the steps is:  595437
# 1003.317721490006  step  55438  of the epoch  9 the steps is:  595438
# 405.1665057936034  step  55439  of the epoch  9 the steps is:  595439
# 80.14588964728051  step  55440  of the epoch  9 the steps is:  595440
# 550.1690150849543  step  55441  of the epoch  9 the steps is:  595441
# 513.0981113309099  step  55442  of the epoch  9 the steps is:  595442
# 89.97881323712963  step  55443  of the epoch  9 the steps is:  595443
# 564.4918973405836  step  55444  of the epoch  9 the steps is:  595444
# 367.43171992612747  step  55445  of the epoch  9 the steps is:  595445
# 557.1458017514672  step  55446  of the epoch  9 the steps is:  595446
# 461.68722300810816  step  55447  of the epoch  9 the steps is:  595447
# 523.814544291608  step  55448  of the epoch  9 the steps is:  595448
# 202.14543081366597  step  55449  of the epoch  9 the steps is:  595449
# 94.10334277499481  step  55450  of the epoch  9 the steps is:  595450
# 549.8498480388913  step  55451  of the epoch  9 the steps is:  595451
# 147.27449091078716  step  55452  of the epoch  9 the steps is:  595452
# 41.051850810104526  step  55453  of the epoch  9 the steps is:  595453
# 65.90313146288193  step  55454  of the epoch  9 the steps is:  595454
# 707.9791581343646  step  55455  of the epoch  9 the steps is:  595455
# 550.420413712712  step  55456  of the epoch  9 the steps is:  595456
# 550.8201425821374  step  55457  of the epoch  9 the steps is:  595457
# 51.38074433298112  step  55458  of the epoch  9 the steps is:  595458
# 493.366406782483  step  55459  of the epoch  9 the steps is:  595459
# 347.36765791528563  step  55460  of the epoch  9 the steps is:  595460
# 415.3619053033236  step  55461  of the epoch  9 the steps is:  595461
# 778.2607464416595  step  55462  of the epoch  9 the steps is:  595462
# 552.7821811162655  step  55463  of the epoch  9 the steps is:  595463
# 549.7472487025692  step  55464  of the epoch  9 the steps is:  595464
# 406.5064542326819  step  55465  of the epoch  9 the steps is:  595465
# 284.40568069978997  step  55466  of the epoch  9 the steps is:  595466
# 550.7716889113256  step  55467  of the epoch  9 the steps is:  595467
# 492.81713600508067  step  55468  of the epoch  9 the steps is:  595468
# 656.6341956628607  step  55469  of the epoch  9 the steps is:  595469
# 549.8228085570536  step  55470  of the epoch  9 the steps is:  595470
# 549.8198112070352  step  55471  of the epoch  9 the steps is:  595471
# 549.7971135878479  step  55472  of the epoch  9 the steps is:  595472
# 109.89788105637177  step  55473  of the epoch  9 the steps is:  595473
# 478.814016499232  step  55474  of the epoch  9 the steps is:  595474
# 235.6510156918111  step  55475  of the epoch  9 the steps is:  595475
# 551.5781085631044  step  55476  of the epoch  9 the steps is:  595476
# 248.69530125773076  step  55477  of the epoch  9 the steps is:  595477
# 319.63111140355363  step  55478  of the epoch  9 the steps is:  595478
# 1684.4796053780283  step  55479  of the epoch  9 the steps is:  595479
# 584.0181898324735  step  55480  of the epoch  9 the steps is:  595480
# 175.02336467862187  step  55481  of the epoch  9 the steps is:  595481
# 340.1368006340873  step  55482  of the epoch  9 the steps is:  595482
# 550.7301834938099  step  55483  of the epoch  9 the steps is:  595483
# 48.05765025030064  step  55484  of the epoch  9 the steps is:  595484
# 294.49105212575546  step  55485  of the epoch  9 the steps is:  595485
# 560.5370537369784  step  55486  of the epoch  9 the steps is:  595486
# 549.6925248505556  step  55487  of the epoch  9 the steps is:  595487
# 236.42555924201866  step  55488  of the epoch  9 the steps is:  595488
# 367.1674225272796  step  55489  of the epoch  9 the steps is:  595489
# 641.0852007385163  step  55490  of the epoch  9 the steps is:  595490
# 550.3297537402077  step  55491  of the epoch  9 the steps is:  595491
# 550.2903568601954  step  55492  of the epoch  9 the steps is:  595492
# 478.8817271772629  step  55493  of the epoch  9 the steps is:  595493
# 550.9707211375334  step  55494  of the epoch  9 the steps is:  595494
# 501.3519028877806  step  55495  of the epoch  9 the steps is:  595495
# 126.96748016851384  step  55496  of the epoch  9 the steps is:  595496
# 30.030595372780738  step  55497  of the epoch  9 the steps is:  595497
# 550.685545964169  step  55498  of the epoch  9 the steps is:  595498
# 116.42741358515576  step  55499  of the epoch  9 the steps is:  595499
# 231.90066723221108  step  55500  of the epoch  9 the steps is:  595500
# 227.46207740703767  step  55501  of the epoch  9 the steps is:  595501
# 317.54090613942367  step  55502  of the epoch  9 the steps is:  595502
# 318.06785682195084  step  55503  of the epoch  9 the steps is:  595503
# 315.82515058687864  step  55504  of the epoch  9 the steps is:  595504
# 196.67019002861753  step  55505  of the epoch  9 the steps is:  595505
# 300.1857812689047  step  55506  of the epoch  9 the steps is:  595506
# 787.9396053074676  step  55507  of the epoch  9 the steps is:  595507
# 549.9341095128036  step  55508  of the epoch  9 the steps is:  595508
# 38.743507795834375  step  55509  of the epoch  9 the steps is:  595509
# 554.8203452563624  step  55510  of the epoch  9 the steps is:  595510
# 126.68022391444441  step  55511  of the epoch  9 the steps is:  595511
# 550.3018939948988  step  55512  of the epoch  9 the steps is:  595512
# 42.21299352792215  step  55513  of the epoch  9 the steps is:  595513
# 438.64172006563194  step  55514  of the epoch  9 the steps is:  595514
# 242.20744935599316  step  55515  of the epoch  9 the steps is:  595515
# 293.2555283802411  step  55516  of the epoch  9 the steps is:  595516
# 550.3376549596735  step  55517  of the epoch  9 the steps is:  595517
# 550.5674649432153  step  55518  of the epoch  9 the steps is:  595518
# 376.64303734727287  step  55519  of the epoch  9 the steps is:  595519
# 388.22163171187543  step  55520  of the epoch  9 the steps is:  595520
# 550.8716753115546  step  55521  of the epoch  9 the steps is:  595521
# 252.69004533292934  step  55522  of the epoch  9 the steps is:  595522
# 357.1394629532439  step  55523  of the epoch  9 the steps is:  595523
# 513.8047233086778  step  55524  of the epoch  9 the steps is:  595524
# 213.01989723620386  step  55525  of the epoch  9 the steps is:  595525
# 841.3248400391362  step  55526  of the epoch  9 the steps is:  595526
# 550.4718274563807  step  55527  of the epoch  9 the steps is:  595527
# 550.4285478298964  step  55528  of the epoch  9 the steps is:  595528
# 137.14127388696625  step  55529  of the epoch  9 the steps is:  595529
# 249.37576269173655  step  55530  of the epoch  9 the steps is:  595530
# 237.30557790763777  step  55531  of the epoch  9 the steps is:  595531
# 298.89063152008896  step  55532  of the epoch  9 the steps is:  595532
# 435.3916838131163  step  55533  of the epoch  9 the steps is:  595533
# 911.9079134264812  step  55534  of the epoch  9 the steps is:  595534
# 120.2336993980351  step  55535  of the epoch  9 the steps is:  595535
# 1096.711960800213  step  55536  of the epoch  9 the steps is:  595536
# 30.030054457439547  step  55537  of the epoch  9 the steps is:  595537
# 231.48563380016216  step  55538  of the epoch  9 the steps is:  595538
# 355.9912378055253  step  55539  of the epoch  9 the steps is:  595539
# 652.6858935738308  step  55540  of the epoch  9 the steps is:  595540
# 550.706894119875  step  55541  of the epoch  9 the steps is:  595541
# 118.35055454186835  step  55542  of the epoch  9 the steps is:  595542
# 564.1441909102595  step  55543  of the epoch  9 the steps is:  595543
# 550.4026782115218  step  55544  of the epoch  9 the steps is:  595544
# 233.197318773049  step  55545  of the epoch  9 the steps is:  595545
# 551.4039309434726  step  55546  of the epoch  9 the steps is:  595546
# 168.16162685630897  step  55547  of the epoch  9 the steps is:  595547
# 701.354670952307  step  55548  of the epoch  9 the steps is:  595548
# 171.65725728905122  step  55549  of the epoch  9 the steps is:  595549
# 382.78081718874546  step  55550  of the epoch  9 the steps is:  595550
# 411.2122124168317  step  55551  of the epoch  9 the steps is:  595551
# 150.85068988650013  step  55552  of the epoch  9 the steps is:  595552
# 466.7139454311932  step  55553  of the epoch  9 the steps is:  595553
# 550.4712077544355  step  55554  of the epoch  9 the steps is:  595554
# 517.638456250712  step  55555  of the epoch  9 the steps is:  595555
# 344.46101009799656  step  55556  of the epoch  9 the steps is:  595556
# 550.0760076687286  step  55557  of the epoch  9 the steps is:  595557
# 239.0107207151316  step  55558  of the epoch  9 the steps is:  595558
# 1231.9799242222655  step  55559  of the epoch  9 the steps is:  595559
# 367.0153811638677  step  55560  of the epoch  9 the steps is:  595560
# 103.95786111048542  step  55561  of the epoch  9 the steps is:  595561
# 84.32499700593331  step  55562  of the epoch  9 the steps is:  595562
# 311.1876050940449  step  55563  of the epoch  9 the steps is:  595563
# 289.78911372457253  step  55564  of the epoch  9 the steps is:  595564
# 357.8583043726021  step  55565  of the epoch  9 the steps is:  595565
# 28.624904742483352  step  55566  of the epoch  9 the steps is:  595566
# 550.6429243002759  step  55567  of the epoch  9 the steps is:  595567
# 227.03705120456416  step  55568  of the epoch  9 the steps is:  595568
# 549.7166737344722  step  55569  of the epoch  9 the steps is:  595569
# 550.6759980860379  step  55570  of the epoch  9 the steps is:  595570
# 110.28947313693754  step  55571  of the epoch  9 the steps is:  595571
# 1212.9219233388294  step  55572  of the epoch  9 the steps is:  595572
# 550.5702179564714  step  55573  of the epoch  9 the steps is:  595573
# 230.58210184675576  step  55574  of the epoch  9 the steps is:  595574
# 550.4020931795483  step  55575  of the epoch  9 the steps is:  595575
# 213.9875285694479  step  55576  of the epoch  9 the steps is:  595576
# 149.17532298479853  step  55577  of the epoch  9 the steps is:  595577
# 550.3338899772732  step  55578  of the epoch  9 the steps is:  595578
# 695.9474737813887  step  55579  of the epoch  9 the steps is:  595579
# 442.55715827134844  step  55580  of the epoch  9 the steps is:  595580
# 63.49724816006608  step  55581  of the epoch  9 the steps is:  595581
# 126.41584219052731  step  55582  of the epoch  9 the steps is:  595582
# 170.10548466270055  step  55583  of the epoch  9 the steps is:  595583
# 551.604374059246  step  55584  of the epoch  9 the steps is:  595584
# 403.9968526096936  step  55585  of the epoch  9 the steps is:  595585
# 463.08679606553926  step  55586  of the epoch  9 the steps is:  595586
# 614.0433071931599  step  55587  of the epoch  9 the steps is:  595587
# 1018.5968678630474  step  55588  of the epoch  9 the steps is:  595588
# 219.77001318005276  step  55589  of the epoch  9 the steps is:  595589
# 550.4805873112745  step  55590  of the epoch  9 the steps is:  595590
# 550.4196708678804  step  55591  of the epoch  9 the steps is:  595591
# ...
# 70.45349286514943  step  59773  of the epoch  9 the steps is:  599773
# 557.8283452903795  step  59774  of the epoch  9 the steps is:  599774
# 31.110283619222542  step  59775  of the epoch  9 the steps is:  599775
# 20.371718353928742  step  59776  of the epoch  9 the steps is:  599776
# 23.621340768037555  step  59777  of the epoch  9 the steps is:  599777
# 329.9663509445887  step  59778  of the epoch  9 the steps is:  599778
# 191.84861047097195  step  59779  of the epoch  9 the steps is:  599779
# 20.075267254238383  step  59780  of the epoch  9 the steps is:  599780
# 550.3442606102033  step  59781  of the epoch  9 the steps is:  599781
# 341.6304033435148  step  59782  of the epoch  9 the steps is:  599782
# 47.851803317761096  step  59783  of the epoch  9 the steps is:  599783
# 83.98637590219275  step  59784  of the epoch  9 the steps is:  599784
# 328.5887297482197  step  59785  of the epoch  9 the steps is:  599785
# 550.3539243630543  step  59786  of the epoch  9 the steps is:  599786
# 400.297132216934  step  59787  of the epoch  9 the steps is:  599787
# 405.68478535225177  step  59788  of the epoch  9 the steps is:  599788
# 422.59186525716586  step  59789  of the epoch  9 the steps is:  599789
# 437.49541920555873  step  59790  of the epoch  9 the steps is:  599790
# 533.2118481220516  step  59791  of the epoch  9 the steps is:  599791
# 44.48129690325729  step  59792  of the epoch  9 the steps is:  599792
# 167.10850358577943  step  59793  of the epoch  9 the steps is:  599793
# 81.97152719105065  step  59794  of the epoch  9 the steps is:  599794
# 550.076213255891  step  59795  of the epoch  9 the steps is:  599795
# 447.4003591888034  step  59796  of the epoch  9 the steps is:  599796
# 502.4986901029326  step  59797  of the epoch  9 the steps is:  599797
# 78.22271733654259  step  59798  of the epoch  9 the steps is:  599798
# 146.65486563635363  step  59799  of the epoch  9 the steps is:  599799
# 358.3831728178994  step  59800  of the epoch  9 the steps is:  599800
# 550.3895501050787  step  59801  of the epoch  9 the steps is:  599801
# 485.4063252770856  step  59802  of the epoch  9 the steps is:  599802
# 580.4423187422478  step  59803  of the epoch  9 the steps is:  599803
# 550.2396045377781  step  59804  of the epoch  9 the steps is:  599804
# 550.4821858185696  step  59805  of the epoch  9 the steps is:  599805
# 85.93900968204514  step  59806  of the epoch  9 the steps is:  599806
# 160.88993504142834  step  59807  of the epoch  9 the steps is:  599807
# 169.79406893362176  step  59808  of the epoch  9 the steps is:  599808
# 549.9249805366732  step  59809  of the epoch  9 the steps is:  599809
# 550.8266273957113  step  59810  of the epoch  9 the steps is:  599810
# 254.52613716845744  step  59811  of the epoch  9 the steps is:  599811
# 244.1370696216337  step  59812  of the epoch  9 the steps is:  599812
# 550.4884548459074  step  59813  of the epoch  9 the steps is:  599813
# 259.47750964097406  step  59814  of the epoch  9 the steps is:  599814
# 115.66458545520771  step  59815  of the epoch  9 the steps is:  599815
# 164.80006595999248  step  59816  of the epoch  9 the steps is:  599816
# 253.28281119498737  step  59817  of the epoch  9 the steps is:  599817
# 211.31101966282324  step  59818  of the epoch  9 the steps is:  599818
# 20.2572663490551  step  59819  of the epoch  9 the steps is:  599819
# 479.6311735144339  step  59820  of the epoch  9 the steps is:  599820
# 169.33614769533602  step  59821  of the epoch  9 the steps is:  599821
# 168.13992001469924  step  59822  of the epoch  9 the steps is:  599822
# 334.2580160068647  step  59823  of the epoch  9 the steps is:  599823
# 550.2819791430778  step  59824  of the epoch  9 the steps is:  599824
# 846.319019745213  step  59825  of the epoch  9 the steps is:  599825
# 233.8425802415016  step  59826  of the epoch  9 the steps is:  599826
# 286.05308369865725  step  59827  of the epoch  9 the steps is:  599827
# 124.35905858735634  step  59828  of the epoch  9 the steps is:  599828
# 267.3549793994865  step  59829  of the epoch  9 the steps is:  599829
# 65.27512857242178  step  59830  of the epoch  9 the steps is:  599830
# 1065.1267188087659  step  59831  of the epoch  9 the steps is:  599831
# 107.96421800003736  step  59832  of the epoch  9 the steps is:  599832
# 344.5902160055018  step  59833  of the epoch  9 the steps is:  599833
# 123.39499334900955  step  59834  of the epoch  9 the steps is:  599834
# 299.98411812834854  step  59835  of the epoch  9 the steps is:  599835
# 91.41900743690277  step  59836  of the epoch  9 the steps is:  599836
# 70.13047524682219  step  59837  of the epoch  9 the steps is:  599837
# 182.18784012349462  step  59838  of the epoch  9 the steps is:  599838
# 791.2162116853956  step  59839  of the epoch  9 the steps is:  599839
# 374.6079697118136  step  59840  of the epoch  9 the steps is:  599840
# 243.09703486401634  step  59841  of the epoch  9 the steps is:  599841
# 550.3747887335755  step  59842  of the epoch  9 the steps is:  599842
# 121.5814988799927  step  59843  of the epoch  9 the steps is:  599843
# 152.2452537088665  step  59844  of the epoch  9 the steps is:  599844
# 91.83368881596607  step  59845  of the epoch  9 the steps is:  599845
# 450.6148665880331  step  59846  of the epoch  9 the steps is:  599846
# 32.15577079304313  step  59847  of the epoch  9 the steps is:  599847
# 198.82454279897487  step  59848  of the epoch  9 the steps is:  599848
# 38.48096341668116  step  59849  of the epoch  9 the steps is:  599849
# 4.776461994507315  step  59850  of the epoch  9 the steps is:  599850
# 69.73296516952348  step  59851  of the epoch  9 the steps is:  599851
# 392.16263605243074  step  59852  of the epoch  9 the steps is:  599852
# 306.33348981367584  step  59853  of the epoch  9 the steps is:  599853
# 255.83858003131007  step  59854  of the epoch  9 the steps is:  599854
# 550.0873012982888  step  59855  of the epoch  9 the steps is:  599855
# 91.94037866212386  step  59856  of the epoch  9 the steps is:  599856
# 343.2957996190075  step  59857  of the epoch  9 the steps is:  599857
# 70.70894636803416  step  59858  of the epoch  9 the steps is:  599858
# 550.6235365717762  step  59859  of the epoch  9 the steps is:  599859
# 550.019363388446  step  59860  of the epoch  9 the steps is:  599860
# 445.9037845412804  step  59861  of the epoch  9 the steps is:  599861
# 52.73003639492043  step  59862  of the epoch  9 the steps is:  599862
# 550.6132075728992  step  59863  of the epoch  9 the steps is:  599863
# 788.5900146970437  step  59864  of the epoch  9 the steps is:  599864
# 745.8053235309909  step  59865  of the epoch  9 the steps is:  599865
# 186.94795081485555  step  59866  of the epoch  9 the steps is:  599866
# 171.80371262040367  step  59867  of the epoch  9 the steps is:  599867
# 90.43515397344734  step  59868  of the epoch  9 the steps is:  599868
# 550.0912202785134  step  59869  of the epoch  9 the steps is:  599869
# 550.0538054523939  step  59870  of the epoch  9 the steps is:  599870
# 200.55209938977438  step  59871  of the epoch  9 the steps is:  599871
# 438.67283330612463  step  59872  of the epoch  9 the steps is:  599872
# 344.7716220488499  step  59873  of the epoch  9 the steps is:  599873
# 156.99671099568118  step  59874  of the epoch  9 the steps is:  599874
# 402.83051208925536  step  59875  of the epoch  9 the steps is:  599875
# 550.6853224404225  step  59876  of the epoch  9 the steps is:  599876
# 581.3529819522389  step  59877  of the epoch  9 the steps is:  599877
# 224.8795568546474  step  59878  of the epoch  9 the steps is:  599878
# 550.6720773066862  step  59879  of the epoch  9 the steps is:  599879
# 550.688561212855  step  59880  of the epoch  9 the steps is:  599880
# 550.4234016635289  step  59881  of the epoch  9 the steps is:  599881
# 550.3408839657293  step  59882  of the epoch  9 the steps is:  599882
# 550.1673557550265  step  59883  of the epoch  9 the steps is:  599883
# 311.15841313089845  step  59884  of the epoch  9 the steps is:  599884
# 550.0420659873389  step  59885  of the epoch  9 the steps is:  599885
# 550.3452939995249  step  59886  of the epoch  9 the steps is:  599886
# 550.158951289757  step  59887  of the epoch  9 the steps is:  599887
# 549.8501828167205  step  59888  of the epoch  9 the steps is:  599888
# 550.3058350775248  step  59889  of the epoch  9 the steps is:  599889
# 550.2088319789946  step  59890  of the epoch  9 the steps is:  599890
# 318.9725264456641  step  59891  of the epoch  9 the steps is:  599891
# 846.7485236802952  step  59892  of the epoch  9 the steps is:  599892
# 195.00512225857136  step  59893  of the epoch  9 the steps is:  599893
# 183.70271145366456  step  59894  of the epoch  9 the steps is:  599894
# 549.984833959814  step  59895  of the epoch  9 the steps is:  599895
# 550.3165548013745  step  59896  of the epoch  9 the steps is:  599896
# 783.6004234275811  step  59897  of the epoch  9 the steps is:  599897
# 51.52019608993072  step  59898  of the epoch  9 the steps is:  599898
# 74.62253994427164  step  59899  of the epoch  9 the steps is:  599899
# 340.6766275420762  step  59900  of the epoch  9 the steps is:  599900
# 12.812025087031543  step  59901  of the epoch  9 the steps is:  599901
# 494.84335336503995  step  59902  of the epoch  9 the steps is:  599902
# 509.2488892875024  step  59903  of the epoch  9 the steps is:  599903
# 550.0769491481135  step  59904  of the epoch  9 the steps is:  599904
# 550.6916670180759  step  59905  of the epoch  9 the steps is:  599905
# 7.50293105373072  step  59906  of the epoch  9 the steps is:  599906
# 361.62880008343694  step  59907  of the epoch  9 the steps is:  599907
# 210.48619673110898  step  59908  of the epoch  9 the steps is:  599908
# 118.95882476817246  step  59909  of the epoch  9 the steps is:  599909
# 224.36322706163895  step  59910  of the epoch  9 the steps is:  599910
# 550.5821854535151  step  59911  of the epoch  9 the steps is:  599911
# 341.55780980072  step  59912  of the epoch  9 the steps is:  599912
# 65.43460745954113  step  59913  of the epoch  9 the steps is:  599913
# 225.55627526701613  step  59914  of the epoch  9 the steps is:  599914
# 374.1675411968853  step  59915  of the epoch  9 the steps is:  599915
# 550.0771108185454  step  59916  of the epoch  9 the steps is:  599916
# 550.0050749293348  step  59917  of the epoch  9 the steps is:  599917
# 46.0701985870497  step  59918  of the epoch  9 the steps is:  599918
# 76.95024963501302  step  59919  of the epoch  9 the steps is:  599919
# 326.79584061223943  step  59920  of the epoch  9 the steps is:  599920
# 898.8811315428179  step  59921  of the epoch  9 the steps is:  599921
# 409.7555093051523  step  59922  of the epoch  9 the steps is:  599922
# 335.12037369567986  step  59923  of the epoch  9 the steps is:  599923
# 227.9844100786483  step  59924  of the epoch  9 the steps is:  599924
# 170.7750035826051  step  59925  of the epoch  9 the steps is:  599925
# 501.7218936663834  step  59926  of the epoch  9 the steps is:  599926
# 183.72323679210112  step  59927  of the epoch  9 the steps is:  599927
# 550.9663798173424  step  59928  of the epoch  9 the steps is:  599928
# 317.16558404156126  step  59929  of the epoch  9 the steps is:  599929
# 549.966281996949  step  59930  of the epoch  9 the steps is:  599930
# 428.774307862501  step  59931  of the epoch  9 the steps is:  599931
# 129.0942255147318  step  59932  of the epoch  9 the steps is:  599932
# 156.79957752036742  step  59933  of the epoch  9 the steps is:  599933
# 486.7214905419662  step  59934  of the epoch  9 the steps is:  599934
# 133.486965101967  step  59935  of the epoch  9 the steps is:  599935
# 353.42116188487745  step  59936  of the epoch  9 the steps is:  599936
# 698.1033461689644  step  59937  of the epoch  9 the steps is:  599937
# 432.224869165252  step  59938  of the epoch  9 the steps is:  599938
# 989.5096153794564  step  59939  of the epoch  9 the steps is:  599939
# 61.8114970215633  step  59940  of the epoch  9 the steps is:  599940
# 337.18359476877947  step  59941  of the epoch  9 the steps is:  599941
# 550.4431117000622  step  59942  of the epoch  9 the steps is:  599942
# 126.09805917636027  step  59943  of the epoch  9 the steps is:  599943
# 106.983588491614  step  59944  of the epoch  9 the steps is:  599944
# 550.5027341394953  step  59945  of the epoch  9 the steps is:  599945
# 475.2845067815657  step  59946  of the epoch  9 the steps is:  599946
# 501.4564540148576  step  59947  of the epoch  9 the steps is:  599947
# 58.57831860937526  step  59948  of the epoch  9 the steps is:  599948
# 550.163546971149  step  59949  of the epoch  9 the steps is:  599949
# 550.2373585318524  step  59950  of the epoch  9 the steps is:  599950
# 196.9397485931629  step  59951  of the epoch  9 the steps is:  599951
# 102.12128666821889  step  59952  of the epoch  9 the steps is:  599952
# 550.3665942913108  step  59953  of the epoch  9 the steps is:  599953
# 84.991479947014  step  59954  of the epoch  9 the steps is:  599954
# 625.9829165474903  step  59955  of the epoch  9 the steps is:  599955
# 428.9679552571073  step  59956  of the epoch  9 the steps is:  599956
# 153.62804504413137  step  59957  of the epoch  9 the steps is:  599957
# 737.9126383202961  step  59958  of the epoch  9 the steps is:  599958
# 550.2503389662687  step  59959  of the epoch  9 the steps is:  599959
# 438.0669793277253  step  59960  of the epoch  9 the steps is:  599960
# 701.3999986274418  step  59961  of the epoch  9 the steps is:  599961
# 43.75968769963296  step  59962  of the epoch  9 the steps is:  599962
# 550.2305633781126  step  59963  of the epoch  9 the steps is:  599963
# 550.5397149398793  step  59964  of the epoch  9 the steps is:  599964
# 550.3424742846717  step  59965  of the epoch  9 the steps is:  599965
# 146.58085515272563  step  59966  of the epoch  9 the steps is:  599966
# 132.56462436948257  step  59967  of the epoch  9 the steps is:  599967
# 549.9664874352707  step  59968  of the epoch  9 the steps is:  599968
# 549.9339810732117  step  59969  of the epoch  9 the steps is:  599969
# 286.1288253655779  step  59970  of the epoch  9 the steps is:  599970
# 422.1254161570487  step  59971  of the epoch  9 the steps is:  599971
# 159.4540978060211  step  59972  of the epoch  9 the steps is:  599972
# 549.8070220454252  step  59973  of the epoch  9 the steps is:  599973
# 550.5713029559358  step  59974  of the epoch  9 the steps is:  599974
# 550.3811135262408  step  59975  of the epoch  9 the steps is:  599975
# 550.3524530178205  step  59976  of the epoch  9 the steps is:  599976
# 550.8465730162283  step  59977  of the epoch  9 the steps is:  599977
# 237.08738390923222  step  59978  of the epoch  9 the steps is:  599978
# 125.03694374031579  step  59979  of the epoch  9 the steps is:  599979
# 413.30586462998957  step  59980  of the epoch  9 the steps is:  599980
# 550.724287646864  step  59981  of the epoch  9 the steps is:  599981
# 550.070831962231  step  59982  of the epoch  9 the steps is:  599982
# 343.6852778839965  step  59983  of the epoch  9 the steps is:  599983
# 549.9341430335601  step  59984  of the epoch  9 the steps is:  599984
# 550.2003582519231  step  59985  of the epoch  9 the steps is:  599985
# 549.8640404800719  step  59986  of the epoch  9 the steps is:  599986
# 562.281039699712  step  59987  of the epoch  9 the steps is:  599987
# 550.367616604909  step  59988  of the epoch  9 the steps is:  599988
# 378.4989562816295  step  59989  of the epoch  9 the steps is:  599989
# 549.8087729505068  step  59990  of the epoch  9 the steps is:  599990
# 332.31070568717524  step  59991  of the epoch  9 the steps is:  599991
# 295.0192793991166  step  59992  of the epoch  9 the steps is:  599992
# 550.4739984498206  step  59993  of the epoch  9 the steps is:  599993
# 131.24789385839546  step  59994  of the epoch  9 the steps is:  599994
# 166.39037832266843  step  59995  of the epoch  9 the steps is:  599995
# 233.93701308897857  step  59996  of the epoch  9 the steps is:  599996
# 285.092051152486  step  59997  of the epoch  9 the steps is:  599997
# 330.34296490067146  step  59998  of the epoch  9 the steps is:  599998
# 53.630920647570974  step  59999  of the epoch  9 the steps is:  599999
# 0.6939666666666666
# time of train : 2870.477666441

# %%
MyNetwork.Test_Network(Test_data, Test_label)
MyNetwork.Test_Network(Train_data, Train_label)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in cosh
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in power
# 0.6871
# 0.6939666666666666
# 0.6939666666666666

# %%
plt.plot(np.arange(1,len(MyNetwork.accuracy_graph_epoch)+1), MyNetwork.accuracy_graph_epoch)
plt.ylabel('Accuracy')
plt.xlabel("number epoch")
plt.grid(True)
plt.show()

# %%
plt.plot(np.arange(1,len(MyNetwork.loss_graph)+1), MyNetwork.loss_graph)
plt.ylabel('loss')
plt.xlabel("number steps")
plt.grid(True)
plt.show()

# %% [markdown]
# This block is Used to save the networks weights

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)

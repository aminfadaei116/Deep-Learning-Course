# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA
from sklearn.utils import shuffle

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
num = 200
noise_data = np.random.normal(loc=0, scale=0.2, size=(num, len(Train_data[0])))
noise_label = 10 * np.ones(shape=(num,1))
Train_data = np.concatenate((Train_data, noise_data))
Train_label = np.concatenate((Train_label, noise_label))
Train_data, Train_label =shuffle(Train_data, Train_label, random_state=0)
Train_label = (Train_label).astype(int)

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx, landa):
  temp = np.multiply(step(landa - vect),-1)
  if idx != 10:
    temp[idx] = 1
  return temp

def gelu(x):
    return 0.5 * np.multiply(x, 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def Dgelu(x):
  return np.divide(0.053516 * np.power(x, 3) + np.multiply(0.398942, x) , np.power(np.cosh(0.0356774 * np.power(x, 3) +np.multiply(0.79788, x)),2)) + 0.5 * ( 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def RBF_encode(data, number_class, dim):
  data = np.reshape(data, (dim,int(data.size/dim)), order='F')
  data = LA.norm(data,1, axis = 0)
  data = np.reshape(data, (number_class, int(data.size/number_class)), order='F')
  return data

def expand(x):
  temp = []
  for i in range(len(x)):
    temp.append(x[i])
    temp.append(x[i])
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.distance_dim = 2
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.landa = 550
    self.attack_rate = 0.1

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = gelu(self.layer["z0"])
    self.layer["s0"] = Dgelu(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = gelu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = Dgelu(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = RBF_encode(self.layer["z" + str(self.number_hidden_layer)], self.number_class_output, self.distance_dim)
    self.layer["s" + str(self.number_hidden_layer)] = np.sign(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    #print(np.transpose(self.score))
    temp = self.decide_RBF(self.score, self.landa)
    return temp
  
  def decide_RBF(self, data, landa):
    self.result = np.argmin(data, axis=0)
    self.result[np.min(data, axis=0)>landa] = 10
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      if label[i] != 10:
        self.loss.append(np.sum(relu((self.landa - temp[i]))) - relu(self.landa- temp[i][label[i]]) +   temp[i][int(label[i])])
      else:
        self.loss.append(np.sum(relu(self.landa - temp[i])))
      self.back_prob_output.append(encode(temp[i], label[i], self.landa))
    self.back_prob_output = np.transpose(self.back_prob_output)/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] - self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] - self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))

  def attack_network(self, data, label):
    self.forward(data)
    self.cal_loss(label)
    D_image = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      D_image = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), D_image)
      D_image = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], D_image)
    D_image = np.matmul(np.transpose(self.weight["w0"]), D_image)
    D_image = np.sign(D_image) 
    return data - self.attack_rate * D_image.reshape((-1,))

# %%
MyNetwork = Network(128,1,[150] ,10)

# %%
MyNetwork.load_weights()

# %%
MyNetwork.set_learning_rate(0.05)
MyNetwork.set_turn(3)
MyNetwork.set_batch_size(128)
MyNetwork.Train_Network(Train_data, Train_label)
# Out:
# [4954.47604963]  step  0  of the epoch  0 the steps is:  0
# 4945.775518328634  step  1  of the epoch  0 the steps is:  1
# 4945.656270322257  step  2  of the epoch  0 the steps is:  2
# 4945.410909074329  step  3  of the epoch  0 the steps is:  3
# 4945.2448728989075  step  4  of the epoch  0 the steps is:  4
# 4945.052530559936  step  5  of the epoch  0 the steps is:  5
# [4948.8323721]  step  6  of the epoch  0 the steps is:  6
# [4956.67368229]  step  7  of the epoch  0 the steps is:  7
# [4947.44186981]  step  8  of the epoch  0 the steps is:  8
# 4942.346677386664  step  9  of the epoch  0 the steps is:  9
# [4945.79204904]  step  10  of the epoch  0 the steps is:  10
# 4939.843325035018  step  11  of the epoch  0 the steps is:  11
# [4946.48247993]  step  12  of the epoch  0 the steps is:  12
# 4936.255368334099  step  13  of the epoch  0 the steps is:  13
# [4937.69098741]  step  14  of the epoch  0 the steps is:  14
# [4935.31140574]  step  15  of the epoch  0 the steps is:  15
# [4931.67357505]  step  16  of the epoch  0 the steps is:  16
# 4922.704211061538  step  17  of the epoch  0 the steps is:  17
# 4917.974033053416  step  18  of the epoch  0 the steps is:  18
# [4914.81926494]  step  19  of the epoch  0 the steps is:  19
# 4901.565522318735  step  20  of the epoch  0 the steps is:  20
# 4890.101948795738  step  21  of the epoch  0 the steps is:  21
# [4883.50400965]  step  22  of the epoch  0 the steps is:  22
# 4861.006037728104  step  23  of the epoch  0 the steps is:  23
# 4838.493334730569  step  24  of the epoch  0 the steps is:  24
# [4818.551249]  step  25  of the epoch  0 the steps is:  25
# [4777.48462342]  step  26  of the epoch  0 the steps is:  26
# 4732.42467427408  step  27  of the epoch  0 the steps is:  27
# 4679.167749366106  step  28  of the epoch  0 the steps is:  28
# 4604.041421730415  step  29  of the epoch  0 the steps is:  29
# 4509.636686670507  step  30  of the epoch  0 the steps is:  30
# 4401.884075138778  step  31  of the epoch  0 the steps is:  31
# 4241.52088403034  step  32  of the epoch  0 the steps is:  32
# 4041.223167996086  step  33  of the epoch  0 the steps is:  33
# [3836.53030448]  step  34  of the epoch  0 the steps is:  34
# [3547.80648836]  step  35  of the epoch  0 the steps is:  35
# 3155.6226052465818  step  36  of the epoch  0 the steps is:  36
# 2660.4758137006693  step  37  of the epoch  0 the steps is:  37
# 2067.58763446924  step  38  of the epoch  0 the steps is:  38
# 1361.8827570710869  step  39  of the epoch  0 the steps is:  39
# 696.2602277592234  step  40  of the epoch  0 the steps is:  40
# 710.961011216623  step  41  of the epoch  0 the steps is:  41
# 812.2743645840178  step  42  of the epoch  0 the steps is:  42
# 934.8644290792246  step  43  of the epoch  0 the steps is:  43
# 1033.203922774076  step  44  of the epoch  0 the steps is:  44
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in power
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in cosh
# 1102.7279503702403  step  45  of the epoch  0 the steps is:  45
# 1197.5427730290612  step  46  of the epoch  0 the steps is:  46
# 1254.399922930556  step  47  of the epoch  0 the steps is:  47
# 1312.0689385552864  step  48  of the epoch  0 the steps is:  48
# 1354.1571481803733  step  49  of the epoch  0 the steps is:  49
# 1367.8669196496994  step  50  of the epoch  0 the steps is:  50
# [1348.13462961]  step  51  of the epoch  0 the steps is:  51
# 1376.1492552071006  step  52  of the epoch  0 the steps is:  52
# 1356.6034537248365  step  53  of the epoch  0 the steps is:  53
# 1368.803641021566  step  54  of the epoch  0 the steps is:  54
# 1354.7331270597356  step  55  of the epoch  0 the steps is:  55
# 1335.1303069471555  step  56  of the epoch  0 the steps is:  56
# [1250.1191282]  step  57  of the epoch  0 the steps is:  57
# 1239.727844042902  step  58  of the epoch  0 the steps is:  58
# [1185.27426674]  step  59  of the epoch  0 the steps is:  59
# 1150.222591203722  step  60  of the epoch  0 the steps is:  60
# 1119.3382107324646  step  61  of the epoch  0 the steps is:  61
# [1071.84294925]  step  62  of the epoch  0 the steps is:  62
# [1012.79506544]  step  63  of the epoch  0 the steps is:  63
# 980.6433790277681  step  64  of the epoch  0 the steps is:  64
# 927.0995457282363  step  65  of the epoch  0 the steps is:  65
# 873.1238739267164  step  66  of the epoch  0 the steps is:  66
# [816.95066002]  step  67  of the epoch  0 the steps is:  67
# [795.39611511]  step  68  of the epoch  0 the steps is:  68
# [738.08003223]  step  69  of the epoch  0 the steps is:  69
# 703.8212928059045  step  70  of the epoch  0 the steps is:  70
# 683.7086597980829  step  71  of the epoch  0 the steps is:  71
# 712.0910727181582  step  72  of the epoch  0 the steps is:  72
# [724.41058781]  step  73  of the epoch  0 the steps is:  73
# 739.2937102917908  step  74  of the epoch  0 the steps is:  74
# 753.7658620989614  step  75  of the epoch  0 the steps is:  75
# 707.341456380603  step  76  of the epoch  0 the steps is:  76
# 705.685554151727  step  77  of the epoch  0 the steps is:  77
# 669.6741111159149  step  78  of the epoch  0 the steps is:  78
# [669.75909965]  step  79  of the epoch  0 the steps is:  79
# [665.27678866]  step  80  of the epoch  0 the steps is:  80
# 664.1009777361388  step  81  of the epoch  0 the steps is:  81
# 672.3053024821431  step  82  of the epoch  0 the steps is:  82
# 676.9620287965743  step  83  of the epoch  0 the steps is:  83
# 685.5004435090418  step  84  of the epoch  0 the steps is:  84
# 682.2580780287071  step  85  of the epoch  0 the steps is:  85
# [685.71124649]  step  86  of the epoch  0 the steps is:  86
# 674.1232495329875  step  87  of the epoch  0 the steps is:  87
# [679.73873053]  step  88  of the epoch  0 the steps is:  88
# [692.9334017]  step  89  of the epoch  0 the steps is:  89
# 679.5587093249699  step  90  of the epoch  0 the steps is:  90
# 663.3444532270289  step  91  of the epoch  0 the steps is:  91
# 660.871985940673  step  92  of the epoch  0 the steps is:  92
# [668.30021915]  step  93  of the epoch  0 the steps is:  93
# 656.2034825000765  step  94  of the epoch  0 the steps is:  94
# 639.7460520496584  step  95  of the epoch  0 the steps is:  95
# 647.5365277674366  step  96  of the epoch  0 the steps is:  96
# [638.89964765]  step  97  of the epoch  0 the steps is:  97
# 627.6037691237834  step  98  of the epoch  0 the steps is:  98
# 639.7619051507991  step  99  of the epoch  0 the steps is:  99
# [646.0438515]  step  100  of the epoch  0 the steps is:  100
# 643.6052941425799  step  101  of the epoch  0 the steps is:  101
# [640.77202107]  step  102  of the epoch  0 the steps is:  102
# 617.585772900863  step  103  of the epoch  0 the steps is:  103
# 637.8239482545368  step  104  of the epoch  0 the steps is:  104
# 622.3814245225842  step  105  of the epoch  0 the steps is:  105
# [643.90896919]  step  106  of the epoch  0 the steps is:  106
# 630.2991190877109  step  107  of the epoch  0 the steps is:  107
# 620.2293413843328  step  108  of the epoch  0 the steps is:  108
# 615.7274273928588  step  109  of the epoch  0 the steps is:  109
# 614.6557521660768  step  110  of the epoch  0 the steps is:  110
# [635.64442644]  step  111  of the epoch  0 the steps is:  111
# 608.4695453235479  step  112  of the epoch  0 the steps is:  112
# [648.46357098]  step  113  of the epoch  0 the steps is:  113
# [613.20052946]  step  114  of the epoch  0 the steps is:  114
# 612.1510999550547  step  115  of the epoch  0 the steps is:  115
# 605.1402323707052  step  116  of the epoch  0 the steps is:  116
# 620.879062322847  step  117  of the epoch  0 the steps is:  117
# 609.0582262817832  step  118  of the epoch  0 the steps is:  118
# 610.9997982451048  step  119  of the epoch  0 the steps is:  119
# [615.49281326]  step  120  of the epoch  0 the steps is:  120
# [619.3864318]  step  121  of the epoch  0 the steps is:  121
# 606.2347872492915  step  122  of the epoch  0 the steps is:  122
# 615.3527946759685  step  123  of the epoch  0 the steps is:  123
# 615.6437478306418  step  124  of the epoch  0 the steps is:  124
# 603.7623065281894  step  125  of the epoch  0 the steps is:  125
# [641.44113323]  step  126  of the epoch  0 the steps is:  126
# 610.413094621053  step  127  of the epoch  0 the steps is:  127
# [614.55032512]  step  128  of the epoch  0 the steps is:  128
# 610.0644733442067  step  129  of the epoch  0 the steps is:  129
# 607.9875549295141  step  130  of the epoch  0 the steps is:  130
# 606.3015121413998  step  131  of the epoch  0 the steps is:  131
# 600.2989638740091  step  132  of the epoch  0 the steps is:  132
# 603.3197427721982  step  133  of the epoch  0 the steps is:  133
# [602.84575319]  step  134  of the epoch  0 the steps is:  134
# 618.2253859841231  step  135  of the epoch  0 the steps is:  135
# 598.6824800914184  step  136  of the epoch  0 the steps is:  136
# [606.89845355]  step  137  of the epoch  0 the steps is:  137
# 595.8586789963608  step  138  of the epoch  0 the steps is:  138
# [609.27564369]  step  139  of the epoch  0 the steps is:  139
# [602.2484272]  step  140  of the epoch  0 the steps is:  140
# 599.9336998951225  step  141  of the epoch  0 the steps is:  141
# [609.10548063]  step  142  of the epoch  0 the steps is:  142
# 592.9900522009398  step  143  of the epoch  0 the steps is:  143
# [599.46821576]  step  144  of the epoch  0 the steps is:  144
# 593.3706849007942  step  145  of the epoch  0 the steps is:  145
# 589.4583018711053  step  146  of the epoch  0 the steps is:  146
# [598.31441045]  step  147  of the epoch  0 the steps is:  147
# 593.2954297888645  step  148  of the epoch  0 the steps is:  148
# [591.93656402]  step  149  of the epoch  0 the steps is:  149
# 591.2599007033364  step  150  of the epoch  0 the steps is:  150
# [592.34773137]  step  151  of the epoch  0 the steps is:  151
# 586.0240471679167  step  152  of the epoch  0 the steps is:  152
# 590.4683014760569  step  153  of the epoch  0 the steps is:  153
# 583.5147926882274  step  154  of the epoch  0 the steps is:  154
# 586.9633706033301  step  155  of the epoch  0 the steps is:  155
# [595.93370436]  step  156  of the epoch  0 the steps is:  156
# [585.09782575]  step  157  of the epoch  0 the steps is:  157
# 586.8747771172493  step  158  of the epoch  0 the steps is:  158
# 584.2003153847569  step  159  of the epoch  0 the steps is:  159
# 580.8551725264385  step  160  of the epoch  0 the steps is:  160
# 581.0617191214031  step  161  of the epoch  0 the steps is:  161
# 581.3310552547617  step  162  of the epoch  0 the steps is:  162
# 581.147890151185  step  163  of the epoch  0 the steps is:  163
# 574.9515587898709  step  164  of the epoch  0 the steps is:  164
# 582.6109151516523  step  165  of the epoch  0 the steps is:  165
# 577.3481074794834  step  166  of the epoch  0 the steps is:  166
# 582.0658389456537  step  167  of the epoch  0 the steps is:  167
# [586.16659351]  step  168  of the epoch  0 the steps is:  168
# 578.9788824332888  step  169  of the epoch  0 the steps is:  169
# [583.8558233]  step  170  of the epoch  0 the steps is:  170
# 576.7799841113315  step  171  of the epoch  0 the steps is:  171
# 578.046338542413  step  172  of the epoch  0 the steps is:  172
# [585.34911066]  step  173  of the epoch  0 the steps is:  173
# 576.4715272124399  step  174  of the epoch  0 the steps is:  174
# 572.7541576540107  step  175  of the epoch  0 the steps is:  175
# 575.6843207398547  step  176  of the epoch  0 the steps is:  176
# [583.06491016]  step  177  of the epoch  0 the steps is:  177
# 577.2961825821194  step  178  of the epoch  0 the steps is:  178
# [576.21120689]  step  179  of the epoch  0 the steps is:  179
# 572.2568717115391  step  180  of the epoch  0 the steps is:  180
# [574.5187187]  step  181  of the epoch  0 the steps is:  181
# 570.0705485164473  step  182  of the epoch  0 the steps is:  182
# 568.6593722462082  step  183  of the epoch  0 the steps is:  183
# [571.96296536]  step  184  of the epoch  0 the steps is:  184
# 567.7031996100565  step  185  of the epoch  0 the steps is:  185
# 569.7295575042629  step  186  of the epoch  0 the steps is:  186
# 568.5541530622559  step  187  of the epoch  0 the steps is:  187
# 572.256295844204  step  188  of the epoch  0 the steps is:  188
# [565.01608373]  step  189  of the epoch  0 the steps is:  189
# 568.8162030097633  step  190  of the epoch  0 the steps is:  190
# 573.2621617071914  step  191  of the epoch  0 the steps is:  191
# 568.2835301969869  step  192  of the epoch  0 the steps is:  192
# 566.549301714977  step  193  of the epoch  0 the steps is:  193
# 565.4858753383876  step  194  of the epoch  0 the steps is:  194
# [574.18268659]  step  195  of the epoch  0 the steps is:  195
# 565.4076344983018  step  196  of the epoch  0 the steps is:  196
# [564.51897589]  step  197  of the epoch  0 the steps is:  197
# [564.76516364]  step  198  of the epoch  0 the steps is:  198
# [563.61561054]  step  199  of the epoch  0 the steps is:  199
# 565.3763940824842  step  200  of the epoch  0 the steps is:  200
# 566.29145635478  step  201  of the epoch  0 the steps is:  201
# [562.32700339]  step  202  of the epoch  0 the steps is:  202
# 565.8320067957125  step  203  of the epoch  0 the steps is:  203
# [559.8352287]  step  204  of the epoch  0 the steps is:  204
# [564.17914996]  step  205  of the epoch  0 the steps is:  205
# 561.3904448886688  step  206  of the epoch  0 the steps is:  206
# 560.0372707117795  step  207  of the epoch  0 the steps is:  207
# [558.84154494]  step  208  of the epoch  0 the steps is:  208
# 564.4553159740617  step  209  of the epoch  0 the steps is:  209
# 560.5780042173158  step  210  of the epoch  0 the steps is:  210
# [553.39213222]  step  211  of the epoch  0 the steps is:  211
# 560.9541712541821  step  212  of the epoch  0 the steps is:  212
# [557.71694545]  step  213  of the epoch  0 the steps is:  213
# 558.2250559349466  step  214  of the epoch  0 the steps is:  214
# 555.788371264342  step  215  of the epoch  0 the steps is:  215
# 556.0857131493476  step  216  of the epoch  0 the steps is:  216
# 557.4190449789799  step  217  of the epoch  0 the steps is:  217
# 556.3544154896383  step  218  of the epoch  0 the steps is:  218
# 554.8430398593398  step  219  of the epoch  0 the steps is:  219
# 562.698011820266  step  220  of the epoch  0 the steps is:  220
# 553.8884182538704  step  221  of the epoch  0 the steps is:  221
# 552.3554666821176  step  222  of the epoch  0 the steps is:  222
# 553.5760251851135  step  223  of the epoch  0 the steps is:  223
# 552.0490287146984  step  224  of the epoch  0 the steps is:  224
# 554.2302926195283  step  225  of the epoch  0 the steps is:  225
# 552.3147471368845  step  226  of the epoch  0 the steps is:  226
# 550.4977432780238  step  227  of the epoch  0 the steps is:  227
# 550.764875905391  step  228  of the epoch  0 the steps is:  228
# 552.2877750279943  step  229  of the epoch  0 the steps is:  229
# 551.6733578761011  step  230  of the epoch  0 the steps is:  230
# [551.93019028]  step  231  of the epoch  0 the steps is:  231
# 551.9978791467241  step  232  of the epoch  0 the steps is:  232
# 552.8851062626425  step  233  of the epoch  0 the steps is:  233
# 552.3570348041717  step  234  of the epoch  0 the steps is:  234
# 552.3059692716929  step  235  of the epoch  0 the steps is:  235
# [550.10901114]  step  236  of the epoch  0 the steps is:  236
# [545.71369662]  step  237  of the epoch  0 the steps is:  237
# 550.0253581812035  step  238  of the epoch  0 the steps is:  238
# 551.028620885103  step  239  of the epoch  0 the steps is:  239
# 550.7558028646093  step  240  of the epoch  0 the steps is:  240
# [547.01794447]  step  241  of the epoch  0 the steps is:  241
# 550.945044424039  step  242  of the epoch  0 the steps is:  242
# [546.10967864]  step  243  of the epoch  0 the steps is:  243
# 550.0702568307879  step  244  of the epoch  0 the steps is:  244
# [543.00153871]  step  245  of the epoch  0 the steps is:  245
# 548.8639992297512  step  246  of the epoch  0 the steps is:  246
# 549.7654313335015  step  247  of the epoch  0 the steps is:  247
# 549.2507520576174  step  248  of the epoch  0 the steps is:  248
# [544.60477865]  step  249  of the epoch  0 the steps is:  249
# [541.40759402]  step  250  of the epoch  0 the steps is:  250
# 549.3679765122035  step  251  of the epoch  0 the steps is:  251
# [543.43935149]  step  252  of the epoch  0 the steps is:  252
# [543.34057421]  step  253  of the epoch  0 the steps is:  253
# 547.686013280244  step  254  of the epoch  0 the steps is:  254
# 546.7039291475598  step  255  of the epoch  0 the steps is:  255
# 548.2952312851962  step  256  of the epoch  0 the steps is:  256
# 548.6402454915125  step  257  of the epoch  0 the steps is:  257
# [543.28667928]  step  258  of the epoch  0 the steps is:  258
# 546.9030344637147  step  259  of the epoch  0 the steps is:  259
# 546.245474933583  step  260  of the epoch  0 the steps is:  260
# [542.7289823]  step  261  of the epoch  0 the steps is:  261
# [541.39979931]  step  262  of the epoch  0 the steps is:  262
# [542.37664868]  step  263  of the epoch  0 the steps is:  263
# 549.5269042837042  step  264  of the epoch  0 the steps is:  264
# 545.5617629511562  step  265  of the epoch  0 the steps is:  265
# [541.28492293]  step  266  of the epoch  0 the steps is:  266
# 545.9073475863854  step  267  of the epoch  0 the steps is:  267
# [539.58917011]  step  268  of the epoch  0 the steps is:  268
# 547.057675219964  step  269  of the epoch  0 the steps is:  269
# [542.63830987]  step  270  of the epoch  0 the steps is:  270
# [542.67939386]  step  271  of the epoch  0 the steps is:  271
# 545.4067259761202  step  272  of the epoch  0 the steps is:  272
# [535.78107717]  step  273  of the epoch  0 the steps is:  273
# [536.35046084]  step  274  of the epoch  0 the steps is:  274
# 545.4684765569975  step  275  of the epoch  0 the steps is:  275
# 545.698552802188  step  276  of the epoch  0 the steps is:  276
# [541.89663421]  step  277  of the epoch  0 the steps is:  277
# [538.26103799]  step  278  of the epoch  0 the steps is:  278
# 545.0973314457067  step  279  of the epoch  0 the steps is:  279
# [540.78019605]  step  280  of the epoch  0 the steps is:  280
# 543.3169047293388  step  281  of the epoch  0 the steps is:  281
# [542.1803205]  step  282  of the epoch  0 the steps is:  282
# 542.8865757071828  step  283  of the epoch  0 the steps is:  283
# 543.2879678037903  step  284  of the epoch  0 the steps is:  284
# [539.93560615]  step  285  of the epoch  0 the steps is:  285
# 544.2143173524152  step  286  of the epoch  0 the steps is:  286
# 542.4008417071602  step  287  of the epoch  0 the steps is:  287
# [538.76731248]  step  288  of the epoch  0 the steps is:  288
# 543.1420728473597  step  289  of the epoch  0 the steps is:  289
# 544.811987779136  step  290  of the epoch  0 the steps is:  290
# [538.60613782]  step  291  of the epoch  0 the steps is:  291
# 543.6917614205046  step  292  of the epoch  0 the steps is:  292
# 545.0926915910017  step  293  of the epoch  0 the steps is:  293
# [539.48066244]  step  294  of the epoch  0 the steps is:  294
# [534.3684132]  step  295  of the epoch  0 the steps is:  295
# [537.56095696]  step  296  of the epoch  0 the steps is:  296
# 541.7546185682585  step  297  of the epoch  0 the steps is:  297
# 542.8912039810673  step  298  of the epoch  0 the steps is:  298
# 541.6673389656405  step  299  of the epoch  0 the steps is:  299
# [536.63188418]  step  300  of the epoch  0 the steps is:  300
# 540.0809625747352  step  301  of the epoch  0 the steps is:  301
# [538.25819493]  step  302  of the epoch  0 the steps is:  302
# 543.1913716097758  step  303  of the epoch  0 the steps is:  303
# 542.5468439457546  step  304  of the epoch  0 the steps is:  304
# [538.37312865]  step  305  of the epoch  0 the steps is:  305
# [536.1913849]  step  306  of the epoch  0 the steps is:  306
# 541.2585291746753  step  307  of the epoch  0 the steps is:  307
# [536.45733967]  step  308  of the epoch  0 the steps is:  308
# [539.31639744]  step  309  of the epoch  0 the steps is:  309
# 542.8975455423324  step  310  of the epoch  0 the steps is:  310
# 540.1114927007934  step  311  of the epoch  0 the steps is:  311
# 542.0532674959958  step  312  of the epoch  0 the steps is:  312
# 539.8421572787634  step  313  of the epoch  0 the steps is:  313
# [538.17599598]  step  314  of the epoch  0 the steps is:  314
# 539.6408342732965  step  315  of the epoch  0 the steps is:  315
# 541.0052507134532  step  316  of the epoch  0 the steps is:  316
# 538.6356064663788  step  317  of the epoch  0 the steps is:  317
# 540.7728116297334  step  318  of the epoch  0 the steps is:  318
# 538.981438168865  step  319  of the epoch  0 the steps is:  319
# 541.8032526394813  step  320  of the epoch  0 the steps is:  320
# 540.8198162627139  step  321  of the epoch  0 the steps is:  321
# 539.5381034804451  step  322  of the epoch  0 the steps is:  322
# 541.4164027793857  step  323  of the epoch  0 the steps is:  323
# [537.03389523]  step  324  of the epoch  0 the steps is:  324
# 541.2367758074982  step  325  of the epoch  0 the steps is:  325
# 540.407885362969  step  326  of the epoch  0 the steps is:  326
# [534.85752408]  step  327  of the epoch  0 the steps is:  327
# 538.1152185777626  step  328  of the epoch  0 the steps is:  328
# [534.6743121]  step  329  of the epoch  0 the steps is:  329
# 540.5701455423982  step  330  of the epoch  0 the steps is:  330
# [529.2658905]  step  331  of the epoch  0 the steps is:  331
# 539.0244753766546  step  332  of the epoch  0 the steps is:  332
# 539.677648282882  step  333  of the epoch  0 the steps is:  333
# 538.8159738263132  step  334  of the epoch  0 the steps is:  334
# 538.7112676681782  step  335  of the epoch  0 the steps is:  335
# [535.0271627]  step  336  of the epoch  0 the steps is:  336
# [529.77087732]  step  337  of the epoch  0 the steps is:  337
# 540.3084906171554  step  338  of the epoch  0 the steps is:  338
# [533.17306843]  step  339  of the epoch  0 the steps is:  339
# [535.38868912]  step  340  of the epoch  0 the steps is:  340
# 540.1556306234265  step  341  of the epoch  0 the steps is:  341
# [532.66168991]  step  342  of the epoch  0 the steps is:  342
# 540.5993290352988  step  343  of the epoch  0 the steps is:  343
# 537.59219687482  step  344  of the epoch  0 the steps is:  344
# [533.65641704]  step  345  of the epoch  0 the steps is:  345
# 540.6371970611353  step  346  of the epoch  0 the steps is:  346
# 535.5762068079019  step  347  of the epoch  0 the steps is:  347
# 535.7882362692075  step  348  of the epoch  0 the steps is:  348
# [535.02101474]  step  349  of the epoch  0 the steps is:  349
# 533.1867095866435  step  350  of the epoch  0 the steps is:  350
# 540.2715682778701  step  351  of the epoch  0 the steps is:  351
# 534.535500887491  step  352  of the epoch  0 the steps is:  352
# [525.41103987]  step  353  of the epoch  0 the steps is:  353
# 534.265582437197  step  354  of the epoch  0 the steps is:  354
# 533.2052922972755  step  355  of the epoch  0 the steps is:  355
# 534.9057973323659  step  356  of the epoch  0 the steps is:  356
# [533.04068055]  step  357  of the epoch  0 the steps is:  357
# 536.9977142205536  step  358  of the epoch  0 the steps is:  358
# [525.87123359]  step  359  of the epoch  0 the steps is:  359
# 530.6509597102486  step  360  of the epoch  0 the steps is:  360
# [533.06382834]  step  361  of the epoch  0 the steps is:  361
# 536.9414181028809  step  362  of the epoch  0 the steps is:  362
# 538.1127350706065  step  363  of the epoch  0 the steps is:  363
# [532.76722422]  step  364  of the epoch  0 the steps is:  364
# [532.40999737]  step  365  of the epoch  0 the steps is:  365
# [522.75389381]  step  366  of the epoch  0 the steps is:  366
# [529.83112038]  step  367  of the epoch  0 the steps is:  367
# 530.810662101959  step  368  of the epoch  0 the steps is:  368
# 538.0624448612405  step  369  of the epoch  0 the steps is:  369
# 530.5403509906946  step  370  of the epoch  0 the steps is:  370
# 540.4414341688891  step  371  of the epoch  0 the steps is:  371
# 537.8893212350914  step  372  of the epoch  0 the steps is:  372
# 533.5207204625372  step  373  of the epoch  0 the steps is:  373
# 533.5207459453429  step  374  of the epoch  0 the steps is:  374
# [516.86572247]  step  375  of the epoch  0 the steps is:  375
# [530.1892294]  step  376  of the epoch  0 the steps is:  376
# 532.3099579256693  step  377  of the epoch  0 the steps is:  377
# 534.2341964494501  step  378  of the epoch  0 the steps is:  378
# 532.055046624891  step  379  of the epoch  0 the steps is:  379
# 531.8060205810859  step  380  of the epoch  0 the steps is:  380
# 537.932656519585  step  381  of the epoch  0 the steps is:  381
# 532.838363686883  step  382  of the epoch  0 the steps is:  382
# 532.3916166909346  step  383  of the epoch  0 the steps is:  383
# [528.81498599]  step  384  of the epoch  0 the steps is:  384
# 531.4013202812368  step  385  of the epoch  0 the steps is:  385
# [530.44619222]  step  386  of the epoch  0 the steps is:  386
# 530.7792071104353  step  387  of the epoch  0 the steps is:  387
# [525.55625255]  step  388  of the epoch  0 the steps is:  388
# 530.9817785675659  step  389  of the epoch  0 the steps is:  389
# 524.9033184037784  step  390  of the epoch  0 the steps is:  390
# [526.92909044]  step  391  of the epoch  0 the steps is:  391
# 532.6830017356641  step  392  of the epoch  0 the steps is:  392
# 534.2491860015638  step  393  of the epoch  0 the steps is:  393
# 538.7066211616175  step  394  of the epoch  0 the steps is:  394
# 532.1776749357259  step  395  of the epoch  0 the steps is:  395
# [525.35753382]  step  396  of the epoch  0 the steps is:  396
# 526.6320944999297  step  397  of the epoch  0 the steps is:  397
# 526.6672917712806  step  398  of the epoch  0 the steps is:  398
# 531.1463026896665  step  399  of the epoch  0 the steps is:  399
# [527.68307118]  step  400  of the epoch  0 the steps is:  400
# [518.97418993]  step  401  of the epoch  0 the steps is:  401
# 524.0942956767581  step  402  of the epoch  0 the steps is:  402
# 532.8914460294675  step  403  of the epoch  0 the steps is:  403
# 528.389487635762  step  404  of the epoch  0 the steps is:  404
# 535.8781644657383  step  405  of the epoch  0 the steps is:  405
# [532.40633287]  step  406  of the epoch  0 the steps is:  406
# 532.9867737547431  step  407  of the epoch  0 the steps is:  407
# [525.51838054]  step  408  of the epoch  0 the steps is:  408
# 533.2843588335613  step  409  of the epoch  0 the steps is:  409
# 531.5639780994661  step  410  of the epoch  0 the steps is:  410
# [526.56501342]  step  411  of the epoch  0 the steps is:  411
# 529.4299501850933  step  412  of the epoch  0 the steps is:  412
# [520.94236772]  step  413  of the epoch  0 the steps is:  413
# 528.4088812774689  step  414  of the epoch  0 the steps is:  414
# 530.109214436382  step  415  of the epoch  0 the steps is:  415
# 525.7588666707637  step  416  of the epoch  0 the steps is:  416
# 524.3704197943101  step  417  of the epoch  0 the steps is:  417
# [519.8653507]  step  418  of the epoch  0 the steps is:  418
# 519.6405788046211  step  419  of the epoch  0 the steps is:  419
# 524.6385096282382  step  420  of the epoch  0 the steps is:  420
# 526.558987985388  step  421  of the epoch  0 the steps is:  421
# 525.6232619602938  step  422  of the epoch  0 the steps is:  422
# 526.9217843155761  step  423  of the epoch  0 the steps is:  423
# 516.3208659626789  step  424  of the epoch  0 the steps is:  424
# [524.83157062]  step  425  of the epoch  0 the steps is:  425
# 527.4214973879618  step  426  of the epoch  0 the steps is:  426
# [520.25039439]  step  427  of the epoch  0 the steps is:  427
# [514.62141752]  step  428  of the epoch  0 the steps is:  428
# 525.5363064254244  step  429  of the epoch  0 the steps is:  429
# [518.22971933]  step  430  of the epoch  0 the steps is:  430
# [523.59388738]  step  431  of the epoch  0 the steps is:  431
# [518.39824913]  step  432  of the epoch  0 the steps is:  432
# [519.444534]  step  433  of the epoch  0 the steps is:  433
# 517.0077687261472  step  434  of the epoch  0 the steps is:  434
# 529.330042269323  step  435  of the epoch  0 the steps is:  435
# 529.5376799928083  step  436  of the epoch  0 the steps is:  436
# [518.83564505]  step  437  of the epoch  0 the steps is:  437
# 519.5626204769433  step  438  of the epoch  0 the steps is:  438
# 526.2854964554624  step  439  of the epoch  0 the steps is:  439
# 516.9612237834181  step  440  of the epoch  0 the steps is:  440
# 528.7542122066486  step  441  of the epoch  0 the steps is:  441
# 525.4891136183112  step  442  of the epoch  0 the steps is:  442
# 523.88572764471  step  443  of the epoch  0 the steps is:  443
# [500.68810207]  step  444  of the epoch  0 the steps is:  444
# [511.78617268]  step  445  of the epoch  0 the steps is:  445
# 518.3733251309029  step  446  of the epoch  0 the steps is:  446
# 524.7525409868222  step  447  of the epoch  0 the steps is:  447
# 526.2686273288788  step  448  of the epoch  0 the steps is:  448
# [508.61174728]  step  449  of the epoch  0 the steps is:  449
# 522.1228855151405  step  450  of the epoch  0 the steps is:  450
# [512.44666972]  step  451  of the epoch  0 the steps is:  451
# [521.23467239]  step  452  of the epoch  0 the steps is:  452
# [521.45529077]  step  453  of the epoch  0 the steps is:  453
# 515.3367881808779  step  454  of the epoch  0 the steps is:  454
# [523.78422901]  step  455  of the epoch  0 the steps is:  455
# 517.9064952044827  step  456  of the epoch  0 the steps is:  456
# 515.2057248920844  step  457  of the epoch  0 the steps is:  457
# 511.8931745964582  step  458  of the epoch  0 the steps is:  458
# 513.3085783146159  step  459  of the epoch  0 the steps is:  459
# 512.2647128138588  step  460  of the epoch  0 the steps is:  460
# 518.9774992967629  step  461  of the epoch  0 the steps is:  461
# 515.8786989191731  step  462  of the epoch  0 the steps is:  462
# 514.8583589523005  step  463  of the epoch  0 the steps is:  463
# 520.6369570438476  step  464  of the epoch  0 the steps is:  464
# [519.83166197]  step  465  of the epoch  0 the steps is:  465
# [509.08345708]  step  466  of the epoch  0 the steps is:  466
# 520.850740258879  step  467  of the epoch  0 the steps is:  467
# 507.59417453679464  step  468  of the epoch  0 the steps is:  468
# [499.59055633]  step  469  of the epoch  0 the steps is:  469
# 520.6013828105121  step  470  of the epoch  0 the steps is:  470
# [503.7873783]  step  0  of the epoch  1 the steps is:  471
# 514.5966749934555  step  1  of the epoch  1 the steps is:  472
# 508.4043912858478  step  2  of the epoch  1 the steps is:  473
# 503.55352981801957  step  3  of the epoch  1 the steps is:  474
# 511.8557482679896  step  4  of the epoch  1 the steps is:  475
# 508.1281627786584  step  5  of the epoch  1 the steps is:  476
# [504.78871374]  step  6  of the epoch  1 the steps is:  477
# [492.69812046]  step  7  of the epoch  1 the steps is:  478
# [501.45334863]  step  8  of the epoch  1 the steps is:  479
# 506.4609794151694  step  9  of the epoch  1 the steps is:  480
# [510.66020132]  step  10  of the epoch  1 the steps is:  481
# 524.0612884479106  step  11  of the epoch  1 the steps is:  482
# [505.80646602]  step  12  of the epoch  1 the steps is:  483
# 505.3692717445328  step  13  of the epoch  1 the steps is:  484
# [489.1731661]  step  14  of the epoch  1 the steps is:  485
# [491.55469144]  step  15  of the epoch  1 the steps is:  486
# [508.44790445]  step  16  of the epoch  1 the steps is:  487
# 511.417977058322  step  17  of the epoch  1 the steps is:  488
# 516.6785600918045  step  18  of the epoch  1 the steps is:  489
# [501.13110034]  step  19  of the epoch  1 the steps is:  490
# 508.03056529646983  step  20  of the epoch  1 the steps is:  491
# 527.5739330674802  step  21  of the epoch  1 the steps is:  492
# [500.98772033]  step  22  of the epoch  1 the steps is:  493
# 505.7404345398777  step  23  of the epoch  1 the steps is:  494
# 517.3541572036307  step  24  of the epoch  1 the steps is:  495
# [496.29783535]  step  25  of the epoch  1 the steps is:  496
# [504.18337757]  step  26  of the epoch  1 the steps is:  497
# 506.6905787487827  step  27  of the epoch  1 the steps is:  498
# 515.6773289049536  step  28  of the epoch  1 the steps is:  499
# 506.1438984112569  step  29  of the epoch  1 the steps is:  500
# 491.1166875498914  step  30  of the epoch  1 the steps is:  501
# 501.95396431021567  step  31  of the epoch  1 the steps is:  502
# 501.2598176965846  step  32  of the epoch  1 the steps is:  503
# 496.7487834709789  step  33  of the epoch  1 the steps is:  504
# [502.1206454]  step  34  of the epoch  1 the steps is:  505
# [494.77153717]  step  35  of the epoch  1 the steps is:  506
# 511.91831827990063  step  36  of the epoch  1 the steps is:  507
# 490.77960221516213  step  37  of the epoch  1 the steps is:  508
# 499.27259266101873  step  38  of the epoch  1 the steps is:  509
# 484.4552902713199  step  39  of the epoch  1 the steps is:  510
# 506.6868988543382  step  40  of the epoch  1 the steps is:  511
# 511.43898282444906  step  41  of the epoch  1 the steps is:  512
# 504.9055579526771  step  42  of the epoch  1 the steps is:  513
# 492.4195776673595  step  43  of the epoch  1 the steps is:  514
# 489.4393153431022  step  44  of the epoch  1 the steps is:  515
# 480.3606034754845  step  45  of the epoch  1 the steps is:  516
# 494.28982643380175  step  46  of the epoch  1 the steps is:  517
# 474.1591425592205  step  47  of the epoch  1 the steps is:  518
# 487.7096118671202  step  48  of the epoch  1 the steps is:  519
# 498.6961552881212  step  49  of the epoch  1 the steps is:  520
# 490.80715437691015  step  50  of the epoch  1 the steps is:  521
# [491.80621372]  step  51  of the epoch  1 the steps is:  522
# 501.71259339481173  step  52  of the epoch  1 the steps is:  523
# 496.4459229423216  step  53  of the epoch  1 the steps is:  524
# 496.8844726611231  step  54  of the epoch  1 the steps is:  525
# 498.27137881380384  step  55  of the epoch  1 the steps is:  526
# 499.9213673965064  step  56  of the epoch  1 the steps is:  527
# [480.80837924]  step  57  of the epoch  1 the steps is:  528
# 505.77232940716544  step  58  of the epoch  1 the steps is:  529
# [502.5075101]  step  59  of the epoch  1 the steps is:  530
# 481.0875895873177  step  60  of the epoch  1 the steps is:  531
# 496.44337984809374  step  61  of the epoch  1 the steps is:  532
# [482.07733804]  step  62  of the epoch  1 the steps is:  533
# [463.46060848]  step  63  of the epoch  1 the steps is:  534
# 495.97909570761647  step  64  of the epoch  1 the steps is:  535
# 482.55606321054944  step  65  of the epoch  1 the steps is:  536
# 486.1376042482529  step  66  of the epoch  1 the steps is:  537
# [488.32074111]  step  67  of the epoch  1 the steps is:  538
# [480.62678575]  step  68  of the epoch  1 the steps is:  539
# [472.94914012]  step  69  of the epoch  1 the steps is:  540
# 480.9332818525478  step  70  of the epoch  1 the steps is:  541
# 499.6567177787433  step  71  of the epoch  1 the steps is:  542
# 476.90817442966005  step  72  of the epoch  1 the steps is:  543
# [502.19195549]  step  73  of the epoch  1 the steps is:  544
# 483.5871576647512  step  74  of the epoch  1 the steps is:  545
# 487.59173998577575  step  75  of the epoch  1 the steps is:  546
# 490.346805429528  step  76  of the epoch  1 the steps is:  547
# 478.9620859249169  step  77  of the epoch  1 the steps is:  548
# 439.80052128308427  step  78  of the epoch  1 the steps is:  549
# [480.58589009]  step  79  of the epoch  1 the steps is:  550
# [485.73708838]  step  80  of the epoch  1 the steps is:  551
# 475.69043467400707  step  81  of the epoch  1 the steps is:  552
# 481.55697246830726  step  82  of the epoch  1 the steps is:  553
# 469.1713307658427  step  83  of the epoch  1 the steps is:  554
# 486.26769770684473  step  84  of the epoch  1 the steps is:  555
# 476.9965357251509  step  85  of the epoch  1 the steps is:  556
# [473.41930061]  step  86  of the epoch  1 the steps is:  557
# 483.29497985469783  step  87  of the epoch  1 the steps is:  558
# [467.92250903]  step  88  of the epoch  1 the steps is:  559
# [468.5158369]  step  89  of the epoch  1 the steps is:  560
# 481.5216291447615  step  90  of the epoch  1 the steps is:  561
# 475.9886732664343  step  91  of the epoch  1 the steps is:  562
# 461.8552750555875  step  92  of the epoch  1 the steps is:  563
# [442.74527997]  step  93  of the epoch  1 the steps is:  564
# 442.22979941523636  step  94  of the epoch  1 the steps is:  565
# 453.65742090192634  step  95  of the epoch  1 the steps is:  566
# 483.46808391495006  step  96  of the epoch  1 the steps is:  567
# [463.6672476]  step  97  of the epoch  1 the steps is:  568
# 454.2623453332553  step  98  of the epoch  1 the steps is:  569
# 475.69050624280044  step  99  of the epoch  1 the steps is:  570
# [460.10135738]  step  100  of the epoch  1 the steps is:  571
# 473.05999077181895  step  101  of the epoch  1 the steps is:  572
# [470.44779264]  step  102  of the epoch  1 the steps is:  573
# 479.00629831826217  step  103  of the epoch  1 the steps is:  574
# 477.638460761533  step  104  of the epoch  1 the steps is:  575
# 475.234822210713  step  105  of the epoch  1 the steps is:  576
# [472.9711855]  step  106  of the epoch  1 the steps is:  577
# 471.1977910602024  step  107  of the epoch  1 the steps is:  578
# 432.20439441546944  step  108  of the epoch  1 the steps is:  579
# 450.29391045905726  step  109  of the epoch  1 the steps is:  580
# 456.6816344892957  step  110  of the epoch  1 the steps is:  581
# [478.1229634]  step  111  of the epoch  1 the steps is:  582
# 472.3542081820309  step  112  of the epoch  1 the steps is:  583
# [464.45383877]  step  113  of the epoch  1 the steps is:  584
# [459.9261835]  step  114  of the epoch  1 the steps is:  585
# 468.001349303574  step  115  of the epoch  1 the steps is:  586
# 459.88902009973265  step  116  of the epoch  1 the steps is:  587
# 475.5447367338313  step  117  of the epoch  1 the steps is:  588
# 466.170408989483  step  118  of the epoch  1 the steps is:  589
# 423.17359717237565  step  119  of the epoch  1 the steps is:  590
# [455.44467956]  step  120  of the epoch  1 the steps is:  591
# [453.57568837]  step  121  of the epoch  1 the steps is:  592
# 451.87930923913683  step  122  of the epoch  1 the steps is:  593
# 471.33570128098586  step  123  of the epoch  1 the steps is:  594
# 460.9646873953498  step  124  of the epoch  1 the steps is:  595
# 488.0196014665213  step  125  of the epoch  1 the steps is:  596
# [421.77706706]  step  126  of the epoch  1 the steps is:  597
# 467.17228695639466  step  127  of the epoch  1 the steps is:  598
# [459.6868479]  step  128  of the epoch  1 the steps is:  599
# 432.25538857087406  step  129  of the epoch  1 the steps is:  600
# 459.402342230851  step  130  of the epoch  1 the steps is:  601
# 451.3623701027783  step  131  of the epoch  1 the steps is:  602
# 453.7817324214982  step  132  of the epoch  1 the steps is:  603
# 455.8115069853313  step  133  of the epoch  1 the steps is:  604
# [470.63476097]  step  134  of the epoch  1 the steps is:  605
# 433.5289148158637  step  135  of the epoch  1 the steps is:  606
# 440.5580661842973  step  136  of the epoch  1 the steps is:  607
# [449.98593749]  step  137  of the epoch  1 the steps is:  608
# 450.0108447299046  step  138  of the epoch  1 the steps is:  609
# [464.61989985]  step  139  of the epoch  1 the steps is:  610
# [462.0103745]  step  140  of the epoch  1 the steps is:  611
# 450.9757099498765  step  141  of the epoch  1 the steps is:  612
# [456.44305521]  step  142  of the epoch  1 the steps is:  613
# 439.54320906634996  step  143  of the epoch  1 the steps is:  614
# [461.42648814]  step  144  of the epoch  1 the steps is:  615
# 432.6530524889284  step  145  of the epoch  1 the steps is:  616
# 464.29956311971483  step  146  of the epoch  1 the steps is:  617
# [454.17198763]  step  147  of the epoch  1 the steps is:  618
# 448.11283359030347  step  148  of the epoch  1 the steps is:  619
# [430.06629195]  step  149  of the epoch  1 the steps is:  620
# 447.493231657259  step  150  of the epoch  1 the steps is:  621
# [438.9679842]  step  151  of the epoch  1 the steps is:  622
# 415.85359465438603  step  152  of the epoch  1 the steps is:  623
# 448.30798774330145  step  153  of the epoch  1 the steps is:  624
# 453.4441641408882  step  154  of the epoch  1 the steps is:  625
# 469.3828995450024  step  155  of the epoch  1 the steps is:  626
# [425.80478338]  step  156  of the epoch  1 the steps is:  627
# [466.11289893]  step  157  of the epoch  1 the steps is:  628
# 449.31968858804504  step  158  of the epoch  1 the steps is:  629
# 458.7755134943209  step  159  of the epoch  1 the steps is:  630
# 425.3290516563789  step  160  of the epoch  1 the steps is:  631
# 453.560636464082  step  161  of the epoch  1 the steps is:  632
# 453.03843431021176  step  162  of the epoch  1 the steps is:  633
# 440.57108816112265  step  163  of the epoch  1 the steps is:  634
# 422.8253542079738  step  164  of the epoch  1 the steps is:  635
# 465.5816405118235  step  165  of the epoch  1 the steps is:  636
# 421.5253035561218  step  166  of the epoch  1 the steps is:  637
# 452.37820223747576  step  167  of the epoch  1 the steps is:  638
# [419.40634004]  step  168  of the epoch  1 the steps is:  639
# 442.49092109017135  step  169  of the epoch  1 the steps is:  640
# [444.41504356]  step  170  of the epoch  1 the steps is:  641
# 446.0923660226539  step  171  of the epoch  1 the steps is:  642
# 450.14882609547936  step  172  of the epoch  1 the steps is:  643
# [444.32661627]  step  173  of the epoch  1 the steps is:  644
# 442.16376801183617  step  174  of the epoch  1 the steps is:  645
# 455.4900678990666  step  175  of the epoch  1 the steps is:  646
# 438.3140861930857  step  176  of the epoch  1 the steps is:  647
# [437.03741527]  step  177  of the epoch  1 the steps is:  648
# 428.2157892845394  step  178  of the epoch  1 the steps is:  649
# [455.37958586]  step  179  of the epoch  1 the steps is:  650
# 450.2442337287294  step  180  of the epoch  1 the steps is:  651
# [426.02266834]  step  181  of the epoch  1 the steps is:  652
# 448.76826523380913  step  182  of the epoch  1 the steps is:  653
# 454.14439111796855  step  183  of the epoch  1 the steps is:  654
# [409.56887781]  step  184  of the epoch  1 the steps is:  655
# 450.94590320612315  step  185  of the epoch  1 the steps is:  656
# 459.4582735373392  step  186  of the epoch  1 the steps is:  657
# 455.6528077481473  step  187  of the epoch  1 the steps is:  658
# 402.9868152647739  step  188  of the epoch  1 the steps is:  659
# [414.86842191]  step  189  of the epoch  1 the steps is:  660
# 449.7174454621808  step  190  of the epoch  1 the steps is:  661
# 421.7691160922865  step  191  of the epoch  1 the steps is:  662
# 464.1563038651314  step  192  of the epoch  1 the steps is:  663
# 441.6023120973238  step  193  of the epoch  1 the steps is:  664
# 412.5647816826908  step  194  of the epoch  1 the steps is:  665
# [442.80229038]  step  195  of the epoch  1 the steps is:  666
# 425.1498419214238  step  196  of the epoch  1 the steps is:  667
# [412.96932381]  step  197  of the epoch  1 the steps is:  668
# [430.54177771]  step  198  of the epoch  1 the steps is:  669
# [425.87909266]  step  199  of the epoch  1 the steps is:  670
# 457.7954118396085  step  200  of the epoch  1 the steps is:  671
# 441.5941389540385  step  201  of the epoch  1 the steps is:  672
# [447.21467286]  step  202  of the epoch  1 the steps is:  673
# 420.1026021001535  step  203  of the epoch  1 the steps is:  674
# [445.40493972]  step  204  of the epoch  1 the steps is:  675
# [468.72110829]  step  205  of the epoch  1 the steps is:  676
# 401.2232975528597  step  206  of the epoch  1 the steps is:  677
# 416.8711997854235  step  207  of the epoch  1 the steps is:  678
# [409.90131874]  step  208  of the epoch  1 the steps is:  679
# 459.65236123027034  step  209  of the epoch  1 the steps is:  680
# 445.11375196167967  step  210  of the epoch  1 the steps is:  681
# [415.07062751]  step  211  of the epoch  1 the steps is:  682
# 461.2560240638504  step  212  of the epoch  1 the steps is:  683
# [435.86556006]  step  213  of the epoch  1 the steps is:  684
# 432.7553153912095  step  214  of the epoch  1 the steps is:  685
# 423.2382832653859  step  215  of the epoch  1 the steps is:  686
# 430.9931159471088  step  216  of the epoch  1 the steps is:  687
# 442.30715911720876  step  217  of the epoch  1 the steps is:  688
# 434.6542761732212  step  218  of the epoch  1 the steps is:  689
# 438.64401621529555  step  219  of the epoch  1 the steps is:  690
# 438.35890518693435  step  220  of the epoch  1 the steps is:  691
# 420.95346243510926  step  221  of the epoch  1 the steps is:  692
# 391.2737734952634  step  222  of the epoch  1 the steps is:  693
# 417.2169178961328  step  223  of the epoch  1 the steps is:  694
# 388.6954513212303  step  224  of the epoch  1 the steps is:  695
# 421.73471132773295  step  225  of the epoch  1 the steps is:  696
# 420.5341017425247  step  226  of the epoch  1 the steps is:  697
# 395.3446627729261  step  227  of the epoch  1 the steps is:  698
# 383.9372588049679  step  228  of the epoch  1 the steps is:  699
# 429.4350836446114  step  229  of the epoch  1 the steps is:  700
# 412.5061637182913  step  230  of the epoch  1 the steps is:  701
# [438.17077521]  step  231  of the epoch  1 the steps is:  702
# 433.36037108341554  step  232  of the epoch  1 the steps is:  703
# 458.1129182414502  step  233  of the epoch  1 the steps is:  704
# 429.40264966450434  step  234  of the epoch  1 the steps is:  705
# 431.6292371748911  step  235  of the epoch  1 the steps is:  706
# [440.89757997]  step  236  of the epoch  1 the steps is:  707
# [397.44838454]  step  237  of the epoch  1 the steps is:  708
# 407.7567945228734  step  238  of the epoch  1 the steps is:  709
# 430.2851000584175  step  239  of the epoch  1 the steps is:  710
# 431.4103019290785  step  240  of the epoch  1 the steps is:  711
# [412.32899889]  step  241  of the epoch  1 the steps is:  712
# 431.8754747461706  step  242  of the epoch  1 the steps is:  713
# [415.00484338]  step  243  of the epoch  1 the steps is:  714
# 441.55814812633594  step  244  of the epoch  1 the steps is:  715
# [408.4678524]  step  245  of the epoch  1 the steps is:  716
# 420.3671738199272  step  246  of the epoch  1 the steps is:  717
# 442.53351182991446  step  247  of the epoch  1 the steps is:  718
# 418.53731438747934  step  248  of the epoch  1 the steps is:  719
# [424.98947653]  step  249  of the epoch  1 the steps is:  720
# [397.82064467]  step  250  of the epoch  1 the steps is:  721
# 429.4199779825667  step  251  of the epoch  1 the steps is:  722
# [420.42838277]  step  252  of the epoch  1 the steps is:  723
# [416.29347861]  step  253  of the epoch  1 the steps is:  724
# 416.67638348246544  step  254  of the epoch  1 the steps is:  725
# 397.689285762349  step  255  of the epoch  1 the steps is:  726
# 433.46363542053086  step  256  of the epoch  1 the steps is:  727
# 445.8598276149138  step  257  of the epoch  1 the steps is:  728
# [419.49416175]  step  258  of the epoch  1 the steps is:  729
# 417.17981744555493  step  259  of the epoch  1 the steps is:  730
# 419.4956272575831  step  260  of the epoch  1 the steps is:  731
# [415.35079015]  step  261  of the epoch  1 the steps is:  732
# [395.49767904]  step  262  of the epoch  1 the steps is:  733
# [422.03329294]  step  263  of the epoch  1 the steps is:  734
# 489.18148194714166  step  264  of the epoch  1 the steps is:  735
# 402.08050033300486  step  265  of the epoch  1 the steps is:  736
# [401.57651316]  step  266  of the epoch  1 the steps is:  737
# 414.6931813536971  step  267  of the epoch  1 the steps is:  738
# [386.07271942]  step  268  of the epoch  1 the steps is:  739
# 427.2231485864126  step  269  of the epoch  1 the steps is:  740
# [420.61531432]  step  270  of the epoch  1 the steps is:  741
# [419.73336216]  step  271  of the epoch  1 the steps is:  742
# 405.1015936387232  step  272  of the epoch  1 the steps is:  743
# [403.48530732]  step  273  of the epoch  1 the steps is:  744
# [411.54511696]  step  274  of the epoch  1 the steps is:  745
# 426.1796658825162  step  275  of the epoch  1 the steps is:  746
# 422.8026186720781  step  276  of the epoch  1 the steps is:  747
# [420.45155413]  step  277  of the epoch  1 the steps is:  748
# [428.16049538]  step  278  of the epoch  1 the steps is:  749
# 415.90593951344397  step  279  of the epoch  1 the steps is:  750
# ...
# 308.54244694962847  step  226  of the epoch  2 the steps is:  1168
# 308.6332824390974  step  227  of the epoch  2 the steps is:  1169
# 274.80129834757315  step  228  of the epoch  2 the steps is:  1170
# 321.77731434630266  step  229  of the epoch  2 the steps is:  1171
# 286.47667647218213  step  230  of the epoch  2 the steps is:  1172
# [346.14533418]  step  231  of the epoch  2 the steps is:  1173
# 305.99985065833744  step  232  of the epoch  2 the steps is:  1174
# 349.9654677022073  step  233  of the epoch  2 the steps is:  1175
# 331.8845647182977  step  234  of the epoch  2 the steps is:  1176
# 314.0423598616607  step  235  of the epoch  2 the steps is:  1177
# [337.67927758]  step  236  of the epoch  2 the steps is:  1178
# [288.23216031]  step  237  of the epoch  2 the steps is:  1179
# 296.1297048577077  step  238  of the epoch  2 the steps is:  1180
# 322.18144626908634  step  239  of the epoch  2 the steps is:  1181
# 325.1404235010133  step  240  of the epoch  2 the steps is:  1182
# [314.4958756]  step  241  of the epoch  2 the steps is:  1183
# 307.41447755442584  step  242  of the epoch  2 the steps is:  1184
# [300.47707103]  step  243  of the epoch  2 the steps is:  1185
# 340.06784273972016  step  244  of the epoch  2 the steps is:  1186
# [293.55500776]  step  245  of the epoch  2 the steps is:  1187
# 302.8912576957309  step  246  of the epoch  2 the steps is:  1188
# 340.1791269165676  step  247  of the epoch  2 the steps is:  1189
# 315.89184257963393  step  248  of the epoch  2 the steps is:  1190
# [307.46286203]  step  249  of the epoch  2 the steps is:  1191
# [265.4541699]  step  250  of the epoch  2 the steps is:  1192
# 318.31814380927017  step  251  of the epoch  2 the steps is:  1193
# [328.10697276]  step  252  of the epoch  2 the steps is:  1194
# [299.02158105]  step  253  of the epoch  2 the steps is:  1195
# 288.85199984552844  step  254  of the epoch  2 the steps is:  1196
# 280.00171999203656  step  255  of the epoch  2 the steps is:  1197
# 347.71640515581345  step  256  of the epoch  2 the steps is:  1198
# 369.2608544106244  step  257  of the epoch  2 the steps is:  1199
# [306.80775906]  step  258  of the epoch  2 the steps is:  1200
# 303.3248759234832  step  259  of the epoch  2 the steps is:  1201
# 339.20172081719215  step  260  of the epoch  2 the steps is:  1202
# [318.2161371]  step  261  of the epoch  2 the steps is:  1203
# [274.3585964]  step  262  of the epoch  2 the steps is:  1204
# [303.14757876]  step  263  of the epoch  2 the steps is:  1205
# 418.990251363315  step  264  of the epoch  2 the steps is:  1206
# 301.0542844163796  step  265  of the epoch  2 the steps is:  1207
# [303.82081159]  step  266  of the epoch  2 the steps is:  1208
# 317.00864705578294  step  267  of the epoch  2 the steps is:  1209
# [292.56053778]  step  268  of the epoch  2 the steps is:  1210
# 320.54870378235415  step  269  of the epoch  2 the steps is:  1211
# [310.77314492]  step  270  of the epoch  2 the steps is:  1212
# [302.2067647]  step  271  of the epoch  2 the steps is:  1213
# 301.6880868316576  step  272  of the epoch  2 the steps is:  1214
# [311.70491691]  step  273  of the epoch  2 the steps is:  1215
# [321.85166647]  step  274  of the epoch  2 the steps is:  1216
# 330.7948774369214  step  275  of the epoch  2 the steps is:  1217
# 312.7773920544947  step  276  of the epoch  2 the steps is:  1218
# [311.46884257]  step  277  of the epoch  2 the steps is:  1219
# [337.21671793]  step  278  of the epoch  2 the steps is:  1220
# 333.2294593127705  step  279  of the epoch  2 the steps is:  1221
# [342.34134597]  step  280  of the epoch  2 the steps is:  1222
# 291.55750562837727  step  281  of the epoch  2 the steps is:  1223
# [337.44951177]  step  282  of the epoch  2 the steps is:  1224
# 280.91624719420906  step  283  of the epoch  2 the steps is:  1225
# 277.6238390631195  step  284  of the epoch  2 the steps is:  1226
# [313.01906627]  step  285  of the epoch  2 the steps is:  1227
# 314.04892348628846  step  286  of the epoch  2 the steps is:  1228
# 277.1905781586569  step  287  of the epoch  2 the steps is:  1229
# [304.3277218]  step  288  of the epoch  2 the steps is:  1230
# 341.6117834372666  step  289  of the epoch  2 the steps is:  1231
# 345.08271811845987  step  290  of the epoch  2 the steps is:  1232
# [321.98565025]  step  291  of the epoch  2 the steps is:  1233
# 275.9510007378442  step  292  of the epoch  2 the steps is:  1234
# 318.37531719961225  step  293  of the epoch  2 the steps is:  1235
# [317.09602401]  step  294  of the epoch  2 the steps is:  1236
# [302.43781458]  step  295  of the epoch  2 the steps is:  1237
# [255.58530236]  step  296  of the epoch  2 the steps is:  1238
# 305.9478163402831  step  297  of the epoch  2 the steps is:  1239
# 261.09250709837147  step  298  of the epoch  2 the steps is:  1240
# 287.3564267385409  step  299  of the epoch  2 the steps is:  1241
# [277.06322732]  step  300  of the epoch  2 the steps is:  1242
# 289.4085842554733  step  301  of the epoch  2 the steps is:  1243
# [303.11164425]  step  302  of the epoch  2 the steps is:  1244
# 320.78034722311975  step  303  of the epoch  2 the steps is:  1245
# 296.1124956308325  step  304  of the epoch  2 the steps is:  1246
# [290.97242061]  step  305  of the epoch  2 the steps is:  1247
# [275.05033678]  step  306  of the epoch  2 the steps is:  1248
# 307.30717218648834  step  307  of the epoch  2 the steps is:  1249
# [251.50734894]  step  308  of the epoch  2 the steps is:  1250
# [343.69033099]  step  309  of the epoch  2 the steps is:  1251
# 325.38252930293237  step  310  of the epoch  2 the steps is:  1252
# 294.92690331101653  step  311  of the epoch  2 the steps is:  1253
# 314.78745369273486  step  312  of the epoch  2 the steps is:  1254
# 294.67534568841086  step  313  of the epoch  2 the steps is:  1255
# [307.09247042]  step  314  of the epoch  2 the steps is:  1256
# 266.57949955512674  step  315  of the epoch  2 the steps is:  1257
# 275.92072132533883  step  316  of the epoch  2 the steps is:  1258
# 270.61951736663394  step  317  of the epoch  2 the steps is:  1259
# 300.588981509618  step  318  of the epoch  2 the steps is:  1260
# 292.3382559062467  step  319  of the epoch  2 the steps is:  1261
# 339.05725723400326  step  320  of the epoch  2 the steps is:  1262
# 324.3183381234485  step  321  of the epoch  2 the steps is:  1263
# 300.40442905903217  step  322  of the epoch  2 the steps is:  1264
# 306.13269766805803  step  323  of the epoch  2 the steps is:  1265
# [284.96084659]  step  324  of the epoch  2 the steps is:  1266
# 310.24655811384156  step  325  of the epoch  2 the steps is:  1267
# 259.8700989462421  step  326  of the epoch  2 the steps is:  1268
# [306.09441787]  step  327  of the epoch  2 the steps is:  1269
# 309.0082037976342  step  328  of the epoch  2 the steps is:  1270
# [302.8218369]  step  329  of the epoch  2 the steps is:  1271
# 316.8953919420762  step  330  of the epoch  2 the steps is:  1272
# [296.91614489]  step  331  of the epoch  2 the steps is:  1273
# 312.6363519503725  step  332  of the epoch  2 the steps is:  1274
# 311.301079762625  step  333  of the epoch  2 the steps is:  1275
# 293.3279063649957  step  334  of the epoch  2 the steps is:  1276
# 295.26744524546376  step  335  of the epoch  2 the steps is:  1277
# [300.96945706]  step  336  of the epoch  2 the steps is:  1278
# [230.31764964]  step  337  of the epoch  2 the steps is:  1279
# 299.3798083732547  step  338  of the epoch  2 the steps is:  1280
# [262.78159881]  step  339  of the epoch  2 the steps is:  1281
# [321.43839693]  step  340  of the epoch  2 the steps is:  1282
# 345.95820847974585  step  341  of the epoch  2 the steps is:  1283
# [299.39637122]  step  342  of the epoch  2 the steps is:  1284
# 318.92950392582253  step  343  of the epoch  2 the steps is:  1285
# 318.3351079945754  step  344  of the epoch  2 the steps is:  1286
# [264.78485722]  step  345  of the epoch  2 the steps is:  1287
# 360.0564395010951  step  346  of the epoch  2 the steps is:  1288
# 334.2801064414566  step  347  of the epoch  2 the steps is:  1289
# 312.03658648594114  step  348  of the epoch  2 the steps is:  1290
# [299.60515877]  step  349  of the epoch  2 the steps is:  1291
# 265.7625062578635  step  350  of the epoch  2 the steps is:  1292
# 337.6148084471446  step  351  of the epoch  2 the steps is:  1293
# 326.0790550235124  step  352  of the epoch  2 the steps is:  1294
# [322.76102952]  step  353  of the epoch  2 the steps is:  1295
# 254.87826145256724  step  354  of the epoch  2 the steps is:  1296
# 253.88520310166808  step  355  of the epoch  2 the steps is:  1297
# 278.2864469506124  step  356  of the epoch  2 the steps is:  1298
# [313.17739271]  step  357  of the epoch  2 the steps is:  1299
# 299.8823631203672  step  358  of the epoch  2 the steps is:  1300
# [344.46152946]  step  359  of the epoch  2 the steps is:  1301
# 259.52659858038754  step  360  of the epoch  2 the steps is:  1302
# [310.11140089]  step  361  of the epoch  2 the steps is:  1303
# 323.2250748818192  step  362  of the epoch  2 the steps is:  1304
# 314.98713913079274  step  363  of the epoch  2 the steps is:  1305
# [307.62873585]  step  364  of the epoch  2 the steps is:  1306
# [317.35841726]  step  365  of the epoch  2 the steps is:  1307
# [341.63519536]  step  366  of the epoch  2 the steps is:  1308
# [273.40947081]  step  367  of the epoch  2 the steps is:  1309
# 279.33466901053157  step  368  of the epoch  2 the steps is:  1310
# 319.6365741622723  step  369  of the epoch  2 the steps is:  1311
# 280.18115764019166  step  370  of the epoch  2 the steps is:  1312
# 335.4801828541392  step  371  of the epoch  2 the steps is:  1313
# 318.81374424379084  step  372  of the epoch  2 the steps is:  1314
# 304.91275311089635  step  373  of the epoch  2 the steps is:  1315
# 295.8375003925943  step  374  of the epoch  2 the steps is:  1316
# [315.18904415]  step  375  of the epoch  2 the steps is:  1317
# [306.22305132]  step  376  of the epoch  2 the steps is:  1318
# 291.60751470435014  step  377  of the epoch  2 the steps is:  1319
# 320.567562862507  step  378  of the epoch  2 the steps is:  1320
# 340.2463012281624  step  379  of the epoch  2 the steps is:  1321
# 279.52287375185625  step  380  of the epoch  2 the steps is:  1322
# 345.1951127290764  step  381  of the epoch  2 the steps is:  1323
# 270.8800750232469  step  382  of the epoch  2 the steps is:  1324
# 283.8126736301864  step  383  of the epoch  2 the steps is:  1325
# [295.46044902]  step  384  of the epoch  2 the steps is:  1326
# 273.2144140474703  step  385  of the epoch  2 the steps is:  1327
# [339.94850826]  step  386  of the epoch  2 the steps is:  1328
# 302.54239664971783  step  387  of the epoch  2 the steps is:  1329
# [280.39402589]  step  388  of the epoch  2 the steps is:  1330
# 290.49361100484975  step  389  of the epoch  2 the steps is:  1331
# 304.22215969044856  step  390  of the epoch  2 the steps is:  1332
# [300.81244367]  step  391  of the epoch  2 the steps is:  1333
# 319.17010879818383  step  392  of the epoch  2 the steps is:  1334
# 316.46540943539344  step  393  of the epoch  2 the steps is:  1335
# 356.6258154241434  step  394  of the epoch  2 the steps is:  1336
# 314.2711978909009  step  395  of the epoch  2 the steps is:  1337
# [294.19120964]  step  396  of the epoch  2 the steps is:  1338
# 269.2378216649844  step  397  of the epoch  2 the steps is:  1339
# 281.765180518136  step  398  of the epoch  2 the steps is:  1340
# 285.2459533883957  step  399  of the epoch  2 the steps is:  1341
# [307.12047221]  step  400  of the epoch  2 the steps is:  1342
# [288.4153591]  step  401  of the epoch  2 the steps is:  1343
# 281.71205952309765  step  402  of the epoch  2 the steps is:  1344
# 314.77561748963547  step  403  of the epoch  2 the steps is:  1345
# 310.7953291019506  step  404  of the epoch  2 the steps is:  1346
# 328.59205863460807  step  405  of the epoch  2 the steps is:  1347
# [302.18688708]  step  406  of the epoch  2 the steps is:  1348
# 277.4403615070529  step  407  of the epoch  2 the steps is:  1349
# [286.42739204]  step  408  of the epoch  2 the steps is:  1350
# 356.6644864457139  step  409  of the epoch  2 the steps is:  1351
# 326.7200009038013  step  410  of the epoch  2 the steps is:  1352
# [324.84267658]  step  411  of the epoch  2 the steps is:  1353
# 303.3499051143069  step  412  of the epoch  2 the steps is:  1354
# [328.08961855]  step  413  of the epoch  2 the steps is:  1355
# 313.4065827571494  step  414  of the epoch  2 the steps is:  1356
# 312.0443119048015  step  415  of the epoch  2 the steps is:  1357
# 289.221293758234  step  416  of the epoch  2 the steps is:  1358
# 289.79943891807136  step  417  of the epoch  2 the steps is:  1359
# [288.8350753]  step  418  of the epoch  2 the steps is:  1360
# 247.55097252011512  step  419  of the epoch  2 the steps is:  1361
# 325.3866625734737  step  420  of the epoch  2 the steps is:  1362
# 270.8824537659984  step  421  of the epoch  2 the steps is:  1363
# 322.9857460608027  step  422  of the epoch  2 the steps is:  1364
# 313.1475188544115  step  423  of the epoch  2 the steps is:  1365
# 293.4400004766107  step  424  of the epoch  2 the steps is:  1366
# [345.44397862]  step  425  of the epoch  2 the steps is:  1367
# 303.8977437453881  step  426  of the epoch  2 the steps is:  1368
# [317.35462695]  step  427  of the epoch  2 the steps is:  1369
# [276.1612696]  step  428  of the epoch  2 the steps is:  1370
# 329.9058324583044  step  429  of the epoch  2 the steps is:  1371
# [299.43189327]  step  430  of the epoch  2 the steps is:  1372
# [342.45635996]  step  431  of the epoch  2 the steps is:  1373
# [316.53742342]  step  432  of the epoch  2 the steps is:  1374
# [303.19924466]  step  433  of the epoch  2 the steps is:  1375
# 275.0257219130261  step  434  of the epoch  2 the steps is:  1376
# 334.7128887122412  step  435  of the epoch  2 the steps is:  1377
# 338.86084582826527  step  436  of the epoch  2 the steps is:  1378
# [314.61785726]  step  437  of the epoch  2 the steps is:  1379
# 288.4680438840861  step  438  of the epoch  2 the steps is:  1380
# 335.83186071648333  step  439  of the epoch  2 the steps is:  1381
# 275.7293661189507  step  440  of the epoch  2 the steps is:  1382
# 323.7926196104198  step  441  of the epoch  2 the steps is:  1383
# 281.3182943087138  step  442  of the epoch  2 the steps is:  1384
# 327.4839205583483  step  443  of the epoch  2 the steps is:  1385
# [248.02896442]  step  444  of the epoch  2 the steps is:  1386
# [305.1971641]  step  445  of the epoch  2 the steps is:  1387
# 317.0287156055796  step  446  of the epoch  2 the steps is:  1388
# 311.5844332892327  step  447  of the epoch  2 the steps is:  1389
# 345.5402620495188  step  448  of the epoch  2 the steps is:  1390
# [317.66850923]  step  449  of the epoch  2 the steps is:  1391
# 305.86456376228296  step  450  of the epoch  2 the steps is:  1392
# [293.40024631]  step  451  of the epoch  2 the steps is:  1393
# [314.08589442]  step  452  of the epoch  2 the steps is:  1394
# [351.40033916]  step  453  of the epoch  2 the steps is:  1395
# 319.4416922815675  step  454  of the epoch  2 the steps is:  1396
# [347.25876607]  step  455  of the epoch  2 the steps is:  1397
# 319.83007170487707  step  456  of the epoch  2 the steps is:  1398
# 262.1548662659334  step  457  of the epoch  2 the steps is:  1399
# 285.40437453884897  step  458  of the epoch  2 the steps is:  1400
# 311.9906031935807  step  459  of the epoch  2 the steps is:  1401
# 298.6461119903272  step  460  of the epoch  2 the steps is:  1402
# 324.40821545625624  step  461  of the epoch  2 the steps is:  1403
# 313.42679168348377  step  462  of the epoch  2 the steps is:  1404
# 297.4745595765122  step  463  of the epoch  2 the steps is:  1405
# 273.6239838067035  step  464  of the epoch  2 the steps is:  1406
# [300.76840011]  step  465  of the epoch  2 the steps is:  1407
# [307.50876515]  step  466  of the epoch  2 the steps is:  1408
# 312.0277102690552  step  467  of the epoch  2 the steps is:  1409
# 285.16301446225043  step  468  of the epoch  2 the steps is:  1410
# [277.16889924]  step  469  of the epoch  2 the steps is:  1411
# 286.2325280186199  step  470  of the epoch  2 the steps is:  1412

# %%
mini_dataSet, mini_labelSet = [],[]
j = 0
for i in range(1000):
  if MyNetwork.forward(Train_data[i]) == Train_label[i]:
    mini_dataSet.append(Train_data[i])
    mini_labelSet.append(Train_label[i])
    j += 1
  if j == 100:
    break

# %%
attacked_image = []
for i in range(100):
  attacked_image.append(MyNetwork.attack_network(mini_dataSet[i], mini_labelSet[i]))

# %%
score1 = 0
score2 = 0
for i in range(100):
  print("The label for the", i,"th data is: ", MyNetwork.forward(mini_dataSet[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))))
  if MyNetwork.forward(mini_dataSet[i]) != MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score1 += 1
  if 10 ==  MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score2 += 1
print("The attacked accuracy was: ", score1)
print("The number rejection is: ", score2)
# Out:
# The label for the 0 th data is:  [3] after attack it became:  [3]
# The label for the 1 th data is:  [1] after attack it became:  [1]
# The label for the 2 th data is:  [9] after attack it became:  [9]
# The label for the 3 th data is:  [1] after attack it became:  [1]
# The label for the 4 th data is:  [4] after attack it became:  [4]
# The label for the 5 th data is:  [5] after attack it became:  [5]
# The label for the 6 th data is:  [0] after attack it became:  [0]
# The label for the 7 th data is:  [2] after attack it became:  [2]
# The label for the 8 th data is:  [9] after attack it became:  [8]
# The label for the 9 th data is:  [5] after attack it became:  [5]
# The label for the 10 th data is:  [9] after attack it became:  [8]
# The label for the 11 th data is:  [8] after attack it became:  [8]
# The label for the 12 th data is:  [1] after attack it became:  [1]
# The label for the 13 th data is:  [1] after attack it became:  [1]
# The label for the 14 th data is:  [5] after attack it became:  [5]
# The label for the 15 th data is:  [4] after attack it became:  [4]
# The label for the 16 th data is:  [1] after attack it became:  [1]
# The label for the 17 th data is:  [5] after attack it became:  [5]
# The label for the 18 th data is:  [0] after attack it became:  [0]
# The label for the 19 th data is:  [9] after attack it became:  [7]
# The label for the 20 th data is:  [5] after attack it became:  [5]
# The label for the 21 th data is:  [9] after attack it became:  [9]
# The label for the 22 th data is:  [9] after attack it became:  [8]
# The label for the 23 th data is:  [0] after attack it became:  [0]
# The label for the 24 th data is:  [7] after attack it became:  [5]
# The label for the 25 th data is:  [9] after attack it became:  [8]
# The label for the 26 th data is:  [1] after attack it became:  [1]
# The label for the 27 th data is:  [8] after attack it became:  [8]
# The label for the 28 th data is:  [9] after attack it became:  [9]
# The label for the 29 th data is:  [1] after attack it became:  [1]
# The label for the 30 th data is:  [9] after attack it became:  [9]
# The label for the 31 th data is:  [9] after attack it became:  [9]
# The label for the 32 th data is:  [7] after attack it became:  [7]
# The label for the 33 th data is:  [9] after attack it became:  [9]
# The label for the 34 th data is:  [3] after attack it became:  [3]
# The label for the 35 th data is:  [1] after attack it became:  [1]
# The label for the 36 th data is:  [2] after attack it became:  [2]
# The label for the 37 th data is:  [5] after attack it became:  [8]
# The label for the 38 th data is:  [8] after attack it became:  [8]
# The label for the 39 th data is:  [4] after attack it became:  [4]
# The label for the 40 th data is:  [2] after attack it became:  [2]
# The label for the 41 th data is:  [3] after attack it became:  [3]
# The label for the 42 th data is:  [4] after attack it became:  [4]
# The label for the 43 th data is:  [7] after attack it became:  [5]
# The label for the 44 th data is:  [3] after attack it became:  [3]
# The label for the 45 th data is:  [1] after attack it became:  [1]
# The label for the 46 th data is:  [6] after attack it became:  [6]
# The label for the 47 th data is:  [3] after attack it became:  [3]
# The label for the 48 th data is:  [5] after attack it became:  [5]
# The label for the 49 th data is:  [4] after attack it became:  [4]
# The label for the 50 th data is:  [5] after attack it became:  [5]
# The label for the 51 th data is:  [0] after attack it became:  [0]
# The label for the 52 th data is:  [8] after attack it became:  [8]
# The label for the 53 th data is:  [5] after attack it became:  [5]
# The label for the 54 th data is:  [5] after attack it became:  [5]
# The label for the 55 th data is:  [4] after attack it became:  [4]
# The label for the 56 th data is:  [8] after attack it became:  [10]
# The label for the 57 th data is:  [7] after attack it became:  [5]
# The label for the 58 th data is:  [8] after attack it became:  [8]
# The label for the 59 th data is:  [8] after attack it became:  [8]
# The label for the 60 th data is:  [3] after attack it became:  [3]
# The label for the 61 th data is:  [1] after attack it became:  [1]
# The label for the 62 th data is:  [8] after attack it became:  [7]
# The label for the 63 th data is:  [0] after attack it became:  [0]
# The label for the 64 th data is:  [9] after attack it became:  [8]
# The label for the 65 th data is:  [6] after attack it became:  [6]
# The label for the 66 th data is:  [3] after attack it became:  [3]
# The label for the 67 th data is:  [4] after attack it became:  [4]
# The label for the 68 th data is:  [5] after attack it became:  [5]
# The label for the 69 th data is:  [1] after attack it became:  [1]
# The label for the 70 th data is:  [8] after attack it became:  [8]
# The label for the 71 th data is:  [8] after attack it became:  [8]
# The label for the 72 th data is:  [5] after attack it became:  [0]
# The label for the 73 th data is:  [9] after attack it became:  [9]
# The label for the 74 th data is:  [7] after attack it became:  [7]
# The label for the 75 th data is:  [3] after attack it became:  [3]
# The label for the 76 th data is:  [3] after attack it became:  [3]
# The label for the 77 th data is:  [2] after attack it became:  [2]
# The label for the 78 th data is:  [3] after attack it became:  [3]
# The label for the 79 th data is:  [8] after attack it became:  [8]
# The label for the 80 th data is:  [3] after attack it became:  [3]
# The label for the 81 th data is:  [1] after attack it became:  [1]
# The label for the 82 th data is:  [4] after attack it became:  [4]
# The label for the 83 th data is:  [1] after attack it became:  [1]
# The label for the 84 th data is:  [7] after attack it became:  [5]
# The label for the 85 th data is:  [6] after attack it became:  [8]
# The label for the 86 th data is:  [9] after attack it became:  [9]
# The label for the 87 th data is:  [8] after attack it became:  [0]
# The label for the 88 th data is:  [1] after attack it became:  [1]
# The label for the 89 th data is:  [1] after attack it became:  [1]
# The label for the 90 th data is:  [7] after attack it became:  [7]
# The label for the 91 th data is:  [1] after attack it became:  [1]
# The label for the 92 th data is:  [0] after attack it became:  [0]
# The label for the 93 th data is:  [9] after attack it became:  [9]
# The label for the 94 th data is:  [7] after attack it became:  [7]
# The label for the 95 th data is:  [0] after attack it became:  [0]
# The label for the 96 th data is:  [2] after attack it became:  [2]
# The label for the 97 th data is:  [4] after attack it became:  [4]
# The label for the 98 th data is:  [2] after attack it became:  [2]
# The label for the 99 th data is:  [7] after attack it became:  [7]
# The attacked accuracy was:  16
# The number rejection is:  1

# %%
for i in range(20):
  print("The label for the", i,"th data is: ", MyNetwork.forward(Test_data[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))), "The true Label", Test_label[i])
# Out:
# The label for the 0 th data is:  [9] after attack it became:  [10] The true Label [9]
# The label for the 1 th data is:  [2] after attack it became:  [2] The true Label [2]
# The label for the 2 th data is:  [1] after attack it became:  [9] The true Label [1]
# The label for the 3 th data is:  [1] after attack it became:  [3] The true Label [1]
# The label for the 4 th data is:  [6] after attack it became:  [3] The true Label [6]
# The label for the 5 th data is:  [1] after attack it became:  [10] The true Label [1]
# The label for the 6 th data is:  [4] after attack it became:  [5] The true Label [4]
# The label for the 7 th data is:  [6] after attack it became:  [6] The true Label [6]
# The label for the 8 th data is:  [5] after attack it became:  [10] The true Label [5]
# The label for the 9 th data is:  [7] after attack it became:  [10] The true Label [7]
# The label for the 10 th data is:  [2] after attack it became:  [8] The true Label [4]
# The label for the 11 th data is:  [7] after attack it became:  [10] The true Label [5]
# The label for the 12 th data is:  [5] after attack it became:  [10] The true Label [7]
# The label for the 13 th data is:  [3] after attack it became:  [0] The true Label [3]
# The label for the 14 th data is:  [4] after attack it became:  [10] The true Label [4]
# The label for the 15 th data is:  [1] after attack it became:  [10] The true Label [1]
# The label for the 16 th data is:  [2] after attack it became:  [8] The true Label [2]
# The label for the 17 th data is:  [4] after attack it became:  [8] The true Label [4]
# The label for the 18 th data is:  [8] after attack it became:  [10] The true Label [8]
# The label for the 19 th data is:  [0] after attack it became:  [10] The true Label [0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in cosh
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in power

# %%
MyNetwork.Test_Network(Train_data, Train_label)
# Out:
# 0.7976744186046512

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-caadd85e0db7> in <module>()
#       3   pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
#       4   pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
# ----> 5   pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     485     else:
#     486         # last ditch effort
# --> 487         data = [tuple(x) for x in data]
#     488         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     489
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/construction.py in <listcomp>(.0)
#     485     else:
#     486         # last ditch effort
# --> 487         data = [tuple(x) for x in data]
#     488         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     489
#
# TypeError: 'numpy.float64' object is not iterable

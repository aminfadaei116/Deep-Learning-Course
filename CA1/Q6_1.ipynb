# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx):
  temp = step(vect)
  temp[idx] = 0
  n = np.sum(temp)
  for i in range(len(temp)):
    if temp[i] == 1:
      temp[i] = -1
  temp[idx] = n
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.01
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.attack_rate = 0.01

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = relu(self.layer["z0"])
    self.layer["s0"] = step(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = relu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = step(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = relu(self.layer["z" + str(self.number_hidden_layer)])
    self.layer["s" + str(self.number_hidden_layer)] = step(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide(self.score)
    return temp
  
  def decide(self, data):
    self.result = np.argmax(data, axis=0)
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu(temp[i] - temp[i][label[i]] + 1))-1)# inja ro bayad taghir bedi
      self.back_prob_output.append(encode((temp[i] - temp[i][label[i]] + 1), label[i]))
    self.back_prob_output = (np.transpose(self.back_prob_output))/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    self.batch_data.clear()
    if len(data) == data.size:
      batch[0] = data
      return
    batch_size = self.batchS
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(self.back_prob_output, self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] + self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] + self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))

  def attach_network(self, data, label):
    self.forward(data)
    print(self.cal_loss(label))
    D_image = np.multiply(self.back_prob_output, self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      D_image = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), D_image)
      D_image = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], D_image)
    D_image = np.matmul(np.transpose(self.weight["w0"]), D_image)
    D_image = np.sign(D_image) 
    return data - self.attack_rate * D_image.reshape((-1,))

# %%
MyNetwork = Network(128,1,[150] ,10)
#MyNetwork.load_weights()

# %%
MyNetwork.set_learning_rate(0.05)
MyNetwork.set_turn(3)
MyNetwork.set_batch_size(128)
MyNetwork.Train_Network(Train_data, Train_label)
# Out:
# 9.62114030924435  step  0  of the epoch  0 the steps is:  0
# 9.484753159808443  step  1  of the epoch  0 the steps is:  1
# 9.152436168580344  step  2  of the epoch  0 the steps is:  2
# 9.470025683749178  step  3  of the epoch  0 the steps is:  3
# 8.867985003586627  step  4  of the epoch  0 the steps is:  4
# 9.240084965198248  step  5  of the epoch  0 the steps is:  5
# 8.763520323405997  step  6  of the epoch  0 the steps is:  6
# 8.60135190620483  step  7  of the epoch  0 the steps is:  7
# 8.828444731455011  step  8  of the epoch  0 the steps is:  8
# 8.290475486142835  step  9  of the epoch  0 the steps is:  9
# 8.625675607266043  step  10  of the epoch  0 the steps is:  10
# 8.06904270543509  step  11  of the epoch  0 the steps is:  11
# 7.643961795586612  step  12  of the epoch  0 the steps is:  12
# 7.572067954324078  step  13  of the epoch  0 the steps is:  13
# 7.922309255768379  step  14  of the epoch  0 the steps is:  14
# 7.075774776111416  step  15  of the epoch  0 the steps is:  15
# 8.128443784722581  step  16  of the epoch  0 the steps is:  16
# 6.679005941646569  step  17  of the epoch  0 the steps is:  17
# 7.879896540069065  step  18  of the epoch  0 the steps is:  18
# 7.49102126228031  step  19  of the epoch  0 the steps is:  19
# 6.108134308876904  step  20  of the epoch  0 the steps is:  20
# 6.783853900853184  step  21  of the epoch  0 the steps is:  21
# 6.758604964061095  step  22  of the epoch  0 the steps is:  22
# 6.281037361493654  step  23  of the epoch  0 the steps is:  23
# 5.672272320866954  step  24  of the epoch  0 the steps is:  24
# 5.83577103413605  step  25  of the epoch  0 the steps is:  25
# 5.7234500136939825  step  26  of the epoch  0 the steps is:  26
# 5.136305238551353  step  27  of the epoch  0 the steps is:  27
# 5.146816142396958  step  28  of the epoch  0 the steps is:  28
# 4.815805823855095  step  29  of the epoch  0 the steps is:  29
# 5.340080992483544  step  30  of the epoch  0 the steps is:  30
# 5.414500845011021  step  31  of the epoch  0 the steps is:  31
# 5.164376825682229  step  32  of the epoch  0 the steps is:  32
# 4.69682263078234  step  33  of the epoch  0 the steps is:  33
# 4.313071029195851  step  34  of the epoch  0 the steps is:  34
# 4.2709914608110084  step  35  of the epoch  0 the steps is:  35
# 4.695582880400798  step  36  of the epoch  0 the steps is:  36
# 4.604144512074588  step  37  of the epoch  0 the steps is:  37
# 3.9424360368017224  step  38  of the epoch  0 the steps is:  38
# 4.856507300642274  step  39  of the epoch  0 the steps is:  39
# 4.542888319123328  step  40  of the epoch  0 the steps is:  40
# 4.430856221852586  step  41  of the epoch  0 the steps is:  41
# 4.78422099181831  step  42  of the epoch  0 the steps is:  42
# 4.173823483284821  step  43  of the epoch  0 the steps is:  43
# 3.584637608259297  step  44  of the epoch  0 the steps is:  44
# 4.015754847812839  step  45  of the epoch  0 the steps is:  45
# 4.383618450472319  step  46  of the epoch  0 the steps is:  46
# 4.084129222912715  step  47  of the epoch  0 the steps is:  47
# 3.646500219854272  step  48  of the epoch  0 the steps is:  48
# 4.600025199826594  step  49  of the epoch  0 the steps is:  49
# 4.465317777853485  step  50  of the epoch  0 the steps is:  50
# 3.6800131901422573  step  51  of the epoch  0 the steps is:  51
# 3.8544229469422517  step  52  of the epoch  0 the steps is:  52
# 3.030973965374596  step  53  of the epoch  0 the steps is:  53
# 3.363801529691655  step  54  of the epoch  0 the steps is:  54
# 3.3574244715123474  step  55  of the epoch  0 the steps is:  55
# 3.5959648714909576  step  56  of the epoch  0 the steps is:  56
# 3.960723798195043  step  57  of the epoch  0 the steps is:  57
# 3.5001495849674926  step  58  of the epoch  0 the steps is:  58
# 3.55755639121331  step  59  of the epoch  0 the steps is:  59
# 3.4110235174101264  step  60  of the epoch  0 the steps is:  60
# 2.7744577947882822  step  61  of the epoch  0 the steps is:  61
# 3.9189517655694015  step  62  of the epoch  0 the steps is:  62
# 2.689920463829727  step  63  of the epoch  0 the steps is:  63
# 3.2783041552053334  step  64  of the epoch  0 the steps is:  64
# 3.3496555166396673  step  65  of the epoch  0 the steps is:  65
# 3.0439385914906794  step  66  of the epoch  0 the steps is:  66
# 3.1358250444067783  step  67  of the epoch  0 the steps is:  67
# 3.6241830324828284  step  68  of the epoch  0 the steps is:  68
# 3.4157360740078353  step  69  of the epoch  0 the steps is:  69
# 3.1489884673055886  step  70  of the epoch  0 the steps is:  70
# 3.575813549745934  step  71  of the epoch  0 the steps is:  71
# 3.385376093592489  step  72  of the epoch  0 the steps is:  72
# 3.262652789371674  step  73  of the epoch  0 the steps is:  73
# 2.9709919960837294  step  74  of the epoch  0 the steps is:  74
# 3.4467965056353185  step  75  of the epoch  0 the steps is:  75
# 3.3297691704638703  step  76  of the epoch  0 the steps is:  76
# 3.2539349313270574  step  77  of the epoch  0 the steps is:  77
# 3.0764067651151072  step  78  of the epoch  0 the steps is:  78
# 3.079312970791791  step  79  of the epoch  0 the steps is:  79
# 2.6120610620164073  step  80  of the epoch  0 the steps is:  80
# 3.403807573665172  step  81  of the epoch  0 the steps is:  81
# 3.076688992900107  step  82  of the epoch  0 the steps is:  82
# 2.809042930978685  step  83  of the epoch  0 the steps is:  83
# 3.1799512254314743  step  84  of the epoch  0 the steps is:  84
# 3.0289423958736386  step  85  of the epoch  0 the steps is:  85
# 2.502135360860299  step  86  of the epoch  0 the steps is:  86
# 2.4180078876008686  step  87  of the epoch  0 the steps is:  87
# 2.726509440148055  step  88  of the epoch  0 the steps is:  88
# 3.4218101937731644  step  89  of the epoch  0 the steps is:  89
# 3.3842411975535867  step  90  of the epoch  0 the steps is:  90
# 2.8414293305670277  step  91  of the epoch  0 the steps is:  91
# 3.149044965166402  step  92  of the epoch  0 the steps is:  92
# 2.610831027293588  step  93  of the epoch  0 the steps is:  93
# 2.819677918061429  step  94  of the epoch  0 the steps is:  94
# 2.833582493162684  step  95  of the epoch  0 the steps is:  95
# 3.0374991895495476  step  96  of the epoch  0 the steps is:  96
# 2.983453109886347  step  97  of the epoch  0 the steps is:  97
# 3.207982047545663  step  98  of the epoch  0 the steps is:  98
# 2.7605164462803664  step  99  of the epoch  0 the steps is:  99
# 2.9314096112242627  step  100  of the epoch  0 the steps is:  100
# 3.1147499358511173  step  101  of the epoch  0 the steps is:  101
# 2.4665208231742968  step  102  of the epoch  0 the steps is:  102
# 3.167983647539635  step  103  of the epoch  0 the steps is:  103
# 3.3110800180909243  step  104  of the epoch  0 the steps is:  104
# 2.8139849314402428  step  105  of the epoch  0 the steps is:  105
# 2.753887145810027  step  106  of the epoch  0 the steps is:  106
# 2.6285591051602197  step  107  of the epoch  0 the steps is:  107
# 2.5365739191016408  step  108  of the epoch  0 the steps is:  108
# 3.180100913691269  step  109  of the epoch  0 the steps is:  109
# 2.638745669000468  step  110  of the epoch  0 the steps is:  110
# 2.8390161920304315  step  111  of the epoch  0 the steps is:  111
# 2.4266823871382783  step  112  of the epoch  0 the steps is:  112
# 2.8157239615877816  step  113  of the epoch  0 the steps is:  113
# 3.081610159163599  step  114  of the epoch  0 the steps is:  114
# 3.3821304601820446  step  115  of the epoch  0 the steps is:  115
# 3.829225196802443  step  116  of the epoch  0 the steps is:  116
# 3.4773442854842744  step  117  of the epoch  0 the steps is:  117
# 3.598090187218977  step  118  of the epoch  0 the steps is:  118
# 3.212740343053495  step  119  of the epoch  0 the steps is:  119
# 2.7923208628544542  step  120  of the epoch  0 the steps is:  120
# 2.9378147450911634  step  121  of the epoch  0 the steps is:  121
# 3.131564469487375  step  122  of the epoch  0 the steps is:  122
# 2.447338032274228  step  123  of the epoch  0 the steps is:  123
# 2.288264136835699  step  124  of the epoch  0 the steps is:  124
# 2.988440468966485  step  125  of the epoch  0 the steps is:  125
# 3.038161151200484  step  126  of the epoch  0 the steps is:  126
# 2.506898873930241  step  127  of the epoch  0 the steps is:  127
# 2.8224696101616757  step  128  of the epoch  0 the steps is:  128
# 2.405310326167479  step  129  of the epoch  0 the steps is:  129
# 2.7009634199156283  step  130  of the epoch  0 the steps is:  130
# 2.45706890300069  step  131  of the epoch  0 the steps is:  131
# 2.392176055633218  step  132  of the epoch  0 the steps is:  132
# 3.132331996899344  step  133  of the epoch  0 the steps is:  133
# 2.8933947943245952  step  134  of the epoch  0 the steps is:  134
# 2.835975872713176  step  135  of the epoch  0 the steps is:  135
# 2.755060975058219  step  136  of the epoch  0 the steps is:  136
# 3.5568346225306406  step  137  of the epoch  0 the steps is:  137
# 3.0346971335814326  step  138  of the epoch  0 the steps is:  138
# 2.923110325822848  step  139  of the epoch  0 the steps is:  139
# 2.570071150195628  step  140  of the epoch  0 the steps is:  140
# 2.967450170563114  step  141  of the epoch  0 the steps is:  141
# 3.2934260219207476  step  142  of the epoch  0 the steps is:  142
# 3.012373643346249  step  143  of the epoch  0 the steps is:  143
# 3.132142706288895  step  144  of the epoch  0 the steps is:  144
# 3.095069919714054  step  145  of the epoch  0 the steps is:  145
# 2.2456384369775417  step  146  of the epoch  0 the steps is:  146
# 2.7806666635510444  step  147  of the epoch  0 the steps is:  147
# 2.301504062205238  step  148  of the epoch  0 the steps is:  148
# 2.892163515774819  step  149  of the epoch  0 the steps is:  149
# 2.9966865387481194  step  150  of the epoch  0 the steps is:  150
# 2.234348981350107  step  151  of the epoch  0 the steps is:  151
# 2.9066762362328964  step  152  of the epoch  0 the steps is:  152
# 1.9258939562135575  step  153  of the epoch  0 the steps is:  153
# 3.501364649574617  step  154  of the epoch  0 the steps is:  154
# 2.5433871523469853  step  155  of the epoch  0 the steps is:  155
# 2.719461164972607  step  156  of the epoch  0 the steps is:  156
# 3.283006331830522  step  157  of the epoch  0 the steps is:  157
# 2.7417479863619745  step  158  of the epoch  0 the steps is:  158
# 2.9466680313669915  step  159  of the epoch  0 the steps is:  159
# 2.033143053494859  step  160  of the epoch  0 the steps is:  160
# 2.731050144395385  step  161  of the epoch  0 the steps is:  161
# 2.871055700547217  step  162  of the epoch  0 the steps is:  162
# 2.1056537285790515  step  163  of the epoch  0 the steps is:  163
# 2.5755723413938143  step  164  of the epoch  0 the steps is:  164
# 2.8781627503953815  step  165  of the epoch  0 the steps is:  165
# 3.004079745336931  step  166  of the epoch  0 the steps is:  166
# 2.194304321886113  step  167  of the epoch  0 the steps is:  167
# 2.440121725679635  step  168  of the epoch  0 the steps is:  168
# 2.74238370940616  step  169  of the epoch  0 the steps is:  169
# 2.5413746799982824  step  170  of the epoch  0 the steps is:  170
# 3.55877458752417  step  171  of the epoch  0 the steps is:  171
# 2.995961467919192  step  172  of the epoch  0 the steps is:  172
# 2.295089742613527  step  173  of the epoch  0 the steps is:  173
# 3.2374211350390745  step  174  of the epoch  0 the steps is:  174
# 2.8945120308480083  step  175  of the epoch  0 the steps is:  175
# 3.0795657169316244  step  176  of the epoch  0 the steps is:  176
# 2.8894434880365027  step  177  of the epoch  0 the steps is:  177
# 2.2086725460924157  step  178  of the epoch  0 the steps is:  178
# 2.2725009489928327  step  179  of the epoch  0 the steps is:  179
# 2.718059663409127  step  180  of the epoch  0 the steps is:  180
# 3.432499394642086  step  181  of the epoch  0 the steps is:  181
# 2.3659759956982858  step  182  of the epoch  0 the steps is:  182
# 2.7290057733098996  step  183  of the epoch  0 the steps is:  183
# 3.3069754867910928  step  184  of the epoch  0 the steps is:  184
# 2.649647190009018  step  185  of the epoch  0 the steps is:  185
# 2.521711813897938  step  186  of the epoch  0 the steps is:  186
# 2.4124646753106025  step  187  of the epoch  0 the steps is:  187
# 1.9651356809957798  step  188  of the epoch  0 the steps is:  188
# 2.9213925154603  step  189  of the epoch  0 the steps is:  189
# 2.763507592345751  step  190  of the epoch  0 the steps is:  190
# 2.8139423499891465  step  191  of the epoch  0 the steps is:  191
# 2.5433922434631464  step  192  of the epoch  0 the steps is:  192
# 2.9153034897890167  step  193  of the epoch  0 the steps is:  193
# 2.8655612301055142  step  194  of the epoch  0 the steps is:  194
# 2.746669965180782  step  195  of the epoch  0 the steps is:  195
# 2.6628684090286914  step  196  of the epoch  0 the steps is:  196
# 2.831170783104239  step  197  of the epoch  0 the steps is:  197
# 2.72825941379358  step  198  of the epoch  0 the steps is:  198
# 2.6083155872607664  step  199  of the epoch  0 the steps is:  199
# 2.0591752207163547  step  200  of the epoch  0 the steps is:  200
# 2.2664176167483068  step  201  of the epoch  0 the steps is:  201
# 2.591152379392524  step  202  of the epoch  0 the steps is:  202
# 2.32273404932036  step  203  of the epoch  0 the steps is:  203
# 3.5281683579655225  step  204  of the epoch  0 the steps is:  204
# 2.2894923875797466  step  205  of the epoch  0 the steps is:  205
# 2.7752012962699943  step  206  of the epoch  0 the steps is:  206
# 2.499929978002741  step  207  of the epoch  0 the steps is:  207
# 2.408457812775894  step  208  of the epoch  0 the steps is:  208
# 2.5712217648182625  step  209  of the epoch  0 the steps is:  209
# 3.2890468882407538  step  210  of the epoch  0 the steps is:  210
# 2.498446703822002  step  211  of the epoch  0 the steps is:  211
# 2.383018959631417  step  212  of the epoch  0 the steps is:  212
# 2.260483784905091  step  213  of the epoch  0 the steps is:  213
# 2.3828338557640953  step  214  of the epoch  0 the steps is:  214
# 2.333735894943634  step  215  of the epoch  0 the steps is:  215
# 2.423715001617804  step  216  of the epoch  0 the steps is:  216
# 2.187642157869399  step  217  of the epoch  0 the steps is:  217
# 3.3781814876270815  step  218  of the epoch  0 the steps is:  218
# 2.2890994063206724  step  219  of the epoch  0 the steps is:  219
# 2.531761743053912  step  220  of the epoch  0 the steps is:  220
# 2.3177081476688937  step  221  of the epoch  0 the steps is:  221
# 2.851423302980687  step  222  of the epoch  0 the steps is:  222
# 2.7039380902869095  step  223  of the epoch  0 the steps is:  223
# 2.324819221829254  step  224  of the epoch  0 the steps is:  224
# 2.1074873697178704  step  225  of the epoch  0 the steps is:  225
# 3.144882552632441  step  226  of the epoch  0 the steps is:  226
# 2.80247865512807  step  227  of the epoch  0 the steps is:  227
# 2.452315985012324  step  228  of the epoch  0 the steps is:  228
# 2.1049775493705436  step  229  of the epoch  0 the steps is:  229
# 2.816775861212488  step  230  of the epoch  0 the steps is:  230
# 2.492765799062226  step  231  of the epoch  0 the steps is:  231
# 2.720363243075495  step  232  of the epoch  0 the steps is:  232
# 2.7652631215864747  step  233  of the epoch  0 the steps is:  233
# 2.6449768041956623  step  234  of the epoch  0 the steps is:  234
# 2.539191411444077  step  235  of the epoch  0 the steps is:  235
# 2.418920387954479  step  236  of the epoch  0 the steps is:  236
# 2.231217862377074  step  237  of the epoch  0 the steps is:  237
# 2.4001255216100716  step  238  of the epoch  0 the steps is:  238
# 2.9733951555036873  step  239  of the epoch  0 the steps is:  239
# 2.416810087955374  step  240  of the epoch  0 the steps is:  240
# 2.8746218203341165  step  241  of the epoch  0 the steps is:  241
# 2.7978549018058807  step  242  of the epoch  0 the steps is:  242
# 2.649241119395282  step  243  of the epoch  0 the steps is:  243
# 3.262228024651767  step  244  of the epoch  0 the steps is:  244
# 3.1833594198168207  step  245  of the epoch  0 the steps is:  245
# 2.906581607167705  step  246  of the epoch  0 the steps is:  246
# 3.195567031361542  step  247  of the epoch  0 the steps is:  247
# 2.339605597563877  step  248  of the epoch  0 the steps is:  248
# 2.8880173182073037  step  249  of the epoch  0 the steps is:  249
# 3.013157590931148  step  250  of the epoch  0 the steps is:  250
# 3.0271042548555256  step  251  of the epoch  0 the steps is:  251
# 2.6628810816773516  step  252  of the epoch  0 the steps is:  252
# 2.633503559684997  step  253  of the epoch  0 the steps is:  253
# 1.9634751538079982  step  254  of the epoch  0 the steps is:  254
# 2.5815696807321658  step  255  of the epoch  0 the steps is:  255
# 2.725205690686657  step  256  of the epoch  0 the steps is:  256
# 2.1654277515787896  step  257  of the epoch  0 the steps is:  257
# 2.8004034610379103  step  258  of the epoch  0 the steps is:  258
# 2.516535186642458  step  259  of the epoch  0 the steps is:  259
# 2.6106341706264358  step  260  of the epoch  0 the steps is:  260
# 3.1387644868367595  step  261  of the epoch  0 the steps is:  261
# 2.3833375454645545  step  262  of the epoch  0 the steps is:  262
# 2.6084735115063795  step  263  of the epoch  0 the steps is:  263
# 3.0366362681609296  step  264  of the epoch  0 the steps is:  264
# 2.7613874349695555  step  265  of the epoch  0 the steps is:  265
# 2.4786786996206205  step  266  of the epoch  0 the steps is:  266
# 2.483531652574086  step  267  of the epoch  0 the steps is:  267
# 3.0764288365755776  step  268  of the epoch  0 the steps is:  268
# 2.3952335742623596  step  269  of the epoch  0 the steps is:  269
# 2.462093159158432  step  270  of the epoch  0 the steps is:  270
# 2.545021067406539  step  271  of the epoch  0 the steps is:  271
# 2.5050174482784557  step  272  of the epoch  0 the steps is:  272
# 1.937591121047487  step  273  of the epoch  0 the steps is:  273
# 2.3977393986390982  step  274  of the epoch  0 the steps is:  274
# 2.794231182234748  step  275  of the epoch  0 the steps is:  275
# 2.851179222837687  step  276  of the epoch  0 the steps is:  276
# 2.3642077102910086  step  277  of the epoch  0 the steps is:  277
# 2.571684811114509  step  278  of the epoch  0 the steps is:  278
# 2.60976416571632  step  279  of the epoch  0 the steps is:  279
# 2.387259243953843  step  280  of the epoch  0 the steps is:  280
# 2.9998025214308557  step  281  of the epoch  0 the steps is:  281
# 2.4728519470488273  step  282  of the epoch  0 the steps is:  282
# 2.226472035065682  step  283  of the epoch  0 the steps is:  283
# 2.769214231905141  step  284  of the epoch  0 the steps is:  284
# 2.2239980995647  step  285  of the epoch  0 the steps is:  285
# 3.0330727445683916  step  286  of the epoch  0 the steps is:  286
# 2.555482851221716  step  287  of the epoch  0 the steps is:  287
# 2.514042920506104  step  288  of the epoch  0 the steps is:  288
# 2.912700539171717  step  289  of the epoch  0 the steps is:  289
# 1.5663004625818562  step  290  of the epoch  0 the steps is:  290
# 2.3576245785676226  step  291  of the epoch  0 the steps is:  291
# 2.605096987403594  step  292  of the epoch  0 the steps is:  292
# 2.7964418321601165  step  293  of the epoch  0 the steps is:  293
# 1.9289664828186994  step  294  of the epoch  0 the steps is:  294
# 2.63969201516095  step  295  of the epoch  0 the steps is:  295
# 2.969582541681734  step  296  of the epoch  0 the steps is:  296
# 2.602433774929633  step  297  of the epoch  0 the steps is:  297
# 3.0240153182915797  step  298  of the epoch  0 the steps is:  298
# 2.671208704891976  step  299  of the epoch  0 the steps is:  299
# 2.1021355305588942  step  300  of the epoch  0 the steps is:  300
# 2.752849669892565  step  301  of the epoch  0 the steps is:  301
# 2.6637045839765863  step  302  of the epoch  0 the steps is:  302
# 2.545834975419104  step  303  of the epoch  0 the steps is:  303
# 2.6101044256270103  step  304  of the epoch  0 the steps is:  304
# 2.891657171046066  step  305  of the epoch  0 the steps is:  305
# 2.563851597252383  step  306  of the epoch  0 the steps is:  306
# 2.478898430221552  step  307  of the epoch  0 the steps is:  307
# 2.3166309459702443  step  308  of the epoch  0 the steps is:  308
# 2.6324963240374064  step  309  of the epoch  0 the steps is:  309
# 2.5648036583159515  step  310  of the epoch  0 the steps is:  310
# 2.2352732818373613  step  311  of the epoch  0 the steps is:  311
# 3.073815394416251  step  312  of the epoch  0 the steps is:  312
# 2.7565407543909135  step  313  of the epoch  0 the steps is:  313
# 2.3849045524382673  step  314  of the epoch  0 the steps is:  314
# 2.4530151605207267  step  315  of the epoch  0 the steps is:  315
# 2.0683359856177232  step  316  of the epoch  0 the steps is:  316
# 2.3442267130951793  step  317  of the epoch  0 the steps is:  317
# 2.116902319453759  step  318  of the epoch  0 the steps is:  318
# 2.5551556703975233  step  319  of the epoch  0 the steps is:  319
# 2.502120559331935  step  320  of the epoch  0 the steps is:  320
# 3.0038737883181974  step  321  of the epoch  0 the steps is:  321
# 2.538598443618204  step  322  of the epoch  0 the steps is:  322
# 2.1399460937327603  step  323  of the epoch  0 the steps is:  323
# 2.7929421212265266  step  324  of the epoch  0 the steps is:  324
# 2.3645674977330033  step  325  of the epoch  0 the steps is:  325
# 1.8139127697472026  step  326  of the epoch  0 the steps is:  326
# 2.6247944227148956  step  327  of the epoch  0 the steps is:  327
# 2.9556405083476607  step  328  of the epoch  0 the steps is:  328
# 2.6924143989503433  step  329  of the epoch  0 the steps is:  329
# 2.9054733939363366  step  330  of the epoch  0 the steps is:  330
# 2.783830658187866  step  331  of the epoch  0 the steps is:  331
# 1.8765866344892648  step  332  of the epoch  0 the steps is:  332
# 2.484895024635464  step  333  of the epoch  0 the steps is:  333
# 2.4418746290033004  step  334  of the epoch  0 the steps is:  334
# 2.0221652076727024  step  335  of the epoch  0 the steps is:  335
# 2.5802160676801287  step  336  of the epoch  0 the steps is:  336
# 2.8205848017059596  step  337  of the epoch  0 the steps is:  337
# 2.6289695673132036  step  338  of the epoch  0 the steps is:  338
# 1.931470171843331  step  339  of the epoch  0 the steps is:  339
# 2.583059023176168  step  340  of the epoch  0 the steps is:  340
# 2.1278109018853533  step  341  of the epoch  0 the steps is:  341
# 2.7388185154419644  step  342  of the epoch  0 the steps is:  342
# 2.833829306921456  step  343  of the epoch  0 the steps is:  343
# 2.565811521287951  step  344  of the epoch  0 the steps is:  344
# 2.576823446819649  step  345  of the epoch  0 the steps is:  345
# 2.132753506384236  step  346  of the epoch  0 the steps is:  346
# 2.5958445803811143  step  347  of the epoch  0 the steps is:  347
# 2.4020980368777063  step  348  of the epoch  0 the steps is:  348
# 2.5213695274194383  step  349  of the epoch  0 the steps is:  349
# 2.7801497426385398  step  350  of the epoch  0 the steps is:  350
# 2.7309791617321815  step  351  of the epoch  0 the steps is:  351
# 3.2053436506323347  step  352  of the epoch  0 the steps is:  352
# 2.317597772195305  step  353  of the epoch  0 the steps is:  353
# 1.6713602977086088  step  354  of the epoch  0 the steps is:  354
# 2.114957599729053  step  355  of the epoch  0 the steps is:  355
# 2.0017239228534267  step  356  of the epoch  0 the steps is:  356
# 2.3725104684707747  step  357  of the epoch  0 the steps is:  357
# 2.2631757545566  step  358  of the epoch  0 the steps is:  358
# 2.084152252610865  step  359  of the epoch  0 the steps is:  359
# 2.0737447838812924  step  360  of the epoch  0 the steps is:  360
# 2.4966875162494695  step  361  of the epoch  0 the steps is:  361
# 2.57174091356195  step  362  of the epoch  0 the steps is:  362
# 2.5157470823719477  step  363  of the epoch  0 the steps is:  363
# 2.999898267782628  step  364  of the epoch  0 the steps is:  364
# 2.2408758467896503  step  365  of the epoch  0 the steps is:  365
# 2.4380393315993123  step  366  of the epoch  0 the steps is:  366
# 2.34951908038047  step  367  of the epoch  0 the steps is:  367
# 3.2715869692718527  step  368  of the epoch  0 the steps is:  368
# 2.815172386867332  step  369  of the epoch  0 the steps is:  369
# 2.003759378218552  step  370  of the epoch  0 the steps is:  370
# 2.8720164142490674  step  371  of the epoch  0 the steps is:  371
# 2.2961837810068073  step  372  of the epoch  0 the steps is:  372
# 2.3476102900830687  step  373  of the epoch  0 the steps is:  373
# 2.1074419438997327  step  374  of the epoch  0 the steps is:  374
# 2.114978574557774  step  375  of the epoch  0 the steps is:  375
# 2.3957656026685097  step  376  of the epoch  0 the steps is:  376
# 2.739998826897076  step  377  of the epoch  0 the steps is:  377
# 2.0431752684375777  step  378  of the epoch  0 the steps is:  378
# 2.460209594843823  step  379  of the epoch  0 the steps is:  379
# 2.829278225742348  step  380  of the epoch  0 the steps is:  380
# 2.2148008436922684  step  381  of the epoch  0 the steps is:  381
# 2.788632067674329  step  382  of the epoch  0 the steps is:  382
# 2.3587822826227423  step  383  of the epoch  0 the steps is:  383
# 2.1356354771335573  step  384  of the epoch  0 the steps is:  384
# 2.1553426560149  step  385  of the epoch  0 the steps is:  385
# 2.121236276873274  step  386  of the epoch  0 the steps is:  386
# 3.076675901049322  step  387  of the epoch  0 the steps is:  387
# 2.968016014119316  step  388  of the epoch  0 the steps is:  388
# 2.6156089652818855  step  389  of the epoch  0 the steps is:  389
# 2.1705384533999212  step  390  of the epoch  0 the steps is:  390
# 2.8579107092099147  step  391  of the epoch  0 the steps is:  391
# 3.067744175798418  step  392  of the epoch  0 the steps is:  392
# 2.779787508883821  step  393  of the epoch  0 the steps is:  393
# 2.421983297955201  step  394  of the epoch  0 the steps is:  394
# 2.0833826284299812  step  395  of the epoch  0 the steps is:  395
# 1.7760963488443737  step  396  of the epoch  0 the steps is:  396
# 1.8926111545705981  step  397  of the epoch  0 the steps is:  397
# 2.5970902093155344  step  398  of the epoch  0 the steps is:  398
# 2.9365955204429417  step  399  of the epoch  0 the steps is:  399
# 2.897566172530073  step  400  of the epoch  0 the steps is:  400
# 2.6780820747842777  step  401  of the epoch  0 the steps is:  401
# 2.20533184279138  step  402  of the epoch  0 the steps is:  402
# 3.33200488988166  step  403  of the epoch  0 the steps is:  403
# 2.212348376949162  step  404  of the epoch  0 the steps is:  404
# 2.274054046483096  step  405  of the epoch  0 the steps is:  405
# 1.953546452595291  step  406  of the epoch  0 the steps is:  406
# 2.808481408799074  step  407  of the epoch  0 the steps is:  407
# 3.217486644543394  step  408  of the epoch  0 the steps is:  408
# 2.536332416827042  step  409  of the epoch  0 the steps is:  409
# 2.0812766088780688  step  410  of the epoch  0 the steps is:  410
# 2.8444841449534204  step  411  of the epoch  0 the steps is:  411
# 2.5853454709134356  step  412  of the epoch  0 the steps is:  412
# 2.208412096456734  step  413  of the epoch  0 the steps is:  413
# 2.349805150273651  step  414  of the epoch  0 the steps is:  414
# 2.0086237145444503  step  415  of the epoch  0 the steps is:  415
# 2.7632125306006654  step  416  of the epoch  0 the steps is:  416
# 2.9040007376236483  step  417  of the epoch  0 the steps is:  417
# 2.613124858953761  step  418  of the epoch  0 the steps is:  418
# 2.1929091091548556  step  419  of the epoch  0 the steps is:  419
# 2.8209091696194086  step  420  of the epoch  0 the steps is:  420
# 2.2626405593709658  step  421  of the epoch  0 the steps is:  421
# 3.076520437395839  step  422  of the epoch  0 the steps is:  422
# 2.1318429303982414  step  423  of the epoch  0 the steps is:  423
# 2.984497007891737  step  424  of the epoch  0 the steps is:  424
# 2.628707888947546  step  425  of the epoch  0 the steps is:  425
# 1.9330143679476548  step  426  of the epoch  0 the steps is:  426
# 2.1773183911636864  step  427  of the epoch  0 the steps is:  427
# 3.2926513083384057  step  428  of the epoch  0 the steps is:  428
# 2.2884288568845887  step  429  of the epoch  0 the steps is:  429
# 2.690203495276643  step  430  of the epoch  0 the steps is:  430
# 2.775318111205375  step  431  of the epoch  0 the steps is:  431
# 2.413641400768495  step  432  of the epoch  0 the steps is:  432
# 2.8210866831311403  step  433  of the epoch  0 the steps is:  433
# 2.9341027920365166  step  434  of the epoch  0 the steps is:  434
# 2.267653677170376  step  435  of the epoch  0 the steps is:  435
# 2.6642588542604213  step  436  of the epoch  0 the steps is:  436
# 2.788490801027828  step  437  of the epoch  0 the steps is:  437
# 2.7409604827188674  step  438  of the epoch  0 the steps is:  438
# 1.9306511717902093  step  439  of the epoch  0 the steps is:  439
# 2.4793017014326915  step  440  of the epoch  0 the steps is:  440
# 2.694370036096768  step  441  of the epoch  0 the steps is:  441
# 3.2931178728870285  step  442  of the epoch  0 the steps is:  442
# 2.1833991274256523  step  443  of the epoch  0 the steps is:  443
# 2.7580676147423278  step  444  of the epoch  0 the steps is:  444
# 3.0015641680601792  step  445  of the epoch  0 the steps is:  445
# 3.0730366789160257  step  446  of the epoch  0 the steps is:  446
# 1.7470472572700713  step  447  of the epoch  0 the steps is:  447
# 2.6768049542522148  step  448  of the epoch  0 the steps is:  448
# 2.6088128409025595  step  449  of the epoch  0 the steps is:  449
# 2.130511472087725  step  450  of the epoch  0 the steps is:  450
# 2.547020771163814  step  451  of the epoch  0 the steps is:  451
# 2.783622356851658  step  452  of the epoch  0 the steps is:  452
# 2.2058451497633715  step  453  of the epoch  0 the steps is:  453
# 2.476810350733386  step  454  of the epoch  0 the steps is:  454
# 2.7324717777595433  step  455  of the epoch  0 the steps is:  455
# 2.646620196789552  step  456  of the epoch  0 the steps is:  456
# 2.3646750528788956  step  457  of the epoch  0 the steps is:  457
# 1.6645289901398699  step  458  of the epoch  0 the steps is:  458
# 2.4757518011635087  step  459  of the epoch  0 the steps is:  459
# 2.5030155704817574  step  460  of the epoch  0 the steps is:  460
# 2.23144903496006  step  461  of the epoch  0 the steps is:  461
# 2.546991064204785  step  462  of the epoch  0 the steps is:  462
# 2.4497994313812765  step  463  of the epoch  0 the steps is:  463
# 2.330139633522653  step  464  of the epoch  0 the steps is:  464
# 2.104536582355833  step  465  of the epoch  0 the steps is:  465
# 2.087824590398454  step  466  of the epoch  0 the steps is:  466
# 2.074692801556288  step  467  of the epoch  0 the steps is:  467
# 2.621918533087697  step  468  of the epoch  0 the steps is:  468
# 2.458219974924898  step  0  of the epoch  1 the steps is:  469
# 2.4892402671849623  step  1  of the epoch  1 the steps is:  470
# 2.633720836510506  step  2  of the epoch  1 the steps is:  471
# 2.3143363104858308  step  3  of the epoch  1 the steps is:  472
# 2.1460513942968165  step  4  of the epoch  1 the steps is:  473
# 2.3467358329981582  step  5  of the epoch  1 the steps is:  474
# 2.7000425602277147  step  6  of the epoch  1 the steps is:  475
# 2.1459553975544665  step  7  of the epoch  1 the steps is:  476
# 2.5260158518212723  step  8  of the epoch  1 the steps is:  477
# 1.7310727192566002  step  9  of the epoch  1 the steps is:  478
# 2.294076381617814  step  10  of the epoch  1 the steps is:  479
# 2.43743901710544  step  11  of the epoch  1 the steps is:  480
# 2.0569685494099668  step  12  of the epoch  1 the steps is:  481
# 2.0440383197655123  step  13  of the epoch  1 the steps is:  482
# 2.069172843064384  step  14  of the epoch  1 the steps is:  483
# 2.0060061633585895  step  15  of the epoch  1 the steps is:  484
# 2.312444526918718  step  16  of the epoch  1 the steps is:  485
# 1.9563092853509434  step  17  of the epoch  1 the steps is:  486
# 2.0327618787626127  step  18  of the epoch  1 the steps is:  487
# 1.778175553452503  step  19  of the epoch  1 the steps is:  488
# 1.8202200371182031  step  20  of the epoch  1 the steps is:  489
# 2.375943048846781  step  21  of the epoch  1 the steps is:  490
# 2.462236855719854  step  22  of the epoch  1 the steps is:  491
# 2.00955300146991  step  23  of the epoch  1 the steps is:  492
# 1.5821841651669495  step  24  of the epoch  1 the steps is:  493
# 1.8949308639947369  step  25  of the epoch  1 the steps is:  494
# 1.839849978103604  step  26  of the epoch  1 the steps is:  495
# 2.026575858462465  step  27  of the epoch  1 the steps is:  496
# 1.4674008336390156  step  28  of the epoch  1 the steps is:  497
# 1.4213699012760626  step  29  of the epoch  1 the steps is:  498
# 2.1636751431221732  step  30  of the epoch  1 the steps is:  499
# 1.9611616459056491  step  31  of the epoch  1 the steps is:  500
# 1.8517624886927828  step  32  of the epoch  1 the steps is:  501
# 1.0499329669951512  step  33  of the epoch  1 the steps is:  502
# 1.4948385450992647  step  34  of the epoch  1 the steps is:  503
# 1.3983535407639962  step  35  of the epoch  1 the steps is:  504
# 1.6847641780832998  step  36  of the epoch  1 the steps is:  505
# 1.77248315676421  step  37  of the epoch  1 the steps is:  506
# 1.7076706426640766  step  38  of the epoch  1 the steps is:  507
# 2.3133975672134564  step  39  of the epoch  1 the steps is:  508
# 2.0878701138998044  step  40  of the epoch  1 the steps is:  509
# 2.062809838151735  step  41  of the epoch  1 the steps is:  510
# 2.0600938620893006  step  42  of the epoch  1 the steps is:  511
# 1.8971294566621755  step  43  of the epoch  1 the steps is:  512
# 1.3025942696261015  step  44  of the epoch  1 the steps is:  513
# 1.9946898857881925  step  45  of the epoch  1 the steps is:  514
# 1.8392469268461813  step  46  of the epoch  1 the steps is:  515
# 2.228899454743957  step  47  of the epoch  1 the steps is:  516
# 1.7930456471158647  step  48  of the epoch  1 the steps is:  517
# 2.1500747180219277  step  49  of the epoch  1 the steps is:  518
# 1.9988404270688875  step  50  of the epoch  1 the steps is:  519
# 1.5540163764684471  step  51  of the epoch  1 the steps is:  520
# 1.675413950267672  step  52  of the epoch  1 the steps is:  521
# 1.413322774956135  step  53  of the epoch  1 the steps is:  522
# 1.6730052427118232  step  54  of the epoch  1 the steps is:  523
# 1.7884397957171432  step  55  of the epoch  1 the steps is:  524
# 1.3849673247377714  step  56  of the epoch  1 the steps is:  525
# 1.8467509296661553  step  57  of the epoch  1 the steps is:  526
# 1.6548310173175986  step  58  of the epoch  1 the steps is:  527
# 1.6235020289712088  step  59  of the epoch  1 the steps is:  528
# 1.787157931492267  step  60  of the epoch  1 the steps is:  529
# 1.5941002531958521  step  61  of the epoch  1 the steps is:  530
# 1.9185512188667389  step  62  of the epoch  1 the steps is:  531
# 1.335885911924087  step  63  of the epoch  1 the steps is:  532
# 1.6414029563677102  step  64  of the epoch  1 the steps is:  533
# 1.7594784950358533  step  65  of the epoch  1 the steps is:  534
# 1.6319579690631778  step  66  of the epoch  1 the steps is:  535
# 1.6209562353573985  step  67  of the epoch  1 the steps is:  536
# 1.936424361869806  step  68  of the epoch  1 the steps is:  537
# 1.8427841144968586  step  69  of the epoch  1 the steps is:  538
# 1.7825489559318406  step  70  of the epoch  1 the steps is:  539
# 1.8720731376425577  step  71  of the epoch  1 the steps is:  540
# 1.4625029998919623  step  72  of the epoch  1 the steps is:  541
# 1.58665716883476  step  73  of the epoch  1 the steps is:  542
# 1.7152269857645455  step  74  of the epoch  1 the steps is:  543
# 1.9037672297031016  step  75  of the epoch  1 the steps is:  544
# 1.9255746840028305  step  76  of the epoch  1 the steps is:  545
# 1.8207971620741312  step  77  of the epoch  1 the steps is:  546
# 1.9498002690701124  step  78  of the epoch  1 the steps is:  547
# 1.6807241353012818  step  79  of the epoch  1 the steps is:  548
# 1.2875482624338428  step  80  of the epoch  1 the steps is:  549
# 2.0286689772084463  step  81  of the epoch  1 the steps is:  550
# 2.060620602809858  step  82  of the epoch  1 the steps is:  551
# 1.4383013714313677  step  83  of the epoch  1 the steps is:  552
# 1.8366266330962608  step  84  of the epoch  1 the steps is:  553
# 1.3808166376918416  step  85  of the epoch  1 the steps is:  554
# 1.2067896404879823  step  86  of the epoch  1 the steps is:  555
# 1.3880761444640632  step  87  of the epoch  1 the steps is:  556
# 1.6032769934726065  step  88  of the epoch  1 the steps is:  557
# 1.5069886083630297  step  89  of the epoch  1 the steps is:  558
# 2.064934089182117  step  90  of the epoch  1 the steps is:  559
# 1.5273938051866456  step  91  of the epoch  1 the steps is:  560
# 1.7511921325013997  step  92  of the epoch  1 the steps is:  561
# 1.1669471043910482  step  93  of the epoch  1 the steps is:  562
# 1.4116384797255375  step  94  of the epoch  1 the steps is:  563
# 1.2672675215069913  step  95  of the epoch  1 the steps is:  564
# 1.6794789646389368  step  96  of the epoch  1 the steps is:  565
# 1.4455828133277082  step  97  of the epoch  1 the steps is:  566
# 1.925133856521007  step  98  of the epoch  1 the steps is:  567
# 1.4071718972886647  step  99  of the epoch  1 the steps is:  568
# 1.7752408843865943  step  100  of the epoch  1 the steps is:  569
# 1.7486455234880016  step  101  of the epoch  1 the steps is:  570
# 1.1409645977352783  step  102  of the epoch  1 the steps is:  571
# 2.1369365756849428  step  103  of the epoch  1 the steps is:  572
# 1.8575637221601333  step  104  of the epoch  1 the steps is:  573
# 1.6601541478743855  step  105  of the epoch  1 the steps is:  574
# 1.7967776455313782  step  106  of the epoch  1 the steps is:  575
# 1.6088425801770376  step  107  of the epoch  1 the steps is:  576
# 1.2351680074907003  step  108  of the epoch  1 the steps is:  577
# 1.9793270487203116  step  109  of the epoch  1 the steps is:  578
# 1.5151617080334283  step  110  of the epoch  1 the steps is:  579
# 1.33207703233193  step  111  of the epoch  1 the steps is:  580
# 1.4301386860710616  step  112  of the epoch  1 the steps is:  581
# 1.3900978321630943  step  113  of the epoch  1 the steps is:  582
# 1.3568532590693438  step  114  of the epoch  1 the steps is:  583
# 2.005248583650091  step  115  of the epoch  1 the steps is:  584
# 2.067365632490799  step  116  of the epoch  1 the steps is:  585
# 1.6088777017470133  step  117  of the epoch  1 the steps is:  586
# 1.925445235053291  step  118  of the epoch  1 the steps is:  587
# 2.011379016576705  step  119  of the epoch  1 the steps is:  588
# 1.7344394882624294  step  120  of the epoch  1 the steps is:  589
# 1.7144874170725157  step  121  of the epoch  1 the steps is:  590
# 1.8181397717064194  step  122  of the epoch  1 the steps is:  591
# 1.531077769698751  step  123  of the epoch  1 the steps is:  592
# 1.5657224025317822  step  124  of the epoch  1 the steps is:  593
# 1.8694606163611869  step  125  of the epoch  1 the steps is:  594
# 1.8723675854241422  step  126  of the epoch  1 the steps is:  595
# 1.5742037313641735  step  127  of the epoch  1 the steps is:  596
# 1.7971847117925637  step  128  of the epoch  1 the steps is:  597
# 1.5684180894636728  step  129  of the epoch  1 the steps is:  598
# 1.55881393046052  step  130  of the epoch  1 the steps is:  599
# 1.3236326682250765  step  131  of the epoch  1 the steps is:  600
# 1.0828016859955962  step  132  of the epoch  1 the steps is:  601
# 1.6340081202430659  step  133  of the epoch  1 the steps is:  602
# 1.8553935877708052  step  134  of the epoch  1 the steps is:  603
# 1.5175018781750687  step  135  of the epoch  1 the steps is:  604
# 1.6460415937450241  step  136  of the epoch  1 the steps is:  605
# 2.215611394850098  step  137  of the epoch  1 the steps is:  606
# 1.5769108916678733  step  138  of the epoch  1 the steps is:  607
# 1.9625575438735465  step  139  of the epoch  1 the steps is:  608
# 1.4979491710446537  step  140  of the epoch  1 the steps is:  609
# 1.7600207099544778  step  141  of the epoch  1 the steps is:  610
# 1.920580955636186  step  142  of the epoch  1 the steps is:  611
# 1.8462989415550373  step  143  of the epoch  1 the steps is:  612
# 1.798478997065227  step  144  of the epoch  1 the steps is:  613
# 2.091314077854197  step  145  of the epoch  1 the steps is:  614
# 1.2303888336653594  step  146  of the epoch  1 the steps is:  615
# 1.8428921806958183  step  147  of the epoch  1 the steps is:  616
# 1.2619608039742864  step  148  of the epoch  1 the steps is:  617
# 1.4997976223279395  step  149  of the epoch  1 the steps is:  618
# 1.9293961064589413  step  150  of the epoch  1 the steps is:  619
# 1.1381844568741415  step  151  of the epoch  1 the steps is:  620
# 1.983128753463732  step  152  of the epoch  1 the steps is:  621
# 1.100022755895398  step  153  of the epoch  1 the steps is:  622
# 1.66220412096369  step  154  of the epoch  1 the steps is:  623
# 1.7484086301038353  step  155  of the epoch  1 the steps is:  624
# 1.508067087668579  step  156  of the epoch  1 the steps is:  625
# 2.1616304744573083  step  157  of the epoch  1 the steps is:  626
# 1.730493523999848  step  158  of the epoch  1 the steps is:  627
# 1.5613653335641695  step  159  of the epoch  1 the steps is:  628
# 1.2586493486703347  step  160  of the epoch  1 the steps is:  629
# 1.6357991716772575  step  161  of the epoch  1 the steps is:  630
# 1.5297230481793638  step  162  of the epoch  1 the steps is:  631
# 1.4142642016849005  step  163  of the epoch  1 the steps is:  632
# 1.9432308305365924  step  164  of the epoch  1 the steps is:  633
# 1.4925416766885817  step  165  of the epoch  1 the steps is:  634
# 1.2728058788406256  step  166  of the epoch  1 the steps is:  635
# 1.5310244059924936  step  167  of the epoch  1 the steps is:  636
# 1.3265388768379598  step  168  of the epoch  1 the steps is:  637
# 1.414910930520592  step  169  of the epoch  1 the steps is:  638
# 1.5931438880514528  step  170  of the epoch  1 the steps is:  639
# 2.1047399437873135  step  171  of the epoch  1 the steps is:  640
# 1.7108838749395912  step  172  of the epoch  1 the steps is:  641
# 1.2742587924639293  step  173  of the epoch  1 the steps is:  642
# 2.473706082822543  step  174  of the epoch  1 the steps is:  643
# 1.4848524481908978  step  175  of the epoch  1 the steps is:  644
# 1.555334154329143  step  176  of the epoch  1 the steps is:  645
# 1.5397265932716295  step  177  of the epoch  1 the steps is:  646
# 1.5302574414144332  step  178  of the epoch  1 the steps is:  647
# 1.4755653706769918  step  179  of the epoch  1 the steps is:  648
# 1.3768217100301379  step  180  of the epoch  1 the steps is:  649
# 1.7544328898572734  step  181  of the epoch  1 the steps is:  650
# 1.642206013486036  step  182  of the epoch  1 the steps is:  651
# 1.5573789427977487  step  183  of the epoch  1 the steps is:  652
# 2.496852044433101  step  184  of the epoch  1 the steps is:  653
# 1.5127568904651705  step  185  of the epoch  1 the steps is:  654
# 1.6412671566146448  step  186  of the epoch  1 the steps is:  655
# 1.694686171419269  step  187  of the epoch  1 the steps is:  656
# 1.297326811960001  step  188  of the epoch  1 the steps is:  657
# 1.7743448606223469  step  189  of the epoch  1 the steps is:  658
# 1.5916214176903423  step  190  of the epoch  1 the steps is:  659
# 1.6444217202554987  step  191  of the epoch  1 the steps is:  660
# 1.3823863472672568  step  192  of the epoch  1 the steps is:  661
# 1.669204413934838  step  193  of the epoch  1 the steps is:  662
# 1.4828166174721402  step  194  of the epoch  1 the steps is:  663
# 1.344662518617751  step  195  of the epoch  1 the steps is:  664
# 1.5122191828011027  step  196  of the epoch  1 the steps is:  665
# 1.4158183038063785  step  197  of the epoch  1 the steps is:  666
# 1.7255454440327338  step  198  of the epoch  1 the steps is:  667
# 1.3328647040420394  step  199  of the epoch  1 the steps is:  668
# 1.0093640097197643  step  200  of the epoch  1 the steps is:  669
# 1.4637982841716781  step  201  of the epoch  1 the steps is:  670
# 1.4338875272660967  step  202  of the epoch  1 the steps is:  671
# 1.2136771632723977  step  203  of the epoch  1 the steps is:  672
# 2.1106767103766457  step  204  of the epoch  1 the steps is:  673
# 1.4084330917003833  step  205  of the epoch  1 the steps is:  674
# 1.7334049033286445  step  206  of the epoch  1 the steps is:  675
# 1.2923487501200683  step  207  of the epoch  1 the steps is:  676
# 1.5005518805688494  step  208  of the epoch  1 the steps is:  677
# 1.700448383763721  step  209  of the epoch  1 the steps is:  678
# 1.9335354236794902  step  210  of the epoch  1 the steps is:  679
# 1.244599164824691  step  211  of the epoch  1 the steps is:  680
# 1.4618843112884932  step  212  of the epoch  1 the steps is:  681
# 1.5460867939074778  step  213  of the epoch  1 the steps is:  682
# 1.450784796476814  step  214  of the epoch  1 the steps is:  683
# 1.301625058253809  step  215  of the epoch  1 the steps is:  684
# 1.4396303740848286  step  216  of the epoch  1 the steps is:  685
# 1.297418120837833  step  217  of the epoch  1 the steps is:  686
# 2.153969794891633  step  218  of the epoch  1 the steps is:  687
# 1.5113561570275844  step  219  of the epoch  1 the steps is:  688
# 1.963236972544352  step  220  of the epoch  1 the steps is:  689
# 1.5369366044858255  step  221  of the epoch  1 the steps is:  690
# 1.8304548823811388  step  222  of the epoch  1 the steps is:  691
# 1.7841780245177323  step  223  of the epoch  1 the steps is:  692
# 1.469726126915078  step  224  of the epoch  1 the steps is:  693
# 1.3842613884562112  step  225  of the epoch  1 the steps is:  694
# 1.6704514405019173  step  226  of the epoch  1 the steps is:  695
# 1.5977406003717676  step  227  of the epoch  1 the steps is:  696
# 1.4721649511824082  step  228  of the epoch  1 the steps is:  697
# 1.7053632878445786  step  229  of the epoch  1 the steps is:  698
# 1.8750661212985298  step  230  of the epoch  1 the steps is:  699
# 1.7247676225768345  step  231  of the epoch  1 the steps is:  700
# 1.424623057662667  step  232  of the epoch  1 the steps is:  701
# 1.7757476723476142  step  233  of the epoch  1 the steps is:  702
# 1.9444724180300992  step  234  of the epoch  1 the steps is:  703
# 1.5410470017496603  step  235  of the epoch  1 the steps is:  704
# 1.2946735594806125  step  236  of the epoch  1 the steps is:  705
# 1.2153592440669083  step  237  of the epoch  1 the steps is:  706
# 1.652666604029034  step  238  of the epoch  1 the steps is:  707
# 1.747983753074187  step  239  of the epoch  1 the steps is:  708
# 1.7905947608176187  step  240  of the epoch  1 the steps is:  709
# 1.7515656814687208  step  241  of the epoch  1 the steps is:  710
# 1.393925125386694  step  242  of the epoch  1 the steps is:  711
# 1.6052664168915498  step  243  of the epoch  1 the steps is:  712
# 2.4417953351955948  step  244  of the epoch  1 the steps is:  713
# 2.009603541910801  step  245  of the epoch  1 the steps is:  714
# 1.5708912125003784  step  246  of the epoch  1 the steps is:  715
# 2.084340211184686  step  247  of the epoch  1 the steps is:  716
# 1.1719091901082321  step  248  of the epoch  1 the steps is:  717
# 1.5491678608620747  step  249  of the epoch  1 the steps is:  718
# 1.7646562408198767  step  250  of the epoch  1 the steps is:  719
# 1.6721674665739141  step  251  of the epoch  1 the steps is:  720
# 1.8487566346490083  step  252  of the epoch  1 the steps is:  721
# 1.708905580327893  step  253  of the epoch  1 the steps is:  722
# 1.2796940112205606  step  254  of the epoch  1 the steps is:  723
# 1.480414112661243  step  255  of the epoch  1 the steps is:  724
# 1.4423377515480649  step  256  of the epoch  1 the steps is:  725
# 1.0939751133643971  step  257  of the epoch  1 the steps is:  726
# 1.4459447190939658  step  258  of the epoch  1 the steps is:  727
# 1.3778185511503311  step  259  of the epoch  1 the steps is:  728
# 1.4035947869499783  step  260  of the epoch  1 the steps is:  729
# 1.804028768799577  step  261  of the epoch  1 the steps is:  730
# 1.5963258384527481  step  262  of the epoch  1 the steps is:  731
# 1.640021334878872  step  263  of the epoch  1 the steps is:  732
# 2.1536829693128565  step  264  of the epoch  1 the steps is:  733
# 1.577237495410615  step  265  of the epoch  1 the steps is:  734
# 1.8376090029718428  step  266  of the epoch  1 the steps is:  735
# 1.4472053158840263  step  267  of the epoch  1 the steps is:  736
# ...
# 1.745688539085875  step  230  of the epoch  2 the steps is:  1168
# 1.6715147527455054  step  231  of the epoch  2 the steps is:  1169
# 1.3292697715523885  step  232  of the epoch  2 the steps is:  1170
# 1.7161803103893203  step  233  of the epoch  2 the steps is:  1171
# 1.8955507381532977  step  234  of the epoch  2 the steps is:  1172
# 1.4632127706499636  step  235  of the epoch  2 the steps is:  1173
# 1.2260318321733283  step  236  of the epoch  2 the steps is:  1174
# 1.1570805264223658  step  237  of the epoch  2 the steps is:  1175
# 1.5559242502092632  step  238  of the epoch  2 the steps is:  1176
# 1.6521686615978686  step  239  of the epoch  2 the steps is:  1177
# 1.7052051332314102  step  240  of the epoch  2 the steps is:  1178
# 1.691304176085423  step  241  of the epoch  2 the steps is:  1179
# 1.3086644707592296  step  242  of the epoch  2 the steps is:  1180
# 1.560440722199869  step  243  of the epoch  2 the steps is:  1181
# 2.3512394377929775  step  244  of the epoch  2 the steps is:  1182
# 1.944469261524812  step  245  of the epoch  2 the steps is:  1183
# 1.4977978844423006  step  246  of the epoch  2 the steps is:  1184
# 1.977958058017363  step  247  of the epoch  2 the steps is:  1185
# 1.0708655158539  step  248  of the epoch  2 the steps is:  1186
# 1.4615581599734337  step  249  of the epoch  2 the steps is:  1187
# 1.68058084733592  step  250  of the epoch  2 the steps is:  1188
# 1.5912165045322135  step  251  of the epoch  2 the steps is:  1189
# 1.7348924622774173  step  252  of the epoch  2 the steps is:  1190
# 1.6143335760898794  step  253  of the epoch  2 the steps is:  1191
# 1.2440716020103437  step  254  of the epoch  2 the steps is:  1192
# 1.3935822228103643  step  255  of the epoch  2 the steps is:  1193
# 1.3721479364179765  step  256  of the epoch  2 the steps is:  1194
# 1.0189522419205779  step  257  of the epoch  2 the steps is:  1195
# 1.3561613956035568  step  258  of the epoch  2 the steps is:  1196
# 1.2621150177754497  step  259  of the epoch  2 the steps is:  1197
# 1.3533116291008964  step  260  of the epoch  2 the steps is:  1198
# 1.6744079376577994  step  261  of the epoch  2 the steps is:  1199
# 1.555915046501602  step  262  of the epoch  2 the steps is:  1200
# 1.6060413916607725  step  263  of the epoch  2 the steps is:  1201
# 2.089804201243628  step  264  of the epoch  2 the steps is:  1202
# 1.5487445880100636  step  265  of the epoch  2 the steps is:  1203
# 1.7932625101360213  step  266  of the epoch  2 the steps is:  1204
# 1.3649827331813744  step  267  of the epoch  2 the steps is:  1205
# 1.8914900025613917  step  268  of the epoch  2 the steps is:  1206
# 1.492744601999323  step  269  of the epoch  2 the steps is:  1207
# 1.3343869616580084  step  270  of the epoch  2 the steps is:  1208
# 1.4464340095221817  step  271  of the epoch  2 the steps is:  1209
# 1.3868996354001584  step  272  of the epoch  2 the steps is:  1210
# 1.3094476731463132  step  273  of the epoch  2 the steps is:  1211
# 1.3874575548237142  step  274  of the epoch  2 the steps is:  1212
# 1.579130129141383  step  275  of the epoch  2 the steps is:  1213
# 1.4633926308378822  step  276  of the epoch  2 the steps is:  1214
# 1.6136705925445165  step  277  of the epoch  2 the steps is:  1215
# 1.4839380325908667  step  278  of the epoch  2 the steps is:  1216
# 1.4290341603649945  step  279  of the epoch  2 the steps is:  1217
# 1.2697478871591776  step  280  of the epoch  2 the steps is:  1218
# 1.754301990481047  step  281  of the epoch  2 the steps is:  1219
# 1.481356322035471  step  282  of the epoch  2 the steps is:  1220
# 1.5042534658780689  step  283  of the epoch  2 the steps is:  1221
# 1.4160221854236652  step  284  of the epoch  2 the steps is:  1222
# 1.0530769752251294  step  285  of the epoch  2 the steps is:  1223
# 1.7551763690519147  step  286  of the epoch  2 the steps is:  1224
# 1.4905222517582426  step  287  of the epoch  2 the steps is:  1225
# 1.4177525843020504  step  288  of the epoch  2 the steps is:  1226
# 1.7767270770330246  step  289  of the epoch  2 the steps is:  1227
# 0.7017991806152184  step  290  of the epoch  2 the steps is:  1228
# 1.783978048630207  step  291  of the epoch  2 the steps is:  1229
# 1.5703736872235905  step  292  of the epoch  2 the steps is:  1230
# 1.5872219430977346  step  293  of the epoch  2 the steps is:  1231
# 1.2358219253309544  step  294  of the epoch  2 the steps is:  1232
# 1.665623527551301  step  295  of the epoch  2 the steps is:  1233
# 1.5050065373126333  step  296  of the epoch  2 the steps is:  1234
# 1.7393334734527284  step  297  of the epoch  2 the steps is:  1235
# 1.7799407437546289  step  298  of the epoch  2 the steps is:  1236
# 1.523518814997233  step  299  of the epoch  2 the steps is:  1237
# 1.3338585338766449  step  300  of the epoch  2 the steps is:  1238
# 1.4809429357435766  step  301  of the epoch  2 the steps is:  1239
# 1.6825499162486723  step  302  of the epoch  2 the steps is:  1240
# 1.688410020553973  step  303  of the epoch  2 the steps is:  1241
# 1.7268575558017303  step  304  of the epoch  2 the steps is:  1242
# 1.1509452233439383  step  305  of the epoch  2 the steps is:  1243
# 1.8234057084683641  step  306  of the epoch  2 the steps is:  1244
# 1.3673370139791727  step  307  of the epoch  2 the steps is:  1245
# 1.4769601917427448  step  308  of the epoch  2 the steps is:  1246
# 1.1674238618841453  step  309  of the epoch  2 the steps is:  1247
# 1.3929468157281961  step  310  of the epoch  2 the steps is:  1248
# 1.0018533700510237  step  311  of the epoch  2 the steps is:  1249
# 1.620515599911922  step  312  of the epoch  2 the steps is:  1250
# 1.4248338580295608  step  313  of the epoch  2 the steps is:  1251
# 1.0993553992330063  step  314  of the epoch  2 the steps is:  1252
# 1.2245730453535244  step  315  of the epoch  2 the steps is:  1253
# 1.0144706639418473  step  316  of the epoch  2 the steps is:  1254
# 1.6271941892672186  step  317  of the epoch  2 the steps is:  1255
# 1.450473106532747  step  318  of the epoch  2 the steps is:  1256
# 1.1582795641812957  step  319  of the epoch  2 the steps is:  1257
# 1.210392408895039  step  320  of the epoch  2 the steps is:  1258
# 1.6732534867639117  step  321  of the epoch  2 the steps is:  1259
# 1.6582575492640264  step  322  of the epoch  2 the steps is:  1260
# 1.3385961713261654  step  323  of the epoch  2 the steps is:  1261
# 1.5177941845580407  step  324  of the epoch  2 the steps is:  1262
# 1.7113978320766434  step  325  of the epoch  2 the steps is:  1263
# 1.1196903682818693  step  326  of the epoch  2 the steps is:  1264
# 1.6924649319982956  step  327  of the epoch  2 the steps is:  1265
# 1.7618440789673995  step  328  of the epoch  2 the steps is:  1266
# 1.704092518055442  step  329  of the epoch  2 the steps is:  1267
# 1.8164175426362459  step  330  of the epoch  2 the steps is:  1268
# 1.2714850417292067  step  331  of the epoch  2 the steps is:  1269
# 1.093707326294525  step  332  of the epoch  2 the steps is:  1270
# 1.7434128833344493  step  333  of the epoch  2 the steps is:  1271
# 1.3762779986227667  step  334  of the epoch  2 the steps is:  1272
# 1.5010403885450663  step  335  of the epoch  2 the steps is:  1273
# 1.435251106792904  step  336  of the epoch  2 the steps is:  1274
# 1.202635383866226  step  337  of the epoch  2 the steps is:  1275
# 1.4480110968910203  step  338  of the epoch  2 the steps is:  1276
# 1.0519557695544866  step  339  of the epoch  2 the steps is:  1277
# 1.6100324292799333  step  340  of the epoch  2 the steps is:  1278
# 1.2486655777021323  step  341  of the epoch  2 the steps is:  1279
# 1.6086981819137987  step  342  of the epoch  2 the steps is:  1280
# 1.454825468698545  step  343  of the epoch  2 the steps is:  1281
# 1.5554919188281568  step  344  of the epoch  2 the steps is:  1282
# 1.8892351912505303  step  345  of the epoch  2 the steps is:  1283
# 1.0688467592850177  step  346  of the epoch  2 the steps is:  1284
# 1.8288071528717937  step  347  of the epoch  2 the steps is:  1285
# 1.4786317557660855  step  348  of the epoch  2 the steps is:  1286
# 1.6695068065603818  step  349  of the epoch  2 the steps is:  1287
# 1.8916086492535809  step  350  of the epoch  2 the steps is:  1288
# 1.7572539615096998  step  351  of the epoch  2 the steps is:  1289
# 1.7850363867936947  step  352  of the epoch  2 the steps is:  1290
# 1.4235237112971537  step  353  of the epoch  2 the steps is:  1291
# 1.259907315359468  step  354  of the epoch  2 the steps is:  1292
# 1.4687180729290643  step  355  of the epoch  2 the steps is:  1293
# 1.0368027198764433  step  356  of the epoch  2 the steps is:  1294
# 1.6763093217204055  step  357  of the epoch  2 the steps is:  1295
# 1.3597083223393898  step  358  of the epoch  2 the steps is:  1296
# 1.482013016168185  step  359  of the epoch  2 the steps is:  1297
# 1.292148756224214  step  360  of the epoch  2 the steps is:  1298
# 1.8043878782302887  step  361  of the epoch  2 the steps is:  1299
# 1.4141442552936851  step  362  of the epoch  2 the steps is:  1300
# 1.169557719216804  step  363  of the epoch  2 the steps is:  1301
# 1.8289337607302802  step  364  of the epoch  2 the steps is:  1302
# 1.6499170253807038  step  365  of the epoch  2 the steps is:  1303
# 1.5985099431525773  step  366  of the epoch  2 the steps is:  1304
# 1.7573209283922098  step  367  of the epoch  2 the steps is:  1305
# 1.8383803364324243  step  368  of the epoch  2 the steps is:  1306
# 1.5262199303540305  step  369  of the epoch  2 the steps is:  1307
# 1.4475294984557658  step  370  of the epoch  2 the steps is:  1308
# 1.6489644997050412  step  371  of the epoch  2 the steps is:  1309
# 1.0394911813287098  step  372  of the epoch  2 the steps is:  1310
# 1.1647681229532243  step  373  of the epoch  2 the steps is:  1311
# 1.1456365985896222  step  374  of the epoch  2 the steps is:  1312
# 1.4918444771050954  step  375  of the epoch  2 the steps is:  1313
# 1.1759160169094305  step  376  of the epoch  2 the steps is:  1314
# 1.4443956656554446  step  377  of the epoch  2 the steps is:  1315
# 1.1759593867420297  step  378  of the epoch  2 the steps is:  1316
# 1.4762680142209046  step  379  of the epoch  2 the steps is:  1317
# 1.5202190831814288  step  380  of the epoch  2 the steps is:  1318
# 1.1700421262347316  step  381  of the epoch  2 the steps is:  1319
# 1.4836292449277133  step  382  of the epoch  2 the steps is:  1320
# 1.4528036648412332  step  383  of the epoch  2 the steps is:  1321
# 1.372328609165034  step  384  of the epoch  2 the steps is:  1322
# 1.3565908131395865  step  385  of the epoch  2 the steps is:  1323
# 1.3190816255657816  step  386  of the epoch  2 the steps is:  1324
# 1.7861644089051283  step  387  of the epoch  2 the steps is:  1325
# 1.311863672821197  step  388  of the epoch  2 the steps is:  1326
# 1.5477387919859018  step  389  of the epoch  2 the steps is:  1327
# 1.4810378399843547  step  390  of the epoch  2 the steps is:  1328
# 1.505824615911457  step  391  of the epoch  2 the steps is:  1329
# 1.7364804216092522  step  392  of the epoch  2 the steps is:  1330
# 1.3830629955958496  step  393  of the epoch  2 the steps is:  1331
# 1.6708994740216943  step  394  of the epoch  2 the steps is:  1332
# 1.4259226186130327  step  395  of the epoch  2 the steps is:  1333
# 1.329179051361871  step  396  of the epoch  2 the steps is:  1334
# 1.160496313331242  step  397  of the epoch  2 the steps is:  1335
# 1.3170640051179077  step  398  of the epoch  2 the steps is:  1336
# 1.6748565069408872  step  399  of the epoch  2 the steps is:  1337
# 1.8078644744254952  step  400  of the epoch  2 the steps is:  1338
# 1.8115380836988542  step  401  of the epoch  2 the steps is:  1339
# 1.3921809222096495  step  402  of the epoch  2 the steps is:  1340
# 2.034415472345028  step  403  of the epoch  2 the steps is:  1341
# 1.2939641598853624  step  404  of the epoch  2 the steps is:  1342
# 1.3982308415489137  step  405  of the epoch  2 the steps is:  1343
# 1.3063655656736761  step  406  of the epoch  2 the steps is:  1344
# 1.8920537132045638  step  407  of the epoch  2 the steps is:  1345
# 2.023366649576119  step  408  of the epoch  2 the steps is:  1346
# 1.4597761894640455  step  409  of the epoch  2 the steps is:  1347
# 1.4703558578682334  step  410  of the epoch  2 the steps is:  1348
# 1.8526967210110423  step  411  of the epoch  2 the steps is:  1349
# 1.319372841270268  step  412  of the epoch  2 the steps is:  1350
# 1.4634455666476514  step  413  of the epoch  2 the steps is:  1351
# 1.100881719396937  step  414  of the epoch  2 the steps is:  1352
# 1.4594094234234447  step  415  of the epoch  2 the steps is:  1353
# 1.8875997402460554  step  416  of the epoch  2 the steps is:  1354
# 1.8848335990379483  step  417  of the epoch  2 the steps is:  1355
# 1.6112960392005047  step  418  of the epoch  2 the steps is:  1356
# 1.3237459047599618  step  419  of the epoch  2 the steps is:  1357
# 1.6253111517810215  step  420  of the epoch  2 the steps is:  1358
# 1.4200501737173925  step  421  of the epoch  2 the steps is:  1359
# 1.6575842096677422  step  422  of the epoch  2 the steps is:  1360
# 1.1155096398639153  step  423  of the epoch  2 the steps is:  1361
# 1.4615346905232902  step  424  of the epoch  2 the steps is:  1362
# 1.5048510130666448  step  425  of the epoch  2 the steps is:  1363
# 1.54195342770559  step  426  of the epoch  2 the steps is:  1364
# 1.2231519674284552  step  427  of the epoch  2 the steps is:  1365
# 1.9676124799539525  step  428  of the epoch  2 the steps is:  1366
# 1.2873361478581726  step  429  of the epoch  2 the steps is:  1367
# 1.5776164747144676  step  430  of the epoch  2 the steps is:  1368
# 1.6241402129055944  step  431  of the epoch  2 the steps is:  1369
# 1.5073181345691806  step  432  of the epoch  2 the steps is:  1370
# 1.4185878264535794  step  433  of the epoch  2 the steps is:  1371
# 1.187431141891274  step  434  of the epoch  2 the steps is:  1372
# 1.6767085720337302  step  435  of the epoch  2 the steps is:  1373
# 1.7910240239787172  step  436  of the epoch  2 the steps is:  1374
# 1.6549608198108687  step  437  of the epoch  2 the steps is:  1375
# 2.0006072044290626  step  438  of the epoch  2 the steps is:  1376
# 1.1691618524340814  step  439  of the epoch  2 the steps is:  1377
# 1.8944483842272244  step  440  of the epoch  2 the steps is:  1378
# 1.3872896639676948  step  441  of the epoch  2 the steps is:  1379
# 1.6641226196090793  step  442  of the epoch  2 the steps is:  1380
# 1.0478320671808672  step  443  of the epoch  2 the steps is:  1381
# 1.8993604110122193  step  444  of the epoch  2 the steps is:  1382
# 1.6289615781106326  step  445  of the epoch  2 the steps is:  1383
# 1.823228536011785  step  446  of the epoch  2 the steps is:  1384
# 1.0552650354329667  step  447  of the epoch  2 the steps is:  1385
# 1.3271585033952602  step  448  of the epoch  2 the steps is:  1386
# 1.5045723753046747  step  449  of the epoch  2 the steps is:  1387
# 1.2835221685277314  step  450  of the epoch  2 the steps is:  1388
# 1.5005075202706877  step  451  of the epoch  2 the steps is:  1389
# 1.6977192941093755  step  452  of the epoch  2 the steps is:  1390
# 1.3518464774653034  step  453  of the epoch  2 the steps is:  1391
# 1.7954995476521103  step  454  of the epoch  2 the steps is:  1392
# 1.4936751895514233  step  455  of the epoch  2 the steps is:  1393
# 1.5088288450635408  step  456  of the epoch  2 the steps is:  1394
# 1.6823149036076588  step  457  of the epoch  2 the steps is:  1395
# 1.2254846665924486  step  458  of the epoch  2 the steps is:  1396
# 1.4027195225774705  step  459  of the epoch  2 the steps is:  1397
# 1.70842813057408  step  460  of the epoch  2 the steps is:  1398
# 1.1801912565482995  step  461  of the epoch  2 the steps is:  1399
# 1.240056060814608  step  462  of the epoch  2 the steps is:  1400
# 1.60421174842051  step  463  of the epoch  2 the steps is:  1401
# 1.355493412962745  step  464  of the epoch  2 the steps is:  1402
# 0.8923693808904  step  465  of the epoch  2 the steps is:  1403
# 1.4644257290889828  step  466  of the epoch  2 the steps is:  1404
# 1.2489106756556976  step  467  of the epoch  2 the steps is:  1405
# 1.4590000365374678  step  468  of the epoch  2 the steps is:  1406

# %%
MyNetwork.Test_Network(Test_data, Test_label)
# Out:
# 0.8396

# %%
mini_dataSet, mini_labelSet = [],[]
j = 0
for i in range(100):
  if MyNetwork.forward(Train_data[i]) == Train_label[i]:
    mini_dataSet.append(Train_data[i])
    mini_labelSet.append(Train_label[i])
    j += 1
  if j == 10:
    break

# %%
attacked_image = []
for i in range(10):
  attacked_image.append(MyNetwork.attach_network(mini_dataSet[i], mini_labelSet[i]))
# Out:
# 0.0
# 0.0
# 0.2184309381199918
# 1.0214633663172488
# 0.0
# 0.3193349080628409
# 0.0
# 0.0
# 0.0
# 0.0

# %%
score = 0
for i in range(10):
  print("The label for the", i,"th data is: ", MyNetwork.forward(mini_dataSet[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))))
  if MyNetwork.forward(mini_dataSet[i]) != MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score += 1
print("The attacked accuracy was: ", score * 10)
# Out:
# The label for the 0 th data is:  [9] after attack it became:  [9]
# The label for the 1 th data is:  [0] after attack it became:  [0]
# The label for the 2 th data is:  [0] after attack it became:  [0]
# The label for the 3 th data is:  [0] after attack it became:  [0]
# The label for the 4 th data is:  [2] after attack it became:  [2]
# The label for the 5 th data is:  [7] after attack it became:  [7]
# The label for the 6 th data is:  [2] after attack it became:  [2]
# The label for the 7 th data is:  [5] after attack it became:  [5]
# The label for the 8 th data is:  [5] after attack it became:  [5]
# The label for the 9 th data is:  [0] after attack it became:  [0]
# The attacked accuracy was:  0

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)

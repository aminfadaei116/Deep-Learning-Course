# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx, landa):
  temp = np.multiply(step(landa - vect),-1)
  temp[idx] = 1
  return temp

def gelu(x):
    return 0.5 * np.multiply(x, 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def Dgelu(x):
  return np.divide(0.053516 * np.power(x, 3) + np.multiply(0.398942, x) , np.power(np.cosh(0.0356774 * np.power(x, 3) +np.multiply(0.79788, x)),2)) + 0.5 * ( 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def RBF_encode(data, number_class, dim):
  data = np.reshape(data, (dim,int(data.size/dim)), order='F')
  data = LA.norm(data,1, axis = 0)
  data = np.reshape(data, (number_class, int(data.size/number_class)), order='F')
  return data

def expand(x):
  temp = []
  for i in range(len(x)):
    temp.append(x[i])
    temp.append(x[i])
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.distance_dim = 2
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.landa = 550
    self.attack_rate = 1

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = gelu(self.layer["z0"])
    self.layer["s0"] = Dgelu(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = gelu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = Dgelu(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = RBF_encode(self.layer["z" + str(self.number_hidden_layer)], self.number_class_output, self.distance_dim)
    self.layer["s" + str(self.number_hidden_layer)] = np.sign(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide_RBF(self.score)
    return temp
  
  def decide_RBF(self, data):
    self.result = np.argmin(data, axis=0)
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu((self.landa - temp[i]))) - relu(self.landa- temp[i][label[i]]) + temp[i][label[i]])
      self.back_prob_output.append(encode(temp[i], label[i], self.landa))
    self.back_prob_output = np.transpose(self.back_prob_output)/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] - self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] - self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))

  def attack_network(self, data, label):
    self.forward(data)
    self.cal_loss(label)
    D_image = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      D_image = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), D_image)
      D_image = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], D_image)
    D_image = np.matmul(np.transpose(self.weight["w0"]), D_image)
    D_image = np.sign(D_image) 
    return data - self.attack_rate * D_image.reshape((-1,))

# %%
MyNetwork = Network(128,1,[150] ,10)
#MyNetwork.load_weights()

# %%
MyNetwork.set_learning_rate(0.05)
MyNetwork.set_turn(3)
MyNetwork.set_batch_size(128)
MyNetwork.Train_Network(Train_data, Train_label)
# Out:
# 4945.557310042795  step  0  of the epoch  0 the steps is:  0
# 4945.60007272353  step  1  of the epoch  0 the steps is:  1
# 4945.323271909465  step  2  of the epoch  0 the steps is:  2
# 4945.099808355788  step  3  of the epoch  0 the steps is:  3
# 4944.454029821204  step  4  of the epoch  0 the steps is:  4
# 4943.885064066695  step  5  of the epoch  0 the steps is:  5
# 4943.376270415738  step  6  of the epoch  0 the steps is:  6
# 4942.2090221640465  step  7  of the epoch  0 the steps is:  7
# 4941.142829269391  step  8  of the epoch  0 the steps is:  8
# 4939.263020310578  step  9  of the epoch  0 the steps is:  9
# 4937.676172150729  step  10  of the epoch  0 the steps is:  10
# 4935.0794877940625  step  11  of the epoch  0 the steps is:  11
# 4933.1168309888435  step  12  of the epoch  0 the steps is:  12
# 4928.878451734632  step  13  of the epoch  0 the steps is:  13
# 4924.728884438577  step  14  of the epoch  0 the steps is:  14
# 4919.237154532351  step  15  of the epoch  0 the steps is:  15
# 4913.15609770752  step  16  of the epoch  0 the steps is:  16
# 4904.275975636687  step  17  of the epoch  0 the steps is:  17
# 4893.447949081394  step  18  of the epoch  0 the steps is:  18
# 4879.371604693255  step  19  of the epoch  0 the steps is:  19
# 4863.730505733291  step  20  of the epoch  0 the steps is:  20
# 4843.485832086628  step  21  of the epoch  0 the steps is:  21
# 4812.956043559076  step  22  of the epoch  0 the steps is:  22
# 4779.8357138601095  step  23  of the epoch  0 the steps is:  23
# 4740.174695165808  step  24  of the epoch  0 the steps is:  24
# 4688.554099121169  step  25  of the epoch  0 the steps is:  25
# 4612.555428735234  step  26  of the epoch  0 the steps is:  26
# 4536.192473924997  step  27  of the epoch  0 the steps is:  27
# 4419.351541560118  step  28  of the epoch  0 the steps is:  28
# 4282.475302731587  step  29  of the epoch  0 the steps is:  29
# 4113.44266173073  step  30  of the epoch  0 the steps is:  30
# 3866.394029642237  step  31  of the epoch  0 the steps is:  31
# 3597.1090632680894  step  32  of the epoch  0 the steps is:  32
# 3225.131817469509  step  33  of the epoch  0 the steps is:  33
# 2791.6916532296327  step  34  of the epoch  0 the steps is:  34
# 2209.7294845518336  step  35  of the epoch  0 the steps is:  35
# 1530.9095920952147  step  36  of the epoch  0 the steps is:  36
# 764.8776613033381  step  37  of the epoch  0 the steps is:  37
# 685.9665760588402  step  38  of the epoch  0 the steps is:  38
# 791.9439442728725  step  39  of the epoch  0 the steps is:  39
# 905.5894792943889  step  40  of the epoch  0 the steps is:  40
# 1003.2674228932774  step  41  of the epoch  0 the steps is:  41
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in power
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in cosh
# 1107.0313918970558  step  42  of the epoch  0 the steps is:  42
# 1187.8276400826155  step  43  of the epoch  0 the steps is:  43
# 1241.7403437769826  step  44  of the epoch  0 the steps is:  44
# 1285.5135088846555  step  45  of the epoch  0 the steps is:  45
# 1319.4614389101082  step  46  of the epoch  0 the steps is:  46
# 1373.7334470665758  step  47  of the epoch  0 the steps is:  47
# 1368.2876745215876  step  48  of the epoch  0 the steps is:  48
# 1365.9637603922072  step  49  of the epoch  0 the steps is:  49
# 1374.3494321871563  step  50  of the epoch  0 the steps is:  50
# 1358.6350098383377  step  51  of the epoch  0 the steps is:  51
# 1330.5236097064808  step  52  of the epoch  0 the steps is:  52
# 1309.1628904355234  step  53  of the epoch  0 the steps is:  53
# 1279.0462104964568  step  54  of the epoch  0 the steps is:  54
# 1236.5128617073028  step  55  of the epoch  0 the steps is:  55
# 1202.7243881814215  step  56  of the epoch  0 the steps is:  56
# 1153.6789328293848  step  57  of the epoch  0 the steps is:  57
# 1108.173557995197  step  58  of the epoch  0 the steps is:  58
# 1060.4595002160818  step  59  of the epoch  0 the steps is:  59
# 1021.6947586954636  step  60  of the epoch  0 the steps is:  60
# 981.6160960716605  step  61  of the epoch  0 the steps is:  61
# 922.0089740921666  step  62  of the epoch  0 the steps is:  62
# 882.50706577659  step  63  of the epoch  0 the steps is:  63
# 835.6447682976786  step  64  of the epoch  0 the steps is:  64
# 783.0744132043603  step  65  of the epoch  0 the steps is:  65
# 752.958674427724  step  66  of the epoch  0 the steps is:  66
# 715.3407006382232  step  67  of the epoch  0 the steps is:  67
# 666.0385040111158  step  68  of the epoch  0 the steps is:  68
# 678.0057303382787  step  69  of the epoch  0 the steps is:  69
# 689.2682815495203  step  70  of the epoch  0 the steps is:  70
# 761.4356629696931  step  71  of the epoch  0 the steps is:  71
# 767.2164182842232  step  72  of the epoch  0 the steps is:  72
# 778.7965930601349  step  73  of the epoch  0 the steps is:  73
# 726.8711965804514  step  74  of the epoch  0 the steps is:  74
# 682.8324339628175  step  75  of the epoch  0 the steps is:  75
# 659.1633307905454  step  76  of the epoch  0 the steps is:  76
# 657.7367300206256  step  77  of the epoch  0 the steps is:  77
# 661.10330131917  step  78  of the epoch  0 the steps is:  78
# 673.4555179917522  step  79  of the epoch  0 the steps is:  79
# 679.4711042584925  step  80  of the epoch  0 the steps is:  80
# 692.7894041089218  step  81  of the epoch  0 the steps is:  81
# 700.1011691705876  step  82  of the epoch  0 the steps is:  82
# 690.3131554116917  step  83  of the epoch  0 the steps is:  83
# 682.274999404808  step  84  of the epoch  0 the steps is:  84
# 665.7025688235415  step  85  of the epoch  0 the steps is:  85
# 678.5192075554831  step  86  of the epoch  0 the steps is:  86
# 657.9550955170625  step  87  of the epoch  0 the steps is:  87
# 651.0563223931065  step  88  of the epoch  0 the steps is:  88
# 643.1376564824398  step  89  of the epoch  0 the steps is:  89
# 632.3299310765342  step  90  of the epoch  0 the steps is:  90
# 646.28807624559  step  91  of the epoch  0 the steps is:  91
# 633.694844790129  step  92  of the epoch  0 the steps is:  92
# 628.2091777174483  step  93  of the epoch  0 the steps is:  93
# 651.8186309208265  step  94  of the epoch  0 the steps is:  94
# 631.3594656987516  step  95  of the epoch  0 the steps is:  95
# 642.1454178784239  step  96  of the epoch  0 the steps is:  96
# 633.1710361271046  step  97  of the epoch  0 the steps is:  97
# 645.6788853338393  step  98  of the epoch  0 the steps is:  98
# 625.0145007801374  step  99  of the epoch  0 the steps is:  99
# 638.0472031551456  step  100  of the epoch  0 the steps is:  100
# 632.5103652098762  step  101  of the epoch  0 the steps is:  101
# 630.3506215043212  step  102  of the epoch  0 the steps is:  102
# 628.9663751988264  step  103  of the epoch  0 the steps is:  103
# 627.9559593386209  step  104  of the epoch  0 the steps is:  104
# 626.8754387050353  step  105  of the epoch  0 the steps is:  105
# 616.6829846460582  step  106  of the epoch  0 the steps is:  106
# 623.2089672191278  step  107  of the epoch  0 the steps is:  107
# 614.5437396667635  step  108  of the epoch  0 the steps is:  108
# 624.6579675523334  step  109  of the epoch  0 the steps is:  109
# 605.3603072749611  step  110  of the epoch  0 the steps is:  110
# 640.5620464936097  step  111  of the epoch  0 the steps is:  111
# 617.0470598513893  step  112  of the epoch  0 the steps is:  112
# 623.0763762628808  step  113  of the epoch  0 the steps is:  113
# 608.5735562510353  step  114  of the epoch  0 the steps is:  114
# 614.7325648757511  step  115  of the epoch  0 the steps is:  115
# 620.8468872548542  step  116  of the epoch  0 the steps is:  116
# 610.3577820418068  step  117  of the epoch  0 the steps is:  117
# 613.0517010196293  step  118  of the epoch  0 the steps is:  118
# 625.3941751586674  step  119  of the epoch  0 the steps is:  119
# 618.315376717105  step  120  of the epoch  0 the steps is:  120
# 617.7476884941269  step  121  of the epoch  0 the steps is:  121
# 611.8541586327676  step  122  of the epoch  0 the steps is:  122
# 597.2922631431812  step  123  of the epoch  0 the steps is:  123
# 621.5633347090561  step  124  of the epoch  0 the steps is:  124
# 609.0641627902223  step  125  of the epoch  0 the steps is:  125
# 603.7794231073212  step  126  of the epoch  0 the steps is:  126
# 609.2921042425223  step  127  of the epoch  0 the steps is:  127
# 602.9626413758178  step  128  of the epoch  0 the steps is:  128
# 612.2394988283147  step  129  of the epoch  0 the steps is:  129
# 615.1889436892934  step  130  of the epoch  0 the steps is:  130
# 605.5583289038033  step  131  of the epoch  0 the steps is:  131
# 605.048390772687  step  132  of the epoch  0 the steps is:  132
# 605.4399182965575  step  133  of the epoch  0 the steps is:  133
# 607.0671790095457  step  134  of the epoch  0 the steps is:  134
# 595.1589522152672  step  135  of the epoch  0 the steps is:  135
# 613.5912443837904  step  136  of the epoch  0 the steps is:  136
# 603.8616500479171  step  137  of the epoch  0 the steps is:  137
# 600.5858760772574  step  138  of the epoch  0 the steps is:  138
# 601.2567838899854  step  139  of the epoch  0 the steps is:  139
# 603.2378496726438  step  140  of the epoch  0 the steps is:  140
# 599.9879743063524  step  141  of the epoch  0 the steps is:  141
# 600.0983154020428  step  142  of the epoch  0 the steps is:  142
# 593.3949420214698  step  143  of the epoch  0 the steps is:  143
# 597.8507547380116  step  144  of the epoch  0 the steps is:  144
# 592.7124336246741  step  145  of the epoch  0 the steps is:  145
# 587.8586453450121  step  146  of the epoch  0 the steps is:  146
# 594.4975417360033  step  147  of the epoch  0 the steps is:  147
# 599.7424459463559  step  148  of the epoch  0 the steps is:  148
# 599.0949788242438  step  149  of the epoch  0 the steps is:  149
# 593.20790638051  step  150  of the epoch  0 the steps is:  150
# 593.7425658694168  step  151  of the epoch  0 the steps is:  151
# 590.7916141795504  step  152  of the epoch  0 the steps is:  152
# 589.3873315173412  step  153  of the epoch  0 the steps is:  153
# 589.8465776601034  step  154  of the epoch  0 the steps is:  154
# 601.6518488405709  step  155  of the epoch  0 the steps is:  155
# 585.350806098229  step  156  of the epoch  0 the steps is:  156
# 588.1210330096369  step  157  of the epoch  0 the steps is:  157
# 591.0336468464197  step  158  of the epoch  0 the steps is:  158
# 585.192548267787  step  159  of the epoch  0 the steps is:  159
# 592.0833286325609  step  160  of the epoch  0 the steps is:  160
# 598.7720393049647  step  161  of the epoch  0 the steps is:  161
# 587.8412254994772  step  162  of the epoch  0 the steps is:  162
# 589.0821746245413  step  163  of the epoch  0 the steps is:  163
# 588.4066728511252  step  164  of the epoch  0 the steps is:  164
# 587.6934336712367  step  165  of the epoch  0 the steps is:  165
# 589.6684572138203  step  166  of the epoch  0 the steps is:  166
# 581.7200538589798  step  167  of the epoch  0 the steps is:  167
# 590.7597812201893  step  168  of the epoch  0 the steps is:  168
# 580.4612990290248  step  169  of the epoch  0 the steps is:  169
# 582.6061288139645  step  170  of the epoch  0 the steps is:  170
# 581.4405580125531  step  171  of the epoch  0 the steps is:  171
# 581.6050827119683  step  172  of the epoch  0 the steps is:  172
# 584.9165449971073  step  173  of the epoch  0 the steps is:  173
# 581.1028117831329  step  174  of the epoch  0 the steps is:  174
# 578.1663009588702  step  175  of the epoch  0 the steps is:  175
# 581.9416161143067  step  176  of the epoch  0 the steps is:  176
# 573.8538437146997  step  177  of the epoch  0 the steps is:  177
# 579.0786454786182  step  178  of the epoch  0 the steps is:  178
# 576.5892396519847  step  179  of the epoch  0 the steps is:  179
# 579.947419794712  step  180  of the epoch  0 the steps is:  180
# 575.9890382256883  step  181  of the epoch  0 the steps is:  181
# 577.0696417048764  step  182  of the epoch  0 the steps is:  182
# 575.7321549871567  step  183  of the epoch  0 the steps is:  183
# 573.2025326201265  step  184  of the epoch  0 the steps is:  184
# 574.6353010382405  step  185  of the epoch  0 the steps is:  185
# 574.4973281925763  step  186  of the epoch  0 the steps is:  186
# 580.9886635121636  step  187  of the epoch  0 the steps is:  187
# 573.0385450115518  step  188  of the epoch  0 the steps is:  188
# 570.2059707480098  step  189  of the epoch  0 the steps is:  189
# 569.710729296067  step  190  of the epoch  0 the steps is:  190
# 574.655571979566  step  191  of the epoch  0 the steps is:  191
# 569.3372858628659  step  192  of the epoch  0 the steps is:  192
# 573.7397549193813  step  193  of the epoch  0 the steps is:  193
# 571.5233709897444  step  194  of the epoch  0 the steps is:  194
# 568.3467221760583  step  195  of the epoch  0 the steps is:  195
# 573.2144126732499  step  196  of the epoch  0 the steps is:  196
# 565.6060045229319  step  197  of the epoch  0 the steps is:  197
# 570.6015149009817  step  198  of the epoch  0 the steps is:  198
# 568.8134634164687  step  199  of the epoch  0 the steps is:  199
# 565.9670889576754  step  200  of the epoch  0 the steps is:  200
# 566.1031048022035  step  201  of the epoch  0 the steps is:  201
# 568.3682179692506  step  202  of the epoch  0 the steps is:  202
# 567.779417978493  step  203  of the epoch  0 the steps is:  203
# 568.0329589807817  step  204  of the epoch  0 the steps is:  204
# 566.7167114732727  step  205  of the epoch  0 the steps is:  205
# 568.4779064552783  step  206  of the epoch  0 the steps is:  206
# 566.2592548663409  step  207  of the epoch  0 the steps is:  207
# 563.1713217182894  step  208  of the epoch  0 the steps is:  208
# 565.2602775978563  step  209  of the epoch  0 the steps is:  209
# 561.294994541468  step  210  of the epoch  0 the steps is:  210
# 562.3805408345859  step  211  of the epoch  0 the steps is:  211
# 563.2045981636659  step  212  of the epoch  0 the steps is:  212
# 561.6201201566943  step  213  of the epoch  0 the steps is:  213
# 569.6051959299194  step  214  of the epoch  0 the steps is:  214
# 565.0191414124454  step  215  of the epoch  0 the steps is:  215
# 559.5125406825495  step  216  of the epoch  0 the steps is:  216
# 560.709701613594  step  217  of the epoch  0 the steps is:  217
# 560.413076248142  step  218  of the epoch  0 the steps is:  218
# 559.1931060140571  step  219  of the epoch  0 the steps is:  219
# 558.6416860185516  step  220  of the epoch  0 the steps is:  220
# 560.2385001324666  step  221  of the epoch  0 the steps is:  221
# 559.6094219452103  step  222  of the epoch  0 the steps is:  222
# 556.7106160469514  step  223  of the epoch  0 the steps is:  223
# 556.1341753982749  step  224  of the epoch  0 the steps is:  224
# 557.0300349092752  step  225  of the epoch  0 the steps is:  225
# 560.2469940051365  step  226  of the epoch  0 the steps is:  226
# 555.3651095313185  step  227  of the epoch  0 the steps is:  227
# 557.122930577981  step  228  of the epoch  0 the steps is:  228
# 559.0472928116594  step  229  of the epoch  0 the steps is:  229
# 557.511221089489  step  230  of the epoch  0 the steps is:  230
# 556.5636639599907  step  231  of the epoch  0 the steps is:  231
# 555.0285416528623  step  232  of the epoch  0 the steps is:  232
# 554.6986748998999  step  233  of the epoch  0 the steps is:  233
# 554.3422862050722  step  234  of the epoch  0 the steps is:  234
# 552.5259368156482  step  235  of the epoch  0 the steps is:  235
# 554.8902337060424  step  236  of the epoch  0 the steps is:  236
# 552.5242298656019  step  237  of the epoch  0 the steps is:  237
# 554.470767061966  step  238  of the epoch  0 the steps is:  238
# 554.4284431325917  step  239  of the epoch  0 the steps is:  239
# 553.0695107037302  step  240  of the epoch  0 the steps is:  240
# 553.9357778723166  step  241  of the epoch  0 the steps is:  241
# 552.4472407077022  step  242  of the epoch  0 the steps is:  242
# 553.5895340599751  step  243  of the epoch  0 the steps is:  243
# 553.4583534994863  step  244  of the epoch  0 the steps is:  244
# 551.7210439515936  step  245  of the epoch  0 the steps is:  245
# 550.3003244878377  step  246  of the epoch  0 the steps is:  246
# 552.785428449767  step  247  of the epoch  0 the steps is:  247
# 549.7437196647281  step  248  of the epoch  0 the steps is:  248
# 549.5273430764853  step  249  of the epoch  0 the steps is:  249
# 550.2476485449167  step  250  of the epoch  0 the steps is:  250
# 549.9426378870551  step  251  of the epoch  0 the steps is:  251
# 550.8171376726206  step  252  of the epoch  0 the steps is:  252
# 549.7575967418627  step  253  of the epoch  0 the steps is:  253
# 549.1993432032091  step  254  of the epoch  0 the steps is:  254
# 549.1414776645087  step  255  of the epoch  0 the steps is:  255
# 550.2336830745407  step  256  of the epoch  0 the steps is:  256
# 548.7880926747503  step  257  of the epoch  0 the steps is:  257
# 547.5535469774272  step  258  of the epoch  0 the steps is:  258
# 547.0389146653906  step  259  of the epoch  0 the steps is:  259
# 547.2885955827591  step  260  of the epoch  0 the steps is:  260
# 549.434948616002  step  261  of the epoch  0 the steps is:  261
# 549.07297573396  step  262  of the epoch  0 the steps is:  262
# 547.8572255188257  step  263  of the epoch  0 the steps is:  263
# 547.9181259366079  step  264  of the epoch  0 the steps is:  264
# 548.8450392795461  step  265  of the epoch  0 the steps is:  265
# 547.9638117629968  step  266  of the epoch  0 the steps is:  266
# 547.7651066015769  step  267  of the epoch  0 the steps is:  267
# 547.5046228520828  step  268  of the epoch  0 the steps is:  268
# 545.2491904165499  step  269  of the epoch  0 the steps is:  269
# 546.3142540151492  step  270  of the epoch  0 the steps is:  270
# 546.933795186957  step  271  of the epoch  0 the steps is:  271
# 546.3439227128706  step  272  of the epoch  0 the steps is:  272
# 546.1413074519188  step  273  of the epoch  0 the steps is:  273
# 545.7582467892424  step  274  of the epoch  0 the steps is:  274
# 545.6683214441491  step  275  of the epoch  0 the steps is:  275
# 545.2891461327431  step  276  of the epoch  0 the steps is:  276
# 546.0649367518151  step  277  of the epoch  0 the steps is:  277
# 544.8371511293553  step  278  of the epoch  0 the steps is:  278
# 545.3397433940122  step  279  of the epoch  0 the steps is:  279
# 544.8527097541898  step  280  of the epoch  0 the steps is:  280
# 543.8720465368056  step  281  of the epoch  0 the steps is:  281
# 544.8520031277895  step  282  of the epoch  0 the steps is:  282
# 546.6359320183612  step  283  of the epoch  0 the steps is:  283
# 544.3273638685391  step  284  of the epoch  0 the steps is:  284
# 543.7301231227297  step  285  of the epoch  0 the steps is:  285
# 546.4111240120487  step  286  of the epoch  0 the steps is:  286
# 546.824586828798  step  287  of the epoch  0 the steps is:  287
# 543.2176480288381  step  288  of the epoch  0 the steps is:  288
# 546.1799929970487  step  289  of the epoch  0 the steps is:  289
# 542.2638277994844  step  290  of the epoch  0 the steps is:  290
# 543.9925193687429  step  291  of the epoch  0 the steps is:  291
# 544.6781180034743  step  292  of the epoch  0 the steps is:  292
# 544.0378563114823  step  293  of the epoch  0 the steps is:  293
# 543.9566959905978  step  294  of the epoch  0 the steps is:  294
# 544.3631253732667  step  295  of the epoch  0 the steps is:  295
# 544.7878211726129  step  296  of the epoch  0 the steps is:  296
# 544.3828400119548  step  297  of the epoch  0 the steps is:  297
# 543.6105069438543  step  298  of the epoch  0 the steps is:  298
# 542.4367494800628  step  299  of the epoch  0 the steps is:  299
# 541.7675596713552  step  300  of the epoch  0 the steps is:  300
# 544.4493662915663  step  301  of the epoch  0 the steps is:  301
# 542.5725431520688  step  302  of the epoch  0 the steps is:  302
# 543.9903367697411  step  303  of the epoch  0 the steps is:  303
# 541.6910732464312  step  304  of the epoch  0 the steps is:  304
# 540.2147697339848  step  305  of the epoch  0 the steps is:  305
# 543.2716735235039  step  306  of the epoch  0 the steps is:  306
# 541.1876342853839  step  307  of the epoch  0 the steps is:  307
# 542.5946533654262  step  308  of the epoch  0 the steps is:  308
# 543.8119070055727  step  309  of the epoch  0 the steps is:  309
# 542.1370397095351  step  310  of the epoch  0 the steps is:  310
# 543.7262028670648  step  311  of the epoch  0 the steps is:  311
# 541.6335178605677  step  312  of the epoch  0 the steps is:  312
# 543.8118020989272  step  313  of the epoch  0 the steps is:  313
# 541.2178327139807  step  314  of the epoch  0 the steps is:  314
# 540.7450511030743  step  315  of the epoch  0 the steps is:  315
# 540.043096639806  step  316  of the epoch  0 the steps is:  316
# 542.1718882439565  step  317  of the epoch  0 the steps is:  317
# 543.3768391876322  step  318  of the epoch  0 the steps is:  318
# 540.2184379598339  step  319  of the epoch  0 the steps is:  319
# 542.1032717055599  step  320  of the epoch  0 the steps is:  320
# 539.2398864798989  step  321  of the epoch  0 the steps is:  321
# 543.1758761457119  step  322  of the epoch  0 the steps is:  322
# 540.267425687396  step  323  of the epoch  0 the steps is:  323
# 542.4325358078462  step  324  of the epoch  0 the steps is:  324
# 540.4803638166285  step  325  of the epoch  0 the steps is:  325
# 540.8691245548858  step  326  of the epoch  0 the steps is:  326
# 540.7542799690684  step  327  of the epoch  0 the steps is:  327
# 542.8004435775179  step  328  of the epoch  0 the steps is:  328
# 540.9108155763604  step  329  of the epoch  0 the steps is:  329
# 540.1050272956586  step  330  of the epoch  0 the steps is:  330
# 539.1472822357737  step  331  of the epoch  0 the steps is:  331
# 537.7658112374822  step  332  of the epoch  0 the steps is:  332
# 542.6501574269685  step  333  of the epoch  0 the steps is:  333
# 540.3236342656653  step  334  of the epoch  0 the steps is:  334
# 541.9452469367529  step  335  of the epoch  0 the steps is:  335
# 541.8350137409184  step  336  of the epoch  0 the steps is:  336
# 542.5327422669782  step  337  of the epoch  0 the steps is:  337
# 540.8833174774927  step  338  of the epoch  0 the steps is:  338
# 538.9951190141242  step  339  of the epoch  0 the steps is:  339
# 539.4096006525697  step  340  of the epoch  0 the steps is:  340
# 537.532877428252  step  341  of the epoch  0 the steps is:  341
# 540.2906023576181  step  342  of the epoch  0 the steps is:  342
# 538.0573688803111  step  343  of the epoch  0 the steps is:  343
# 537.8926108016208  step  344  of the epoch  0 the steps is:  344
# 539.8722241597798  step  345  of the epoch  0 the steps is:  345
# 539.7162675520291  step  346  of the epoch  0 the steps is:  346
# 540.2147937102744  step  347  of the epoch  0 the steps is:  347
# 535.9146408478996  step  348  of the epoch  0 the steps is:  348
# 540.1892065376026  step  349  of the epoch  0 the steps is:  349
# 538.1370502685152  step  350  of the epoch  0 the steps is:  350
# 539.2480870396355  step  351  of the epoch  0 the steps is:  351
# 540.6793290322328  step  352  of the epoch  0 the steps is:  352
# 542.0223508547854  step  353  of the epoch  0 the steps is:  353
# 535.842360770604  step  354  of the epoch  0 the steps is:  354
# 537.7061923884733  step  355  of the epoch  0 the steps is:  355
# 538.8907519705845  step  356  of the epoch  0 the steps is:  356
# 538.4400361090832  step  357  of the epoch  0 the steps is:  357
# 537.5338079570328  step  358  of the epoch  0 the steps is:  358
# 535.5383118293588  step  359  of the epoch  0 the steps is:  359
# 536.617800641513  step  360  of the epoch  0 the steps is:  360
# 537.303373694085  step  361  of the epoch  0 the steps is:  361
# 535.1932458427549  step  362  of the epoch  0 the steps is:  362
# 533.690840300416  step  363  of the epoch  0 the steps is:  363
# 537.4478043703814  step  364  of the epoch  0 the steps is:  364
# 539.229803746987  step  365  of the epoch  0 the steps is:  365
# 538.3225721440639  step  366  of the epoch  0 the steps is:  366
# 537.7681007461695  step  367  of the epoch  0 the steps is:  367
# 536.8597802082422  step  368  of the epoch  0 the steps is:  368
# 538.8417373559089  step  369  of the epoch  0 the steps is:  369
# 537.5672169904137  step  370  of the epoch  0 the steps is:  370
# 537.3195527168027  step  371  of the epoch  0 the steps is:  371
# 534.6609273245165  step  372  of the epoch  0 the steps is:  372
# 531.9867451105538  step  373  of the epoch  0 the steps is:  373
# 532.7369738867735  step  374  of the epoch  0 the steps is:  374
# 532.9293860773203  step  375  of the epoch  0 the steps is:  375
# 535.555605645764  step  376  of the epoch  0 the steps is:  376
# 535.7556341737891  step  377  of the epoch  0 the steps is:  377
# 530.7497375790688  step  378  of the epoch  0 the steps is:  378
# 534.2305547739152  step  379  of the epoch  0 the steps is:  379
# 532.4715397496225  step  380  of the epoch  0 the steps is:  380
# 533.1315178767803  step  381  of the epoch  0 the steps is:  381
# 533.3399146038389  step  382  of the epoch  0 the steps is:  382
# 535.274763669317  step  383  of the epoch  0 the steps is:  383
# 534.0138384831446  step  384  of the epoch  0 the steps is:  384
# 530.7686469691928  step  385  of the epoch  0 the steps is:  385
# 535.7278156390503  step  386  of the epoch  0 the steps is:  386
# 532.5048904033865  step  387  of the epoch  0 the steps is:  387
# 534.0639725096953  step  388  of the epoch  0 the steps is:  388
# 530.1317930889809  step  389  of the epoch  0 the steps is:  389
# 532.9836173021906  step  390  of the epoch  0 the steps is:  390
# 535.6050949202476  step  391  of the epoch  0 the steps is:  391
# 535.4335653033165  step  392  of the epoch  0 the steps is:  392
# 533.4244019937288  step  393  of the epoch  0 the steps is:  393
# 529.4698273825653  step  394  of the epoch  0 the steps is:  394
# 534.4377196390906  step  395  of the epoch  0 the steps is:  395
# 529.1175027666668  step  396  of the epoch  0 the steps is:  396
# 530.5943506838171  step  397  of the epoch  0 the steps is:  397
# 531.1517873974406  step  398  of the epoch  0 the steps is:  398
# 534.3321617721842  step  399  of the epoch  0 the steps is:  399
# 537.4110919339624  step  400  of the epoch  0 the steps is:  400
# 533.4958343117585  step  401  of the epoch  0 the steps is:  401
# 527.4286824983155  step  402  of the epoch  0 the steps is:  402
# 538.4645877714418  step  403  of the epoch  0 the steps is:  403
# 529.2271713945349  step  404  of the epoch  0 the steps is:  404
# 528.0740484022392  step  405  of the epoch  0 the steps is:  405
# 520.8801686474776  step  406  of the epoch  0 the steps is:  406
# 526.5819135756371  step  407  of the epoch  0 the steps is:  407
# 532.0235272052248  step  408  of the epoch  0 the steps is:  408
# 532.1627726771833  step  409  of the epoch  0 the steps is:  409
# 534.5170856726062  step  410  of the epoch  0 the steps is:  410
# 533.5601901670339  step  411  of the epoch  0 the steps is:  411
# 529.8403590925848  step  412  of the epoch  0 the steps is:  412
# 530.7771389773184  step  413  of the epoch  0 the steps is:  413
# 525.9317786167612  step  414  of the epoch  0 the steps is:  414
# 529.359991371101  step  415  of the epoch  0 the steps is:  415
# 530.3227323081426  step  416  of the epoch  0 the steps is:  416
# 521.6286967692906  step  417  of the epoch  0 the steps is:  417
# 526.3242193088706  step  418  of the epoch  0 the steps is:  418
# 526.6691059821421  step  419  of the epoch  0 the steps is:  419
# 529.070411915537  step  420  of the epoch  0 the steps is:  420
# 529.2120548492022  step  421  of the epoch  0 the steps is:  421
# 530.0782274596968  step  422  of the epoch  0 the steps is:  422
# 532.0994204080479  step  423  of the epoch  0 the steps is:  423
# 525.3360777034371  step  424  of the epoch  0 the steps is:  424
# 528.6749796552672  step  425  of the epoch  0 the steps is:  425
# 530.0515344240864  step  426  of the epoch  0 the steps is:  426
# 519.2468886662616  step  427  of the epoch  0 the steps is:  427
# 530.0235151913148  step  428  of the epoch  0 the steps is:  428
# 524.4112178326694  step  429  of the epoch  0 the steps is:  429
# 519.4542425721887  step  430  of the epoch  0 the steps is:  430
# 524.2155063000148  step  431  of the epoch  0 the steps is:  431
# 529.7879508053206  step  432  of the epoch  0 the steps is:  432
# 525.9813158216677  step  433  of the epoch  0 the steps is:  433
# 525.9931014172628  step  434  of the epoch  0 the steps is:  434
# 518.3069007219492  step  435  of the epoch  0 the steps is:  435
# 522.2539648525527  step  436  of the epoch  0 the steps is:  436
# 525.0664026945601  step  437  of the epoch  0 the steps is:  437
# 525.7418172184091  step  438  of the epoch  0 the steps is:  438
# 524.0753913660346  step  439  of the epoch  0 the steps is:  439
# 523.1159776769603  step  440  of the epoch  0 the steps is:  440
# 519.9607398429771  step  441  of the epoch  0 the steps is:  441
# 529.8652983003334  step  442  of the epoch  0 the steps is:  442
# 523.2962942443919  step  443  of the epoch  0 the steps is:  443
# 516.4414419221345  step  444  of the epoch  0 the steps is:  444
# 527.0309169867512  step  445  of the epoch  0 the steps is:  445
# 527.341058375813  step  446  of the epoch  0 the steps is:  446
# 517.0033351160137  step  447  of the epoch  0 the steps is:  447
# 521.1928867272524  step  448  of the epoch  0 the steps is:  448
# 524.7835327744344  step  449  of the epoch  0 the steps is:  449
# 514.4842259260452  step  450  of the epoch  0 the steps is:  450
# 512.287587028031  step  451  of the epoch  0 the steps is:  451
# 516.0727176136072  step  452  of the epoch  0 the steps is:  452
# 523.1219622634949  step  453  of the epoch  0 the steps is:  453
# 524.6637938372086  step  454  of the epoch  0 the steps is:  454
# 523.0295957126718  step  455  of the epoch  0 the steps is:  455
# 524.1798839171594  step  456  of the epoch  0 the steps is:  456
# 521.1440723741641  step  457  of the epoch  0 the steps is:  457
# 519.9870167716335  step  458  of the epoch  0 the steps is:  458
# 508.04604854035097  step  459  of the epoch  0 the steps is:  459
# 518.8331279897359  step  460  of the epoch  0 the steps is:  460
# 517.6840040972702  step  461  of the epoch  0 the steps is:  461
# 516.5672367829483  step  462  of the epoch  0 the steps is:  462
# 515.2608420227689  step  463  of the epoch  0 the steps is:  463
# 511.2108460075147  step  464  of the epoch  0 the steps is:  464
# 524.7365239992213  step  465  of the epoch  0 the steps is:  465
# 514.354075787428  step  466  of the epoch  0 the steps is:  466
# 515.1070228842761  step  467  of the epoch  0 the steps is:  467
# 520.6096027810286  step  468  of the epoch  0 the steps is:  468
# 510.3952179419199  step  0  of the epoch  1 the steps is:  469
# 525.131291466038  step  1  of the epoch  1 the steps is:  470
# 517.9744883123778  step  2  of the epoch  1 the steps is:  471
# 510.4207064911059  step  3  of the epoch  1 the steps is:  472
# 512.9583198181509  step  4  of the epoch  1 the steps is:  473
# 504.5390358663469  step  5  of the epoch  1 the steps is:  474
# 509.84413262436703  step  6  of the epoch  1 the steps is:  475
# 517.285955747897  step  7  of the epoch  1 the steps is:  476
# 514.2912113518277  step  8  of the epoch  1 the steps is:  477
# 514.7006887142932  step  9  of the epoch  1 the steps is:  478
# 517.8755064011407  step  10  of the epoch  1 the steps is:  479
# 509.4113982043526  step  11  of the epoch  1 the steps is:  480
# 497.10858960060114  step  12  of the epoch  1 the steps is:  481
# 504.60477373735034  step  13  of the epoch  1 the steps is:  482
# 516.3723124134051  step  14  of the epoch  1 the steps is:  483
# 510.7257113164605  step  15  of the epoch  1 the steps is:  484
# 520.0480949783456  step  16  of the epoch  1 the steps is:  485
# 496.4721040690836  step  17  of the epoch  1 the steps is:  486
# 519.0582575267697  step  18  of the epoch  1 the steps is:  487
# 510.45180569639183  step  19  of the epoch  1 the steps is:  488
# 507.91985665057257  step  20  of the epoch  1 the steps is:  489
# 516.7233878614252  step  21  of the epoch  1 the steps is:  490
# 517.398531859182  step  22  of the epoch  1 the steps is:  491
# 505.71573089735216  step  23  of the epoch  1 the steps is:  492
# 503.18200763358186  step  24  of the epoch  1 the steps is:  493
# 506.87196536253975  step  25  of the epoch  1 the steps is:  494
# 503.817166596104  step  26  of the epoch  1 the steps is:  495
# 502.42190286131074  step  27  of the epoch  1 the steps is:  496
# 505.0819221543558  step  28  of the epoch  1 the steps is:  497
# 503.6516229856677  step  29  of the epoch  1 the steps is:  498
# 512.2655572230924  step  30  of the epoch  1 the steps is:  499
# 501.8631566935847  step  31  of the epoch  1 the steps is:  500
# 502.5044536696057  step  32  of the epoch  1 the steps is:  501
# 503.20825311028113  step  33  of the epoch  1 the steps is:  502
# 503.0757752122405  step  34  of the epoch  1 the steps is:  503
# 501.3486789467413  step  35  of the epoch  1 the steps is:  504
# 483.2985623473559  step  36  of the epoch  1 the steps is:  505
# 499.97421318302406  step  37  of the epoch  1 the steps is:  506
# 487.76350602411026  step  38  of the epoch  1 the steps is:  507
# 512.0450467433278  step  39  of the epoch  1 the steps is:  508
# 507.54469848521325  step  40  of the epoch  1 the steps is:  509
# 509.96020890755847  step  41  of the epoch  1 the steps is:  510
# 512.3596521463736  step  42  of the epoch  1 the steps is:  511
# 501.9022163090791  step  43  of the epoch  1 the steps is:  512
# 497.7226665453915  step  44  of the epoch  1 the steps is:  513
# 506.33477088190784  step  45  of the epoch  1 the steps is:  514
# 505.3368689841283  step  46  of the epoch  1 the steps is:  515
# 486.05624100794046  step  47  of the epoch  1 the steps is:  516
# 489.8910794053097  step  48  of the epoch  1 the steps is:  517
# 504.64430308779015  step  49  of the epoch  1 the steps is:  518
# 503.58480350233253  step  50  of the epoch  1 the steps is:  519
# 494.1167693654468  step  51  of the epoch  1 the steps is:  520
# 494.5833573241704  step  52  of the epoch  1 the steps is:  521
# 489.57859713840946  step  53  of the epoch  1 the steps is:  522
# 487.37712607632943  step  54  of the epoch  1 the steps is:  523
# 483.9853864259609  step  55  of the epoch  1 the steps is:  524
# 499.13654562454394  step  56  of the epoch  1 the steps is:  525
# 514.956882218007  step  57  of the epoch  1 the steps is:  526
# 490.54055955543004  step  58  of the epoch  1 the steps is:  527
# 507.33464069436843  step  59  of the epoch  1 the steps is:  528
# 504.76181532811006  step  60  of the epoch  1 the steps is:  529
# 477.15523790520353  step  61  of the epoch  1 the steps is:  530
# 508.0431434826607  step  62  of the epoch  1 the steps is:  531
# 483.43070737607286  step  63  of the epoch  1 the steps is:  532
# 497.4897573528791  step  64  of the epoch  1 the steps is:  533
# 498.2625797011055  step  65  of the epoch  1 the steps is:  534
# 486.466383621265  step  66  of the epoch  1 the steps is:  535
# 496.9765530691376  step  67  of the epoch  1 the steps is:  536
# 496.6656395881096  step  68  of the epoch  1 the steps is:  537
# 500.9424600101013  step  69  of the epoch  1 the steps is:  538
# 481.83117389279164  step  70  of the epoch  1 the steps is:  539
# 490.1939882997802  step  71  of the epoch  1 the steps is:  540
# 475.5124448652761  step  72  of the epoch  1 the steps is:  541
# 507.4332378411359  step  73  of the epoch  1 the steps is:  542
# 497.6238010632643  step  74  of the epoch  1 the steps is:  543
# 497.60085578503674  step  75  of the epoch  1 the steps is:  544
# 499.6605434451905  step  76  of the epoch  1 the steps is:  545
# 490.7886378443086  step  77  of the epoch  1 the steps is:  546
# 484.7960126760171  step  78  of the epoch  1 the steps is:  547
# 485.7788293496052  step  79  of the epoch  1 the steps is:  548
# 472.3917411590171  step  80  of the epoch  1 the steps is:  549
# 492.3392576189186  step  81  of the epoch  1 the steps is:  550
# 466.68137545064064  step  82  of the epoch  1 the steps is:  551
# 476.0098142624511  step  83  of the epoch  1 the steps is:  552
# 488.9767754703071  step  84  of the epoch  1 the steps is:  553
# 497.7560927459634  step  85  of the epoch  1 the steps is:  554
# 469.4839481257302  step  86  of the epoch  1 the steps is:  555
# 466.94272770201684  step  87  of the epoch  1 the steps is:  556
# 475.8249520435476  step  88  of the epoch  1 the steps is:  557
# 487.7807317493175  step  89  of the epoch  1 the steps is:  558
# 472.7847560329635  step  90  of the epoch  1 the steps is:  559
# 490.40421543565  step  91  of the epoch  1 the steps is:  560
# 480.0759726802175  step  92  of the epoch  1 the steps is:  561
# 492.8445758948652  step  93  of the epoch  1 the steps is:  562
# 488.3197705937065  step  94  of the epoch  1 the steps is:  563
# 482.443891912764  step  95  of the epoch  1 the steps is:  564
# 483.34407833893624  step  96  of the epoch  1 the steps is:  565
# 465.7842679796564  step  97  of the epoch  1 the steps is:  566
# 466.8589554773922  step  98  of the epoch  1 the steps is:  567
# 467.1370378820004  step  99  of the epoch  1 the steps is:  568
# 465.84232657636346  step  100  of the epoch  1 the steps is:  569
# 469.6309024867723  step  101  of the epoch  1 the steps is:  570
# 446.86255635189184  step  102  of the epoch  1 the steps is:  571
# 462.17997608326493  step  103  of the epoch  1 the steps is:  572
# 468.9743489781722  step  104  of the epoch  1 the steps is:  573
# 466.05326664073436  step  105  of the epoch  1 the steps is:  574
# 463.0169780740351  step  106  of the epoch  1 the steps is:  575
# 452.36307170944804  step  107  of the epoch  1 the steps is:  576
# 457.0067332055613  step  108  of the epoch  1 the steps is:  577
# 481.52580095367784  step  109  of the epoch  1 the steps is:  578
# 475.5243218069869  step  110  of the epoch  1 the steps is:  579
# 464.5677743937472  step  111  of the epoch  1 the steps is:  580
# 447.4890598942799  step  112  of the epoch  1 the steps is:  581
# 463.9457067789892  step  113  of the epoch  1 the steps is:  582
# 471.60446077230756  step  114  of the epoch  1 the steps is:  583
# 467.1850451186125  step  115  of the epoch  1 the steps is:  584
# 471.63038114954077  step  116  of the epoch  1 the steps is:  585
# 461.257987146745  step  117  of the epoch  1 the steps is:  586
# 472.52873872845356  step  118  of the epoch  1 the steps is:  587
# 454.0687994961475  step  119  of the epoch  1 the steps is:  588
# 464.60781789648377  step  120  of the epoch  1 the steps is:  589
# 466.944965901672  step  121  of the epoch  1 the steps is:  590
# 444.1775123004297  step  122  of the epoch  1 the steps is:  591
# 464.0457739385221  step  123  of the epoch  1 the steps is:  592
# 465.69760486567986  step  124  of the epoch  1 the steps is:  593
# 469.9834934213797  step  125  of the epoch  1 the steps is:  594
# 449.3058333533271  step  126  of the epoch  1 the steps is:  595
# 431.6847880797342  step  127  of the epoch  1 the steps is:  596
# 448.9546086945994  step  128  of the epoch  1 the steps is:  597
# 429.23191426713555  step  129  of the epoch  1 the steps is:  598
# 456.68123868389546  step  130  of the epoch  1 the steps is:  599
# 455.74705427630795  step  131  of the epoch  1 the steps is:  600
# 463.5762227339658  step  132  of the epoch  1 the steps is:  601
# 467.49117540331844  step  133  of the epoch  1 the steps is:  602
# 454.5313548621654  step  134  of the epoch  1 the steps is:  603
# 471.55369293543947  step  135  of the epoch  1 the steps is:  604
# 469.74233281646946  step  136  of the epoch  1 the steps is:  605
# 476.4672706941767  step  137  of the epoch  1 the steps is:  606
# 457.5744344395887  step  138  of the epoch  1 the steps is:  607
# 447.92180249694394  step  139  of the epoch  1 the steps is:  608
# 474.8765515205092  step  140  of the epoch  1 the steps is:  609
# 473.1388576668328  step  141  of the epoch  1 the steps is:  610
# 466.0665855018152  step  142  of the epoch  1 the steps is:  611
# 447.4542571489807  step  143  of the epoch  1 the steps is:  612
# 454.56710455391305  step  144  of the epoch  1 the steps is:  613
# 450.5384650492804  step  145  of the epoch  1 the steps is:  614
# 457.1064881373309  step  146  of the epoch  1 the steps is:  615
# 466.5929655426086  step  147  of the epoch  1 the steps is:  616
# 439.4488857864299  step  148  of the epoch  1 the steps is:  617
# 461.56264248404227  step  149  of the epoch  1 the steps is:  618
# 456.04912467090867  step  150  of the epoch  1 the steps is:  619
# 402.94729626865274  step  151  of the epoch  1 the steps is:  620
# 454.49963761083364  step  152  of the epoch  1 the steps is:  621
# 414.1224828978989  step  153  of the epoch  1 the steps is:  622
# 446.03263630464653  step  154  of the epoch  1 the steps is:  623
# 460.25275370481006  step  155  of the epoch  1 the steps is:  624
# 449.0681758015854  step  156  of the epoch  1 the steps is:  625
# 460.7798551814584  step  157  of the epoch  1 the steps is:  626
# 451.35110063386605  step  158  of the epoch  1 the steps is:  627
# 458.8393774829615  step  159  of the epoch  1 the steps is:  628
# 456.7448926545885  step  160  of the epoch  1 the steps is:  629
# 448.90759002034173  step  161  of the epoch  1 the steps is:  630
# 446.2916914891602  step  162  of the epoch  1 the steps is:  631
# 435.39361323773824  step  163  of the epoch  1 the steps is:  632
# 443.29237155218095  step  164  of the epoch  1 the steps is:  633
# 412.33907652626203  step  165  of the epoch  1 the steps is:  634
# 462.5577183446943  step  166  of the epoch  1 the steps is:  635
# 455.3957791161682  step  167  of the epoch  1 the steps is:  636
# 421.49594938577405  step  168  of the epoch  1 the steps is:  637
# 453.4180203793992  step  169  of the epoch  1 the steps is:  638
# 450.70893575572853  step  170  of the epoch  1 the steps is:  639
# 458.4278422975435  step  171  of the epoch  1 the steps is:  640
# 444.6552070996372  step  172  of the epoch  1 the steps is:  641
# 416.25034702085793  step  173  of the epoch  1 the steps is:  642
# 453.6372148536007  step  174  of the epoch  1 the steps is:  643
# 444.6554642672425  step  175  of the epoch  1 the steps is:  644
# 474.44785745322184  step  176  of the epoch  1 the steps is:  645
# 408.92961165533325  step  177  of the epoch  1 the steps is:  646
# 434.8815572496596  step  178  of the epoch  1 the steps is:  647
# 452.17479689753554  step  179  of the epoch  1 the steps is:  648
# 450.4764072896051  step  180  of the epoch  1 the steps is:  649
# 459.5390420729903  step  181  of the epoch  1 the steps is:  650
# 432.2728254601701  step  182  of the epoch  1 the steps is:  651
# 428.41085612320114  step  183  of the epoch  1 the steps is:  652
# 456.7008625693487  step  184  of the epoch  1 the steps is:  653
# 451.60291911978095  step  185  of the epoch  1 the steps is:  654
# 403.38311748740705  step  186  of the epoch  1 the steps is:  655
# 454.0683219756673  step  187  of the epoch  1 the steps is:  656
# 427.0230686162206  step  188  of the epoch  1 the steps is:  657
# 430.21654004492166  step  189  of the epoch  1 the steps is:  658
# 441.5799273164082  step  190  of the epoch  1 the steps is:  659
# 434.343177339034  step  191  of the epoch  1 the steps is:  660
# 431.8516013210913  step  192  of the epoch  1 the steps is:  661
# 447.1386702424686  step  193  of the epoch  1 the steps is:  662
# 412.4961296214583  step  194  of the epoch  1 the steps is:  663
# 440.27813797478734  step  195  of the epoch  1 the steps is:  664
# 443.6585588634066  step  196  of the epoch  1 the steps is:  665
# 412.06392750617636  step  197  of the epoch  1 the steps is:  666
# 443.2015916866635  step  198  of the epoch  1 the steps is:  667
# 433.32061546647077  step  199  of the epoch  1 the steps is:  668
# 407.63233127907176  step  200  of the epoch  1 the steps is:  669
# 442.87129182158856  step  201  of the epoch  1 the steps is:  670
# 423.8269812139599  step  202  of the epoch  1 the steps is:  671
# 453.66900272006785  step  203  of the epoch  1 the steps is:  672
# 448.8709315691966  step  204  of the epoch  1 the steps is:  673
# 432.9205244721587  step  205  of the epoch  1 the steps is:  674
# 431.4989963034141  step  206  of the epoch  1 the steps is:  675
# 422.05757036630496  step  207  of the epoch  1 the steps is:  676
# 431.44017845630174  step  208  of the epoch  1 the steps is:  677
# 402.4500785964388  step  209  of the epoch  1 the steps is:  678
# 403.38838584931943  step  210  of the epoch  1 the steps is:  679
# 420.7188172391528  step  211  of the epoch  1 the steps is:  680
# 441.0353074685398  step  212  of the epoch  1 the steps is:  681
# 429.681292875342  step  213  of the epoch  1 the steps is:  682
# 450.7577144119735  step  214  of the epoch  1 the steps is:  683
# 433.8895819475552  step  215  of the epoch  1 the steps is:  684
# 450.2637623272228  step  216  of the epoch  1 the steps is:  685
# 420.62513514629245  step  217  of the epoch  1 the steps is:  686
# 458.9601489478058  step  218  of the epoch  1 the steps is:  687
# 441.35456849871593  step  219  of the epoch  1 the steps is:  688
# 423.9906505644431  step  220  of the epoch  1 the steps is:  689
# 414.06441374308883  step  221  of the epoch  1 the steps is:  690
# 442.5771219227835  step  222  of the epoch  1 the steps is:  691
# 412.73069380211416  step  223  of the epoch  1 the steps is:  692
# 418.1265415743221  step  224  of the epoch  1 the steps is:  693
# 438.0298579171175  step  225  of the epoch  1 the steps is:  694
# 433.735616699693  step  226  of the epoch  1 the steps is:  695
# 407.504705579483  step  227  of the epoch  1 the steps is:  696
# 431.1070944731201  step  228  of the epoch  1 the steps is:  697
# 398.01648287497994  step  229  of the epoch  1 the steps is:  698
# 467.27438814097866  step  230  of the epoch  1 the steps is:  699
# 456.5635421186182  step  231  of the epoch  1 the steps is:  700
# 419.2203855891895  step  232  of the epoch  1 the steps is:  701
# 430.2723920782419  step  233  of the epoch  1 the steps is:  702
# 426.1410453651417  step  234  of the epoch  1 the steps is:  703
# 426.3839210985708  step  235  of the epoch  1 the steps is:  704
# 430.81359183992197  step  236  of the epoch  1 the steps is:  705
# 395.7372096517156  step  237  of the epoch  1 the steps is:  706
# 420.645229346797  step  238  of the epoch  1 the steps is:  707
# 423.82947382599855  step  239  of the epoch  1 the steps is:  708
# 401.9885515722991  step  240  of the epoch  1 the steps is:  709
# 444.5880492337839  step  241  of the epoch  1 the steps is:  710
# 420.44147352174775  step  242  of the epoch  1 the steps is:  711
# 408.50406870152983  step  243  of the epoch  1 the steps is:  712
# 438.0742289779938  step  244  of the epoch  1 the steps is:  713
# 402.80495004245086  step  245  of the epoch  1 the steps is:  714
# 404.7898778622015  step  246  of the epoch  1 the steps is:  715
# 416.6720385256971  step  247  of the epoch  1 the steps is:  716
# 417.20982571368  step  248  of the epoch  1 the steps is:  717
# 426.9715179379957  step  249  of the epoch  1 the steps is:  718
# 442.1388392002756  step  250  of the epoch  1 the steps is:  719
# 415.9622595151609  step  251  of the epoch  1 the steps is:  720
# 407.2578908887736  step  252  of the epoch  1 the steps is:  721
# 414.7317424251423  step  253  of the epoch  1 the steps is:  722
# 406.3708823377591  step  254  of the epoch  1 the steps is:  723
# 391.0948945688367  step  255  of the epoch  1 the steps is:  724
# 421.6557964791334  step  256  of the epoch  1 the steps is:  725
# 404.96145961396405  step  257  of the epoch  1 the steps is:  726
# 393.8315060785844  step  258  of the epoch  1 the steps is:  727
# 387.94552229777264  step  259  of the epoch  1 the steps is:  728
# 387.2898210050933  step  260  of the epoch  1 the steps is:  729
# 428.00568639812604  step  261  of the epoch  1 the steps is:  730
# 411.1082853382025  step  262  of the epoch  1 the steps is:  731
# 422.1462418995021  step  263  of the epoch  1 the steps is:  732
# 395.07160542283424  step  264  of the epoch  1 the steps is:  733
# 416.1793914493069  step  265  of the epoch  1 the steps is:  734
# 411.3163245232399  step  266  of the epoch  1 the steps is:  735
# 418.4014043690291  step  267  of the epoch  1 the steps is:  736
# 426.4459979273529  step  268  of the epoch  1 the steps is:  737
# 364.10826885380425  step  269  of the epoch  1 the steps is:  738
# ...
# 327.7441459074165  step  228  of the epoch  2 the steps is:  1166
# 312.23217874133115  step  229  of the epoch  2 the steps is:  1167
# 369.0233200026038  step  230  of the epoch  2 the steps is:  1168
# 355.51451130780237  step  231  of the epoch  2 the steps is:  1169
# 315.4404461245095  step  232  of the epoch  2 the steps is:  1170
# 283.7733115398944  step  233  of the epoch  2 the steps is:  1171
# 312.96912470860104  step  234  of the epoch  2 the steps is:  1172
# 342.0834945552837  step  235  of the epoch  2 the steps is:  1173
# 312.31566496437256  step  236  of the epoch  2 the steps is:  1174
# 269.47911780747086  step  237  of the epoch  2 the steps is:  1175
# 309.5473517976437  step  238  of the epoch  2 the steps is:  1176
# 295.60166285989555  step  239  of the epoch  2 the steps is:  1177
# 318.6113774550226  step  240  of the epoch  2 the steps is:  1178
# 306.5800760207907  step  241  of the epoch  2 the steps is:  1179
# 278.964730864839  step  242  of the epoch  2 the steps is:  1180
# 280.238107689313  step  243  of the epoch  2 the steps is:  1181
# 336.3989501959933  step  244  of the epoch  2 the steps is:  1182
# 287.9785101444203  step  245  of the epoch  2 the steps is:  1183
# 300.1060714552201  step  246  of the epoch  2 the steps is:  1184
# 313.1353210674808  step  247  of the epoch  2 the steps is:  1185
# 321.7863017234312  step  248  of the epoch  2 the steps is:  1186
# 285.830556802615  step  249  of the epoch  2 the steps is:  1187
# 335.6723077788023  step  250  of the epoch  2 the steps is:  1188
# 307.7298705835688  step  251  of the epoch  2 the steps is:  1189
# 295.1182979927399  step  252  of the epoch  2 the steps is:  1190
# 308.08338074721195  step  253  of the epoch  2 the steps is:  1191
# 268.3120588842048  step  254  of the epoch  2 the steps is:  1192
# 293.28441611235985  step  255  of the epoch  2 the steps is:  1193
# 326.10333354813554  step  256  of the epoch  2 the steps is:  1194
# 323.51673565756073  step  257  of the epoch  2 the steps is:  1195
# 287.19227600955446  step  258  of the epoch  2 the steps is:  1196
# 276.6810790286553  step  259  of the epoch  2 the steps is:  1197
# 296.1099413899674  step  260  of the epoch  2 the steps is:  1198
# 337.2254759540841  step  261  of the epoch  2 the steps is:  1199
# 295.05619552572045  step  262  of the epoch  2 the steps is:  1200
# 337.68031887641183  step  263  of the epoch  2 the steps is:  1201
# 282.0657492474462  step  264  of the epoch  2 the steps is:  1202
# 322.21406139284977  step  265  of the epoch  2 the steps is:  1203
# 324.1264939398229  step  266  of the epoch  2 the steps is:  1204
# 346.1610565380568  step  267  of the epoch  2 the steps is:  1205
# 332.5708278360811  step  268  of the epoch  2 the steps is:  1206
# 259.99274183896114  step  269  of the epoch  2 the steps is:  1207
# 308.48895405610074  step  270  of the epoch  2 the steps is:  1208
# 297.94746631758346  step  271  of the epoch  2 the steps is:  1209
# 326.88741180371863  step  272  of the epoch  2 the steps is:  1210
# 316.1547483665822  step  273  of the epoch  2 the steps is:  1211
# 300.9588916758489  step  274  of the epoch  2 the steps is:  1212
# 258.90321305590555  step  275  of the epoch  2 the steps is:  1213
# 282.76356970749293  step  276  of the epoch  2 the steps is:  1214
# 335.9802719163025  step  277  of the epoch  2 the steps is:  1215
# 297.753540542328  step  278  of the epoch  2 the steps is:  1216
# 324.83322545622656  step  279  of the epoch  2 the steps is:  1217
# 280.6845029937486  step  280  of the epoch  2 the steps is:  1218
# 308.60794410411165  step  281  of the epoch  2 the steps is:  1219
# 296.38599427461986  step  282  of the epoch  2 the steps is:  1220
# 339.15764494292387  step  283  of the epoch  2 the steps is:  1221
# 344.5300422927116  step  284  of the epoch  2 the steps is:  1222
# 314.3960134042753  step  285  of the epoch  2 the steps is:  1223
# 353.2294310955973  step  286  of the epoch  2 the steps is:  1224
# 339.5993538821215  step  287  of the epoch  2 the steps is:  1225
# 269.75167201776185  step  288  of the epoch  2 the steps is:  1226
# 338.6230992687738  step  289  of the epoch  2 the steps is:  1227
# 286.3512242100922  step  290  of the epoch  2 the steps is:  1228
# 318.8650928690047  step  291  of the epoch  2 the steps is:  1229
# 320.9852342712271  step  292  of the epoch  2 the steps is:  1230
# 297.24768143481936  step  293  of the epoch  2 the steps is:  1231
# 294.1994730664047  step  294  of the epoch  2 the steps is:  1232
# 304.62540401066815  step  295  of the epoch  2 the steps is:  1233
# 326.11612490692727  step  296  of the epoch  2 the steps is:  1234
# 333.2126982476556  step  297  of the epoch  2 the steps is:  1235
# 302.3122738629052  step  298  of the epoch  2 the steps is:  1236
# 272.7739208454957  step  299  of the epoch  2 the steps is:  1237
# 294.73948153417916  step  300  of the epoch  2 the steps is:  1238
# 337.81053281661093  step  301  of the epoch  2 the steps is:  1239
# 292.2313619410396  step  302  of the epoch  2 the steps is:  1240
# 328.7860264482339  step  303  of the epoch  2 the steps is:  1241
# 277.7707183740106  step  304  of the epoch  2 the steps is:  1242
# 268.37517484388724  step  305  of the epoch  2 the steps is:  1243
# 325.34207746186746  step  306  of the epoch  2 the steps is:  1244
# 276.1430912028097  step  307  of the epoch  2 the steps is:  1245
# 302.5111119081959  step  308  of the epoch  2 the steps is:  1246
# 352.4775578766282  step  309  of the epoch  2 the steps is:  1247
# 308.20656455051335  step  310  of the epoch  2 the steps is:  1248
# 325.8841115800298  step  311  of the epoch  2 the steps is:  1249
# 287.07633792200863  step  312  of the epoch  2 the steps is:  1250
# 319.2926038409408  step  313  of the epoch  2 the steps is:  1251
# 327.080091023255  step  314  of the epoch  2 the steps is:  1252
# 292.6915235377154  step  315  of the epoch  2 the steps is:  1253
# 276.12167753654865  step  316  of the epoch  2 the steps is:  1254
# 301.62762640303714  step  317  of the epoch  2 the steps is:  1255
# 328.7115412898544  step  318  of the epoch  2 the steps is:  1256
# 276.61965032100096  step  319  of the epoch  2 the steps is:  1257
# 315.658161577744  step  320  of the epoch  2 the steps is:  1258
# 282.83524914854297  step  321  of the epoch  2 the steps is:  1259
# 333.58532018308335  step  322  of the epoch  2 the steps is:  1260
# 332.5499036711812  step  323  of the epoch  2 the steps is:  1261
# 287.5737514527363  step  324  of the epoch  2 the steps is:  1262
# 324.40487263456646  step  325  of the epoch  2 the steps is:  1263
# 283.20650616391293  step  326  of the epoch  2 the steps is:  1264
# 305.52756414064015  step  327  of the epoch  2 the steps is:  1265
# 328.7888278205192  step  328  of the epoch  2 the steps is:  1266
# 293.5683056753371  step  329  of the epoch  2 the steps is:  1267
# 317.301621505503  step  330  of the epoch  2 the steps is:  1268
# 305.5408372593316  step  331  of the epoch  2 the steps is:  1269
# 272.46416794577453  step  332  of the epoch  2 the steps is:  1270
# 328.52236033132243  step  333  of the epoch  2 the steps is:  1271
# 304.9743245701378  step  334  of the epoch  2 the steps is:  1272
# 342.62346591336296  step  335  of the epoch  2 the steps is:  1273
# 319.4627393610665  step  336  of the epoch  2 the steps is:  1274
# 297.88841051303496  step  337  of the epoch  2 the steps is:  1275
# 331.5010337966509  step  338  of the epoch  2 the steps is:  1276
# 305.8114326887944  step  339  of the epoch  2 the steps is:  1277
# 278.5844255249994  step  340  of the epoch  2 the steps is:  1278
# 293.47356159497514  step  341  of the epoch  2 the steps is:  1279
# 324.5510550762301  step  342  of the epoch  2 the steps is:  1280
# 285.55593699188523  step  343  of the epoch  2 the steps is:  1281
# 296.93616669426586  step  344  of the epoch  2 the steps is:  1282
# 333.1823753695067  step  345  of the epoch  2 the steps is:  1283
# 317.36492059144575  step  346  of the epoch  2 the steps is:  1284
# 271.6202362128346  step  347  of the epoch  2 the steps is:  1285
# 273.8508560679622  step  348  of the epoch  2 the steps is:  1286
# 311.1448297591213  step  349  of the epoch  2 the steps is:  1287
# 303.3544302957414  step  350  of the epoch  2 the steps is:  1288
# 334.2785058398763  step  351  of the epoch  2 the steps is:  1289
# 307.23389401088446  step  352  of the epoch  2 the steps is:  1290
# 342.7924124103614  step  353  of the epoch  2 the steps is:  1291
# 295.1517398410688  step  354  of the epoch  2 the steps is:  1292
# 275.1806469643177  step  355  of the epoch  2 the steps is:  1293
# 329.38572173879163  step  356  of the epoch  2 the steps is:  1294
# 328.5397648087383  step  357  of the epoch  2 the steps is:  1295
# 314.5598297739833  step  358  of the epoch  2 the steps is:  1296
# 295.005691825154  step  359  of the epoch  2 the steps is:  1297
# 307.94798640394356  step  360  of the epoch  2 the steps is:  1298
# 317.7390822006422  step  361  of the epoch  2 the steps is:  1299
# 298.28953232653026  step  362  of the epoch  2 the steps is:  1300
# 266.1449704514964  step  363  of the epoch  2 the steps is:  1301
# 318.6520963068886  step  364  of the epoch  2 the steps is:  1302
# 310.36835824599547  step  365  of the epoch  2 the steps is:  1303
# 317.55761319034053  step  366  of the epoch  2 the steps is:  1304
# 290.6923650213128  step  367  of the epoch  2 the steps is:  1305
# 337.55050829309357  step  368  of the epoch  2 the steps is:  1306
# 316.6013590994214  step  369  of the epoch  2 the steps is:  1307
# 319.8911432373534  step  370  of the epoch  2 the steps is:  1308
# 342.4031084603687  step  371  of the epoch  2 the steps is:  1309
# 280.09970491481715  step  372  of the epoch  2 the steps is:  1310
# 263.3201938048576  step  373  of the epoch  2 the steps is:  1311
# 273.18136434653155  step  374  of the epoch  2 the steps is:  1312
# 277.01579780682346  step  375  of the epoch  2 the steps is:  1313
# 289.348975942856  step  376  of the epoch  2 the steps is:  1314
# 296.38943708132643  step  377  of the epoch  2 the steps is:  1315
# 255.20186218541596  step  378  of the epoch  2 the steps is:  1316
# 298.92794773302484  step  379  of the epoch  2 the steps is:  1317
# 310.6329651017883  step  380  of the epoch  2 the steps is:  1318
# 268.9443532942263  step  381  of the epoch  2 the steps is:  1319
# 304.688762902485  step  382  of the epoch  2 the steps is:  1320
# 319.0235976046112  step  383  of the epoch  2 the steps is:  1321
# 278.02610843079816  step  384  of the epoch  2 the steps is:  1322
# 288.1579450786498  step  385  of the epoch  2 the steps is:  1323
# 305.61368414961566  step  386  of the epoch  2 the steps is:  1324
# 270.1390392764797  step  387  of the epoch  2 the steps is:  1325
# 303.47679095807564  step  388  of the epoch  2 the steps is:  1326
# 310.7242901216532  step  389  of the epoch  2 the steps is:  1327
# 317.04959476727174  step  390  of the epoch  2 the steps is:  1328
# 330.2215986506774  step  391  of the epoch  2 the steps is:  1329
# 312.1465243487178  step  392  of the epoch  2 the steps is:  1330
# 291.8428894603042  step  393  of the epoch  2 the steps is:  1331
# 303.00568559162855  step  394  of the epoch  2 the steps is:  1332
# 335.046196264509  step  395  of the epoch  2 the steps is:  1333
# 282.6453056149062  step  396  of the epoch  2 the steps is:  1334
# 293.7189764417173  step  397  of the epoch  2 the steps is:  1335
# 274.4175601247176  step  398  of the epoch  2 the steps is:  1336
# 333.9424060978405  step  399  of the epoch  2 the steps is:  1337
# 331.2721669425447  step  400  of the epoch  2 the steps is:  1338
# 300.3788313501633  step  401  of the epoch  2 the steps is:  1339
# 294.1873082956648  step  402  of the epoch  2 the steps is:  1340
# 357.2219622149465  step  403  of the epoch  2 the steps is:  1341
# 291.8840447683796  step  404  of the epoch  2 the steps is:  1342
# 312.23825158630984  step  405  of the epoch  2 the steps is:  1343
# 251.5467383346147  step  406  of the epoch  2 the steps is:  1344
# 270.93881081165824  step  407  of the epoch  2 the steps is:  1345
# 313.04240508596365  step  408  of the epoch  2 the steps is:  1346
# 284.6319297774693  step  409  of the epoch  2 the steps is:  1347
# 349.5633334624656  step  410  of the epoch  2 the steps is:  1348
# 320.99779330277613  step  411  of the epoch  2 the steps is:  1349
# 315.2978070035309  step  412  of the epoch  2 the steps is:  1350
# 309.37294801149665  step  413  of the epoch  2 the steps is:  1351
# 301.8976905570553  step  414  of the epoch  2 the steps is:  1352
# 340.2811811788698  step  415  of the epoch  2 the steps is:  1353
# 321.6690814489194  step  416  of the epoch  2 the steps is:  1354
# 294.7478084530182  step  417  of the epoch  2 the steps is:  1355
# 302.8295128510017  step  418  of the epoch  2 the steps is:  1356
# 313.0288804928943  step  419  of the epoch  2 the steps is:  1357
# 314.24324174638895  step  420  of the epoch  2 the steps is:  1358
# 330.8684954977855  step  421  of the epoch  2 the steps is:  1359
# 305.2977295620266  step  422  of the epoch  2 the steps is:  1360
# 341.6184675956181  step  423  of the epoch  2 the steps is:  1361
# 271.057701292517  step  424  of the epoch  2 the steps is:  1362
# 322.21762211850694  step  425  of the epoch  2 the steps is:  1363
# 330.0800833353593  step  426  of the epoch  2 the steps is:  1364
# 260.24444628874  step  427  of the epoch  2 the steps is:  1365
# 311.3775632592928  step  428  of the epoch  2 the steps is:  1366
# 311.44807788712467  step  429  of the epoch  2 the steps is:  1367
# 235.00485072428165  step  430  of the epoch  2 the steps is:  1368
# 286.1837636910716  step  431  of the epoch  2 the steps is:  1369
# 324.06478099241383  step  432  of the epoch  2 the steps is:  1370
# 311.1495912356787  step  433  of the epoch  2 the steps is:  1371
# 317.65198170215456  step  434  of the epoch  2 the steps is:  1372
# 270.08325795169577  step  435  of the epoch  2 the steps is:  1373
# 289.38759999708157  step  436  of the epoch  2 the steps is:  1374
# 300.57822539855505  step  437  of the epoch  2 the steps is:  1375
# 320.78591156242203  step  438  of the epoch  2 the steps is:  1376
# 293.5125188496036  step  439  of the epoch  2 the steps is:  1377
# 292.8320812220652  step  440  of the epoch  2 the steps is:  1378
# 274.76569499251707  step  441  of the epoch  2 the steps is:  1379
# 288.70066148483335  step  442  of the epoch  2 the steps is:  1380
# 305.3166978854221  step  443  of the epoch  2 the steps is:  1381
# 282.05101907431947  step  444  of the epoch  2 the steps is:  1382
# 343.8763831087416  step  445  of the epoch  2 the steps is:  1383
# 329.3690205029467  step  446  of the epoch  2 the steps is:  1384
# 245.12816525871622  step  447  of the epoch  2 the steps is:  1385
# 268.9128044857214  step  448  of the epoch  2 the steps is:  1386
# 292.98305982078926  step  449  of the epoch  2 the steps is:  1387
# 282.5248348282132  step  450  of the epoch  2 the steps is:  1388
# 279.52133746793953  step  451  of the epoch  2 the steps is:  1389
# 288.5536024017214  step  452  of the epoch  2 the steps is:  1390
# 324.54684087002687  step  453  of the epoch  2 the steps is:  1391
# 317.0615339574795  step  454  of the epoch  2 the steps is:  1392
# 310.3336476843069  step  455  of the epoch  2 the steps is:  1393
# 296.63850790991967  step  456  of the epoch  2 the steps is:  1394
# 291.135066790996  step  457  of the epoch  2 the steps is:  1395
# 286.4520265320838  step  458  of the epoch  2 the steps is:  1396
# 295.617369508064  step  459  of the epoch  2 the steps is:  1397
# 276.78954095599204  step  460  of the epoch  2 the steps is:  1398
# 285.4287130268851  step  461  of the epoch  2 the steps is:  1399
# 300.11561141680886  step  462  of the epoch  2 the steps is:  1400
# 289.8773158782291  step  463  of the epoch  2 the steps is:  1401
# 288.11311819657294  step  464  of the epoch  2 the steps is:  1402
# 303.6718005621809  step  465  of the epoch  2 the steps is:  1403
# 298.6512984860119  step  466  of the epoch  2 the steps is:  1404
# 277.8265372117106  step  467  of the epoch  2 the steps is:  1405
# 311.178005166973  step  468  of the epoch  2 the steps is:  1406

# %%
MyNetwork.Test_Network(Test_data, Test_label)
# Out:
# 0.7923
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in power

# %%
mini_dataSet, mini_labelSet = [],[]
j = 0
for i in range(100):
  if MyNetwork.forward(Train_data[i]) == Train_label[i]:
    mini_dataSet.append(Train_data[i])
    mini_labelSet.append(Train_label[i])
    j += 1
  if j == 10:
    break

# %%
attacked_image = []
for i in range(10):
  attacked_image.append(MyNetwork.attack_network(mini_dataSet[i], mini_labelSet[i]))

# %%
score = 0
for i in range(10):
  print("The label for the", i,"th data is: ", MyNetwork.forward(mini_dataSet[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))))
  if MyNetwork.forward(mini_dataSet[i]) != MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score += 1
print("The attacked accuracy was: ", score * 10)
# Out:
# The label for the 0 th data is:  [9] after attack it became:  [8]
# The label for the 1 th data is:  [0] after attack it became:  [9]
# The label for the 2 th data is:  [2] after attack it became:  [3]
# The label for the 3 th data is:  [7] after attack it became:  [0]
# The label for the 4 th data is:  [2] after attack it became:  [2]
# The label for the 5 th data is:  [5] after attack it became:  [7]
# The label for the 6 th data is:  [5] after attack it became:  [7]
# The label for the 7 th data is:  [0] after attack it became:  [8]
# The label for the 8 th data is:  [9] after attack it became:  [1]
# The label for the 9 th data is:  [5] after attack it became:  [8]
# The attacked accuracy was:  90
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in cosh
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in power

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)

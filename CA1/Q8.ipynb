# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA
from sklearn.utils import shuffle

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
num = 200
noise_data = np.random.normal(loc=0, scale=0.2, size=(num, len(Train_data[0])))
noise_label = 10 * np.ones(shape=(num,1))
Train_data = np.concatenate((Train_data, noise_data))
Train_label = np.concatenate((Train_label, noise_label))
Train_data, Train_label =shuffle(Train_data, Train_label, random_state=0)
Train_label = (Train_label).astype(int)

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx, landa):
  temp = np.multiply(step(landa - vect),-1)
  if idx != 10:
    temp[idx] = 1
  return temp

def gelu(x):
    return 0.5 * np.multiply(x, 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def Dgelu(x):
  return np.divide(0.053516 * np.power(x, 3) + np.multiply(0.398942, x) , np.power(np.cosh(0.0356774 * np.power(x, 3) +np.multiply(0.79788, x)),2)) + 0.5 * ( 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def RBF_encode(data, number_class, dim):
  data = np.reshape(data, (dim,int(data.size/dim)), order='F')
  data = LA.norm(data,1, axis = 0)
  data = np.reshape(data, (number_class, int(data.size/number_class)), order='F')
  return data

def expand(x):
  temp = []
  for i in range(len(x)):
    temp.append(x[i])
    temp.append(x[i])
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.distance_dim = 2
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.landa = 50
    self.attack_rate = 0.5

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = gelu(self.layer["z0"])
    self.layer["s0"] = Dgelu(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = gelu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = Dgelu(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = RBF_encode(self.layer["z" + str(self.number_hidden_layer)], self.number_class_output, self.distance_dim)
    self.layer["s" + str(self.number_hidden_layer)] = np.sign(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    #print(np.transpose(self.score))
    temp = self.decide_RBF(self.score, self.landa)
    return temp
  
  def decide_RBF(self, data, landa):
    self.result = np.argmin(data, axis=0)
    self.result[np.min(data, axis=0)>landa] = 10
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      if label[i] != 10:
        self.loss.append(np.sum(relu((self.landa - temp[i]))) - relu(self.landa- temp[i][label[i]]) +   temp[i][int(label[i])])
      else:
        self.loss.append(np.sum(relu(self.landa - temp[i])))
      self.back_prob_output.append(encode(temp[i], label[i], self.landa))
    self.back_prob_output = np.transpose(self.back_prob_output)/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] - self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] - self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))

  def attack_network(self, data, label):
    self.forward(data)
    self.cal_loss(label)
    D_image = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      D_image = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), D_image)
      D_image = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], D_image)
    D_image = np.matmul(np.transpose(self.weight["w0"]), D_image)
    D_image = np.sign(D_image) 
    return data - self.attack_rate * D_image.reshape((-1,))

  def set_landa(self,x):
    self.landa = x

# %%
MyNetwork = Network(128,1,[150] ,10)

# %%
MyNetwork.set_learning_rate(0.05)
MyNetwork.set_turn(3)
MyNetwork.set_batch_size(128)
MyNetwork.Train_Network(Train_data, Train_label)
# Out:
# [445.80454974]  step  0  of the epoch  0 the steps is:  0
# 444.9101225502173  step  1  of the epoch  0 the steps is:  1
# 444.63520409704756  step  2  of the epoch  0 the steps is:  2
# 444.3491734488099  step  3  of the epoch  0 the steps is:  3
# 443.64595345196136  step  4  of the epoch  0 the steps is:  4
# 443.234939264349  step  5  of the epoch  0 the steps is:  5
# [442.73672522]  step  6  of the epoch  0 the steps is:  6
# [442.28932373]  step  7  of the epoch  0 the steps is:  7
# [440.01877911]  step  8  of the epoch  0 the steps is:  8
# 438.3844652265311  step  9  of the epoch  0 the steps is:  9
# [437.1692526]  step  10  of the epoch  0 the steps is:  10
# 434.2742423907859  step  11  of the epoch  0 the steps is:  11
# [431.59273585]  step  12  of the epoch  0 the steps is:  12
# 428.0309965776307  step  13  of the epoch  0 the steps is:  13
# [423.32709177]  step  14  of the epoch  0 the steps is:  14
# [418.92350292]  step  15  of the epoch  0 the steps is:  15
# [413.01496117]  step  16  of the epoch  0 the steps is:  16
# 403.8692504933151  step  17  of the epoch  0 the steps is:  17
# 394.21181961130384  step  18  of the epoch  0 the steps is:  18
# [380.07578589]  step  19  of the epoch  0 the steps is:  19
# 362.74335996105935  step  20  of the epoch  0 the steps is:  20
# 341.07387107152454  step  21  of the epoch  0 the steps is:  21
# [316.29540932]  step  22  of the epoch  0 the steps is:  22
# 282.44883246476843  step  23  of the epoch  0 the steps is:  23
# 238.22480568300108  step  24  of the epoch  0 the steps is:  24
# [187.30609695]  step  25  of the epoch  0 the steps is:  25
# [114.97721658]  step  26  of the epoch  0 the steps is:  26
# 70.11518337650077  step  27  of the epoch  0 the steps is:  27
# 67.7098767947735  step  28  of the epoch  0 the steps is:  28
# 75.2426601889203  step  29  of the epoch  0 the steps is:  29
# 84.48414380373686  step  30  of the epoch  0 the steps is:  30
# 92.9458225567495  step  31  of the epoch  0 the steps is:  31
# 103.0742795513622  step  32  of the epoch  0 the steps is:  32
# 110.84361551018958  step  33  of the epoch  0 the steps is:  33
# [113.28487582]  step  34  of the epoch  0 the steps is:  34
# [117.8912487]  step  35  of the epoch  0 the steps is:  35
# 121.28814617991836  step  36  of the epoch  0 the steps is:  36
# 123.9956414393773  step  37  of the epoch  0 the steps is:  37
# 125.18436363091615  step  38  of the epoch  0 the steps is:  38
# 122.81729130814172  step  39  of the epoch  0 the steps is:  39
# 125.21097766699117  step  40  of the epoch  0 the steps is:  40
# 123.0436157821465  step  41  of the epoch  0 the steps is:  41
# 120.46337664856381  step  42  of the epoch  0 the steps is:  42
# 119.1493313707993  step  43  of the epoch  0 the steps is:  43
# 116.29861398775941  step  44  of the epoch  0 the steps is:  44
# 110.79562674018095  step  45  of the epoch  0 the steps is:  45
# 108.78483176610536  step  46  of the epoch  0 the steps is:  46
# 104.74138776451647  step  47  of the epoch  0 the steps is:  47
# 101.53915595183533  step  48  of the epoch  0 the steps is:  48
# 97.69954144494986  step  49  of the epoch  0 the steps is:  49
# 92.49569327934691  step  50  of the epoch  0 the steps is:  50
# [87.13134226]  step  51  of the epoch  0 the steps is:  51
# 83.67512393347147  step  52  of the epoch  0 the steps is:  52
# 78.08960628007881  step  53  of the epoch  0 the steps is:  53
# 74.87676636842627  step  54  of the epoch  0 the steps is:  54
# 71.21517874172648  step  55  of the epoch  0 the steps is:  55
# 67.77660979776698  step  56  of the epoch  0 the steps is:  56
# [63.69296867]  step  57  of the epoch  0 the steps is:  57
# 60.032957236093594  step  58  of the epoch  0 the steps is:  58
# [66.24669594]  step  59  of the epoch  0 the steps is:  59
# 63.600890736854076  step  60  of the epoch  0 the steps is:  60
# 64.68081979514307  step  61  of the epoch  0 the steps is:  61
# [65.40269552]  step  62  of the epoch  0 the steps is:  62
# [72.9239082]  step  63  of the epoch  0 the steps is:  63
# 64.72492927765522  step  64  of the epoch  0 the steps is:  64
# 59.35943490100203  step  65  of the epoch  0 the steps is:  65
# 59.36061939879282  step  66  of the epoch  0 the steps is:  66
# [59.7884894]  step  67  of the epoch  0 the steps is:  67
# [59.89922686]  step  68  of the epoch  0 the steps is:  68
# [59.66597742]  step  69  of the epoch  0 the steps is:  69
# 61.164065049993326  step  70  of the epoch  0 the steps is:  70
# 60.458036214939504  step  71  of the epoch  0 the steps is:  71
# 60.855303864122675  step  72  of the epoch  0 the steps is:  72
# [62.63573609]  step  73  of the epoch  0 the steps is:  73
# 59.56130652734895  step  74  of the epoch  0 the steps is:  74
# 60.251780093828366  step  75  of the epoch  0 the steps is:  75
# 59.96809810884812  step  76  of the epoch  0 the steps is:  76
# 59.291457464099395  step  77  of the epoch  0 the steps is:  77
# 58.4892400216142  step  78  of the epoch  0 the steps is:  78
# [59.90608]  step  79  of the epoch  0 the steps is:  79
# [58.41514495]  step  80  of the epoch  0 the steps is:  80
# 56.70903995922596  step  81  of the epoch  0 the steps is:  81
# 57.855381102209606  step  82  of the epoch  0 the steps is:  82
# 57.476490907783614  step  83  of the epoch  0 the steps is:  83
# 56.79755918825997  step  84  of the epoch  0 the steps is:  84
# 55.73828762619496  step  85  of the epoch  0 the steps is:  85
# [57.78454265]  step  86  of the epoch  0 the steps is:  86
# 57.1570629903366  step  87  of the epoch  0 the steps is:  87
# [56.5076436]  step  88  of the epoch  0 the steps is:  88
# [58.08224503]  step  89  of the epoch  0 the steps is:  89
# 56.29779853044232  step  90  of the epoch  0 the steps is:  90
# 55.477396207185244  step  91  of the epoch  0 the steps is:  91
# 56.27990228911931  step  92  of the epoch  0 the steps is:  92
# [57.21085386]  step  93  of the epoch  0 the steps is:  93
# 56.40171225250039  step  94  of the epoch  0 the steps is:  94
# 56.19627396925159  step  95  of the epoch  0 the steps is:  95
# 56.44264224557341  step  96  of the epoch  0 the steps is:  96
# [55.16627954]  step  97  of the epoch  0 the steps is:  97
# 54.35087421287791  step  98  of the epoch  0 the steps is:  98
# 55.00152234950213  step  99  of the epoch  0 the steps is:  99
# [56.10340632]  step  100  of the epoch  0 the steps is:  100
# 55.42533991564136  step  101  of the epoch  0 the steps is:  101
# [56.31634075]  step  102  of the epoch  0 the steps is:  102
# 53.93093062822644  step  103  of the epoch  0 the steps is:  103
# 55.3737455082039  step  104  of the epoch  0 the steps is:  104
# 53.744113372145634  step  105  of the epoch  0 the steps is:  105
# [55.37004697]  step  106  of the epoch  0 the steps is:  106
# 54.81535762381644  step  107  of the epoch  0 the steps is:  107
# 53.43175775835603  step  108  of the epoch  0 the steps is:  108
# 53.78496139359682  step  109  of the epoch  0 the steps is:  109
# 53.472143739314596  step  110  of the epoch  0 the steps is:  110
# [56.48744324]  step  111  of the epoch  0 the steps is:  111
# 53.46902351024905  step  112  of the epoch  0 the steps is:  112
# [56.4939297]  step  113  of the epoch  0 the steps is:  113
# [53.34417996]  step  114  of the epoch  0 the steps is:  114
# 53.366366586309184  step  115  of the epoch  0 the steps is:  115
# 53.331226239788265  step  116  of the epoch  0 the steps is:  116
# 54.18579982571987  step  117  of the epoch  0 the steps is:  117
# 53.15010823615846  step  118  of the epoch  0 the steps is:  118
# 53.053045410222886  step  119  of the epoch  0 the steps is:  119
# [53.73081148]  step  120  of the epoch  0 the steps is:  120
# [53.68239689]  step  121  of the epoch  0 the steps is:  121
# 52.488386145795054  step  122  of the epoch  0 the steps is:  122
# 53.779597439489564  step  123  of the epoch  0 the steps is:  123
# 53.811109838572825  step  124  of the epoch  0 the steps is:  124
# 52.59591995702064  step  125  of the epoch  0 the steps is:  125
# [55.07964703]  step  126  of the epoch  0 the steps is:  126
# 53.490402968961675  step  127  of the epoch  0 the steps is:  127
# [53.68339487]  step  128  of the epoch  0 the steps is:  128
# 53.19165906813997  step  129  of the epoch  0 the steps is:  129
# 52.88038837251964  step  130  of the epoch  0 the steps is:  130
# 52.78499851538936  step  131  of the epoch  0 the steps is:  131
# 52.43798570452542  step  132  of the epoch  0 the steps is:  132
# 52.75266224461254  step  133  of the epoch  0 the steps is:  133
# [53.7654715]  step  134  of the epoch  0 the steps is:  134
# 53.923781350097016  step  135  of the epoch  0 the steps is:  135
# 52.24884049667425  step  136  of the epoch  0 the steps is:  136
# [53.11683893]  step  137  of the epoch  0 the steps is:  137
# 51.817293613458645  step  138  of the epoch  0 the steps is:  138
# [53.68925658]  step  139  of the epoch  0 the steps is:  139
# [52.97723582]  step  140  of the epoch  0 the steps is:  140
# 52.34311016782829  step  141  of the epoch  0 the steps is:  141
# [52.4326447]  step  142  of the epoch  0 the steps is:  142
# 51.7126088663738  step  143  of the epoch  0 the steps is:  143
# [52.42035133]  step  144  of the epoch  0 the steps is:  144
# 51.9252445107812  step  145  of the epoch  0 the steps is:  145
# 51.577947454537075  step  146  of the epoch  0 the steps is:  146
# [52.39779285]  step  147  of the epoch  0 the steps is:  147
# 51.78531087316328  step  148  of the epoch  0 the steps is:  148
# [52.03877574]  step  149  of the epoch  0 the steps is:  149
# 51.75200168428941  step  150  of the epoch  0 the steps is:  150
# [51.84591418]  step  151  of the epoch  0 the steps is:  151
# 51.17599955092649  step  152  of the epoch  0 the steps is:  152
# 51.68225995375491  step  153  of the epoch  0 the steps is:  153
# 51.09861883081637  step  154  of the epoch  0 the steps is:  154
# 51.36974364627528  step  155  of the epoch  0 the steps is:  155
# [51.57019838]  step  156  of the epoch  0 the steps is:  156
# [51.55495237]  step  157  of the epoch  0 the steps is:  157
# 51.12371395426276  step  158  of the epoch  0 the steps is:  158
# 51.332036387177155  step  159  of the epoch  0 the steps is:  159
# 50.57663621875413  step  160  of the epoch  0 the steps is:  160
# 50.70697313918119  step  161  of the epoch  0 the steps is:  161
# 51.08214883521079  step  162  of the epoch  0 the steps is:  162
# 50.866651666699525  step  163  of the epoch  0 the steps is:  163
# 50.24859359808882  step  164  of the epoch  0 the steps is:  164
# 51.20453759092448  step  165  of the epoch  0 the steps is:  165
# 50.661562368261635  step  166  of the epoch  0 the steps is:  166
# 50.858434430142495  step  167  of the epoch  0 the steps is:  167
# [50.9669645]  step  168  of the epoch  0 the steps is:  168
# 50.59835269580265  step  169  of the epoch  0 the steps is:  169
# [51.39543777]  step  170  of the epoch  0 the steps is:  170
# 50.429725553876935  step  171  of the epoch  0 the steps is:  171
# 50.39656541274513  step  172  of the epoch  0 the steps is:  172
# [51.45285614]  step  173  of the epoch  0 the steps is:  173
# 50.015631602695855  step  174  of the epoch  0 the steps is:  174
# 50.5308738375378  step  175  of the epoch  0 the steps is:  175
# 50.503085475975766  step  176  of the epoch  0 the steps is:  176
# [50.79226523]  step  177  of the epoch  0 the steps is:  177
# 50.4657132597043  step  178  of the epoch  0 the steps is:  178
# [50.37513286]  step  179  of the epoch  0 the steps is:  179
# 50.25324011601173  step  180  of the epoch  0 the steps is:  180
# [49.7448573]  step  181  of the epoch  0 the steps is:  181
# 50.083677524874176  step  182  of the epoch  0 the steps is:  182
# 50.20443205531886  step  183  of the epoch  0 the steps is:  183
# [49.92561835]  step  184  of the epoch  0 the steps is:  184
# 49.697403908782604  step  185  of the epoch  0 the steps is:  185
# 50.1589519332083  step  186  of the epoch  0 the steps is:  186
# 50.23349697171588  step  187  of the epoch  0 the steps is:  187
# 49.764923284931186  step  188  of the epoch  0 the steps is:  188
# [49.76094937]  step  189  of the epoch  0 the steps is:  189
# 49.949113686734265  step  190  of the epoch  0 the steps is:  190
# 50.815186669419354  step  191  of the epoch  0 the steps is:  191
# 50.016572750952285  step  192  of the epoch  0 the steps is:  192
# 49.80523563950379  step  193  of the epoch  0 the steps is:  193
# 49.367693329992946  step  194  of the epoch  0 the steps is:  194
# [50.65351729]  step  195  of the epoch  0 the steps is:  195
# 49.46358420742155  step  196  of the epoch  0 the steps is:  196
# [49.72387266]  step  197  of the epoch  0 the steps is:  197
# [49.06719351]  step  198  of the epoch  0 the steps is:  198
# [49.40147369]  step  199  of the epoch  0 the steps is:  199
# 49.6786259573029  step  200  of the epoch  0 the steps is:  200
# 49.70727107070226  step  201  of the epoch  0 the steps is:  201
# [49.1722494]  step  202  of the epoch  0 the steps is:  202
# 49.31952614074892  step  203  of the epoch  0 the steps is:  203
# [49.85247115]  step  204  of the epoch  0 the steps is:  204
# [49.6165645]  step  205  of the epoch  0 the steps is:  205
# 48.78093525098482  step  206  of the epoch  0 the steps is:  206
# 48.99795971718939  step  207  of the epoch  0 the steps is:  207
# [48.3554493]  step  208  of the epoch  0 the steps is:  208
# 49.33221753812944  step  209  of the epoch  0 the steps is:  209
# 49.05154135301022  step  210  of the epoch  0 the steps is:  210
# [49.35360402]  step  211  of the epoch  0 the steps is:  211
# 49.49140911237329  step  212  of the epoch  0 the steps is:  212
# [48.88871936]  step  213  of the epoch  0 the steps is:  213
# 48.6116242233259  step  214  of the epoch  0 the steps is:  214
# 48.50901633990836  step  215  of the epoch  0 the steps is:  215
# 48.65051926736142  step  216  of the epoch  0 the steps is:  216
# 48.87674171466469  step  217  of the epoch  0 the steps is:  217
# 48.773532703409984  step  218  of the epoch  0 the steps is:  218
# 48.51946768345257  step  219  of the epoch  0 the steps is:  219
# 49.266762082881016  step  220  of the epoch  0 the steps is:  220
# 48.36219941776362  step  221  of the epoch  0 the steps is:  221
# 47.98899658082757  step  222  of the epoch  0 the steps is:  222
# 48.58587179648909  step  223  of the epoch  0 the steps is:  223
# 47.37853003844706  step  224  of the epoch  0 the steps is:  224
# 47.77116538695421  step  225  of the epoch  0 the steps is:  225
# 48.02394455731121  step  226  of the epoch  0 the steps is:  226
# 47.840634133217456  step  227  of the epoch  0 the steps is:  227
# 47.85196910199271  step  228  of the epoch  0 the steps is:  228
# 48.26402564638323  step  229  of the epoch  0 the steps is:  229
# 47.959813832521654  step  230  of the epoch  0 the steps is:  230
# [48.3676045]  step  231  of the epoch  0 the steps is:  231
# 48.410165693069864  step  232  of the epoch  0 the steps is:  232
# 49.06862711428512  step  233  of the epoch  0 the steps is:  233
# 48.3437676498922  step  234  of the epoch  0 the steps is:  234
# 48.09717366380066  step  235  of the epoch  0 the steps is:  235
# [48.40417087]  step  236  of the epoch  0 the steps is:  236
# [47.4568188]  step  237  of the epoch  0 the steps is:  237
# 47.329063040976024  step  238  of the epoch  0 the steps is:  238
# 48.329475140071935  step  239  of the epoch  0 the steps is:  239
# 48.20765102931778  step  240  of the epoch  0 the steps is:  240
# [47.80663487]  step  241  of the epoch  0 the steps is:  241
# 47.789450054710976  step  242  of the epoch  0 the steps is:  242
# [47.84501993]  step  243  of the epoch  0 the steps is:  243
# 47.98337357592857  step  244  of the epoch  0 the steps is:  244
# [47.40328181]  step  245  of the epoch  0 the steps is:  245
# 47.31341536257142  step  246  of the epoch  0 the steps is:  246
# 48.59564777111211  step  247  of the epoch  0 the steps is:  247
# 47.243455740108175  step  248  of the epoch  0 the steps is:  248
# [47.41056679]  step  249  of the epoch  0 the steps is:  249
# [46.84997916]  step  250  of the epoch  0 the steps is:  250
# 47.8480934104399  step  251  of the epoch  0 the steps is:  251
# [47.4235034]  step  252  of the epoch  0 the steps is:  252
# [47.47527059]  step  253  of the epoch  0 the steps is:  253
# 47.40896235018087  step  254  of the epoch  0 the steps is:  254
# 46.78450711968979  step  255  of the epoch  0 the steps is:  255
# 47.58509596490855  step  256  of the epoch  0 the steps is:  256
# 47.566395829524055  step  257  of the epoch  0 the steps is:  257
# [46.95397604]  step  258  of the epoch  0 the steps is:  258
# 47.11340527381503  step  259  of the epoch  0 the steps is:  259
# 47.29899869415463  step  260  of the epoch  0 the steps is:  260
# [47.13759441]  step  261  of the epoch  0 the steps is:  261
# [46.16736445]  step  262  of the epoch  0 the steps is:  262
# [46.91999178]  step  263  of the epoch  0 the steps is:  263
# 48.839740772553995  step  264  of the epoch  0 the steps is:  264
# 46.452551190320094  step  265  of the epoch  0 the steps is:  265
# [46.53158937]  step  266  of the epoch  0 the steps is:  266
# 46.63290979438325  step  267  of the epoch  0 the steps is:  267
# [46.14411524]  step  268  of the epoch  0 the steps is:  268
# 47.12518409548814  step  269  of the epoch  0 the steps is:  269
# [47.06248322]  step  270  of the epoch  0 the steps is:  270
# [46.8999134]  step  271  of the epoch  0 the steps is:  271
# 46.66605848471316  step  272  of the epoch  0 the steps is:  272
# [45.95194946]  step  273  of the epoch  0 the steps is:  273
# [46.26044942]  step  274  of the epoch  0 the steps is:  274
# 46.830493012689516  step  275  of the epoch  0 the steps is:  275
# 46.60114630581798  step  276  of the epoch  0 the steps is:  276
# [46.58897902]  step  277  of the epoch  0 the steps is:  277
# [46.93457576]  step  278  of the epoch  0 the steps is:  278
# 46.45628129894204  step  279  of the epoch  0 the steps is:  279
# [46.84192139]  step  280  of the epoch  0 the steps is:  280
# 45.625430514488905  step  281  of the epoch  0 the steps is:  281
# [46.69163557]  step  282  of the epoch  0 the steps is:  282
# 45.174187088507054  step  283  of the epoch  0 the steps is:  283
# 45.70519779168427  step  284  of the epoch  0 the steps is:  284
# [46.10898903]  step  285  of the epoch  0 the steps is:  285
# 45.90469432003741  step  286  of the epoch  0 the steps is:  286
# 45.21696414912399  step  287  of the epoch  0 the steps is:  287
# [45.70865116]  step  288  of the epoch  0 the steps is:  288
# 45.92565423773428  step  289  of the epoch  0 the steps is:  289
# 46.4941034413484  step  290  of the epoch  0 the steps is:  290
# [45.74923762]  step  291  of the epoch  0 the steps is:  291
# 45.31451482028723  step  292  of the epoch  0 the steps is:  292
# 46.11572161314804  step  293  of the epoch  0 the steps is:  293
# [45.34915007]  step  294  of the epoch  0 the steps is:  294
# [45.30329263]  step  295  of the epoch  0 the steps is:  295
# [44.42314135]  step  296  of the epoch  0 the steps is:  296
# 45.1184543512945  step  297  of the epoch  0 the steps is:  297
# 45.53879387932085  step  298  of the epoch  0 the steps is:  298
# 44.61482014727084  step  299  of the epoch  0 the steps is:  299
# [43.61754654]  step  300  of the epoch  0 the steps is:  300
# 44.1634349644327  step  301  of the epoch  0 the steps is:  301
# [44.8523905]  step  302  of the epoch  0 the steps is:  302
# 45.72183550135597  step  303  of the epoch  0 the steps is:  303
# 44.98179377858687  step  304  of the epoch  0 the steps is:  304
# [44.55423824]  step  305  of the epoch  0 the steps is:  305
# [44.14056846]  step  306  of the epoch  0 the steps is:  306
# 44.985137451676565  step  307  of the epoch  0 the steps is:  307
# [43.89461297]  step  308  of the epoch  0 the steps is:  308
# [45.65045775]  step  309  of the epoch  0 the steps is:  309
# 45.167040952475745  step  310  of the epoch  0 the steps is:  310
# 44.26016679859725  step  311  of the epoch  0 the steps is:  311
# 45.24453953700235  step  312  of the epoch  0 the steps is:  312
# 43.546104687699966  step  313  of the epoch  0 the steps is:  313
# [44.89143663]  step  314  of the epoch  0 the steps is:  314
# 43.728369791462384  step  315  of the epoch  0 the steps is:  315
# 44.18562042845899  step  316  of the epoch  0 the steps is:  316
# 43.30515289529187  step  317  of the epoch  0 the steps is:  317
# 44.41691536387634  step  318  of the epoch  0 the steps is:  318
# 43.918870513451196  step  319  of the epoch  0 the steps is:  319
# 45.125015683527636  step  320  of the epoch  0 the steps is:  320
# 44.95289784708331  step  321  of the epoch  0 the steps is:  321
# 43.602897426246074  step  322  of the epoch  0 the steps is:  322
# 44.414176647583126  step  323  of the epoch  0 the steps is:  323
# [43.89701342]  step  324  of the epoch  0 the steps is:  324
# 44.8316405134845  step  325  of the epoch  0 the steps is:  325
# 43.54204052753698  step  326  of the epoch  0 the steps is:  326
# [43.45814357]  step  327  of the epoch  0 the steps is:  327
# 43.02093058698492  step  328  of the epoch  0 the steps is:  328
# [43.25312322]  step  329  of the epoch  0 the steps is:  329
# 44.16773271087099  step  330  of the epoch  0 the steps is:  330
# [42.45909811]  step  331  of the epoch  0 the steps is:  331
# 43.26446127755916  step  332  of the epoch  0 the steps is:  332
# 44.26817396248124  step  333  of the epoch  0 the steps is:  333
# 43.3893058219853  step  334  of the epoch  0 the steps is:  334
# 43.159327178773836  step  335  of the epoch  0 the steps is:  335
# [43.59778489]  step  336  of the epoch  0 the steps is:  336
# [40.50739278]  step  337  of the epoch  0 the steps is:  337
# 43.64477473147069  step  338  of the epoch  0 the steps is:  338
# [42.20001282]  step  339  of the epoch  0 the steps is:  339
# [43.23753425]  step  340  of the epoch  0 the steps is:  340
# 44.472634812229295  step  341  of the epoch  0 the steps is:  341
# [42.5331216]  step  342  of the epoch  0 the steps is:  342
# 43.74800910507193  step  343  of the epoch  0 the steps is:  343
# 42.77946072203211  step  344  of the epoch  0 the steps is:  344
# [42.26426797]  step  345  of the epoch  0 the steps is:  345
# 44.49159427927125  step  346  of the epoch  0 the steps is:  346
# 42.03139175924622  step  347  of the epoch  0 the steps is:  347
# 42.024369024308896  step  348  of the epoch  0 the steps is:  348
# [43.1296165]  step  349  of the epoch  0 the steps is:  349
# 41.00905532376201  step  350  of the epoch  0 the steps is:  350
# 43.66275843088025  step  351  of the epoch  0 the steps is:  351
# 42.08297067943854  step  352  of the epoch  0 the steps is:  352
# [42.31508024]  step  353  of the epoch  0 the steps is:  353
# 41.021226703958334  step  354  of the epoch  0 the steps is:  354
# 40.57600088103535  step  355  of the epoch  0 the steps is:  355
# 41.261392644683504  step  356  of the epoch  0 the steps is:  356
# [42.54957485]  step  357  of the epoch  0 the steps is:  357
# 42.298832420476344  step  358  of the epoch  0 the steps is:  358
# [42.90536573]  step  359  of the epoch  0 the steps is:  359
# 39.28679378871057  step  360  of the epoch  0 the steps is:  360
# [42.04586259]  step  361  of the epoch  0 the steps is:  361
# 42.44695074883988  step  362  of the epoch  0 the steps is:  362
# 43.3337093968526  step  363  of the epoch  0 the steps is:  363
# [42.30693865]  step  364  of the epoch  0 the steps is:  364
# [41.3761214]  step  365  of the epoch  0 the steps is:  365
# [41.86019427]  step  366  of the epoch  0 the steps is:  366
# [40.37008246]  step  367  of the epoch  0 the steps is:  367
# 39.652063466340515  step  368  of the epoch  0 the steps is:  368
# 43.22971018171117  step  369  of the epoch  0 the steps is:  369
# 39.912527170634576  step  370  of the epoch  0 the steps is:  370
# 43.607486962171066  step  371  of the epoch  0 the steps is:  371
# 42.67891410285128  step  372  of the epoch  0 the steps is:  372
# 40.61231925980377  step  373  of the epoch  0 the steps is:  373
# 40.597203489744814  step  374  of the epoch  0 the steps is:  374
# [40.68586044]  step  375  of the epoch  0 the steps is:  375
# [41.57519964]  step  376  of the epoch  0 the steps is:  376
# 40.780251087380705  step  377  of the epoch  0 the steps is:  377
# 41.18894919521061  step  378  of the epoch  0 the steps is:  378
# 40.90566236164422  step  379  of the epoch  0 the steps is:  379
# 40.32010136153737  step  380  of the epoch  0 the steps is:  380
# 43.030225338935175  step  381  of the epoch  0 the steps is:  381
# 39.70312984122885  step  382  of the epoch  0 the steps is:  382
# 39.92765136925476  step  383  of the epoch  0 the steps is:  383
# [40.00122357]  step  384  of the epoch  0 the steps is:  384
# 39.501244861446075  step  385  of the epoch  0 the steps is:  385
# [41.34147925]  step  386  of the epoch  0 the steps is:  386
# 40.125149262994775  step  387  of the epoch  0 the steps is:  387
# [38.35866095]  step  388  of the epoch  0 the steps is:  388
# 40.146920112461075  step  389  of the epoch  0 the steps is:  389
# 37.7773446838506  step  390  of the epoch  0 the steps is:  390
# [39.58917424]  step  391  of the epoch  0 the steps is:  391
# 40.877433970579716  step  392  of the epoch  0 the steps is:  392
# 41.32972494258553  step  393  of the epoch  0 the steps is:  393
# 43.04109979726998  step  394  of the epoch  0 the steps is:  394
# 40.49014941486631  step  395  of the epoch  0 the steps is:  395
# [39.38471123]  step  396  of the epoch  0 the steps is:  396
# 37.91697978130022  step  397  of the epoch  0 the steps is:  397
# 38.036975942423226  step  398  of the epoch  0 the steps is:  398
# 39.453634904931235  step  399  of the epoch  0 the steps is:  399
# [39.46499115]  step  400  of the epoch  0 the steps is:  400
# [36.64356195]  step  401  of the epoch  0 the steps is:  401
# 37.66803606949435  step  402  of the epoch  0 the steps is:  402
# 40.406361877280176  step  403  of the epoch  0 the steps is:  403
# 39.22430471185369  step  404  of the epoch  0 the steps is:  404
# 41.75066068111143  step  405  of the epoch  0 the steps is:  405
# [41.23425342]  step  406  of the epoch  0 the steps is:  406
# 40.01343448368688  step  407  of the epoch  0 the steps is:  407
# [38.40118146]  step  408  of the epoch  0 the steps is:  408
# 41.6814328432211  step  409  of the epoch  0 the steps is:  409
# 40.95591446412538  step  410  of the epoch  0 the steps is:  410
# [39.70196591]  step  411  of the epoch  0 the steps is:  411
# 39.63017268498628  step  412  of the epoch  0 the steps is:  412
# [39.17186564]  step  413  of the epoch  0 the steps is:  413
# 38.90210982774125  step  414  of the epoch  0 the steps is:  414
# 38.987302862401506  step  415  of the epoch  0 the steps is:  415
# 37.63495345670117  step  416  of the epoch  0 the steps is:  416
# 37.99136557954103  step  417  of the epoch  0 the steps is:  417
# [37.03313353]  step  418  of the epoch  0 the steps is:  418
# 34.95694844088145  step  419  of the epoch  0 the steps is:  419
# 38.596684196296906  step  420  of the epoch  0 the steps is:  420
# 37.41160428776018  step  421  of the epoch  0 the steps is:  421
# 38.2656387020084  step  422  of the epoch  0 the steps is:  422
# 39.382762123051634  step  423  of the epoch  0 the steps is:  423
# 36.170316758994375  step  424  of the epoch  0 the steps is:  424
# [40.68653364]  step  425  of the epoch  0 the steps is:  425
# 39.13830197556687  step  426  of the epoch  0 the steps is:  426
# [37.39362672]  step  427  of the epoch  0 the steps is:  427
# [36.65959626]  step  428  of the epoch  0 the steps is:  428
# 39.238640168191466  step  429  of the epoch  0 the steps is:  429
# [37.92613037]  step  430  of the epoch  0 the steps is:  430
# [39.36113103]  step  431  of the epoch  0 the steps is:  431
# [38.26502952]  step  432  of the epoch  0 the steps is:  432
# [37.63661679]  step  433  of the epoch  0 the steps is:  433
# 35.28904692810832  step  434  of the epoch  0 the steps is:  434
# 39.99306581220207  step  435  of the epoch  0 the steps is:  435
# 40.790161680163415  step  436  of the epoch  0 the steps is:  436
# [38.1887023]  step  437  of the epoch  0 the steps is:  437
# 36.44174527052369  step  438  of the epoch  0 the steps is:  438
# 40.21818334384764  step  439  of the epoch  0 the steps is:  439
# 34.828691444831044  step  440  of the epoch  0 the steps is:  440
# 39.944947092085144  step  441  of the epoch  0 the steps is:  441
# 37.16393183934992  step  442  of the epoch  0 the steps is:  442
# 37.993121969490446  step  443  of the epoch  0 the steps is:  443
# [33.72655997]  step  444  of the epoch  0 the steps is:  444
# [36.04031119]  step  445  of the epoch  0 the steps is:  445
# 37.25502567014874  step  446  of the epoch  0 the steps is:  446
# 38.65744517575678  step  447  of the epoch  0 the steps is:  447
# 38.95553018897929  step  448  of the epoch  0 the steps is:  448
# [37.45432586]  step  449  of the epoch  0 the steps is:  449
# 37.93429750590371  step  450  of the epoch  0 the steps is:  450
# [35.52695262]  step  451  of the epoch  0 the steps is:  451
# [38.5592778]  step  452  of the epoch  0 the steps is:  452
# [39.79165635]  step  453  of the epoch  0 the steps is:  453
# 35.9476508603627  step  454  of the epoch  0 the steps is:  454
# [39.41528146]  step  455  of the epoch  0 the steps is:  455
# 38.188843684969726  step  456  of the epoch  0 the steps is:  456
# 34.85275620140584  step  457  of the epoch  0 the steps is:  457
# 35.67680101879982  step  458  of the epoch  0 the steps is:  458
# 36.200883105093936  step  459  of the epoch  0 the steps is:  459
# 36.14050150270785  step  460  of the epoch  0 the steps is:  460
# 38.04757192002007  step  461  of the epoch  0 the steps is:  461
# 36.73839659683969  step  462  of the epoch  0 the steps is:  462
# 34.89654032802757  step  463  of the epoch  0 the steps is:  463
# 36.50985844479614  step  464  of the epoch  0 the steps is:  464
# [38.09164185]  step  465  of the epoch  0 the steps is:  465
# [35.5718242]  step  466  of the epoch  0 the steps is:  466
# 37.45658883556592  step  467  of the epoch  0 the steps is:  467
# 33.574676540140985  step  468  of the epoch  0 the steps is:  468
# [33.49629047]  step  469  of the epoch  0 the steps is:  469
# 37.6320340474833  step  470  of the epoch  0 the steps is:  470
# [36.36027601]  step  0  of the epoch  1 the steps is:  471
# 37.82991330643087  step  1  of the epoch  1 the steps is:  472
# 34.25502312056143  step  2  of the epoch  1 the steps is:  473
# 33.03228325896586  step  3  of the epoch  1 the steps is:  474
# 33.939655525857944  step  4  of the epoch  1 the steps is:  475
# 35.151589564822345  step  5  of the epoch  1 the steps is:  476
# [34.72120363]  step  6  of the epoch  1 the steps is:  477
# [33.4130178]  step  7  of the epoch  1 the steps is:  478
# [33.25307844]  step  8  of the epoch  1 the steps is:  479
# 33.885341288746716  step  9  of the epoch  1 the steps is:  480
# [38.05977582]  step  10  of the epoch  1 the steps is:  481
# 38.51460769406057  step  11  of the epoch  1 the steps is:  482
# [37.05092315]  step  12  of the epoch  1 the steps is:  483
# 34.51249911318837  step  13  of the epoch  1 the steps is:  484
# [33.01388996]  step  14  of the epoch  1 the steps is:  485
# [31.1303441]  step  15  of the epoch  1 the steps is:  486
# [35.84395697]  step  16  of the epoch  1 the steps is:  487
# 35.18187141239929  step  17  of the epoch  1 the steps is:  488
# 36.63960337430186  step  18  of the epoch  1 the steps is:  489
# [36.35672044]  step  19  of the epoch  1 the steps is:  490
# 34.85832267126915  step  20  of the epoch  1 the steps is:  491
# 40.83654908201481  step  21  of the epoch  1 the steps is:  492
# [35.73411988]  step  22  of the epoch  1 the steps is:  493
# 35.626904129649944  step  23  of the epoch  1 the steps is:  494
# 39.62131886682445  step  24  of the epoch  1 the steps is:  495
# [33.83885599]  step  25  of the epoch  1 the steps is:  496
# [35.60170072]  step  26  of the epoch  1 the steps is:  497
# 34.91960026847559  step  27  of the epoch  1 the steps is:  498
# 37.79837939845186  step  28  of the epoch  1 the steps is:  499
# 34.49462804972717  step  29  of the epoch  1 the steps is:  500
# 32.849273332958035  step  30  of the epoch  1 the steps is:  501
# 34.17771977029938  step  31  of the epoch  1 the steps is:  502
# 34.34100766477425  step  32  of the epoch  1 the steps is:  503
# 36.380376611542864  step  33  of the epoch  1 the steps is:  504
# [34.53988036]  step  34  of the epoch  1 the steps is:  505
# [35.0387515]  step  35  of the epoch  1 the steps is:  506
# 37.64194481015737  step  36  of the epoch  1 the steps is:  507
# 34.43276077053056  step  37  of the epoch  1 the steps is:  508
# 34.79200235633007  step  38  of the epoch  1 the steps is:  509
# 32.2541846905577  step  39  of the epoch  1 the steps is:  510
# 35.912152779774964  step  40  of the epoch  1 the steps is:  511
# 35.860294944429  step  41  of the epoch  1 the steps is:  512
# 34.81746689701896  step  42  of the epoch  1 the steps is:  513
# 33.429972245817865  step  43  of the epoch  1 the steps is:  514
# 32.88397063838138  step  44  of the epoch  1 the steps is:  515
# 32.26865433399743  step  45  of the epoch  1 the steps is:  516
# 34.2270080278666  step  46  of the epoch  1 the steps is:  517
# 30.6974818569875  step  47  of the epoch  1 the steps is:  518
# 31.521249264244048  step  48  of the epoch  1 the steps is:  519
# 35.42246234990523  step  49  of the epoch  1 the steps is:  520
# 33.28011095857809  step  50  of the epoch  1 the steps is:  521
# [33.75196301]  step  51  of the epoch  1 the steps is:  522
# 35.302969158825846  step  52  of the epoch  1 the steps is:  523
# 35.47271547312289  step  53  of the epoch  1 the steps is:  524
# 34.37756141143812  step  54  of the epoch  1 the steps is:  525
# 37.66149020017369  step  55  of the epoch  1 the steps is:  526
# 34.26888474015689  step  56  of the epoch  1 the steps is:  527
# [34.68660841]  step  57  of the epoch  1 the steps is:  528
# 36.948143175132685  step  58  of the epoch  1 the steps is:  529
# [37.51466624]  step  59  of the epoch  1 the steps is:  530
# 33.38516948215124  step  60  of the epoch  1 the steps is:  531
# 36.89126156967738  step  61  of the epoch  1 the steps is:  532
# [33.89866757]  step  62  of the epoch  1 the steps is:  533
# [31.15452038]  step  63  of the epoch  1 the steps is:  534
# 36.38458039299253  step  64  of the epoch  1 the steps is:  535
# 30.55905918225483  step  65  of the epoch  1 the steps is:  536
# 33.2239979854274  step  66  of the epoch  1 the steps is:  537
# [33.51030281]  step  67  of the epoch  1 the steps is:  538
# [31.87641172]  step  68  of the epoch  1 the steps is:  539
# [32.4052208]  step  69  of the epoch  1 the steps is:  540
# 35.01574844216422  step  70  of the epoch  1 the steps is:  541
# 36.547397206953846  step  71  of the epoch  1 the steps is:  542
# 32.26254130144283  step  72  of the epoch  1 the steps is:  543
# [37.22584382]  step  73  of the epoch  1 the steps is:  544
# 30.907074610358496  step  74  of the epoch  1 the steps is:  545
# 32.963884125199215  step  75  of the epoch  1 the steps is:  546
# 34.557690394649406  step  76  of the epoch  1 the steps is:  547
# 32.76409427673521  step  77  of the epoch  1 the steps is:  548
# 29.776654001979313  step  78  of the epoch  1 the steps is:  549
# [32.10650567]  step  79  of the epoch  1 the steps is:  550
# [35.0893483]  step  80  of the epoch  1 the steps is:  551
# 33.06608276745711  step  81  of the epoch  1 the steps is:  552
# 32.786810071529814  step  82  of the epoch  1 the steps is:  553
# 32.52835999898025  step  83  of the epoch  1 the steps is:  554
# 36.475228834769304  step  84  of the epoch  1 the steps is:  555
# 34.181200728346525  step  85  of the epoch  1 the steps is:  556
# [32.87539713]  step  86  of the epoch  1 the steps is:  557
# 32.05659431683535  step  87  of the epoch  1 the steps is:  558
# [31.8053947]  step  88  of the epoch  1 the steps is:  559
# [32.30385024]  step  89  of the epoch  1 the steps is:  560
# 33.088368359137455  step  90  of the epoch  1 the steps is:  561
# 32.903812317672156  step  91  of the epoch  1 the steps is:  562
# 28.860451447452434  step  92  of the epoch  1 the steps is:  563
# [28.34469345]  step  93  of the epoch  1 the steps is:  564
# 30.612048905802666  step  94  of the epoch  1 the steps is:  565
# 30.617639631388553  step  95  of the epoch  1 the steps is:  566
# 33.04926809401613  step  96  of the epoch  1 the steps is:  567
# [33.58580299]  step  97  of the epoch  1 the steps is:  568
# 32.424268768285586  step  98  of the epoch  1 the steps is:  569
# 32.806243400313775  step  99  of the epoch  1 the steps is:  570
# [33.90486516]  step  100  of the epoch  1 the steps is:  571
# 32.55733314780327  step  101  of the epoch  1 the steps is:  572
# [34.09838907]  step  102  of the epoch  1 the steps is:  573
# 33.84230030939303  step  103  of the epoch  1 the steps is:  574
# 33.68691463416168  step  104  of the epoch  1 the steps is:  575
# 32.0882667885774  step  105  of the epoch  1 the steps is:  576
# [31.42905571]  step  106  of the epoch  1 the steps is:  577
# 32.76332107095394  step  107  of the epoch  1 the steps is:  578
# 30.755508852827994  step  108  of the epoch  1 the steps is:  579
# 30.899249224958528  step  109  of the epoch  1 the steps is:  580
# 32.13136356590266  step  110  of the epoch  1 the steps is:  581
# [34.5546076]  step  111  of the epoch  1 the steps is:  582
# 33.07213104231393  step  112  of the epoch  1 the steps is:  583
# [34.30186825]  step  113  of the epoch  1 the steps is:  584
# [32.71870397]  step  114  of the epoch  1 the steps is:  585
# 32.67621681315159  step  115  of the epoch  1 the steps is:  586
# 32.416716271214106  step  116  of the epoch  1 the steps is:  587
# 32.6910755231435  step  117  of the epoch  1 the steps is:  588
# 33.564416555157216  step  118  of the epoch  1 the steps is:  589
# 29.115696664527274  step  119  of the epoch  1 the steps is:  590
# [30.8976677]  step  120  of the epoch  1 the steps is:  591
# [31.47132955]  step  121  of the epoch  1 the steps is:  592
# 29.774861109111562  step  122  of the epoch  1 the steps is:  593
# 35.299580852844024  step  123  of the epoch  1 the steps is:  594
# 34.675573482120825  step  124  of the epoch  1 the steps is:  595
# 33.15360320443542  step  125  of the epoch  1 the steps is:  596
# [29.1192795]  step  126  of the epoch  1 the steps is:  597
# 33.753217831105886  step  127  of the epoch  1 the steps is:  598
# [33.60109485]  step  128  of the epoch  1 the steps is:  599
# 30.185007039602247  step  129  of the epoch  1 the steps is:  600
# 32.519578822961655  step  130  of the epoch  1 the steps is:  601
# 31.619306313459823  step  131  of the epoch  1 the steps is:  602
# 31.331758113694313  step  132  of the epoch  1 the steps is:  603
# 31.951505922620008  step  133  of the epoch  1 the steps is:  604
# [33.3869827]  step  134  of the epoch  1 the steps is:  605
# 30.7861408307659  step  135  of the epoch  1 the steps is:  606
# 29.313372437093573  step  136  of the epoch  1 the steps is:  607
# [32.30220235]  step  137  of the epoch  1 the steps is:  608
# 34.29278065307662  step  138  of the epoch  1 the steps is:  609
# [33.14045956]  step  139  of the epoch  1 the steps is:  610
# [33.99140797]  step  140  of the epoch  1 the steps is:  611
# 32.56517663311004  step  141  of the epoch  1 the steps is:  612
# [31.55028704]  step  142  of the epoch  1 the steps is:  613
# 27.731950171862625  step  143  of the epoch  1 the steps is:  614
# [31.54033262]  step  144  of the epoch  1 the steps is:  615
# 27.41173301097838  step  145  of the epoch  1 the steps is:  616
# 31.21493323114511  step  146  of the epoch  1 the steps is:  617
# [30.41638374]  step  147  of the epoch  1 the steps is:  618
# 31.899485527320948  step  148  of the epoch  1 the steps is:  619
# [29.5009622]  step  149  of the epoch  1 the steps is:  620
# 31.765654328808306  step  150  of the epoch  1 the steps is:  621
# [30.96253157]  step  151  of the epoch  1 the steps is:  622
# 29.77049884333162  step  152  of the epoch  1 the steps is:  623
# 31.638474712323173  step  153  of the epoch  1 the steps is:  624
# 33.06381305174261  step  154  of the epoch  1 the steps is:  625
# 33.11843772024808  step  155  of the epoch  1 the steps is:  626
# [28.37093927]  step  156  of the epoch  1 the steps is:  627
# [31.00152174]  step  157  of the epoch  1 the steps is:  628
# 29.98229930582687  step  158  of the epoch  1 the steps is:  629
# 31.146721263912905  step  159  of the epoch  1 the steps is:  630
# 29.218975788480662  step  160  of the epoch  1 the steps is:  631
# 30.900373365526402  step  161  of the epoch  1 the steps is:  632
# 35.122109190023984  step  162  of the epoch  1 the steps is:  633
# 33.16123098758295  step  163  of the epoch  1 the steps is:  634
# 29.206729177574427  step  164  of the epoch  1 the steps is:  635
# 32.608226749968544  step  165  of the epoch  1 the steps is:  636
# 30.338647579478458  step  166  of the epoch  1 the steps is:  637
# 31.430246170958902  step  167  of the epoch  1 the steps is:  638
# [29.40194906]  step  168  of the epoch  1 the steps is:  639
# 30.753245115859215  step  169  of the epoch  1 the steps is:  640
# [29.19175629]  step  170  of the epoch  1 the steps is:  641
# 30.012934715850225  step  171  of the epoch  1 the steps is:  642
# 29.847717265931514  step  172  of the epoch  1 the steps is:  643
# [31.32683158]  step  173  of the epoch  1 the steps is:  644
# 30.198149631302453  step  174  of the epoch  1 the steps is:  645
# 32.76346942218457  step  175  of the epoch  1 the steps is:  646
# 31.70999910452847  step  176  of the epoch  1 the steps is:  647
# [31.03382751]  step  177  of the epoch  1 the steps is:  648
# 31.06779205261966  step  178  of the epoch  1 the steps is:  649
# [32.26969954]  step  179  of the epoch  1 the steps is:  650
# 30.86311363868687  step  180  of the epoch  1 the steps is:  651
# [30.5674739]  step  181  of the epoch  1 the steps is:  652
# 32.64784627988563  step  182  of the epoch  1 the steps is:  653
# 32.11143643202938  step  183  of the epoch  1 the steps is:  654
# [29.76620494]  step  184  of the epoch  1 the steps is:  655
# 31.76152647082873  step  185  of the epoch  1 the steps is:  656
# 31.140542734680597  step  186  of the epoch  1 the steps is:  657
# 33.93487990205483  step  187  of the epoch  1 the steps is:  658
# 29.198435345901217  step  188  of the epoch  1 the steps is:  659
# [28.71566486]  step  189  of the epoch  1 the steps is:  660
# 31.737351437447185  step  190  of the epoch  1 the steps is:  661
# 29.94786565771674  step  191  of the epoch  1 the steps is:  662
# 35.195788008661566  step  192  of the epoch  1 the steps is:  663
# 32.2093709332994  step  193  of the epoch  1 the steps is:  664
# 25.73148720448178  step  194  of the epoch  1 the steps is:  665
# [31.87247612]  step  195  of the epoch  1 the steps is:  666
# 27.615216227294358  step  196  of the epoch  1 the steps is:  667
# [27.73480068]  step  197  of the epoch  1 the steps is:  668
# [29.12347043]  step  198  of the epoch  1 the steps is:  669
# [29.15539402]  step  199  of the epoch  1 the steps is:  670
# 33.95919793225835  step  200  of the epoch  1 the steps is:  671
# 28.765651568719854  step  201  of the epoch  1 the steps is:  672
# [32.13728348]  step  202  of the epoch  1 the steps is:  673
# 29.85126644565951  step  203  of the epoch  1 the steps is:  674
# [30.73243272]  step  204  of the epoch  1 the steps is:  675
# [33.19347353]  step  205  of the epoch  1 the steps is:  676
# 27.445362093117563  step  206  of the epoch  1 the steps is:  677
# 28.840308609877944  step  207  of the epoch  1 the steps is:  678
# [28.89346603]  step  208  of the epoch  1 the steps is:  679
# 31.849212530906343  step  209  of the epoch  1 the steps is:  680
# 30.77595209265468  step  210  of the epoch  1 the steps is:  681
# [30.25344398]  step  211  of the epoch  1 the steps is:  682
# 31.883914535090973  step  212  of the epoch  1 the steps is:  683
# [29.11189862]  step  213  of the epoch  1 the steps is:  684
# 30.80149343496251  step  214  of the epoch  1 the steps is:  685
# 28.251399300308126  step  215  of the epoch  1 the steps is:  686
# 30.454633635880338  step  216  of the epoch  1 the steps is:  687
# 31.984272850371482  step  217  of the epoch  1 the steps is:  688
# 30.218681632921626  step  218  of the epoch  1 the steps is:  689
# 30.587640840420065  step  219  of the epoch  1 the steps is:  690
# 30.147720068144597  step  220  of the epoch  1 the steps is:  691
# 27.008740888526724  step  221  of the epoch  1 the steps is:  692
# 27.850947023309285  step  222  of the epoch  1 the steps is:  693
# 30.024956512157793  step  223  of the epoch  1 the steps is:  694
# 27.38152509184816  step  224  of the epoch  1 the steps is:  695
# 28.73933481303674  step  225  of the epoch  1 the steps is:  696
# 29.182571221134022  step  226  of the epoch  1 the steps is:  697
# 29.40118480665833  step  227  of the epoch  1 the steps is:  698
# 27.37994203795245  step  228  of the epoch  1 the steps is:  699
# 31.28409336377377  step  229  of the epoch  1 the steps is:  700
# 27.74769604454425  step  230  of the epoch  1 the steps is:  701
# [33.06694328]  step  231  of the epoch  1 the steps is:  702
# 29.4421502915502  step  232  of the epoch  1 the steps is:  703
# 33.585156167898504  step  233  of the epoch  1 the steps is:  704
# 31.300744211162378  step  234  of the epoch  1 the steps is:  705
# 29.975192405225016  step  235  of the epoch  1 the steps is:  706
# [31.66522344]  step  236  of the epoch  1 the steps is:  707
# [27.82004829]  step  237  of the epoch  1 the steps is:  708
# 28.298660168978397  step  238  of the epoch  1 the steps is:  709
# 30.387452048010253  step  239  of the epoch  1 the steps is:  710
# 31.51120343013095  step  240  of the epoch  1 the steps is:  711
# [30.56594161]  step  241  of the epoch  1 the steps is:  712
# 29.255913208657674  step  242  of the epoch  1 the steps is:  713
# [28.76368109]  step  243  of the epoch  1 the steps is:  714
# 31.87995729686903  step  244  of the epoch  1 the steps is:  715
# [28.19016618]  step  245  of the epoch  1 the steps is:  716
# 28.860670713108064  step  246  of the epoch  1 the steps is:  717
# 32.20983997857775  step  247  of the epoch  1 the steps is:  718
# 29.271844573123026  step  248  of the epoch  1 the steps is:  719
# [29.90426784]  step  249  of the epoch  1 the steps is:  720
# [26.18999994]  step  250  of the epoch  1 the steps is:  721
# 30.19832129411721  step  251  of the epoch  1 the steps is:  722
# [30.88006565]  step  252  of the epoch  1 the steps is:  723
# [28.47358519]  step  253  of the epoch  1 the steps is:  724
# 27.390067742077047  step  254  of the epoch  1 the steps is:  725
# 26.576371403015308  step  255  of the epoch  1 the steps is:  726
# 32.01309534489677  step  256  of the epoch  1 the steps is:  727
# 33.85939305350564  step  257  of the epoch  1 the steps is:  728
# [28.50278552]  step  258  of the epoch  1 the steps is:  729
# 28.6408653891811  step  259  of the epoch  1 the steps is:  730
# 32.17816026498218  step  260  of the epoch  1 the steps is:  731
# [29.89540293]  step  261  of the epoch  1 the steps is:  732
# [26.18631558]  step  262  of the epoch  1 the steps is:  733
# [28.55432085]  step  263  of the epoch  1 the steps is:  734
# 38.0857737214119  step  264  of the epoch  1 the steps is:  735
# 28.091602732003317  step  265  of the epoch  1 the steps is:  736
# [28.81761228]  step  266  of the epoch  1 the steps is:  737
# 29.342526466555046  step  267  of the epoch  1 the steps is:  738
# [27.75425863]  step  268  of the epoch  1 the steps is:  739
# 29.694745435542252  step  269  of the epoch  1 the steps is:  740
# [29.72131176]  step  270  of the epoch  1 the steps is:  741
# [28.40153007]  step  271  of the epoch  1 the steps is:  742
# 28.526048607755087  step  272  of the epoch  1 the steps is:  743
# [29.25501318]  step  273  of the epoch  1 the steps is:  744
# [30.3070394]  step  274  of the epoch  1 the steps is:  745
# 31.22137541239281  step  275  of the epoch  1 the steps is:  746
# 29.45488481821777  step  276  of the epoch  1 the steps is:  747
# [30.02844532]  step  277  of the epoch  1 the steps is:  748
# [31.3661558]  step  278  of the epoch  1 the steps is:  749
# 31.07790724698254  step  279  of the epoch  1 the steps is:  750
# [31.89587345]  step  280  of the epoch  1 the steps is:  751
# 27.797977196774966  step  281  of the epoch  1 the steps is:  752
# [32.10334942]  step  282  of the epoch  1 the steps is:  753
# 26.83204873703327  step  283  of the epoch  1 the steps is:  754
# 26.56574225018255  step  284  of the epoch  1 the steps is:  755
# [29.89537212]  step  285  of the epoch  1 the steps is:  756
# ...
# 24.57258844023731  step  225  of the epoch  2 the steps is:  1167
# 23.79390059369899  step  226  of the epoch  2 the steps is:  1168
# 25.889865860505708  step  227  of the epoch  2 the steps is:  1169
# 22.13645557221715  step  228  of the epoch  2 the steps is:  1170
# 26.84994407169397  step  229  of the epoch  2 the steps is:  1171
# 22.97203632566368  step  230  of the epoch  2 the steps is:  1172
# [31.4368603]  step  231  of the epoch  2 the steps is:  1173
# 25.56205848253001  step  232  of the epoch  2 the steps is:  1174
# 31.296938688665342  step  233  of the epoch  2 the steps is:  1175
# 26.184047120787845  step  234  of the epoch  2 the steps is:  1176
# 25.605716838574597  step  235  of the epoch  2 the steps is:  1177
# [29.71186609]  step  236  of the epoch  2 the steps is:  1178
# [24.76474261]  step  237  of the epoch  2 the steps is:  1179
# 24.30956226255823  step  238  of the epoch  2 the steps is:  1180
# 25.052760224615252  step  239  of the epoch  2 the steps is:  1181
# 28.788285364291145  step  240  of the epoch  2 the steps is:  1182
# [27.10888107]  step  241  of the epoch  2 the steps is:  1183
# 23.6701248330799  step  242  of the epoch  2 the steps is:  1184
# [25.23715928]  step  243  of the epoch  2 the steps is:  1185
# 26.361812557909268  step  244  of the epoch  2 the steps is:  1186
# [24.1343998]  step  245  of the epoch  2 the steps is:  1187
# 26.354849570269476  step  246  of the epoch  2 the steps is:  1188
# 27.91320507095041  step  247  of the epoch  2 the steps is:  1189
# 24.43295192900483  step  248  of the epoch  2 the steps is:  1190
# [25.61249866]  step  249  of the epoch  2 the steps is:  1191
# [22.03946673]  step  250  of the epoch  2 the steps is:  1192
# 26.38489949207571  step  251  of the epoch  2 the steps is:  1193
# [27.10409095]  step  252  of the epoch  2 the steps is:  1194
# [24.65168381]  step  253  of the epoch  2 the steps is:  1195
# 23.604204362472963  step  254  of the epoch  2 the steps is:  1196
# 21.93374768149328  step  255  of the epoch  2 the steps is:  1197
# 27.917266527083175  step  256  of the epoch  2 the steps is:  1198
# 28.163734357969204  step  257  of the epoch  2 the steps is:  1199
# [24.31256365]  step  258  of the epoch  2 the steps is:  1200
# 25.237452980198643  step  259  of the epoch  2 the steps is:  1201
# 28.517181983749744  step  260  of the epoch  2 the steps is:  1202
# [26.20270759]  step  261  of the epoch  2 the steps is:  1203
# [21.27217172]  step  262  of the epoch  2 the steps is:  1204
# [24.45651026]  step  263  of the epoch  2 the steps is:  1205
# 35.073819595142524  step  264  of the epoch  2 the steps is:  1206
# 23.94544905066267  step  265  of the epoch  2 the steps is:  1207
# [24.61051444]  step  266  of the epoch  2 the steps is:  1208
# 24.13148151753037  step  267  of the epoch  2 the steps is:  1209
# [25.36672757]  step  268  of the epoch  2 the steps is:  1210
# 26.08675246621968  step  269  of the epoch  2 the steps is:  1211
# [26.37637214]  step  270  of the epoch  2 the steps is:  1212
# [25.07310733]  step  271  of the epoch  2 the steps is:  1213
# 24.271402386043906  step  272  of the epoch  2 the steps is:  1214
# [25.46503902]  step  273  of the epoch  2 the steps is:  1215
# [27.93442217]  step  274  of the epoch  2 the steps is:  1216
# 27.59298131929002  step  275  of the epoch  2 the steps is:  1217
# 26.438452658702964  step  276  of the epoch  2 the steps is:  1218
# [27.01327873]  step  277  of the epoch  2 the steps is:  1219
# [29.54852742]  step  278  of the epoch  2 the steps is:  1220
# 26.104228264022268  step  279  of the epoch  2 the steps is:  1221
# [30.10300393]  step  280  of the epoch  2 the steps is:  1222
# 24.89941955374353  step  281  of the epoch  2 the steps is:  1223
# [30.00285167]  step  282  of the epoch  2 the steps is:  1224
# 23.53900444469265  step  283  of the epoch  2 the steps is:  1225
# 23.078981848844624  step  284  of the epoch  2 the steps is:  1226
# [27.04227081]  step  285  of the epoch  2 the steps is:  1227
# 26.432002723084743  step  286  of the epoch  2 the steps is:  1228
# 22.92501422752549  step  287  of the epoch  2 the steps is:  1229
# [24.07917]  step  288  of the epoch  2 the steps is:  1230
# 27.918300972592846  step  289  of the epoch  2 the steps is:  1231
# 28.12280576409613  step  290  of the epoch  2 the steps is:  1232
# [25.10360698]  step  291  of the epoch  2 the steps is:  1233
# 22.341896442952155  step  292  of the epoch  2 the steps is:  1234
# 27.58320818121328  step  293  of the epoch  2 the steps is:  1235
# [27.44068069]  step  294  of the epoch  2 the steps is:  1236
# [26.61455237]  step  295  of the epoch  2 the steps is:  1237
# [20.0232206]  step  296  of the epoch  2 the steps is:  1238
# 24.453183903587234  step  297  of the epoch  2 the steps is:  1239
# 20.942198108617177  step  298  of the epoch  2 the steps is:  1240
# 23.01796821317173  step  299  of the epoch  2 the steps is:  1241
# [23.23204743]  step  300  of the epoch  2 the steps is:  1242
# 24.890845906833746  step  301  of the epoch  2 the steps is:  1243
# [25.40464968]  step  302  of the epoch  2 the steps is:  1244
# 26.69216315297204  step  303  of the epoch  2 the steps is:  1245
# 24.408280990781133  step  304  of the epoch  2 the steps is:  1246
# [22.19930607]  step  305  of the epoch  2 the steps is:  1247
# [23.1142365]  step  306  of the epoch  2 the steps is:  1248
# 25.117613179030656  step  307  of the epoch  2 the steps is:  1249
# [22.11513252]  step  308  of the epoch  2 the steps is:  1250
# [27.83098262]  step  309  of the epoch  2 the steps is:  1251
# 28.525347545970206  step  310  of the epoch  2 the steps is:  1252
# 24.562297974684988  step  311  of the epoch  2 the steps is:  1253
# 26.45352903431782  step  312  of the epoch  2 the steps is:  1254
# 26.195837524900323  step  313  of the epoch  2 the steps is:  1255
# [24.76731719]  step  314  of the epoch  2 the steps is:  1256
# 23.01371287224655  step  315  of the epoch  2 the steps is:  1257
# 22.99235434040495  step  316  of the epoch  2 the steps is:  1258
# 21.569746607272247  step  317  of the epoch  2 the steps is:  1259
# 25.176966044840043  step  318  of the epoch  2 the steps is:  1260
# 24.32138502778295  step  319  of the epoch  2 the steps is:  1261
# 29.033713805743318  step  320  of the epoch  2 the steps is:  1262
# 26.7449495925027  step  321  of the epoch  2 the steps is:  1263
# 25.091493427183693  step  322  of the epoch  2 the steps is:  1264
# 26.813299262293995  step  323  of the epoch  2 the steps is:  1265
# [23.42693978]  step  324  of the epoch  2 the steps is:  1266
# 25.78161475461198  step  325  of the epoch  2 the steps is:  1267
# 21.422909807757648  step  326  of the epoch  2 the steps is:  1268
# [24.75232727]  step  327  of the epoch  2 the steps is:  1269
# 24.366502384217153  step  328  of the epoch  2 the steps is:  1270
# [24.90063212]  step  329  of the epoch  2 the steps is:  1271
# 26.15064073531208  step  330  of the epoch  2 the steps is:  1272
# [24.71035194]  step  331  of the epoch  2 the steps is:  1273
# 27.32273764094765  step  332  of the epoch  2 the steps is:  1274
# 26.174613812879706  step  333  of the epoch  2 the steps is:  1275
# 23.570303030038282  step  334  of the epoch  2 the steps is:  1276
# 24.48327121192249  step  335  of the epoch  2 the steps is:  1277
# [24.84685491]  step  336  of the epoch  2 the steps is:  1278
# [19.04203605]  step  337  of the epoch  2 the steps is:  1279
# 23.97270727420012  step  338  of the epoch  2 the steps is:  1280
# [22.59726277]  step  339  of the epoch  2 the steps is:  1281
# [25.55463577]  step  340  of the epoch  2 the steps is:  1282
# 29.786288882848538  step  341  of the epoch  2 the steps is:  1283
# [23.86831827]  step  342  of the epoch  2 the steps is:  1284
# 26.72430615468147  step  343  of the epoch  2 the steps is:  1285
# 27.324739963542168  step  344  of the epoch  2 the steps is:  1286
# [19.65958478]  step  345  of the epoch  2 the steps is:  1287
# 29.833977764120746  step  346  of the epoch  2 the steps is:  1288
# 27.612585082375723  step  347  of the epoch  2 the steps is:  1289
# 25.439592319772984  step  348  of the epoch  2 the steps is:  1290
# [24.4067359]  step  349  of the epoch  2 the steps is:  1291
# 21.878945813688333  step  350  of the epoch  2 the steps is:  1292
# 27.40757283307795  step  351  of the epoch  2 the steps is:  1293
# 25.322051303277938  step  352  of the epoch  2 the steps is:  1294
# [25.72442904]  step  353  of the epoch  2 the steps is:  1295
# 20.373055940788653  step  354  of the epoch  2 the steps is:  1296
# 20.41515958553166  step  355  of the epoch  2 the steps is:  1297
# 22.152274807857225  step  356  of the epoch  2 the steps is:  1298
# [27.42046349]  step  357  of the epoch  2 the steps is:  1299
# 24.618215762426395  step  358  of the epoch  2 the steps is:  1300
# [28.23029285]  step  359  of the epoch  2 the steps is:  1301
# 21.85688564220186  step  360  of the epoch  2 the steps is:  1302
# [27.53634682]  step  361  of the epoch  2 the steps is:  1303
# 26.877093132447044  step  362  of the epoch  2 the steps is:  1304
# 25.371930417615047  step  363  of the epoch  2 the steps is:  1305
# [26.33346042]  step  364  of the epoch  2 the steps is:  1306
# [25.49371878]  step  365  of the epoch  2 the steps is:  1307
# [27.54248187]  step  366  of the epoch  2 the steps is:  1308
# [23.60794763]  step  367  of the epoch  2 the steps is:  1309
# 23.305590302397643  step  368  of the epoch  2 the steps is:  1310
# 26.361709188023518  step  369  of the epoch  2 the steps is:  1311
# 23.18243817039277  step  370  of the epoch  2 the steps is:  1312
# 27.526608265300247  step  371  of the epoch  2 the steps is:  1313
# 27.796186458627098  step  372  of the epoch  2 the steps is:  1314
# 26.044425030063664  step  373  of the epoch  2 the steps is:  1315
# 24.624105059609008  step  374  of the epoch  2 the steps is:  1316
# [25.49537518]  step  375  of the epoch  2 the steps is:  1317
# [26.03129198]  step  376  of the epoch  2 the steps is:  1318
# 23.716074544655687  step  377  of the epoch  2 the steps is:  1319
# 26.327345195764806  step  378  of the epoch  2 the steps is:  1320
# 28.335398295820138  step  379  of the epoch  2 the steps is:  1321
# 23.321797984384574  step  380  of the epoch  2 the steps is:  1322
# 29.972728106814515  step  381  of the epoch  2 the steps is:  1323
# 22.79885438161873  step  382  of the epoch  2 the steps is:  1324
# 23.24984208625284  step  383  of the epoch  2 the steps is:  1325
# [23.39910922]  step  384  of the epoch  2 the steps is:  1326
# 23.357855498146147  step  385  of the epoch  2 the steps is:  1327
# [28.33671051]  step  386  of the epoch  2 the steps is:  1328
# 24.851351408911437  step  387  of the epoch  2 the steps is:  1329
# [22.79395414]  step  388  of the epoch  2 the steps is:  1330
# 24.858929451246336  step  389  of the epoch  2 the steps is:  1331
# 26.322794503897576  step  390  of the epoch  2 the steps is:  1332
# [24.35638043]  step  391  of the epoch  2 the steps is:  1333
# 26.29449623151223  step  392  of the epoch  2 the steps is:  1334
# 24.618365663727374  step  393  of the epoch  2 the steps is:  1335
# 29.581430492528852  step  394  of the epoch  2 the steps is:  1336
# 26.771932731190503  step  395  of the epoch  2 the steps is:  1337
# [25.64572128]  step  396  of the epoch  2 the steps is:  1338
# 23.416134026157412  step  397  of the epoch  2 the steps is:  1339
# 23.25781827263759  step  398  of the epoch  2 the steps is:  1340
# 22.23815930719714  step  399  of the epoch  2 the steps is:  1341
# [25.91734326]  step  400  of the epoch  2 the steps is:  1342
# [23.92994245]  step  401  of the epoch  2 the steps is:  1343
# 23.62554465932209  step  402  of the epoch  2 the steps is:  1344
# 26.182475659081156  step  403  of the epoch  2 the steps is:  1345
# 25.416800223659763  step  404  of the epoch  2 the steps is:  1346
# 27.96580162269263  step  405  of the epoch  2 the steps is:  1347
# [26.24025141]  step  406  of the epoch  2 the steps is:  1348
# 24.66971499905698  step  407  of the epoch  2 the steps is:  1349
# [23.8922881]  step  408  of the epoch  2 the steps is:  1350
# 28.771722799928224  step  409  of the epoch  2 the steps is:  1351
# 26.04199613273904  step  410  of the epoch  2 the steps is:  1352
# [25.74159187]  step  411  of the epoch  2 the steps is:  1353
# 25.347349409582126  step  412  of the epoch  2 the steps is:  1354
# [27.21497118]  step  413  of the epoch  2 the steps is:  1355
# 27.436187974923413  step  414  of the epoch  2 the steps is:  1356
# 27.240260203862675  step  415  of the epoch  2 the steps is:  1357
# 24.12908164974148  step  416  of the epoch  2 the steps is:  1358
# 24.61073694892853  step  417  of the epoch  2 the steps is:  1359
# [24.53214206]  step  418  of the epoch  2 the steps is:  1360
# 20.182061171322164  step  419  of the epoch  2 the steps is:  1361
# 27.514095480942895  step  420  of the epoch  2 the steps is:  1362
# 21.663679233472607  step  421  of the epoch  2 the steps is:  1363
# 27.38901300796386  step  422  of the epoch  2 the steps is:  1364
# 26.151166790415452  step  423  of the epoch  2 the steps is:  1365
# 24.998260275527304  step  424  of the epoch  2 the steps is:  1366
# [28.94508618]  step  425  of the epoch  2 the steps is:  1367
# 24.04178627139565  step  426  of the epoch  2 the steps is:  1368
# [27.62842263]  step  427  of the epoch  2 the steps is:  1369
# [24.29060732]  step  428  of the epoch  2 the steps is:  1370
# 27.21792693156731  step  429  of the epoch  2 the steps is:  1371
# [25.40528473]  step  430  of the epoch  2 the steps is:  1372
# [29.81025655]  step  431  of the epoch  2 the steps is:  1373
# [28.67288375]  step  432  of the epoch  2 the steps is:  1374
# [25.33206746]  step  433  of the epoch  2 the steps is:  1375
# 22.977484104592822  step  434  of the epoch  2 the steps is:  1376
# 27.39332038255415  step  435  of the epoch  2 the steps is:  1377
# 28.029741093035085  step  436  of the epoch  2 the steps is:  1378
# [25.89582569]  step  437  of the epoch  2 the steps is:  1379
# 24.702093796095255  step  438  of the epoch  2 the steps is:  1380
# 27.990969273177594  step  439  of the epoch  2 the steps is:  1381
# 23.346691121690323  step  440  of the epoch  2 the steps is:  1382
# 26.835533085132376  step  441  of the epoch  2 the steps is:  1383
# 24.13397972086358  step  442  of the epoch  2 the steps is:  1384
# 28.7643760303123  step  443  of the epoch  2 the steps is:  1385
# [20.02016595]  step  444  of the epoch  2 the steps is:  1386
# [24.1230489]  step  445  of the epoch  2 the steps is:  1387
# 26.523150944388533  step  446  of the epoch  2 the steps is:  1388
# 23.82967267173869  step  447  of the epoch  2 the steps is:  1389
# 28.43525885782554  step  448  of the epoch  2 the steps is:  1390
# [27.09947953]  step  449  of the epoch  2 the steps is:  1391
# 24.011703534101258  step  450  of the epoch  2 the steps is:  1392
# [25.58277267]  step  451  of the epoch  2 the steps is:  1393
# [25.33578996]  step  452  of the epoch  2 the steps is:  1394
# [29.93914222]  step  453  of the epoch  2 the steps is:  1395
# 26.79998037864054  step  454  of the epoch  2 the steps is:  1396
# [30.47971599]  step  455  of the epoch  2 the steps is:  1397
# 27.246537539084716  step  456  of the epoch  2 the steps is:  1398
# 21.860644492620093  step  457  of the epoch  2 the steps is:  1399
# 23.104959004828608  step  458  of the epoch  2 the steps is:  1400
# 27.198019554198755  step  459  of the epoch  2 the steps is:  1401
# 24.54143812215963  step  460  of the epoch  2 the steps is:  1402
# 27.78821052996097  step  461  of the epoch  2 the steps is:  1403
# 25.625812969673976  step  462  of the epoch  2 the steps is:  1404
# 25.052377036381813  step  463  of the epoch  2 the steps is:  1405
# 23.859951583850666  step  464  of the epoch  2 the steps is:  1406
# [25.44896242]  step  465  of the epoch  2 the steps is:  1407
# [23.85289446]  step  466  of the epoch  2 the steps is:  1408
# 27.284762318085207  step  467  of the epoch  2 the steps is:  1409
# 23.989045621589614  step  468  of the epoch  2 the steps is:  1410
# [22.55135692]  step  469  of the epoch  2 the steps is:  1411
# 24.44687845552527  step  470  of the epoch  2 the steps is:  1412

# %%
MyNetwork.Test_Network(Train_data, Train_label)
# Out:
# 0.815813953488372

# %%
mini_dataSet, mini_labelSet = [],[]
j = 0
for i in range(1000):
  if MyNetwork.forward(Train_data[i]) == Train_label[i]:
    mini_dataSet.append(Train_data[i])
    mini_labelSet.append(Train_label[i])
    j += 1
  if j == 100:
    break

# %%
attacked_image = []
for i in range(100):
  attacked_image.append(MyNetwork.attack_network(mini_dataSet[i], mini_labelSet[i]))

# %%
score1 = 0
score2 = 0
for i in range(100):
  print("The label for the", i,"th data is: ", MyNetwork.forward(mini_dataSet[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))))
  if MyNetwork.forward(mini_dataSet[i]) != MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score1 += 1
  if 10 ==  MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score2 += 1
print("The attacked accuracy was: ", score1)
print("The number rejection is: ", score2)
# Out:
# The label for the 0 th data is:  [3] after attack it became:  [1]
# The label for the 1 th data is:  [1] after attack it became:  [0]
# The label for the 2 th data is:  [9] after attack it became:  [10]
# The label for the 3 th data is:  [1] after attack it became:  [4]
# The label for the 4 th data is:  [4] after attack it became:  [4]
# The label for the 5 th data is:  [5] after attack it became:  [10]
# The label for the 6 th data is:  [0] after attack it became:  [10]
# The label for the 7 th data is:  [2] after attack it became:  [10]
# The label for the 8 th data is:  [9] after attack it became:  [5]
# The label for the 9 th data is:  [5] after attack it became:  [10]
# The label for the 10 th data is:  [9] after attack it became:  [8]
# The label for the 11 th data is:  [8] after attack it became:  [10]
# The label for the 12 th data is:  [1] after attack it became:  [3]
# The label for the 13 th data is:  [1] after attack it became:  [10]
# The label for the 14 th data is:  [5] after attack it became:  [10]
# The label for the 15 th data is:  [4] after attack it became:  [10]
# The label for the 16 th data is:  [1] after attack it became:  [3]
# The label for the 17 th data is:  [5] after attack it became:  [3]
# The label for the 18 th data is:  [0] after attack it became:  [10]
# The label for the 19 th data is:  [9] after attack it became:  [10]
# The label for the 20 th data is:  [5] after attack it became:  [10]
# The label for the 21 th data is:  [9] after attack it became:  [10]
# The label for the 22 th data is:  [9] after attack it became:  [8]
# The label for the 23 th data is:  [0] after attack it became:  [10]
# The label for the 24 th data is:  [7] after attack it became:  [8]
# The label for the 25 th data is:  [9] after attack it became:  [8]
# The label for the 26 th data is:  [1] after attack it became:  [5]
# The label for the 27 th data is:  [8] after attack it became:  [10]
# The label for the 28 th data is:  [9] after attack it became:  [10]
# The label for the 29 th data is:  [1] after attack it became:  [8]
# The label for the 30 th data is:  [9] after attack it became:  [10]
# The label for the 31 th data is:  [9] after attack it became:  [10]
# The label for the 32 th data is:  [7] after attack it became:  [10]
# The label for the 33 th data is:  [9] after attack it became:  [10]
# The label for the 34 th data is:  [3] after attack it became:  [10]
# The label for the 35 th data is:  [1] after attack it became:  [3]
# The label for the 36 th data is:  [2] after attack it became:  [10]
# The label for the 37 th data is:  [5] after attack it became:  [7]
# The label for the 38 th data is:  [8] after attack it became:  [10]
# The label for the 39 th data is:  [4] after attack it became:  [10]
# The label for the 40 th data is:  [2] after attack it became:  [10]
# The label for the 41 th data is:  [3] after attack it became:  [10]
# The label for the 42 th data is:  [4] after attack it became:  [10]
# The label for the 43 th data is:  [7] after attack it became:  [8]
# The label for the 44 th data is:  [3] after attack it became:  [10]
# The label for the 45 th data is:  [1] after attack it became:  [10]
# The label for the 46 th data is:  [6] after attack it became:  [6]
# The label for the 47 th data is:  [3] after attack it became:  [10]
# The label for the 48 th data is:  [5] after attack it became:  [10]
# The label for the 49 th data is:  [4] after attack it became:  [10]
# The label for the 50 th data is:  [5] after attack it became:  [7]
# The label for the 51 th data is:  [0] after attack it became:  [3]
# The label for the 52 th data is:  [8] after attack it became:  [10]
# The label for the 53 th data is:  [5] after attack it became:  [10]
# The label for the 54 th data is:  [5] after attack it became:  [10]
# The label for the 55 th data is:  [4] after attack it became:  [10]
# The label for the 56 th data is:  [8] after attack it became:  [2]
# The label for the 57 th data is:  [4] after attack it became:  [10]
# The label for the 58 th data is:  [7] after attack it became:  [8]
# The label for the 59 th data is:  [8] after attack it became:  [5]
# The label for the 60 th data is:  [8] after attack it became:  [10]
# The label for the 61 th data is:  [3] after attack it became:  [1]
# The label for the 62 th data is:  [1] after attack it became:  [3]
# The label for the 63 th data is:  [8] after attack it became:  [9]
# The label for the 64 th data is:  [0] after attack it became:  [10]
# The label for the 65 th data is:  [9] after attack it became:  [8]
# The label for the 66 th data is:  [6] after attack it became:  [6]
# The label for the 67 th data is:  [3] after attack it became:  [3]
# The label for the 68 th data is:  [4] after attack it became:  [7]
# The label for the 69 th data is:  [7] after attack it became:  [10]
# The label for the 70 th data is:  [5] after attack it became:  [10]
# The label for the 71 th data is:  [1] after attack it became:  [4]
# The label for the 72 th data is:  [8] after attack it became:  [5]
# The label for the 73 th data is:  [8] after attack it became:  [10]
# The label for the 74 th data is:  [5] after attack it became:  [7]
# The label for the 75 th data is:  [9] after attack it became:  [5]
# The label for the 76 th data is:  [7] after attack it became:  [10]
# The label for the 77 th data is:  [3] after attack it became:  [10]
# The label for the 78 th data is:  [3] after attack it became:  [10]
# The label for the 79 th data is:  [2] after attack it became:  [4]
# The label for the 80 th data is:  [3] after attack it became:  [10]
# The label for the 81 th data is:  [8] after attack it became:  [10]
# The label for the 82 th data is:  [3] after attack it became:  [10]
# The label for the 83 th data is:  [1] after attack it became:  [3]
# The label for the 84 th data is:  [6] after attack it became:  [8]
# The label for the 85 th data is:  [4] after attack it became:  [2]
# The label for the 86 th data is:  [1] after attack it became:  [10]
# The label for the 87 th data is:  [7] after attack it became:  [8]
# The label for the 88 th data is:  [6] after attack it became:  [10]
# The label for the 89 th data is:  [9] after attack it became:  [9]
# The label for the 90 th data is:  [8] after attack it became:  [2]
# The label for the 91 th data is:  [1] after attack it became:  [3]
# The label for the 92 th data is:  [6] after attack it became:  [10]
# The label for the 93 th data is:  [1] after attack it became:  [10]
# The label for the 94 th data is:  [7] after attack it became:  [7]
# The label for the 95 th data is:  [1] after attack it became:  [5]
# The label for the 96 th data is:  [0] after attack it became:  [10]
# The label for the 97 th data is:  [9] after attack it became:  [5]
# The label for the 98 th data is:  [7] after attack it became:  [10]
# The label for the 99 th data is:  [0] after attack it became:  [10]
# The attacked accuracy was:  94
# The number rejection is:  55

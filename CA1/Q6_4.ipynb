# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testData.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainData.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx):
  temp = step(vect)
  temp[idx] = 0
  n = np.sum(temp)
  for i in range(len(temp)):
    if temp[i] == 1:
      temp[i] = -1
  temp[idx] = n
  return temp

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.attack_rate = 1

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = relu(self.layer["z0"])
    self.layer["s0"] = step(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = relu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = step(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = relu(self.layer["z" + str(self.number_hidden_layer)])
    self.layer["s" + str(self.number_hidden_layer)] = step(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide(self.score)
    return temp
  
  def decide(self, data):
    self.result = np.argmax(data, axis=0)
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu(temp[i] - temp[i][label[i]] + 1))-1)# inja ro bayad taghir bedi
      self.back_prob_output.append(encode((temp[i] - temp[i][label[i]] + 1), label[i]))
    self.back_prob_output = (np.transpose(self.back_prob_output))/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(self.back_prob_output, self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] + self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] + self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))
           
  def attach_network(self, data, label):
    self.forward(data)
    self.cal_loss(label)
    D_image = np.multiply(self.back_prob_output, self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      D_image = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), D_image)
      D_image = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], D_image)
    D_image = np.matmul(np.transpose(self.weight["w0"]), D_image)
    D_image = np.sign(D_image) 
    return data - self.attack_rate * D_image.reshape((-1,))

# %%
MyNetwork = Network(784,1,[150] ,10)
#MyNetwork.load_weights()

# %%
MyNetwork.set_learning_rate(0.001)
MyNetwork.set_turn(1)
MyNetwork.set_batch_size(1)
MyNetwork.Train_Network(Train_data, Train_label)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.0  step  55001  of the epoch  0 the steps is:  55001
# 0.5869210135793042  step  55002  of the epoch  0 the steps is:  55002
# 2.244836699430719  step  55003  of the epoch  0 the steps is:  55003
# 0.0  step  55004  of the epoch  0 the steps is:  55004
# 0.0  step  55005  of the epoch  0 the steps is:  55005
# 0.303629227299691  step  55006  of the epoch  0 the steps is:  55006
# 0.0  step  55007  of the epoch  0 the steps is:  55007
# 0.0  step  55008  of the epoch  0 the steps is:  55008
# 0.0  step  55009  of the epoch  0 the steps is:  55009
# 2.296126372583465  step  55010  of the epoch  0 the steps is:  55010
# 0.0  step  55011  of the epoch  0 the steps is:  55011
# 0.0  step  55012  of the epoch  0 the steps is:  55012
# 2.928747412309403  step  55013  of the epoch  0 the steps is:  55013
# 0.0  step  55014  of the epoch  0 the steps is:  55014
# 0.6561996594883732  step  55015  of the epoch  0 the steps is:  55015
# 0.0  step  55016  of the epoch  0 the steps is:  55016
# 4.563815575724125  step  55017  of the epoch  0 the steps is:  55017
# 2.7248368832267156  step  55018  of the epoch  0 the steps is:  55018
# 1.6791565696569841  step  55019  of the epoch  0 the steps is:  55019
# 0.0  step  55020  of the epoch  0 the steps is:  55020
# 0.0  step  55021  of the epoch  0 the steps is:  55021
# 0.0  step  55022  of the epoch  0 the steps is:  55022
# 1.5181746922194135  step  55023  of the epoch  0 the steps is:  55023
# 0.0  step  55024  of the epoch  0 the steps is:  55024
# 0.0  step  55025  of the epoch  0 the steps is:  55025
# 0.0  step  55026  of the epoch  0 the steps is:  55026
# 0.0  step  55027  of the epoch  0 the steps is:  55027
# 0.0  step  55028  of the epoch  0 the steps is:  55028
# 2.7511112801297943  step  55029  of the epoch  0 the steps is:  55029
# 0.0  step  55030  of the epoch  0 the steps is:  55030
# 0.0  step  55031  of the epoch  0 the steps is:  55031
# 0.0  step  55032  of the epoch  0 the steps is:  55032
# 0.0  step  55033  of the epoch  0 the steps is:  55033
# 0.0  step  55034  of the epoch  0 the steps is:  55034
# 0.0  step  55035  of the epoch  0 the steps is:  55035
# 5.331649631648124  step  55036  of the epoch  0 the steps is:  55036
# 6.794330051352267  step  55037  of the epoch  0 the steps is:  55037
# 0.0  step  55038  of the epoch  0 the steps is:  55038
# 0.0  step  55039  of the epoch  0 the steps is:  55039
# 0.0  step  55040  of the epoch  0 the steps is:  55040
# 1.3569249146319322  step  55041  of the epoch  0 the steps is:  55041
# 0.0  step  55042  of the epoch  0 the steps is:  55042
# 0.0  step  55043  of the epoch  0 the steps is:  55043
# 1.9560019130296435  step  55044  of the epoch  0 the steps is:  55044
# 0.5335919997867533  step  55045  of the epoch  0 the steps is:  55045
# 0.0  step  55046  of the epoch  0 the steps is:  55046
# 0.0  step  55047  of the epoch  0 the steps is:  55047
# 0.0  step  55048  of the epoch  0 the steps is:  55048
# 0.0  step  55049  of the epoch  0 the steps is:  55049
# 0.0  step  55050  of the epoch  0 the steps is:  55050
# 0.0  step  55051  of the epoch  0 the steps is:  55051
# 0.0  step  55052  of the epoch  0 the steps is:  55052
# 0.0  step  55053  of the epoch  0 the steps is:  55053
# 0.07741596637667403  step  55054  of the epoch  0 the steps is:  55054
# 0.0  step  55055  of the epoch  0 the steps is:  55055
# 0.0  step  55056  of the epoch  0 the steps is:  55056
# 0.0  step  55057  of the epoch  0 the steps is:  55057
# 0.0  step  55058  of the epoch  0 the steps is:  55058
# 0.8619860318382031  step  55059  of the epoch  0 the steps is:  55059
# 0.0  step  55060  of the epoch  0 the steps is:  55060
# 0.0  step  55061  of the epoch  0 the steps is:  55061
# 0.0  step  55062  of the epoch  0 the steps is:  55062
# 0.5843198633769271  step  55063  of the epoch  0 the steps is:  55063
# 0.0  step  55064  of the epoch  0 the steps is:  55064
# 3.213256895695255  step  55065  of the epoch  0 the steps is:  55065
# 2.0022055910422374  step  55066  of the epoch  0 the steps is:  55066
# 0.0  step  55067  of the epoch  0 the steps is:  55067
# 0.0  step  55068  of the epoch  0 the steps is:  55068
# 0.055979747309626404  step  55069  of the epoch  0 the steps is:  55069
# 0.0  step  55070  of the epoch  0 the steps is:  55070
# 2.251596631028926  step  55071  of the epoch  0 the steps is:  55071
# 0.0  step  55072  of the epoch  0 the steps is:  55072
# 0.0  step  55073  of the epoch  0 the steps is:  55073
# 0.8941336799201263  step  55074  of the epoch  0 the steps is:  55074
# 1.0288541663427866  step  55075  of the epoch  0 the steps is:  55075
# 0.5184229101114739  step  55076  of the epoch  0 the steps is:  55076
# 0.0  step  55077  of the epoch  0 the steps is:  55077
# 0.6582937468324763  step  55078  of the epoch  0 the steps is:  55078
# 0.0  step  55079  of the epoch  0 the steps is:  55079
# 0.0  step  55080  of the epoch  0 the steps is:  55080
# 3.344473284183988  step  55081  of the epoch  0 the steps is:  55081
# 0.0  step  55082  of the epoch  0 the steps is:  55082
# 0.0  step  55083  of the epoch  0 the steps is:  55083
# 0.0  step  55084  of the epoch  0 the steps is:  55084
# 0.8617326813944604  step  55085  of the epoch  0 the steps is:  55085
# 0.0  step  55086  of the epoch  0 the steps is:  55086
# 0.0  step  55087  of the epoch  0 the steps is:  55087
# 0.0  step  55088  of the epoch  0 the steps is:  55088
# 0.0  step  55089  of the epoch  0 the steps is:  55089
# 0.0  step  55090  of the epoch  0 the steps is:  55090
# 0.7059617586768452  step  55091  of the epoch  0 the steps is:  55091
# 0.0  step  55092  of the epoch  0 the steps is:  55092
# 0.0  step  55093  of the epoch  0 the steps is:  55093
# 0.0  step  55094  of the epoch  0 the steps is:  55094
# 0.0  step  55095  of the epoch  0 the steps is:  55095
# 0.48583836679156756  step  55096  of the epoch  0 the steps is:  55096
# 0.0  step  55097  of the epoch  0 the steps is:  55097
# 7.235232864720791  step  55098  of the epoch  0 the steps is:  55098
# 0.40928500205217055  step  55099  of the epoch  0 the steps is:  55099
# 0.11830709259013794  step  55100  of the epoch  0 the steps is:  55100
# 0.0  step  55101  of the epoch  0 the steps is:  55101
# 0.0  step  55102  of the epoch  0 the steps is:  55102
# 0.0  step  55103  of the epoch  0 the steps is:  55103
# 0.0  step  55104  of the epoch  0 the steps is:  55104
# 0.0  step  55105  of the epoch  0 the steps is:  55105
# 0.0  step  55106  of the epoch  0 the steps is:  55106
# 0.0  step  55107  of the epoch  0 the steps is:  55107
# 0.0  step  55108  of the epoch  0 the steps is:  55108
# 0.0  step  55109  of the epoch  0 the steps is:  55109
# 0.0  step  55110  of the epoch  0 the steps is:  55110
# 0.0  step  55111  of the epoch  0 the steps is:  55111
# 0.0005633611238193836  step  55112  of the epoch  0 the steps is:  55112
# 0.0  step  55113  of the epoch  0 the steps is:  55113
# 1.2072101386895602  step  55114  of the epoch  0 the steps is:  55114
# 0.0  step  55115  of the epoch  0 the steps is:  55115
# 0.0  step  55116  of the epoch  0 the steps is:  55116
# 0.0  step  55117  of the epoch  0 the steps is:  55117
# 1.0424077063890635  step  55118  of the epoch  0 the steps is:  55118
# 0.0  step  55119  of the epoch  0 the steps is:  55119
# 0.0  step  55120  of the epoch  0 the steps is:  55120
# 0.11385413027882141  step  55121  of the epoch  0 the steps is:  55121
# 1.4594132758223664  step  55122  of the epoch  0 the steps is:  55122
# 0.0  step  55123  of the epoch  0 the steps is:  55123
# 0.0  step  55124  of the epoch  0 the steps is:  55124
# 1.381891976975985  step  55125  of the epoch  0 the steps is:  55125
# 12.961378702015653  step  55126  of the epoch  0 the steps is:  55126
# 0.0  step  55127  of the epoch  0 the steps is:  55127
# 2.52845672038144  step  55128  of the epoch  0 the steps is:  55128
# 0.0  step  55129  of the epoch  0 the steps is:  55129
# 0.0  step  55130  of the epoch  0 the steps is:  55130
# 0.0  step  55131  of the epoch  0 the steps is:  55131
# 0.0  step  55132  of the epoch  0 the steps is:  55132
# 0.5648626355981636  step  55133  of the epoch  0 the steps is:  55133
# 0.0  step  55134  of the epoch  0 the steps is:  55134
# 0.0  step  55135  of the epoch  0 the steps is:  55135
# 3.8807175940130865  step  55136  of the epoch  0 the steps is:  55136
# 0.0  step  55137  of the epoch  0 the steps is:  55137
# 0.0  step  55138  of the epoch  0 the steps is:  55138
# 0.0  step  55139  of the epoch  0 the steps is:  55139
# 0.0  step  55140  of the epoch  0 the steps is:  55140
# 0.0  step  55141  of the epoch  0 the steps is:  55141
# 0.0  step  55142  of the epoch  0 the steps is:  55142
# 0.0  step  55143  of the epoch  0 the steps is:  55143
# 0.8549512885123849  step  55144  of the epoch  0 the steps is:  55144
# 0.0  step  55145  of the epoch  0 the steps is:  55145
# 0.0  step  55146  of the epoch  0 the steps is:  55146
# 0.28690505933805444  step  55147  of the epoch  0 the steps is:  55147
# 0.0  step  55148  of the epoch  0 the steps is:  55148
# 0.0  step  55149  of the epoch  0 the steps is:  55149
# 0.0  step  55150  of the epoch  0 the steps is:  55150
# 0.0  step  55151  of the epoch  0 the steps is:  55151
# 0.3245016518418389  step  55152  of the epoch  0 the steps is:  55152
# 0.0  step  55153  of the epoch  0 the steps is:  55153
# 0.0  step  55154  of the epoch  0 the steps is:  55154
# 1.6756126131352356  step  55155  of the epoch  0 the steps is:  55155
# 0.0  step  55156  of the epoch  0 the steps is:  55156
# 16.68518608966249  step  55157  of the epoch  0 the steps is:  55157
# 0.0  step  55158  of the epoch  0 the steps is:  55158
# 2.931290585048235  step  55159  of the epoch  0 the steps is:  55159
# 0.0  step  55160  of the epoch  0 the steps is:  55160
# 0.0  step  55161  of the epoch  0 the steps is:  55161
# 0.0  step  55162  of the epoch  0 the steps is:  55162
# 0.0  step  55163  of the epoch  0 the steps is:  55163
# 0.6813206277495372  step  55164  of the epoch  0 the steps is:  55164
# 0.5423681899351127  step  55165  of the epoch  0 the steps is:  55165
# 0.16284508211317528  step  55166  of the epoch  0 the steps is:  55166
# 0.0  step  55167  of the epoch  0 the steps is:  55167
# 0.0  step  55168  of the epoch  0 the steps is:  55168
# 0.0  step  55169  of the epoch  0 the steps is:  55169
# 3.9392109433198517  step  55170  of the epoch  0 the steps is:  55170
# 0.0  step  55171  of the epoch  0 the steps is:  55171
# 0.0  step  55172  of the epoch  0 the steps is:  55172
# 0.0  step  55173  of the epoch  0 the steps is:  55173
# 0.0  step  55174  of the epoch  0 the steps is:  55174
# 0.0  step  55175  of the epoch  0 the steps is:  55175
# 0.0  step  55176  of the epoch  0 the steps is:  55176
# 0.0  step  55177  of the epoch  0 the steps is:  55177
# 0.0  step  55178  of the epoch  0 the steps is:  55178
# 0.0  step  55179  of the epoch  0 the steps is:  55179
# 0.0  step  55180  of the epoch  0 the steps is:  55180
# 0.28978966694430586  step  55181  of the epoch  0 the steps is:  55181
# 2.119825492825609  step  55182  of the epoch  0 the steps is:  55182
# 0.0  step  55183  of the epoch  0 the steps is:  55183
# 0.7410322057323784  step  55184  of the epoch  0 the steps is:  55184
# 0.0  step  55185  of the epoch  0 the steps is:  55185
# 2.3307340208396017  step  55186  of the epoch  0 the steps is:  55186
# 0.0  step  55187  of the epoch  0 the steps is:  55187
# 2.1499394984988225  step  55188  of the epoch  0 the steps is:  55188
# 0.0  step  55189  of the epoch  0 the steps is:  55189
# 2.5501718673887654  step  55190  of the epoch  0 the steps is:  55190
# 0.8496240165359104  step  55191  of the epoch  0 the steps is:  55191
# 0.0  step  55192  of the epoch  0 the steps is:  55192
# 0.0  step  55193  of the epoch  0 the steps is:  55193
# 0.0  step  55194  of the epoch  0 the steps is:  55194
# 0.34821767953274074  step  55195  of the epoch  0 the steps is:  55195
# 0.0  step  55196  of the epoch  0 the steps is:  55196
# 0.0  step  55197  of the epoch  0 the steps is:  55197
# 0.0  step  55198  of the epoch  0 the steps is:  55198
# 0.0  step  55199  of the epoch  0 the steps is:  55199
# 0.0  step  55200  of the epoch  0 the steps is:  55200
# 0.0  step  55201  of the epoch  0 the steps is:  55201
# 0.0  step  55202  of the epoch  0 the steps is:  55202
# 1.1778086891165582  step  55203  of the epoch  0 the steps is:  55203
# 0.7140797975534676  step  55204  of the epoch  0 the steps is:  55204
# 0.0  step  55205  of the epoch  0 the steps is:  55205
# 0.0  step  55206  of the epoch  0 the steps is:  55206
# 0.0  step  55207  of the epoch  0 the steps is:  55207
# 0.0  step  55208  of the epoch  0 the steps is:  55208
# 0.0  step  55209  of the epoch  0 the steps is:  55209
# 0.0  step  55210  of the epoch  0 the steps is:  55210
# 0.0  step  55211  of the epoch  0 the steps is:  55211
# 0.0  step  55212  of the epoch  0 the steps is:  55212
# 0.0  step  55213  of the epoch  0 the steps is:  55213
# 0.0  step  55214  of the epoch  0 the steps is:  55214
# 0.0  step  55215  of the epoch  0 the steps is:  55215
# 2.972111457680741  step  55216  of the epoch  0 the steps is:  55216
# 0.0  step  55217  of the epoch  0 the steps is:  55217
# 0.0  step  55218  of the epoch  0 the steps is:  55218
# 0.0  step  55219  of the epoch  0 the steps is:  55219
# 0.0  step  55220  of the epoch  0 the steps is:  55220
# 0.0  step  55221  of the epoch  0 the steps is:  55221
# 0.0  step  55222  of the epoch  0 the steps is:  55222
# 0.0  step  55223  of the epoch  0 the steps is:  55223
# 1.3127919077716368  step  55224  of the epoch  0 the steps is:  55224
# 0.0  step  55225  of the epoch  0 the steps is:  55225
# 2.140226974949671  step  55226  of the epoch  0 the steps is:  55226
# 0.0  step  55227  of the epoch  0 the steps is:  55227
# 0.0  step  55228  of the epoch  0 the steps is:  55228
# 0.0  step  55229  of the epoch  0 the steps is:  55229
# 0.0  step  55230  of the epoch  0 the steps is:  55230
# 0.0  step  55231  of the epoch  0 the steps is:  55231
# 0.03596902489021847  step  55232  of the epoch  0 the steps is:  55232
# 0.0  step  55233  of the epoch  0 the steps is:  55233
# 0.0  step  55234  of the epoch  0 the steps is:  55234
# 0.0  step  55235  of the epoch  0 the steps is:  55235
# 0.0  step  55236  of the epoch  0 the steps is:  55236
# 5.3386347703846315  step  55237  of the epoch  0 the steps is:  55237
# 0.0  step  55238  of the epoch  0 the steps is:  55238
# 0.7199555121552192  step  55239  of the epoch  0 the steps is:  55239
# 1.1745239020195513  step  55240  of the epoch  0 the steps is:  55240
# 2.224686925955746  step  55241  of the epoch  0 the steps is:  55241
# 1.3095818831063761  step  55242  of the epoch  0 the steps is:  55242
# 0.0  step  55243  of the epoch  0 the steps is:  55243
# 0.0  step  55244  of the epoch  0 the steps is:  55244
# 0.0  step  55245  of the epoch  0 the steps is:  55245
# 0.0  step  55246  of the epoch  0 the steps is:  55246
# 0.0  step  55247  of the epoch  0 the steps is:  55247
# 0.0  step  55248  of the epoch  0 the steps is:  55248
# 0.5448058811200456  step  55249  of the epoch  0 the steps is:  55249
# 0.0  step  55250  of the epoch  0 the steps is:  55250
# 1.232376707259494  step  55251  of the epoch  0 the steps is:  55251
# 0.0  step  55252  of the epoch  0 the steps is:  55252
# 0.0  step  55253  of the epoch  0 the steps is:  55253
# 0.0  step  55254  of the epoch  0 the steps is:  55254
# 0.0  step  55255  of the epoch  0 the steps is:  55255
# 0.0  step  55256  of the epoch  0 the steps is:  55256
# 0.0  step  55257  of the epoch  0 the steps is:  55257
# 2.331374183174563  step  55258  of the epoch  0 the steps is:  55258
# 0.0  step  55259  of the epoch  0 the steps is:  55259
# 0.0  step  55260  of the epoch  0 the steps is:  55260
# 3.6045517769367983  step  55261  of the epoch  0 the steps is:  55261
# 0.0  step  55262  of the epoch  0 the steps is:  55262
# 0.0  step  55263  of the epoch  0 the steps is:  55263
# 0.0  step  55264  of the epoch  0 the steps is:  55264
# 0.0  step  55265  of the epoch  0 the steps is:  55265
# 0.0  step  55266  of the epoch  0 the steps is:  55266
# 0.24657848229173496  step  55267  of the epoch  0 the steps is:  55267
# 0.0  step  55268  of the epoch  0 the steps is:  55268
# 0.8650908462345832  step  55269  of the epoch  0 the steps is:  55269
# 0.0  step  55270  of the epoch  0 the steps is:  55270
# 0.0  step  55271  of the epoch  0 the steps is:  55271
# 0.0  step  55272  of the epoch  0 the steps is:  55272
# 0.0  step  55273  of the epoch  0 the steps is:  55273
# 0.18065727991045577  step  55274  of the epoch  0 the steps is:  55274
# 4.107291746079515  step  55275  of the epoch  0 the steps is:  55275
# 0.0  step  55276  of the epoch  0 the steps is:  55276
# 0.0  step  55277  of the epoch  0 the steps is:  55277
# 2.5368087541899085  step  55278  of the epoch  0 the steps is:  55278
# 0.0  step  55279  of the epoch  0 the steps is:  55279
# 0.0  step  55280  of the epoch  0 the steps is:  55280
# 3.543964865247161  step  55281  of the epoch  0 the steps is:  55281
# 0.0  step  55282  of the epoch  0 the steps is:  55282
# 0.15264970356141916  step  55283  of the epoch  0 the steps is:  55283
# 0.0  step  55284  of the epoch  0 the steps is:  55284
# 2.4209800806823587  step  55285  of the epoch  0 the steps is:  55285
# 0.0  step  55286  of the epoch  0 the steps is:  55286
# 0.0  step  55287  of the epoch  0 the steps is:  55287
# 0.0  step  55288  of the epoch  0 the steps is:  55288
# 0.0  step  55289  of the epoch  0 the steps is:  55289
# 0.0  step  55290  of the epoch  0 the steps is:  55290
# 0.0  step  55291  of the epoch  0 the steps is:  55291
# 0.0  step  55292  of the epoch  0 the steps is:  55292
# 0.0  step  55293  of the epoch  0 the steps is:  55293
# 0.12632103295144592  step  55294  of the epoch  0 the steps is:  55294
# 0.0  step  55295  of the epoch  0 the steps is:  55295
# 0.0  step  55296  of the epoch  0 the steps is:  55296
# 0.0  step  55297  of the epoch  0 the steps is:  55297
# 4.112100440582382  step  55298  of the epoch  0 the steps is:  55298
# 0.0  step  55299  of the epoch  0 the steps is:  55299
# 0.0  step  55300  of the epoch  0 the steps is:  55300
# 6.7371431392436065  step  55301  of the epoch  0 the steps is:  55301
# 0.0  step  55302  of the epoch  0 the steps is:  55302
# 0.0  step  55303  of the epoch  0 the steps is:  55303
# 0.0  step  55304  of the epoch  0 the steps is:  55304
# 0.0  step  55305  of the epoch  0 the steps is:  55305
# 0.0  step  55306  of the epoch  0 the steps is:  55306
# 0.6271061137807665  step  55307  of the epoch  0 the steps is:  55307
# 0.0  step  55308  of the epoch  0 the steps is:  55308
# 3.6430703932141633  step  55309  of the epoch  0 the steps is:  55309
# 0.0  step  55310  of the epoch  0 the steps is:  55310
# 0.0  step  55311  of the epoch  0 the steps is:  55311
# 0.0  step  55312  of the epoch  0 the steps is:  55312
# 0.0  step  55313  of the epoch  0 the steps is:  55313
# 0.0  step  55314  of the epoch  0 the steps is:  55314
# 0.0  step  55315  of the epoch  0 the steps is:  55315
# 0.3385191443657023  step  55316  of the epoch  0 the steps is:  55316
# 0.0  step  55317  of the epoch  0 the steps is:  55317
# 0.0  step  55318  of the epoch  0 the steps is:  55318
# 0.0  step  55319  of the epoch  0 the steps is:  55319
# 0.0  step  55320  of the epoch  0 the steps is:  55320
# 0.0  step  55321  of the epoch  0 the steps is:  55321
# 0.0  step  55322  of the epoch  0 the steps is:  55322
# 0.0  step  55323  of the epoch  0 the steps is:  55323
# 0.0  step  55324  of the epoch  0 the steps is:  55324
# 2.2221375739968945  step  55325  of the epoch  0 the steps is:  55325
# 0.0  step  55326  of the epoch  0 the steps is:  55326
# 0.0  step  55327  of the epoch  0 the steps is:  55327
# 0.0  step  55328  of the epoch  0 the steps is:  55328
# 0.0  step  55329  of the epoch  0 the steps is:  55329
# 0.0  step  55330  of the epoch  0 the steps is:  55330
# 0.0  step  55331  of the epoch  0 the steps is:  55331
# 23.990464094221103  step  55332  of the epoch  0 the steps is:  55332
# 3.602982860682719  step  55333  of the epoch  0 the steps is:  55333
# 1.2385233247848069  step  55334  of the epoch  0 the steps is:  55334
# 3.2756858437954115  step  55335  of the epoch  0 the steps is:  55335
# 3.667666895284161  step  55336  of the epoch  0 the steps is:  55336
# 0.0  step  55337  of the epoch  0 the steps is:  55337
# 0.0  step  55338  of the epoch  0 the steps is:  55338
# 0.0  step  55339  of the epoch  0 the steps is:  55339
# 0.0  step  55340  of the epoch  0 the steps is:  55340
# 0.0  step  55341  of the epoch  0 the steps is:  55341
# 0.0  step  55342  of the epoch  0 the steps is:  55342
# 0.0  step  55343  of the epoch  0 the steps is:  55343
# 0.0  step  55344  of the epoch  0 the steps is:  55344
# 0.0  step  55345  of the epoch  0 the steps is:  55345
# 0.0  step  55346  of the epoch  0 the steps is:  55346
# 5.089337963373618  step  55347  of the epoch  0 the steps is:  55347
# 0.0  step  55348  of the epoch  0 the steps is:  55348
# 0.1023932847464426  step  55349  of the epoch  0 the steps is:  55349
# 0.0  step  55350  of the epoch  0 the steps is:  55350
# 4.592273388228982  step  55351  of the epoch  0 the steps is:  55351
# 1.5318737881558153  step  55352  of the epoch  0 the steps is:  55352
# 0.0  step  55353  of the epoch  0 the steps is:  55353
# 0.0  step  55354  of the epoch  0 the steps is:  55354
# 0.0  step  55355  of the epoch  0 the steps is:  55355
# 0.6831178403427343  step  55356  of the epoch  0 the steps is:  55356
# 0.0  step  55357  of the epoch  0 the steps is:  55357
# 0.0  step  55358  of the epoch  0 the steps is:  55358
# 7.5781854684575425  step  55359  of the epoch  0 the steps is:  55359
# 0.0  step  55360  of the epoch  0 the steps is:  55360
# 0.0  step  55361  of the epoch  0 the steps is:  55361
# 4.450707540438886  step  55362  of the epoch  0 the steps is:  55362
# 0.0  step  55363  of the epoch  0 the steps is:  55363
# 1.6841417560046583  step  55364  of the epoch  0 the steps is:  55364
# 0.0  step  55365  of the epoch  0 the steps is:  55365
# 0.9438262572553127  step  55366  of the epoch  0 the steps is:  55366
# 0.46862190626789246  step  55367  of the epoch  0 the steps is:  55367
# 0.6108260696499856  step  55368  of the epoch  0 the steps is:  55368
# 0.0  step  55369  of the epoch  0 the steps is:  55369
# 0.0  step  55370  of the epoch  0 the steps is:  55370
# 3.1918445684658447  step  55371  of the epoch  0 the steps is:  55371
# 1.7604715868359344  step  55372  of the epoch  0 the steps is:  55372
# 0.0  step  55373  of the epoch  0 the steps is:  55373
# 0.0  step  55374  of the epoch  0 the steps is:  55374
# 0.0  step  55375  of the epoch  0 the steps is:  55375
# 0.0  step  55376  of the epoch  0 the steps is:  55376
# 0.0  step  55377  of the epoch  0 the steps is:  55377
# 0.0  step  55378  of the epoch  0 the steps is:  55378
# 0.10127060331922522  step  55379  of the epoch  0 the steps is:  55379
# 1.4649826470138212  step  55380  of the epoch  0 the steps is:  55380
# 2.4799489647920536  step  55381  of the epoch  0 the steps is:  55381
# 0.0  step  55382  of the epoch  0 the steps is:  55382
# 0.0  step  55383  of the epoch  0 the steps is:  55383
# 0.0  step  55384  of the epoch  0 the steps is:  55384
# 0.0  step  55385  of the epoch  0 the steps is:  55385
# 2.344455352421159  step  55386  of the epoch  0 the steps is:  55386
# 1.2030308229940063  step  55387  of the epoch  0 the steps is:  55387
# 0.0  step  55388  of the epoch  0 the steps is:  55388
# 0.0  step  55389  of the epoch  0 the steps is:  55389
# 0.0  step  55390  of the epoch  0 the steps is:  55390
# 0.0  step  55391  of the epoch  0 the steps is:  55391
# 3.3629697451542144  step  55392  of the epoch  0 the steps is:  55392
# 0.0  step  55393  of the epoch  0 the steps is:  55393
# 2.1610394026132713  step  55394  of the epoch  0 the steps is:  55394
# 0.004405439673973888  step  55395  of the epoch  0 the steps is:  55395
# 0.0  step  55396  of the epoch  0 the steps is:  55396
# 0.0  step  55397  of the epoch  0 the steps is:  55397
# 0.0  step  55398  of the epoch  0 the steps is:  55398
# 5.335866606394377  step  55399  of the epoch  0 the steps is:  55399
# 0.0  step  55400  of the epoch  0 the steps is:  55400
# 0.0  step  55401  of the epoch  0 the steps is:  55401
# 0.20374759871955916  step  55402  of the epoch  0 the steps is:  55402
# 0.0  step  55403  of the epoch  0 the steps is:  55403
# 0.0  step  55404  of the epoch  0 the steps is:  55404
# 0.32722122251743  step  55405  of the epoch  0 the steps is:  55405
# 1.1999215082360113  step  55406  of the epoch  0 the steps is:  55406
# 0.0  step  55407  of the epoch  0 the steps is:  55407
# 0.0  step  55408  of the epoch  0 the steps is:  55408
# 0.0  step  55409  of the epoch  0 the steps is:  55409
# 0.0  step  55410  of the epoch  0 the steps is:  55410
# 2.2591209717449416  step  55411  of the epoch  0 the steps is:  55411
# 1.5548569848341662  step  55412  of the epoch  0 the steps is:  55412
# 0.0  step  55413  of the epoch  0 the steps is:  55413
# 0.0  step  55414  of the epoch  0 the steps is:  55414
# 0.0  step  55415  of the epoch  0 the steps is:  55415
# 0.0  step  55416  of the epoch  0 the steps is:  55416
# 0.0  step  55417  of the epoch  0 the steps is:  55417
# 0.0  step  55418  of the epoch  0 the steps is:  55418
# 0.9264285215067254  step  55419  of the epoch  0 the steps is:  55419
# 0.0  step  55420  of the epoch  0 the steps is:  55420
# 2.2928854235578147  step  55421  of the epoch  0 the steps is:  55421
# 0.0  step  55422  of the epoch  0 the steps is:  55422
# 0.0  step  55423  of the epoch  0 the steps is:  55423
# 0.0  step  55424  of the epoch  0 the steps is:  55424
# 0.0  step  55425  of the epoch  0 the steps is:  55425
# 0.5971865666517644  step  55426  of the epoch  0 the steps is:  55426
# 0.0  step  55427  of the epoch  0 the steps is:  55427
# 0.0  step  55428  of the epoch  0 the steps is:  55428
# 4.647262594102719  step  55429  of the epoch  0 the steps is:  55429
# 2.1155419397122204  step  55430  of the epoch  0 the steps is:  55430
# 0.0  step  55431  of the epoch  0 the steps is:  55431
# 0.0  step  55432  of the epoch  0 the steps is:  55432
# 0.0  step  55433  of the epoch  0 the steps is:  55433
# 0.0  step  55434  of the epoch  0 the steps is:  55434
# 0.0  step  55435  of the epoch  0 the steps is:  55435
# 0.0  step  55436  of the epoch  0 the steps is:  55436
# 0.0  step  55437  of the epoch  0 the steps is:  55437
# 4.882031731753983  step  55438  of the epoch  0 the steps is:  55438
# 0.0  step  55439  of the epoch  0 the steps is:  55439
# 0.0  step  55440  of the epoch  0 the steps is:  55440
# 0.0  step  55441  of the epoch  0 the steps is:  55441
# 0.050445489121832665  step  55442  of the epoch  0 the steps is:  55442
# 0.0  step  55443  of the epoch  0 the steps is:  55443
# 2.2323276611532843  step  55444  of the epoch  0 the steps is:  55444
# 0.0  step  55445  of the epoch  0 the steps is:  55445
# 0.0  step  55446  of the epoch  0 the steps is:  55446
# 0.0  step  55447  of the epoch  0 the steps is:  55447
# 0.13201270694088896  step  55448  of the epoch  0 the steps is:  55448
# 0.0  step  55449  of the epoch  0 the steps is:  55449
# 0.0  step  55450  of the epoch  0 the steps is:  55450
# 0.0  step  55451  of the epoch  0 the steps is:  55451
# 0.0  step  55452  of the epoch  0 the steps is:  55452
# 0.0  step  55453  of the epoch  0 the steps is:  55453
# 0.0  step  55454  of the epoch  0 the steps is:  55454
# 0.0  step  55455  of the epoch  0 the steps is:  55455
# 1.9249706988642692  step  55456  of the epoch  0 the steps is:  55456
# 0.9074624537895044  step  55457  of the epoch  0 the steps is:  55457
# 0.0  step  55458  of the epoch  0 the steps is:  55458
# 0.0  step  55459  of the epoch  0 the steps is:  55459
# 0.0  step  55460  of the epoch  0 the steps is:  55460
# 0.0  step  55461  of the epoch  0 the steps is:  55461
# 2.526158330434142  step  55462  of the epoch  0 the steps is:  55462
# 1.5679158298273963  step  55463  of the epoch  0 the steps is:  55463
# 1.981468685213036  step  55464  of the epoch  0 the steps is:  55464
# 0.0  step  55465  of the epoch  0 the steps is:  55465
# 0.0  step  55466  of the epoch  0 the steps is:  55466
# 11.28289974038147  step  55467  of the epoch  0 the steps is:  55467
# 0.0  step  55468  of the epoch  0 the steps is:  55468
# 2.2363119303748977  step  55469  of the epoch  0 the steps is:  55469
# 0.0  step  55470  of the epoch  0 the steps is:  55470
# 0.0  step  55471  of the epoch  0 the steps is:  55471
# 0.9240303717394518  step  55472  of the epoch  0 the steps is:  55472
# 0.0  step  55473  of the epoch  0 the steps is:  55473
# 3.5627350037461447  step  55474  of the epoch  0 the steps is:  55474
# 0.0  step  55475  of the epoch  0 the steps is:  55475
# 0.0  step  55476  of the epoch  0 the steps is:  55476
# 0.0  step  55477  of the epoch  0 the steps is:  55477
# 0.0  step  55478  of the epoch  0 the steps is:  55478
# 0.45989740555721514  step  55479  of the epoch  0 the steps is:  55479
# 0.0  step  55480  of the epoch  0 the steps is:  55480
# 0.0  step  55481  of the epoch  0 the steps is:  55481
# 0.0  step  55482  of the epoch  0 the steps is:  55482
# 2.5180907116165465  step  55483  of the epoch  0 the steps is:  55483
# 0.6768684633339426  step  55484  of the epoch  0 the steps is:  55484
# 0.0  step  55485  of the epoch  0 the steps is:  55485
# 0.0  step  55486  of the epoch  0 the steps is:  55486
# 0.0  step  55487  of the epoch  0 the steps is:  55487
# 0.0  step  55488  of the epoch  0 the steps is:  55488
# 1.1584725133097873  step  55489  of the epoch  0 the steps is:  55489
# 0.0  step  55490  of the epoch  0 the steps is:  55490
# 0.0  step  55491  of the epoch  0 the steps is:  55491
# 2.4792527285074035  step  55492  of the epoch  0 the steps is:  55492
# 3.1581690593094045  step  55493  of the epoch  0 the steps is:  55493
# 1.8138844970539636  step  55494  of the epoch  0 the steps is:  55494
# 0.0  step  55495  of the epoch  0 the steps is:  55495
# 0.3309605460897229  step  55496  of the epoch  0 the steps is:  55496
# 0.0  step  55497  of the epoch  0 the steps is:  55497
# 2.3345767729905775  step  55498  of the epoch  0 the steps is:  55498
# 0.0  step  55499  of the epoch  0 the steps is:  55499
# 0.0  step  55500  of the epoch  0 the steps is:  55500
# 0.0  step  55501  of the epoch  0 the steps is:  55501
# 0.0  step  55502  of the epoch  0 the steps is:  55502
# 0.0  step  55503  of the epoch  0 the steps is:  55503
# 0.6213965037032105  step  55504  of the epoch  0 the steps is:  55504
# 0.0  step  55505  of the epoch  0 the steps is:  55505
# 0.0  step  55506  of the epoch  0 the steps is:  55506
# 0.3576312780341473  step  55507  of the epoch  0 the steps is:  55507
# 2.107152155047805  step  55508  of the epoch  0 the steps is:  55508
# 0.0  step  55509  of the epoch  0 the steps is:  55509
# 0.06765349036598556  step  55510  of the epoch  0 the steps is:  55510
# 0.0  step  55511  of the epoch  0 the steps is:  55511
# 0.3412514059209073  step  55512  of the epoch  0 the steps is:  55512
# 0.0  step  55513  of the epoch  0 the steps is:  55513
# 0.0  step  55514  of the epoch  0 the steps is:  55514
# 0.0  step  55515  of the epoch  0 the steps is:  55515
# 0.0  step  55516  of the epoch  0 the steps is:  55516
# 0.26917370526639406  step  55517  of the epoch  0 the steps is:  55517
# 1.2545570841372529  step  55518  of the epoch  0 the steps is:  55518
# 0.9778782823536787  step  55519  of the epoch  0 the steps is:  55519
# 0.0  step  55520  of the epoch  0 the steps is:  55520
# 0.0  step  55521  of the epoch  0 the steps is:  55521
# 0.0  step  55522  of the epoch  0 the steps is:  55522
# 0.0  step  55523  of the epoch  0 the steps is:  55523
# 0.0  step  55524  of the epoch  0 the steps is:  55524
# 0.5678424970048104  step  55525  of the epoch  0 the steps is:  55525
# 0.30965593560541205  step  55526  of the epoch  0 the steps is:  55526
# 1.4097240194949627  step  55527  of the epoch  0 the steps is:  55527
# 0.0  step  55528  of the epoch  0 the steps is:  55528
# 0.0  step  55529  of the epoch  0 the steps is:  55529
# 0.0  step  55530  of the epoch  0 the steps is:  55530
# 0.0  step  55531  of the epoch  0 the steps is:  55531
# 0.09667922324182543  step  55532  of the epoch  0 the steps is:  55532
# 0.0  step  55533  of the epoch  0 the steps is:  55533
# 2.786156900063748  step  55534  of the epoch  0 the steps is:  55534
# 0.0  step  55535  of the epoch  0 the steps is:  55535
# 3.2619073791543016  step  55536  of the epoch  0 the steps is:  55536
# 0.0  step  55537  of the epoch  0 the steps is:  55537
# 0.0  step  55538  of the epoch  0 the steps is:  55538
# 0.0  step  55539  of the epoch  0 the steps is:  55539
# 1.2318537888809287  step  55540  of the epoch  0 the steps is:  55540
# 10.515025530136015  step  55541  of the epoch  0 the steps is:  55541
# 0.0  step  55542  of the epoch  0 the steps is:  55542
# 0.0  step  55543  of the epoch  0 the steps is:  55543
# 0.8222879001732171  step  55544  of the epoch  0 the steps is:  55544
# 0.0  step  55545  of the epoch  0 the steps is:  55545
# 0.37656659909597057  step  55546  of the epoch  0 the steps is:  55546
# 0.0  step  55547  of the epoch  0 the steps is:  55547
# 0.4084621383701741  step  55548  of the epoch  0 the steps is:  55548
# 0.0  step  55549  of the epoch  0 the steps is:  55549
# 0.0  step  55550  of the epoch  0 the steps is:  55550
# 0.0  step  55551  of the epoch  0 the steps is:  55551
# 0.0  step  55552  of the epoch  0 the steps is:  55552
# 0.0  step  55553  of the epoch  0 the steps is:  55553
# 1.4540572938036593  step  55554  of the epoch  0 the steps is:  55554
# 0.0  step  55555  of the epoch  0 the steps is:  55555
# 0.0  step  55556  of the epoch  0 the steps is:  55556
# 2.836221233576735  step  55557  of the epoch  0 the steps is:  55557
# 0.0  step  55558  of the epoch  0 the steps is:  55558
# 6.174321021907263  step  55559  of the epoch  0 the steps is:  55559
# 0.0  step  55560  of the epoch  0 the steps is:  55560
# 0.0  step  55561  of the epoch  0 the steps is:  55561
# 0.0  step  55562  of the epoch  0 the steps is:  55562
# 0.0  step  55563  of the epoch  0 the steps is:  55563
# 0.0  step  55564  of the epoch  0 the steps is:  55564
# 0.0  step  55565  of the epoch  0 the steps is:  55565
# 0.0  step  55566  of the epoch  0 the steps is:  55566
# 0.042698066178552097  step  55567  of the epoch  0 the steps is:  55567
# 0.0  step  55568  of the epoch  0 the steps is:  55568
# 8.799153047059132  step  55569  of the epoch  0 the steps is:  55569
# 0.0  step  55570  of the epoch  0 the steps is:  55570
# 0.0  step  55571  of the epoch  0 the steps is:  55571
# 1.0977871040090994  step  55572  of the epoch  0 the steps is:  55572
# 0.0  step  55573  of the epoch  0 the steps is:  55573
# 0.0  step  55574  of the epoch  0 the steps is:  55574
# 0.7317297346749685  step  55575  of the epoch  0 the steps is:  55575
# 0.0  step  55576  of the epoch  0 the steps is:  55576
# 0.0  step  55577  of the epoch  0 the steps is:  55577
# 1.1210789742066076  step  55578  of the epoch  0 the steps is:  55578
# 0.0  step  55579  of the epoch  0 the steps is:  55579
# 0.0  step  55580  of the epoch  0 the steps is:  55580
# 0.0  step  55581  of the epoch  0 the steps is:  55581
# 0.0  step  55582  of the epoch  0 the steps is:  55582
# 0.0  step  55583  of the epoch  0 the steps is:  55583
# 5.971494890625907  step  55584  of the epoch  0 the steps is:  55584
# 0.0  step  55585  of the epoch  0 the steps is:  55585
# 2.1027570263596322  step  55586  of the epoch  0 the steps is:  55586
# 2.9257756905189107  step  55587  of the epoch  0 the steps is:  55587
# 1.8913402670619943  step  55588  of the epoch  0 the steps is:  55588
# 0.0  step  55589  of the epoch  0 the steps is:  55589
# 0.0  step  55590  of the epoch  0 the steps is:  55590
# 0.0  step  55591  of the epoch  0 the steps is:  55591
# 0.0  step  55592  of the epoch  0 the steps is:  55592
# 1.025223553744297  step  55593  of the epoch  0 the steps is:  55593
# 0.1509295303677911  step  55594  of the epoch  0 the steps is:  55594
# 0.0  step  55595  of the epoch  0 the steps is:  55595
# 0.24192585510351083  step  55596  of the epoch  0 the steps is:  55596
# 0.0  step  55597  of the epoch  0 the steps is:  55597
# 0.0  step  55598  of the epoch  0 the steps is:  55598
# 0.0  step  55599  of the epoch  0 the steps is:  55599
# 0.04101221442053449  step  55600  of the epoch  0 the steps is:  55600
# 0.0  step  55601  of the epoch  0 the steps is:  55601
# 0.0  step  55602  of the epoch  0 the steps is:  55602
# 0.0  step  55603  of the epoch  0 the steps is:  55603
# 0.0  step  55604  of the epoch  0 the steps is:  55604
# 0.0  step  55605  of the epoch  0 the steps is:  55605
# 0.0  step  55606  of the epoch  0 the steps is:  55606
# 0.03690853359304436  step  55607  of the epoch  0 the steps is:  55607
# 0.0  step  55608  of the epoch  0 the steps is:  55608
# 0.0  step  55609  of the epoch  0 the steps is:  55609
# 0.0  step  55610  of the epoch  0 the steps is:  55610
# 0.0  step  55611  of the epoch  0 the steps is:  55611
# 0.0  step  55612  of the epoch  0 the steps is:  55612
# 0.0  step  55613  of the epoch  0 the steps is:  55613
# 0.0  step  55614  of the epoch  0 the steps is:  55614
# 0.0  step  55615  of the epoch  0 the steps is:  55615
# 0.0  step  55616  of the epoch  0 the steps is:  55616
# 0.0  step  55617  of the epoch  0 the steps is:  55617
# 0.0  step  55618  of the epoch  0 the steps is:  55618
# 0.7906180444698965  step  55619  of the epoch  0 the steps is:  55619
# 0.11976234590892298  step  55620  of the epoch  0 the steps is:  55620
# 0.0  step  55621  of the epoch  0 the steps is:  55621
# 0.0  step  55622  of the epoch  0 the steps is:  55622
# 6.961952093493002  step  55623  of the epoch  0 the steps is:  55623
# 0.0  step  55624  of the epoch  0 the steps is:  55624
# 0.0  step  55625  of the epoch  0 the steps is:  55625
# 0.0  step  55626  of the epoch  0 the steps is:  55626
# 0.0  step  55627  of the epoch  0 the steps is:  55627
# 0.0  step  55628  of the epoch  0 the steps is:  55628
# 0.0  step  55629  of the epoch  0 the steps is:  55629
# 1.3424486285333397  step  55630  of the epoch  0 the steps is:  55630
# 0.0  step  55631  of the epoch  0 the steps is:  55631
# 0.0  step  55632  of the epoch  0 the steps is:  55632
# 0.0  step  55633  of the epoch  0 the steps is:  55633
# 0.0  step  55634  of the epoch  0 the steps is:  55634
# 0.0  step  55635  of the epoch  0 the steps is:  55635
# 2.6947033792518367  step  55636  of the epoch  0 the steps is:  55636
# 0.22743960384771889  step  55637  of the epoch  0 the steps is:  55637
# 0.0  step  55638  of the epoch  0 the steps is:  55638
# 0.0  step  55639  of the epoch  0 the steps is:  55639
# 0.08173799995611208  step  55640  of the epoch  0 the steps is:  55640
# 0.9987385395975794  step  55641  of the epoch  0 the steps is:  55641
# 2.5273655052543003  step  55642  of the epoch  0 the steps is:  55642
# 0.0  step  55643  of the epoch  0 the steps is:  55643
# 0.2767320633634762  step  55644  of the epoch  0 the steps is:  55644
# 0.0  step  55645  of the epoch  0 the steps is:  55645
# 0.652246290820877  step  55646  of the epoch  0 the steps is:  55646
# 0.9717141432691605  step  55647  of the epoch  0 the steps is:  55647
# 0.0  step  55648  of the epoch  0 the steps is:  55648
# 7.268143998178889  step  55649  of the epoch  0 the steps is:  55649
# 0.0  step  55650  of the epoch  0 the steps is:  55650
# 0.48064305116575934  step  55651  of the epoch  0 the steps is:  55651
# 0.0  step  55652  of the epoch  0 the steps is:  55652
# 0.0  step  55653  of the epoch  0 the steps is:  55653
# 0.28374240789771044  step  55654  of the epoch  0 the steps is:  55654
# 2.8217457505231853  step  55655  of the epoch  0 the steps is:  55655
# 0.9097292402458601  step  55656  of the epoch  0 the steps is:  55656
# 0.0  step  55657  of the epoch  0 the steps is:  55657
# 0.2459398140811575  step  55658  of the epoch  0 the steps is:  55658
# 2.5643332701887362  step  55659  of the epoch  0 the steps is:  55659
# 0.0  step  55660  of the epoch  0 the steps is:  55660
# 0.06713741288289832  step  55661  of the epoch  0 the steps is:  55661
# 0.0  step  55662  of the epoch  0 the steps is:  55662
# 0.0  step  55663  of the epoch  0 the steps is:  55663
# 0.0  step  55664  of the epoch  0 the steps is:  55664
# 1.5012060076028995  step  55665  of the epoch  0 the steps is:  55665
# 2.0197613630200517  step  55666  of the epoch  0 the steps is:  55666
# 0.0  step  55667  of the epoch  0 the steps is:  55667
# 1.2664512150401124  step  55668  of the epoch  0 the steps is:  55668
# 2.104884385508317  step  55669  of the epoch  0 the steps is:  55669
# 0.5423332689821878  step  55670  of the epoch  0 the steps is:  55670
# 0.0  step  55671  of the epoch  0 the steps is:  55671
# 0.0  step  55672  of the epoch  0 the steps is:  55672
# 0.0  step  55673  of the epoch  0 the steps is:  55673
# 0.0  step  55674  of the epoch  0 the steps is:  55674
# 0.0  step  55675  of the epoch  0 the steps is:  55675
# 0.7352234971405864  step  55676  of the epoch  0 the steps is:  55676
# 0.0  step  55677  of the epoch  0 the steps is:  55677
# 0.0  step  55678  of the epoch  0 the steps is:  55678
# 0.0  step  55679  of the epoch  0 the steps is:  55679
# 0.0  step  55680  of the epoch  0 the steps is:  55680
# 0.0  step  55681  of the epoch  0 the steps is:  55681
# 2.217018202336552  step  55682  of the epoch  0 the steps is:  55682
# 0.0  step  55683  of the epoch  0 the steps is:  55683
# 0.0  step  55684  of the epoch  0 the steps is:  55684
# 0.6289013840849922  step  55685  of the epoch  0 the steps is:  55685
# 0.0  step  55686  of the epoch  0 the steps is:  55686
# 0.3467707360970631  step  55687  of the epoch  0 the steps is:  55687
# 0.0  step  55688  of the epoch  0 the steps is:  55688
# 0.0  step  55689  of the epoch  0 the steps is:  55689
# 2.5043712373713065  step  55690  of the epoch  0 the steps is:  55690
# 0.0  step  55691  of the epoch  0 the steps is:  55691
# 0.0  step  55692  of the epoch  0 the steps is:  55692
# 0.717212187524888  step  55693  of the epoch  0 the steps is:  55693
# 0.8376582378738231  step  55694  of the epoch  0 the steps is:  55694
# 0.0  step  55695  of the epoch  0 the steps is:  55695
# 0.0  step  55696  of the epoch  0 the steps is:  55696
# 1.628250024292396  step  55697  of the epoch  0 the steps is:  55697
# 0.0  step  55698  of the epoch  0 the steps is:  55698
# 0.0  step  55699  of the epoch  0 the steps is:  55699
# 0.0  step  55700  of the epoch  0 the steps is:  55700
# 0.0  step  55701  of the epoch  0 the steps is:  55701
# 0.0  step  55702  of the epoch  0 the steps is:  55702
# 2.909490113629804  step  55703  of the epoch  0 the steps is:  55703
# 0.0  step  55704  of the epoch  0 the steps is:  55704
# 4.82880100269626  step  55705  of the epoch  0 the steps is:  55705
# 6.748541583166487  step  55706  of the epoch  0 the steps is:  55706
# 0.0  step  55707  of the epoch  0 the steps is:  55707
# 0.0  step  55708  of the epoch  0 the steps is:  55708
# 0.44616527985779797  step  55709  of the epoch  0 the steps is:  55709
# 0.399349076929294  step  55710  of the epoch  0 the steps is:  55710
# 0.3468325078262193  step  55711  of the epoch  0 the steps is:  55711
# 0.0  step  55712  of the epoch  0 the steps is:  55712
# 0.0  step  55713  of the epoch  0 the steps is:  55713
# 0.0  step  55714  of the epoch  0 the steps is:  55714
# 0.0  step  55715  of the epoch  0 the steps is:  55715
# 0.0  step  55716  of the epoch  0 the steps is:  55716
# 0.0  step  55717  of the epoch  0 the steps is:  55717
# 3.1418056515392907  step  55718  of the epoch  0 the steps is:  55718
# 0.0  step  55719  of the epoch  0 the steps is:  55719
# 0.0  step  55720  of the epoch  0 the steps is:  55720
# 0.0  step  55721  of the epoch  0 the steps is:  55721
# 0.0  step  55722  of the epoch  0 the steps is:  55722
# 0.0  step  55723  of the epoch  0 the steps is:  55723
# 0.0  step  55724  of the epoch  0 the steps is:  55724
# 0.0  step  55725  of the epoch  0 the steps is:  55725
# 0.0  step  55726  of the epoch  0 the steps is:  55726
# 7.309833787903095  step  55727  of the epoch  0 the steps is:  55727
# 0.0  step  55728  of the epoch  0 the steps is:  55728
# 2.9032251222872345  step  55729  of the epoch  0 the steps is:  55729
# 0.0  step  55730  of the epoch  0 the steps is:  55730
# 0.0  step  55731  of the epoch  0 the steps is:  55731
# 0.0  step  55732  of the epoch  0 the steps is:  55732
# 0.0  step  55733  of the epoch  0 the steps is:  55733
# 0.0  step  55734  of the epoch  0 the steps is:  55734
# 0.0  step  55735  of the epoch  0 the steps is:  55735
# 0.0  step  55736  of the epoch  0 the steps is:  55736
# 0.0  step  55737  of the epoch  0 the steps is:  55737
# 0.3870705768150877  step  55738  of the epoch  0 the steps is:  55738
# 0.0  step  55739  of the epoch  0 the steps is:  55739
# 0.21550729818454695  step  55740  of the epoch  0 the steps is:  55740
# 0.0  step  55741  of the epoch  0 the steps is:  55741
# 0.0  step  55742  of the epoch  0 the steps is:  55742
# 1.8021186366183821  step  55743  of the epoch  0 the steps is:  55743
# 2.425259660286805  step  55744  of the epoch  0 the steps is:  55744
# 0.0  step  55745  of the epoch  0 the steps is:  55745
# 0.0  step  55746  of the epoch  0 the steps is:  55746
# 0.0  step  55747  of the epoch  0 the steps is:  55747
# 0.0  step  55748  of the epoch  0 the steps is:  55748
# 1.2210149787849969  step  55749  of the epoch  0 the steps is:  55749
# 0.0  step  55750  of the epoch  0 the steps is:  55750
# 0.9270150185344068  step  55751  of the epoch  0 the steps is:  55751
# 0.0  step  55752  of the epoch  0 the steps is:  55752
# 0.0  step  55753  of the epoch  0 the steps is:  55753
# 0.0  step  55754  of the epoch  0 the steps is:  55754
# 1.960959781427039  step  55755  of the epoch  0 the steps is:  55755
# 0.05692975053524485  step  55756  of the epoch  0 the steps is:  55756
# 0.0  step  55757  of the epoch  0 the steps is:  55757
# 4.650869396057347  step  55758  of the epoch  0 the steps is:  55758
# 0.0  step  55759  of the epoch  0 the steps is:  55759
# 0.0  step  55760  of the epoch  0 the steps is:  55760
# 0.0  step  55761  of the epoch  0 the steps is:  55761
# 5.532387544359784  step  55762  of the epoch  0 the steps is:  55762
# 0.0  step  55763  of the epoch  0 the steps is:  55763
# 3.1272247421949837  step  55764  of the epoch  0 the steps is:  55764
# 7.869056595126304  step  55765  of the epoch  0 the steps is:  55765
# 0.948437653510513  step  55766  of the epoch  0 the steps is:  55766
# 0.0  step  55767  of the epoch  0 the steps is:  55767
# 0.005889926956236913  step  55768  of the epoch  0 the steps is:  55768
# 0.0  step  55769  of the epoch  0 the steps is:  55769
# 0.0  step  55770  of the epoch  0 the steps is:  55770
# 0.0  step  55771  of the epoch  0 the steps is:  55771
# 0.0  step  55772  of the epoch  0 the steps is:  55772
# 0.0  step  55773  of the epoch  0 the steps is:  55773
# 0.0  step  55774  of the epoch  0 the steps is:  55774
# 0.0  step  55775  of the epoch  0 the steps is:  55775
# 2.2947356145055795  step  55776  of the epoch  0 the steps is:  55776
# 0.0  step  55777  of the epoch  0 the steps is:  55777
# 0.0  step  55778  of the epoch  0 the steps is:  55778
# 0.0  step  55779  of the epoch  0 the steps is:  55779
# 0.0  step  55780  of the epoch  0 the steps is:  55780
# 0.3885062877754768  step  55781  of the epoch  0 the steps is:  55781
# 0.0  step  55782  of the epoch  0 the steps is:  55782
# 0.0  step  55783  of the epoch  0 the steps is:  55783
# 1.5771555493633933  step  55784  of the epoch  0 the steps is:  55784
# 0.0  step  55785  of the epoch  0 the steps is:  55785
# 1.0141615258458687  step  55786  of the epoch  0 the steps is:  55786
# 0.0  step  55787  of the epoch  0 the steps is:  55787
# 0.0  step  55788  of the epoch  0 the steps is:  55788
# 0.0  step  55789  of the epoch  0 the steps is:  55789
# 0.0  step  55790  of the epoch  0 the steps is:  55790
# 0.0  step  55791  of the epoch  0 the steps is:  55791
# 0.259186773648997  step  55792  of the epoch  0 the steps is:  55792
# 0.0  step  55793  of the epoch  0 the steps is:  55793
# 0.0  step  55794  of the epoch  0 the steps is:  55794
# 0.12204126291083295  step  55795  of the epoch  0 the steps is:  55795
# 0.5997286543801197  step  55796  of the epoch  0 the steps is:  55796
# 0.03039894745441929  step  55797  of the epoch  0 the steps is:  55797
# 0.0  step  55798  of the epoch  0 the steps is:  55798
# 0.0  step  55799  of the epoch  0 the steps is:  55799
# 0.0  step  55800  of the epoch  0 the steps is:  55800
# 0.0  step  55801  of the epoch  0 the steps is:  55801
# 1.7468579382645744  step  55802  of the epoch  0 the steps is:  55802
# 0.0  step  55803  of the epoch  0 the steps is:  55803
# ...
# 0.18232921001284108  step  59731  of the epoch  0 the steps is:  59731
# 0.0  step  59732  of the epoch  0 the steps is:  59732
# 0.0  step  59733  of the epoch  0 the steps is:  59733
# 0.18936586326830707  step  59734  of the epoch  0 the steps is:  59734
# 0.0  step  59735  of the epoch  0 the steps is:  59735
# 0.0  step  59736  of the epoch  0 the steps is:  59736
# 0.0  step  59737  of the epoch  0 the steps is:  59737
# 0.45999813239684784  step  59738  of the epoch  0 the steps is:  59738
# 0.0  step  59739  of the epoch  0 the steps is:  59739
# 0.0  step  59740  of the epoch  0 the steps is:  59740
# 2.142027279345049  step  59741  of the epoch  0 the steps is:  59741
# 0.0  step  59742  of the epoch  0 the steps is:  59742
# 0.36197653480437264  step  59743  of the epoch  0 the steps is:  59743
# 0.0  step  59744  of the epoch  0 the steps is:  59744
# 0.0  step  59745  of the epoch  0 the steps is:  59745
# 5.03678721656266  step  59746  of the epoch  0 the steps is:  59746
# 1.2460443726411778  step  59747  of the epoch  0 the steps is:  59747
# 0.0  step  59748  of the epoch  0 the steps is:  59748
# 2.525992855776681  step  59749  of the epoch  0 the steps is:  59749
# 0.0  step  59750  of the epoch  0 the steps is:  59750
# 0.0  step  59751  of the epoch  0 the steps is:  59751
# 4.0282397667089995  step  59752  of the epoch  0 the steps is:  59752
# 2.9120484859917424  step  59753  of the epoch  0 the steps is:  59753
# 0.0  step  59754  of the epoch  0 the steps is:  59754
# 0.0  step  59755  of the epoch  0 the steps is:  59755
# 0.0  step  59756  of the epoch  0 the steps is:  59756
# 0.0  step  59757  of the epoch  0 the steps is:  59757
# 0.0  step  59758  of the epoch  0 the steps is:  59758
# 0.0  step  59759  of the epoch  0 the steps is:  59759
# 0.0  step  59760  of the epoch  0 the steps is:  59760
# 0.6239425487682393  step  59761  of the epoch  0 the steps is:  59761
# 6.2337563339587465  step  59762  of the epoch  0 the steps is:  59762
# 0.3695962868640521  step  59763  of the epoch  0 the steps is:  59763
# 0.0  step  59764  of the epoch  0 the steps is:  59764
# 0.07148412060403952  step  59765  of the epoch  0 the steps is:  59765
# 0.0  step  59766  of the epoch  0 the steps is:  59766
# 0.0  step  59767  of the epoch  0 the steps is:  59767
# 0.0  step  59768  of the epoch  0 the steps is:  59768
# 1.3915071365184484  step  59769  of the epoch  0 the steps is:  59769
# 0.0  step  59770  of the epoch  0 the steps is:  59770
# 2.166985869725674  step  59771  of the epoch  0 the steps is:  59771
# 0.0  step  59772  of the epoch  0 the steps is:  59772
# 0.0  step  59773  of the epoch  0 the steps is:  59773
# 0.7628743977790813  step  59774  of the epoch  0 the steps is:  59774
# 0.0  step  59775  of the epoch  0 the steps is:  59775
# 0.0  step  59776  of the epoch  0 the steps is:  59776
# 0.0  step  59777  of the epoch  0 the steps is:  59777
# 0.0  step  59778  of the epoch  0 the steps is:  59778
# 0.0  step  59779  of the epoch  0 the steps is:  59779
# 0.0  step  59780  of the epoch  0 the steps is:  59780
# 0.0  step  59781  of the epoch  0 the steps is:  59781
# 0.0  step  59782  of the epoch  0 the steps is:  59782
# 0.0  step  59783  of the epoch  0 the steps is:  59783
# 0.0  step  59784  of the epoch  0 the steps is:  59784
# 0.0  step  59785  of the epoch  0 the steps is:  59785
# 1.8576308493818132  step  59786  of the epoch  0 the steps is:  59786
# 0.0  step  59787  of the epoch  0 the steps is:  59787
# 0.0  step  59788  of the epoch  0 the steps is:  59788
# 0.0  step  59789  of the epoch  0 the steps is:  59789
# 0.0  step  59790  of the epoch  0 the steps is:  59790
# 1.7347063783168992  step  59791  of the epoch  0 the steps is:  59791
# 0.0  step  59792  of the epoch  0 the steps is:  59792
# 0.0  step  59793  of the epoch  0 the steps is:  59793
# 0.0  step  59794  of the epoch  0 the steps is:  59794
# 0.0  step  59795  of the epoch  0 the steps is:  59795
# 0.7683380083941103  step  59796  of the epoch  0 the steps is:  59796
# 0.0  step  59797  of the epoch  0 the steps is:  59797
# 0.0  step  59798  of the epoch  0 the steps is:  59798
# 0.0  step  59799  of the epoch  0 the steps is:  59799
# 0.0  step  59800  of the epoch  0 the steps is:  59800
# 0.44657179132008107  step  59801  of the epoch  0 the steps is:  59801
# 0.0  step  59802  of the epoch  0 the steps is:  59802
# 0.0  step  59803  of the epoch  0 the steps is:  59803
# 0.7720575617319794  step  59804  of the epoch  0 the steps is:  59804
# 0.6264952061622551  step  59805  of the epoch  0 the steps is:  59805
# 0.0  step  59806  of the epoch  0 the steps is:  59806
# 0.0  step  59807  of the epoch  0 the steps is:  59807
# 0.0  step  59808  of the epoch  0 the steps is:  59808
# 0.0  step  59809  of the epoch  0 the steps is:  59809
# 0.0  step  59810  of the epoch  0 the steps is:  59810
# 0.0  step  59811  of the epoch  0 the steps is:  59811
# 0.0  step  59812  of the epoch  0 the steps is:  59812
# 1.47326787609759  step  59813  of the epoch  0 the steps is:  59813
# 0.18151188611103297  step  59814  of the epoch  0 the steps is:  59814
# 0.0  step  59815  of the epoch  0 the steps is:  59815
# 0.3743028385585818  step  59816  of the epoch  0 the steps is:  59816
# 0.0  step  59817  of the epoch  0 the steps is:  59817
# 0.0  step  59818  of the epoch  0 the steps is:  59818
# 0.0  step  59819  of the epoch  0 the steps is:  59819
# 0.0  step  59820  of the epoch  0 the steps is:  59820
# 0.0  step  59821  of the epoch  0 the steps is:  59821
# 0.0  step  59822  of the epoch  0 the steps is:  59822
# 0.0  step  59823  of the epoch  0 the steps is:  59823
# 0.0  step  59824  of the epoch  0 the steps is:  59824
# 0.0  step  59825  of the epoch  0 the steps is:  59825
# 0.7763192459306745  step  59826  of the epoch  0 the steps is:  59826
# 0.0  step  59827  of the epoch  0 the steps is:  59827
# 0.0  step  59828  of the epoch  0 the steps is:  59828
# 0.0  step  59829  of the epoch  0 the steps is:  59829
# 0.0  step  59830  of the epoch  0 the steps is:  59830
# 1.4853096564015633  step  59831  of the epoch  0 the steps is:  59831
# 0.0  step  59832  of the epoch  0 the steps is:  59832
# 0.0  step  59833  of the epoch  0 the steps is:  59833
# 0.0  step  59834  of the epoch  0 the steps is:  59834
# 0.0  step  59835  of the epoch  0 the steps is:  59835
# 0.0  step  59836  of the epoch  0 the steps is:  59836
# 0.0  step  59837  of the epoch  0 the steps is:  59837
# 0.0  step  59838  of the epoch  0 the steps is:  59838
# 0.0  step  59839  of the epoch  0 the steps is:  59839
# 0.0  step  59840  of the epoch  0 the steps is:  59840
# 0.0  step  59841  of the epoch  0 the steps is:  59841
# 7.2533138331142055  step  59842  of the epoch  0 the steps is:  59842
# 0.0  step  59843  of the epoch  0 the steps is:  59843
# 0.0  step  59844  of the epoch  0 the steps is:  59844
# 0.0  step  59845  of the epoch  0 the steps is:  59845
# 0.0  step  59846  of the epoch  0 the steps is:  59846
# 0.0  step  59847  of the epoch  0 the steps is:  59847
# 0.0  step  59848  of the epoch  0 the steps is:  59848
# 0.0  step  59849  of the epoch  0 the steps is:  59849
# 0.0  step  59850  of the epoch  0 the steps is:  59850
# 0.0  step  59851  of the epoch  0 the steps is:  59851
# 1.3723579224116742  step  59852  of the epoch  0 the steps is:  59852
# 0.0  step  59853  of the epoch  0 the steps is:  59853
# 0.0  step  59854  of the epoch  0 the steps is:  59854
# 0.5450661644841057  step  59855  of the epoch  0 the steps is:  59855
# 0.0  step  59856  of the epoch  0 the steps is:  59856
# 0.0  step  59857  of the epoch  0 the steps is:  59857
# 0.0  step  59858  of the epoch  0 the steps is:  59858
# 1.0283084479921882  step  59859  of the epoch  0 the steps is:  59859
# 2.1038628498638428  step  59860  of the epoch  0 the steps is:  59860
# 1.7470630705926116  step  59861  of the epoch  0 the steps is:  59861
# 0.0  step  59862  of the epoch  0 the steps is:  59862
# 0.3860394264296376  step  59863  of the epoch  0 the steps is:  59863
# 0.0  step  59864  of the epoch  0 the steps is:  59864
# 1.2799314644843296  step  59865  of the epoch  0 the steps is:  59865
# 0.0  step  59866  of the epoch  0 the steps is:  59866
# 0.0  step  59867  of the epoch  0 the steps is:  59867
# 0.0  step  59868  of the epoch  0 the steps is:  59868
# 0.0  step  59869  of the epoch  0 the steps is:  59869
# 0.5812386006076746  step  59870  of the epoch  0 the steps is:  59870
# 0.0  step  59871  of the epoch  0 the steps is:  59871
# 0.0  step  59872  of the epoch  0 the steps is:  59872
# 0.0  step  59873  of the epoch  0 the steps is:  59873
# 0.0  step  59874  of the epoch  0 the steps is:  59874
# 0.0  step  59875  of the epoch  0 the steps is:  59875
# 0.0  step  59876  of the epoch  0 the steps is:  59876
# 0.0  step  59877  of the epoch  0 the steps is:  59877
# 0.0  step  59878  of the epoch  0 the steps is:  59878
# 0.0  step  59879  of the epoch  0 the steps is:  59879
# 0.041902752300543966  step  59880  of the epoch  0 the steps is:  59880
# 1.6425035664329752  step  59881  of the epoch  0 the steps is:  59881
# 0.9542322532490237  step  59882  of the epoch  0 the steps is:  59882
# 3.4756691663056856  step  59883  of the epoch  0 the steps is:  59883
# 0.0  step  59884  of the epoch  0 the steps is:  59884
# 4.513549647917303  step  59885  of the epoch  0 the steps is:  59885
# 0.0  step  59886  of the epoch  0 the steps is:  59886
# 0.427530652151769  step  59887  of the epoch  0 the steps is:  59887
# 0.0  step  59888  of the epoch  0 the steps is:  59888
# 0.0  step  59889  of the epoch  0 the steps is:  59889
# 0.0217670695876393  step  59890  of the epoch  0 the steps is:  59890
# 0.0  step  59891  of the epoch  0 the steps is:  59891
# 0.0  step  59892  of the epoch  0 the steps is:  59892
# 0.0  step  59893  of the epoch  0 the steps is:  59893
# 0.0  step  59894  of the epoch  0 the steps is:  59894
# 2.9376980572701656  step  59895  of the epoch  0 the steps is:  59895
# 2.3948228193095398  step  59896  of the epoch  0 the steps is:  59896
# 0.6766136250427399  step  59897  of the epoch  0 the steps is:  59897
# 0.5653335011161538  step  59898  of the epoch  0 the steps is:  59898
# 0.0  step  59899  of the epoch  0 the steps is:  59899
# 0.0  step  59900  of the epoch  0 the steps is:  59900
# 0.0  step  59901  of the epoch  0 the steps is:  59901
# 0.06226453929568532  step  59902  of the epoch  0 the steps is:  59902
# 0.0  step  59903  of the epoch  0 the steps is:  59903
# 2.346819780100927  step  59904  of the epoch  0 the steps is:  59904
# 2.022143748593349  step  59905  of the epoch  0 the steps is:  59905
# 0.4328984850267661  step  59906  of the epoch  0 the steps is:  59906
# 0.09100638625294444  step  59907  of the epoch  0 the steps is:  59907
# 0.0  step  59908  of the epoch  0 the steps is:  59908
# 0.0  step  59909  of the epoch  0 the steps is:  59909
# 0.0  step  59910  of the epoch  0 the steps is:  59910
# 2.312245367000127  step  59911  of the epoch  0 the steps is:  59911
# 0.0  step  59912  of the epoch  0 the steps is:  59912
# 0.0  step  59913  of the epoch  0 the steps is:  59913
# 0.0  step  59914  of the epoch  0 the steps is:  59914
# 0.0  step  59915  of the epoch  0 the steps is:  59915
# 0.1664925880600543  step  59916  of the epoch  0 the steps is:  59916
# 0.0  step  59917  of the epoch  0 the steps is:  59917
# 0.0  step  59918  of the epoch  0 the steps is:  59918
# 0.0  step  59919  of the epoch  0 the steps is:  59919
# 0.0  step  59920  of the epoch  0 the steps is:  59920
# 0.0  step  59921  of the epoch  0 the steps is:  59921
# 0.0  step  59922  of the epoch  0 the steps is:  59922
# 0.0017234136487838114  step  59923  of the epoch  0 the steps is:  59923
# 0.0  step  59924  of the epoch  0 the steps is:  59924
# 0.0  step  59925  of the epoch  0 the steps is:  59925
# 0.5051429575176791  step  59926  of the epoch  0 the steps is:  59926
# 0.6859534629444566  step  59927  of the epoch  0 the steps is:  59927
# 0.0  step  59928  of the epoch  0 the steps is:  59928
# 0.0  step  59929  of the epoch  0 the steps is:  59929
# 0.0  step  59930  of the epoch  0 the steps is:  59930
# 0.0  step  59931  of the epoch  0 the steps is:  59931
# 0.0  step  59932  of the epoch  0 the steps is:  59932
# 0.0  step  59933  of the epoch  0 the steps is:  59933
# 0.0  step  59934  of the epoch  0 the steps is:  59934
# 0.0  step  59935  of the epoch  0 the steps is:  59935
# 0.0  step  59936  of the epoch  0 the steps is:  59936
# 0.0  step  59937  of the epoch  0 the steps is:  59937
# 0.0  step  59938  of the epoch  0 the steps is:  59938
# 2.2313227014734025  step  59939  of the epoch  0 the steps is:  59939
# 0.0  step  59940  of the epoch  0 the steps is:  59940
# 0.0  step  59941  of the epoch  0 the steps is:  59941
# 5.367530756019869  step  59942  of the epoch  0 the steps is:  59942
# 0.0  step  59943  of the epoch  0 the steps is:  59943
# 0.0  step  59944  of the epoch  0 the steps is:  59944
# 0.0  step  59945  of the epoch  0 the steps is:  59945
# 0.0  step  59946  of the epoch  0 the steps is:  59946
# 1.4437804291477603  step  59947  of the epoch  0 the steps is:  59947
# 0.0  step  59948  of the epoch  0 the steps is:  59948
# 0.0  step  59949  of the epoch  0 the steps is:  59949
# 0.742140233596857  step  59950  of the epoch  0 the steps is:  59950
# 0.0  step  59951  of the epoch  0 the steps is:  59951
# 0.0  step  59952  of the epoch  0 the steps is:  59952
# 1.3237828803504406  step  59953  of the epoch  0 the steps is:  59953
# 0.0  step  59954  of the epoch  0 the steps is:  59954
# 2.1615688294869333  step  59955  of the epoch  0 the steps is:  59955
# 0.0  step  59956  of the epoch  0 the steps is:  59956
# 0.0  step  59957  of the epoch  0 the steps is:  59957
# 0.0  step  59958  of the epoch  0 the steps is:  59958
# 0.0  step  59959  of the epoch  0 the steps is:  59959
# 0.0  step  59960  of the epoch  0 the steps is:  59960
# 4.273481635014942  step  59961  of the epoch  0 the steps is:  59961
# 0.0  step  59962  of the epoch  0 the steps is:  59962
# 0.31996905823534405  step  59963  of the epoch  0 the steps is:  59963
# 0.0  step  59964  of the epoch  0 the steps is:  59964
# 0.7948533993492228  step  59965  of the epoch  0 the steps is:  59965
# 0.0  step  59966  of the epoch  0 the steps is:  59966
# 0.0  step  59967  of the epoch  0 the steps is:  59967
# 2.7088947740840013  step  59968  of the epoch  0 the steps is:  59968
# 0.0  step  59969  of the epoch  0 the steps is:  59969
# 0.0  step  59970  of the epoch  0 the steps is:  59970
# 0.0  step  59971  of the epoch  0 the steps is:  59971
# 0.0  step  59972  of the epoch  0 the steps is:  59972
# 0.0  step  59973  of the epoch  0 the steps is:  59973
# 2.0765515580976803  step  59974  of the epoch  0 the steps is:  59974
# 1.6717952928575368  step  59975  of the epoch  0 the steps is:  59975
# 0.0  step  59976  of the epoch  0 the steps is:  59976
# 0.05818974096927354  step  59977  of the epoch  0 the steps is:  59977
# 0.0  step  59978  of the epoch  0 the steps is:  59978
# 0.0  step  59979  of the epoch  0 the steps is:  59979
# 0.0  step  59980  of the epoch  0 the steps is:  59980
# 1.2551973937368768  step  59981  of the epoch  0 the steps is:  59981
# 0.2253599662993131  step  59982  of the epoch  0 the steps is:  59982
# 0.8939535002730921  step  59983  of the epoch  0 the steps is:  59983
# 0.16225832609497814  step  59984  of the epoch  0 the steps is:  59984
# 0.0  step  59985  of the epoch  0 the steps is:  59985
# 0.0  step  59986  of the epoch  0 the steps is:  59986
# 2.090154784261798  step  59987  of the epoch  0 the steps is:  59987
# 0.0  step  59988  of the epoch  0 the steps is:  59988
# 0.0  step  59989  of the epoch  0 the steps is:  59989
# 1.1102641576146413  step  59990  of the epoch  0 the steps is:  59990
# 0.0  step  59991  of the epoch  0 the steps is:  59991
# 0.0  step  59992  of the epoch  0 the steps is:  59992
# 0.8376731145136906  step  59993  of the epoch  0 the steps is:  59993
# 0.0  step  59994  of the epoch  0 the steps is:  59994
# 0.0  step  59995  of the epoch  0 the steps is:  59995
# 0.0  step  59996  of the epoch  0 the steps is:  59996
# 0.0  step  59997  of the epoch  0 the steps is:  59997
# 0.0  step  59998  of the epoch  0 the steps is:  59998
# 0.0  step  59999  of the epoch  0 the steps is:  59999

# %%
MyNetwork.Test_Network(Test_data, Test_label)
# Out:
# 0.8321

# %%
mini_dataSet, mini_labelSet = [],[]
j = 0
for i in range(100):
  if MyNetwork.forward(Train_data[i]) == Train_label[i]:
    mini_dataSet.append(Train_data[i])
    mini_labelSet.append(Train_label[i])
    j += 1
  if j == 10:
    break

# %%
attacked_image = []
for i in range(10):
  attacked_image.append(MyNetwork.attach_network(mini_dataSet[i], mini_labelSet[i]))

# %%
attacked_image = []
for i in range(20):
  attacked_image.append(MyNetwork.attach_network(Test_data[i], Test_label[i]))

# %%
score = 0
for i in range(10):
  print("The label for the", i,"th data is: ", MyNetwork.forward(mini_dataSet[i]), "after attack it became: ", MyNetwork.forward(attacked_image[i].reshape((-1,))))
  if MyNetwork.forward(mini_dataSet[i]) != MyNetwork.forward(attacked_image[i].reshape((-1,))):
    score += 1
print("The attacked accuracy was: ", score * 10)
# Out:
# The label for the 0 th data is:  [9] after attack it became:  [7]
# The label for the 1 th data is:  [0] after attack it became:  [2]
# The label for the 2 th data is:  [2] after attack it became:  [1]
# The label for the 3 th data is:  [7] after attack it became:  [1]
# The label for the 4 th data is:  [5] after attack it became:  [6]
# The label for the 5 th data is:  [5] after attack it became:  [1]
# The label for the 6 th data is:  [0] after attack it became:  [4]
# The label for the 7 th data is:  [9] after attack it became:  [1]
# The label for the 8 th data is:  [5] after attack it became:  [7]
# The label for the 9 th data is:  [5] after attack it became:  [7]
# The attacked accuracy was:  100

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)
